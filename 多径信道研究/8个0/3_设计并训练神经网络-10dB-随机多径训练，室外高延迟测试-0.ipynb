# %%
import matplotlib.pyplot as plt
import torchvision as tv
from torchvision import transforms, utils


import torch.nn.functional as F
import torch 
import torch.nn as nn
from torch.autograd import Variable
import torchvision.models as models
# from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader
# from PIL import Image
# import numpy as np
import torch.optim as optim
# import os
import time

import loadData

# %%
device = torch.device("cuda:3")

# %%
# 日志记录模块2
import logging
logger = logging.getLogger(__name__)
logger.setLevel(level = logging.INFO)
handler = logging.FileHandler("./result-随机多径训练，室外高延迟测试-0")
handler.setLevel(logging.INFO)
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

console = logging.StreamHandler()
console.setLevel(logging.INFO)

logger.addHandler(handler)
logger.addHandler(console)

# %%
startTime = time.time()

# %%
transforms = tv.transforms.Compose([
    transforms.ToTensor(),
])


numOfBatch = 9
pixel = 64
flag = 0
root = f'./{numOfBatch}/data'
batchSize = 4
train_data = loadData.MyDataset(txt=f'files随机多径.txt', transform=None)
test_data = loadData.MyDataset(txt=f'files室外高延迟.txt', transform=None)



train_loader = DataLoader(dataset=train_data, batch_size=batchSize, shuffle=True, num_workers=2)
test_loader = DataLoader(dataset=test_data, batch_size=batchSize, shuffle=True, num_workers=2)


print(train_loader)
print(test_loader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7f3d7dd94210>
# <torch.utils.data.dataloader.DataLoader object at 0x7f3e10e427d0>

# %%
print(len(train_data))
print(len(test_loader))
# Out:
# 8100
# 2025

# %%
# data = iter(train_loader)

# # print(type(data))
# # print(len(data))
# data_, label = data.next()
# print(train_loader.batch_size)
# print(data_.shape)
# # print(label)
# # print(data_, label)

# %%
x = torch.randn(4, 1, 1200, 2).float()
conv = nn.Conv2d(in_channels = 1, out_channels = 128, kernel_size = (10, 1))
x = conv(x)
x.shape
conv2 = nn.Conv2d(in_channels = 128, out_channels = 256, kernel_size = (3, 2))
x = conv2(x)
x.shape
# Out:
# torch.Size([4, 256, 1189, 1])

# %%
# 256*1189

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(in_channels = 1, out_channels = 8, kernel_size = (1, 100))
        self.conv2 = nn.Conv2d(in_channels = 8, out_channels = 16, kernel_size = (2, 300))
        
        self.dropout1 = nn.Dropout(0.5)
        self.dropout2 = nn.Dropout(0.5)
        
        self.fc1 = nn.Linear(14112, 1024)
        self.fc2 = nn.Linear(1024, 500)
        self.fc3 = nn.Linear(500, 54)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 1)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 1)
    
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.dropout1(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.dropout2(x)
        x = self.fc3(x)
        output = F.log_softmax(x, dim=1)
        return output

# %%
# TensorBoard
# from tensorboardX import SummaryWriter
# net = Net()
# # writer = SummaryWriter('writer928') #建立一个保存数据用的东西
# dummy_input = torch.rand(2,160,400)  # 假设输入20张1*28*28的图片
# with SummaryWriter(comment='Net1') as w:
#     w.add_graph(net, (dummy_input,))

# %%
net = Net()

net = net.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(params=net.parameters(), lr=0.0001, momentum=0.9)

epochs = 1500
average_loss_series = []

# %%
for a, b in enumerate(train_loader):
    inputs, labels = b
    print(inputs.shape)
    break
# Out:
# torch.Size([4, 1, 2, 1280])

# %%
# %matplotlib inline


if __name__ == '__main__':
    for epoch in range(epochs):
        running_loss = 0.0
        running_acc = 0.0

        for i, data in enumerate(train_loader):
#             print("i:", i )
#             print("data: ", data[0])
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()

#             inputs = inputs.permute(0, 2, 1)
            
            inputs = torch.tensor(inputs, dtype=torch.float32, device = device)

            outputs = net(inputs)
            _, predicted = torch.max(outputs.data, dim=1)
            total = labels.size(0)
#             print('原来的值:{0}, 预测的值:{1}'.format(labels, predicted))
            running_correct = (predicted == labels).sum()
            running_acc += running_correct
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            loss.backward()
            optimizer.step()

            # 每loopNum个batch打印一次训练状态
            loopNum = 1000
            if i % loopNum == loopNum - 1:
                average_loss = running_loss / loopNum
                logger.info('[{0}, {1}] loss: {2}'.format(epoch + 1, i + 1, average_loss))
                logger.info('设备号为: {0}，预测的设备号为:{1}'.format(labels, predicted))
#                 logger.info(torch.cuda.current_device ())
                running_acc = running_acc.float()
                average_acc = running_acc / loopNum / total
                
                logger.info('[{0}, {1}] acc: {2}'.format(epoch + 1, i + 1, average_acc))
                average_loss_series.append(average_loss)
                running_loss = 0.0
                running_acc = 0.0

    x = range(0, len(average_loss_series))
    plt.figure()
    plt.plot(x, average_loss_series)
#     plt.savefig("Loss.png")
    plt.savefig("Loss.png", bbox_inches="tight")
    plt.show()
    

    # %%
    # 在测试集上测试
    realLabel = []
    predictedLabel = []

    def correct_rate(net, testloader):
        correct = 0.0
        total = 0.0
        count = 0
        correctpredict = 0

        for data in testloader:
            images, labels = data
            images, labels = images.to(device),labels.to(device)
            realLabel.append([int(label) for label in labels])
    
            tests = torch.tensor(images, dtype=torch.float32,device=device)
            outputs = net(tests)

            _, predicted = torch.max(outputs.data, dim=1)
            logger.info('设备号为: {0}，模型训练后得到的设备号为:{1}'.format(labels, predicted))
#             deviceNumber = torch.cuda.current_device ()
#             logger.info(deviceNumber)
            
            labelsn = labels.cpu().numpy()
            pn = predicted.cpu().numpy()
            count += len(labelsn)
            
            for i in range(len(labelsn)):
                if labelsn[i] == pn[i]:
                    correctpredict += 1
                
            
            logger.info('目前一共测试了{0}组，预测成功的一共有{1}组'.format(count, correctpredict))
            predictedLabel.append([int(label) for label in predicted])
            
            total += labels.size(0)
            correct += (predicted == labels).sum()

            
        logger.info("total的值为：{total}")
#         return 100 * correct  # / total
        return 100 * correct/ total 


    correct = correct_rate(net, test_loader)
    logger.info(f'{len(test_loader) * 3}张测试集中准确率为： {correct}%')

    # %%
    import itertools
    from sklearn.metrics import confusion_matrix

    realLabel = list(itertools.chain.from_iterable(realLabel))
    predictedLabel = list(itertools.chain.from_iterable(predictedLabel))

    cm = confusion_matrix(realLabel, predictedLabel)
    logger.info(cm)

#     logger.info('the running time is:{1}'.format(time.time() - startTime))
    torch.save(net.state_dict(), f'./model_随机多径训练，室外高延迟测试_0.pkl')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# [1, 1000] loss: 3.9890704238414765
# 设备号为: tensor([37, 43, 16, 10], device='cuda:3')，预测的设备号为:tensor([ 1,  1, 41,  1], device='cuda:3')
# [1, 1000] acc: 0.017000000923871994
# [1, 2000] loss: 3.9895064747333526
# 设备号为: tensor([ 1, 45, 50, 43], device='cuda:3')，预测的设备号为:tensor([14, 41,  1, 41], device='cuda:3')
# [1, 2000] acc: 0.018000001087784767
# [2, 1000] loss: 3.9882858843803404
# 设备号为: tensor([ 5, 25, 44,  4], device='cuda:3')，预测的设备号为:tensor([51, 41, 14,  1], device='cuda:3')
# [2, 1000] acc: 0.02175000123679638
# [2, 2000] loss: 3.9883779382705686
# 设备号为: tensor([18,  4, 43, 13], device='cuda:3')，预测的设备号为:tensor([ 1, 41,  1, 39], device='cuda:3')
# [2, 2000] acc: 0.0215000007301569
# [3, 1000] loss: 3.9863507924079893
# 设备号为: tensor([ 5, 22, 36, 24], device='cuda:3')，预测的设备号为:tensor([46, 41, 46, 45], device='cuda:3')
# [3, 1000] acc: 0.024250000715255737
# [3, 2000] loss: 3.9818497698307036
# 设备号为: tensor([17, 22, 40, 38], device='cuda:3')，预测的设备号为:tensor([ 1, 45, 26,  1], device='cuda:3')
# [3, 2000] acc: 0.029000001028180122
# [4, 1000] loss: 3.9481942636966707
# 设备号为: tensor([51, 28, 41, 20], device='cuda:3')，预测的设备号为:tensor([ 3,  9, 45,  3], device='cuda:3')
# [4, 1000] acc: 0.02850000187754631
# [4, 2000] loss: 3.7802341384887694
# 设备号为: tensor([10,  4, 39, 35], device='cuda:3')，预测的设备号为:tensor([28,  8, 11, 11], device='cuda:3')
# [4, 2000] acc: 0.027500001713633537
# [5, 1000] loss: 3.6716619882583617
# 设备号为: tensor([21, 49, 34, 26], device='cuda:3')，预测的设备号为:tensor([18, 22,  3,  6], device='cuda:3')
# [5, 1000] acc: 0.04100000113248825
# [5, 2000] loss: 3.5565247960090636
# 设备号为: tensor([11,  1, 36, 50], device='cuda:3')，预测的设备号为:tensor([11, 11, 38, 40], device='cuda:3')
# [5, 2000] acc: 0.048500001430511475
# [6, 1000] loss: 3.3975178644657134
# 设备号为: tensor([51, 11, 37, 16], device='cuda:3')，预测的设备号为:tensor([21, 28, 21, 52], device='cuda:3')
# [6, 1000] acc: 0.05700000375509262
# [6, 2000] loss: 3.293433013796806
# 设备号为: tensor([33, 12, 20, 29], device='cuda:3')，预测的设备号为:tensor([26, 42, 40, 35], device='cuda:3')
# [6, 2000] acc: 0.070250004529953
# [7, 1000] loss: 3.1999415962696074
# 设备号为: tensor([40, 27, 44, 24], device='cuda:3')，预测的设备号为:tensor([47, 27, 52, 53], device='cuda:3')
# [7, 1000] acc: 0.0807500034570694
# [7, 2000] loss: 3.111842537164688
# 设备号为: tensor([49, 28,  3, 24], device='cuda:3')，预测的设备号为:tensor([17, 31,  9, 23], device='cuda:3')
# [7, 2000] acc: 0.09025000780820847
# [8, 1000] loss: 3.047290007710457
# 设备号为: tensor([36, 42, 47, 19], device='cuda:3')，预测的设备号为:tensor([36, 19, 42, 17], device='cuda:3')
# [8, 1000] acc: 0.09600000083446503
# [8, 2000] loss: 2.995807444691658
# 设备号为: tensor([45, 16,  9, 36], device='cuda:3')，预测的设备号为:tensor([53, 46,  6, 38], device='cuda:3')
# [8, 2000] acc: 0.0962500050663948
# [9, 1000] loss: 2.947536257505417
# 设备号为: tensor([ 1, 23, 19, 18], device='cuda:3')，预测的设备号为:tensor([28, 49, 47, 19], device='cuda:3')
# [9, 1000] acc: 0.10050000250339508
# [9, 2000] loss: 2.914686056137085
# 设备号为: tensor([42, 23, 26, 13], device='cuda:3')，预测的设备号为:tensor([15, 43, 28, 53], device='cuda:3')
# [9, 2000] acc: 0.10050000250339508
# [10, 1000] loss: 2.862149140357971
# 设备号为: tensor([51, 15, 48,  7], device='cuda:3')，预测的设备号为:tensor([53, 18, 18, 38], device='cuda:3')
# [10, 1000] acc: 0.10850000381469727
# [10, 2000] loss: 2.8445670078992844
# 设备号为: tensor([49, 49, 17, 15], device='cuda:3')，预测的设备号为:tensor([21, 19, 49, 46], device='cuda:3')
# [10, 2000] acc: 0.12125000357627869
# [11, 1000] loss: 2.8119456348419187
# 设备号为: tensor([14, 31, 26, 12], device='cuda:3')，预测的设备号为:tensor([12, 26, 35, 14], device='cuda:3')
# [11, 1000] acc: 0.11225000768899918
# [11, 2000] loss: 2.755587756872177
# 设备号为: tensor([39, 49, 50, 52], device='cuda:3')，预测的设备号为:tensor([25, 48, 45, 52], device='cuda:3')
# [11, 2000] acc: 0.12150000780820847
# [12, 1000] loss: 2.769794672012329
# 设备号为: tensor([24, 14, 26, 34], device='cuda:3')，预测的设备号为:tensor([21, 12, 35, 34], device='cuda:3')
# [12, 1000] acc: 0.12050000578165054
# [12, 2000] loss: 2.7122228540182114
# 设备号为: tensor([ 1,  0,  7, 23], device='cuda:3')，预测的设备号为:tensor([ 0,  3, 39, 53], device='cuda:3')
# [12, 2000] acc: 0.12325000762939453
# [13, 1000] loss: 2.6835282733440398
# 设备号为: tensor([35,  5, 42, 27], device='cuda:3')，预测的设备号为:tensor([33, 34, 16, 32], device='cuda:3')
# [13, 1000] acc: 0.12700000405311584
# [13, 2000] loss: 2.6487919063568115
# 设备号为: tensor([28, 20, 28, 35], device='cuda:3')，预测的设备号为:tensor([ 1, 15, 26, 26], device='cuda:3')
# [13, 2000] acc: 0.13475000858306885
# [14, 1000] loss: 2.6311533794403075
# 设备号为: tensor([40, 12, 21, 27], device='cuda:3')，预测的设备号为:tensor([44, 21, 47,  5], device='cuda:3')
# [14, 1000] acc: 0.1302500069141388
# [14, 2000] loss: 2.601085333943367
# 设备号为: tensor([15, 10,  1, 27], device='cuda:3')，预测的设备号为:tensor([46, 35,  3, 36], device='cuda:3')
# [14, 2000] acc: 0.13975000381469727
# [15, 1000] loss: 2.577579381942749
# 设备号为: tensor([36,  6,  4, 38], device='cuda:3')，预测的设备号为:tensor([34,  6, 10,  7], device='cuda:3')
# [15, 1000] acc: 0.14800000190734863
# [15, 2000] loss: 2.5706435950994493
# 设备号为: tensor([30, 31, 36, 41], device='cuda:3')，预测的设备号为:tensor([32, 33, 32, 48], device='cuda:3')
# [15, 2000] acc: 0.1355000138282776
# [16, 1000] loss: 2.5548322056531907
# 设备号为: tensor([ 3,  8, 12, 33], device='cuda:3')，预测的设备号为:tensor([ 6,  8, 49, 26], device='cuda:3')
# [16, 1000] acc: 0.12975001335144043
# [16, 2000] loss: 2.523853216648102
# 设备号为: tensor([40,  0, 52, 21], device='cuda:3')，预测的设备号为:tensor([44,  4, 45, 44], device='cuda:3')
# [16, 2000] acc: 0.14875000715255737
# [17, 1000] loss: 2.52047082555294
# 设备号为: tensor([45,  2, 33,  4], device='cuda:3')，预测的设备号为:tensor([17, 34, 33,  1], device='cuda:3')
# [17, 1000] acc: 0.1420000046491623
# [17, 2000] loss: 2.482590915322304
# 设备号为: tensor([44, 50, 43, 21], device='cuda:3')，预测的设备号为:tensor([12, 45, 18, 51], device='cuda:3')
# [17, 2000] acc: 0.15025000274181366
# [18, 1000] loss: 2.5024522933959963
# 设备号为: tensor([13, 27, 34, 51], device='cuda:3')，预测的设备号为:tensor([14, 27, 32, 20], device='cuda:3')
# [18, 1000] acc: 0.14350000023841858
# [18, 2000] loss: 2.474044507980347
# 设备号为: tensor([21, 44, 41, 20], device='cuda:3')，预测的设备号为:tensor([24, 14, 52, 12], device='cuda:3')
# [18, 2000] acc: 0.15275000035762787
# [19, 1000] loss: 2.457277963757515
# 设备号为: tensor([37, 21,  6, 49], device='cuda:3')，预测的设备号为:tensor([30, 44,  9, 22], device='cuda:3')
# [19, 1000] acc: 0.15525001287460327
# [19, 2000] loss: 2.4438344695568084
# 设备号为: tensor([ 5, 11, 31, 32], device='cuda:3')，预测的设备号为:tensor([34,  6,  7, 37], device='cuda:3')
# [19, 2000] acc: 0.1510000079870224
# [20, 1000] loss: 2.436548103809357
# 设备号为: tensor([18,  5, 16, 10], device='cuda:3')，预测的设备号为:tensor([44, 27, 19, 26], device='cuda:3')
# [20, 1000] acc: 0.15200001001358032
# [20, 2000] loss: 2.445729411959648
# 设备号为: tensor([ 4, 31, 18,  6], device='cuda:3')，预测的设备号为:tensor([ 4,  0, 16,  9], device='cuda:3')
# [20, 2000] acc: 0.15275000035762787
# [21, 1000] loss: 2.4388725751638414
# 设备号为: tensor([53, 17,  3, 53], device='cuda:3')，预测的设备号为:tensor([17, 52,  9, 23], device='cuda:3')
# [21, 1000] acc: 0.1495000123977661
# [21, 2000] loss: 2.4125239119529724
# 设备号为: tensor([13,  5,  6, 40], device='cuda:3')，预测的设备号为:tensor([20, 27,  3, 12], device='cuda:3')
# [21, 2000] acc: 0.1550000011920929
# [22, 1000] loss: 2.4044533901214598
# 设备号为: tensor([35,  6,  9, 32], device='cuda:3')，预测的设备号为:tensor([26,  6, 11, 32], device='cuda:3')
# [22, 1000] acc: 0.1535000056028366
# [22, 2000] loss: 2.38652846121788
# 设备号为: tensor([ 7,  5, 26, 32], device='cuda:3')，预测的设备号为:tensor([ 7,  5, 33, 36], device='cuda:3')
# [22, 2000] acc: 0.16075000166893005
# [23, 1000] loss: 2.4156514461040497
# 设备号为: tensor([17, 45, 40, 12], device='cuda:3')，预测的设备号为:tensor([43, 42, 20, 46], device='cuda:3')
# [23, 1000] acc: 0.16250000894069672
# [23, 2000] loss: 2.4079564021825792
# 设备号为: tensor([50,  2, 11, 21], device='cuda:3')，预测的设备号为:tensor([18, 39,  3, 21], device='cuda:3')
# [23, 2000] acc: 0.1522500067949295
# [24, 1000] loss: 2.360125933766365
# 设备号为: tensor([10, 25, 19, 45], device='cuda:3')，预测的设备号为:tensor([ 1, 25, 41, 50], device='cuda:3')
# [24, 1000] acc: 0.17500001192092896
# [24, 2000] loss: 2.35372927737236
# 设备号为: tensor([44, 27, 39, 40], device='cuda:3')，预测的设备号为:tensor([20,  5, 29, 14], device='cuda:3')
# [24, 2000] acc: 0.1745000034570694
# [25, 1000] loss: 2.3628284615278243
# 设备号为: tensor([48, 39, 49,  4], device='cuda:3')，预测的设备号为:tensor([42, 34, 52,  9], device='cuda:3')
# [25, 1000] acc: 0.16100001335144043
# [25, 2000] loss: 2.354291604042053
# 设备号为: tensor([28, 23,  9, 53], device='cuda:3')，预测的设备号为:tensor([ 0, 16, 11, 49], device='cuda:3')
# [25, 2000] acc: 0.17275001108646393
# [26, 1000] loss: 2.3487025558948518
# 设备号为: tensor([26, 15, 31, 33], device='cuda:3')，预测的设备号为:tensor([33, 46, 33, 26], device='cuda:3')
# [26, 1000] acc: 0.15825000405311584
# [26, 2000] loss: 2.326214247107506
# 设备号为: tensor([33,  3, 30, 48], device='cuda:3')，预测的设备号为:tensor([33,  9, 15, 23], device='cuda:3')
# [26, 2000] acc: 0.1705000102519989
# [27, 1000] loss: 2.3445027297735215
# 设备号为: tensor([24, 33, 28, 18], device='cuda:3')，预测的设备号为:tensor([46, 28, 39, 16], device='cuda:3')
# [27, 1000] acc: 0.15950000286102295
# [27, 2000] loss: 2.33078592646122
# 设备号为: tensor([20, 33, 32, 13], device='cuda:3')，预测的设备号为:tensor([22,  7,  5, 16], device='cuda:3')
# [27, 2000] acc: 0.18025000393390656
# [28, 1000] loss: 2.3456933394670485
# 设备号为: tensor([18, 30,  5,  0], device='cuda:3')，预测的设备号为:tensor([53,  5,  5, 35], device='cuda:3')
# [28, 1000] acc: 0.17550000548362732
# [28, 2000] loss: 2.316847158193588
# 设备号为: tensor([16, 38,  4,  2], device='cuda:3')，预测的设备号为:tensor([53,  2,  4, 34], device='cuda:3')
# [28, 2000] acc: 0.16600000858306885
# [29, 1000] loss: 2.307320715546608
# 设备号为: tensor([ 5, 28,  7, 41], device='cuda:3')，预测的设备号为:tensor([32,  0, 26, 47], device='cuda:3')
# [29, 1000] acc: 0.17475001513957977
# [29, 2000] loss: 2.324276917219162
# 设备号为: tensor([35, 25,  9,  4], device='cuda:3')，预测的设备号为:tensor([28,  7,  6,  9], device='cuda:3')
# [29, 2000] acc: 0.16475000977516174
# [30, 1000] loss: 2.293102922797203
# 设备号为: tensor([28, 16, 22,  7], device='cuda:3')，预测的设备号为:tensor([35, 21, 41, 38], device='cuda:3')
# [30, 1000] acc: 0.16725000739097595
# [30, 2000] loss: 2.326271190404892
# 设备号为: tensor([44, 23, 28, 33], device='cuda:3')，预测的设备号为:tensor([13, 49, 26, 35], device='cuda:3')
# [30, 2000] acc: 0.1720000058412552
# [31, 1000] loss: 2.299259426832199
# 设备号为: tensor([22, 32,  5, 46], device='cuda:3')，预测的设备号为:tensor([22, 37, 34, 44], device='cuda:3')
# [31, 1000] acc: 0.16750000417232513
# [31, 2000] loss: 2.3247428560256957
# 设备号为: tensor([52, 40, 39, 31], device='cuda:3')，预测的设备号为:tensor([42, 16, 38, 29], device='cuda:3')
# [31, 2000] acc: 0.16575001180171967
# [32, 1000] loss: 2.2748917866945266
# 设备号为: tensor([33, 18, 35, 15], device='cuda:3')，预测的设备号为:tensor([33, 22,  0, 15], device='cuda:3')
# [32, 1000] acc: 0.17675000429153442
# [32, 2000] loss: 2.2853753632307052
# 设备号为: tensor([18, 32, 29, 33], device='cuda:3')，预测的设备号为:tensor([49, 32,  7, 28], device='cuda:3')
# [32, 2000] acc: 0.17750000953674316
# [33, 1000] loss: 2.292704491496086
# 设备号为: tensor([19, 20, 22, 45], device='cuda:3')，预测的设备号为:tensor([47, 44, 24, 48], device='cuda:3')
# [33, 1000] acc: 0.17625001072883606
# [33, 2000] loss: 2.2617159192562104
# 设备号为: tensor([16, 15, 22,  2], device='cuda:3')，预测的设备号为:tensor([16, 30, 43, 38], device='cuda:3')
# [33, 2000] acc: 0.18325001001358032
# [34, 1000] loss: 2.294668272972107
# 设备号为: tensor([16, 21, 38,  5], device='cuda:3')，预测的设备号为:tensor([42, 13, 29,  5], device='cuda:3')
# [34, 1000] acc: 0.17350000143051147
# [34, 2000] loss: 2.2550322110652923
# 设备号为: tensor([35, 37, 49, 33], device='cuda:3')，预测的设备号为:tensor([35, 32, 18, 35], device='cuda:3')
# [34, 2000] acc: 0.17750000953674316
# [35, 1000] loss: 2.251394147872925
# 设备号为: tensor([20, 28, 51, 40], device='cuda:3')，预测的设备号为:tensor([44, 31, 46, 21], device='cuda:3')
# [35, 1000] acc: 0.17800000309944153
# [35, 2000] loss: 2.2826435035467147
# 设备号为: tensor([ 5, 28, 27, 35], device='cuda:3')，预测的设备号为:tensor([27, 39, 34,  7], device='cuda:3')
# [35, 2000] acc: 0.171750009059906
# [36, 1000] loss: 2.27817113161087
# 设备号为: tensor([17, 15, 47,  5], device='cuda:3')，预测的设备号为:tensor([47, 30, 47, 34], device='cuda:3')
# [36, 1000] acc: 0.18725000321865082
# [36, 2000] loss: 2.2913788461685183
# 设备号为: tensor([52, 13, 21,  9], device='cuda:3')，预测的设备号为:tensor([48, 40, 40,  6], device='cuda:3')
# [36, 2000] acc: 0.16750000417232513
# [37, 1000] loss: 2.276682797551155
# 设备号为: tensor([19, 53, 16, 42], device='cuda:3')，预测的设备号为:tensor([48, 18, 18, 50], device='cuda:3')
# [37, 1000] acc: 0.16375000774860382
# [37, 2000] loss: 2.2601175738573076
# 设备号为: tensor([13, 35, 41,  7], device='cuda:3')，预测的设备号为:tensor([44, 26, 41, 25], device='cuda:3')
# [37, 2000] acc: 0.17600001394748688
# [38, 1000] loss: 2.2276177693605423
# 设备号为: tensor([ 8, 34, 15, 48], device='cuda:3')，预测的设备号为:tensor([ 3, 38, 30, 47], device='cuda:3')
# [38, 1000] acc: 0.1850000023841858
# [38, 2000] loss: 2.2675574885606764
# 设备号为: tensor([51, 19, 32, 10], device='cuda:3')，预测的设备号为:tensor([51, 48, 32, 26], device='cuda:3')
# [38, 2000] acc: 0.18025000393390656
# [39, 1000] loss: 2.2056928012371064
# 设备号为: tensor([26, 19, 39,  1], device='cuda:3')，预测的设备号为:tensor([26, 45, 26,  1], device='cuda:3')
# [39, 1000] acc: 0.19450001418590546
# [39, 2000] loss: 2.25042788875103
# 设备号为: tensor([29, 16,  0, 30], device='cuda:3')，预测的设备号为:tensor([ 2, 22, 31, 30], device='cuda:3')
# [39, 2000] acc: 0.18125000596046448
# [40, 1000] loss: 2.2507762402296065
# 设备号为: tensor([45, 10,  9, 52], device='cuda:3')，预测的设备号为:tensor([45,  3,  6, 45], device='cuda:3')
# [40, 1000] acc: 0.18250000476837158
# [40, 2000] loss: 2.2177037209272386
# 设备号为: tensor([51, 13, 23, 32], device='cuda:3')，预测的设备号为:tensor([13, 44, 49, 32], device='cuda:3')
# [40, 2000] acc: 0.18425001204013824
# [41, 1000] loss: 2.2184979075193407
# 设备号为: tensor([19,  8, 14, 31], device='cuda:3')，预测的设备号为:tensor([18,  1, 51,  2], device='cuda:3')
# [41, 1000] acc: 0.18400001525878906
# [41, 2000] loss: 2.2363062541484835
# 设备号为: tensor([48, 15, 15,  5], device='cuda:3')，预测的设备号为:tensor([45, 46, 15, 27], device='cuda:3')
# [41, 2000] acc: 0.1837500035762787
# [42, 1000] loss: 2.231452605009079
# 设备号为: tensor([39, 43, 34,  1], device='cuda:3')，预测的设备号为:tensor([ 7, 17, 27,  1], device='cuda:3')
# [42, 1000] acc: 0.18150000274181366
# [42, 2000] loss: 2.2385240109562874
# 设备号为: tensor([45, 53, 40, 34], device='cuda:3')，预测的设备号为:tensor([45, 50, 22,  2], device='cuda:3')
# [42, 2000] acc: 0.18850000202655792
# [43, 1000] loss: 2.173080171227455
# 设备号为: tensor([10, 27, 34, 46], device='cuda:3')，预测的设备号为:tensor([35, 37, 36, 46], device='cuda:3')
# [43, 1000] acc: 0.1912500113248825
# [43, 2000] loss: 2.2064432817697526
# 设备号为: tensor([ 5, 35,  6, 41], device='cuda:3')，预测的设备号为:tensor([27, 26,  9, 52], device='cuda:3')
# [43, 2000] acc: 0.19025000929832458
# [44, 1000] loss: 2.2253514742851257
# 设备号为: tensor([23, 44, 32, 34], device='cuda:3')，预测的设备号为:tensor([24, 13, 32, 36], device='cuda:3')
# [44, 1000] acc: 0.19075000286102295
# [44, 2000] loss: 2.177952118575573
# 设备号为: tensor([34, 50, 27, 42], device='cuda:3')，预测的设备号为:tensor([36, 19, 34, 19], device='cuda:3')
# [44, 2000] acc: 0.2005000114440918
# [45, 1000] loss: 2.1646098036766053
# 设备号为: tensor([35,  3, 26, 37], device='cuda:3')，预测的设备号为:tensor([35,  9, 33, 27], device='cuda:3')
# [45, 1000] acc: 0.20500001311302185
# [45, 2000] loss: 2.1837212059497833
# 设备号为: tensor([25, 41, 25, 42], device='cuda:3')，预测的设备号为:tensor([38, 17, 25, 42], device='cuda:3')
# [45, 2000] acc: 0.1860000044107437
# [46, 1000] loss: 2.1555873893499373
# 设备号为: tensor([53, 38, 24, 41], device='cuda:3')，预测的设备号为:tensor([17, 38, 16, 53], device='cuda:3')
# [46, 1000] acc: 0.2095000147819519
# [46, 2000] loss: 2.1332890747785567
# 设备号为: tensor([14, 22, 10, 43], device='cuda:3')，预测的设备号为:tensor([20, 40,  3, 53], device='cuda:3')
# [46, 2000] acc: 0.20200000703334808

# %%
torch.cuda.current_device ()

# %%
aa = iter(train_loader)
a, b = aa.next()
print(a[0].shape)
print(a)

# %%
input = torch.randn(20, 16, 50, 100)
input.shape

# %%
m2=nn.Conv2d(16,33,(3,5),stride=(2,1),padding=(4,2))
inpu1=Variable(torch.randn(20,16,50,100))
print(inpu1.shape)
output=m2(inpu1)
print(output.shape)

# %%
total

# %%
torch.cuda.current_device ()

# %%
x = range(0, len(average_loss_series))
plt.figure()
plt.plot(x, average_loss_series)
plt.savefig("Loss随机多径训练，室外高延迟测试.png", bbox_inches="tight")
plt.show()
