# %%
import matplotlib.pyplot as plt
import torchvision as tv
from torchvision import transforms, utils


import torch.nn.functional as F
import torch 
import torch.nn as nn
from torch.autograd import Variable
import torchvision.models as models
# from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader
# from PIL import Image
# import numpy as np
import torch.optim as optim
# import os
import time

import loadData

# %%
device = torch.device("cuda:3")

# %%
# 日志记录模块2
import logging
logger = logging.getLogger(__name__)
logger.setLevel(level = logging.INFO)
handler = logging.FileHandler("./省略最后三项-1.log")
handler.setLevel(logging.INFO)
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

console = logging.StreamHandler()
console.setLevel(logging.INFO)

logger.addHandler(handler)
logger.addHandler(console)

# %%
startTime = time.time()

# %%
transforms = tv.transforms.Compose([
    transforms.ToTensor(),
])


numOfBatch = 9
pixel = 64
flag = 0
root = f'./{numOfBatch}/data'
batchSize = 4
train_data = loadData.MyDataset(txt=f'files_train10-省略最后三项.txt', transform=None)
test_data = loadData.MyDataset(txt=f'files_test10-省略最后三项.txt', transform=None)



train_loader = DataLoader(dataset=train_data, batch_size=batchSize, shuffle=True, num_workers=2)
test_loader = DataLoader(dataset=test_data, batch_size=batchSize, shuffle=True, num_workers=2)


print(train_loader)
print(test_loader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7f3974531cd0>
# <torch.utils.data.dataloader.DataLoader object at 0x7f3978d1fc10>

# %%
print(len(train_data))
print(len(test_loader))
# Out:
# 6426
# 419

# %%
# data = iter(train_loader)

# # print(type(data))
# # print(len(data))
# data_, label = data.next()
# print(train_loader.batch_size)
# print(data_.shape)
# # print(label)
# # print(data_, label)

# %%
x = torch.randn(4, 1, 1200, 2).float()
conv = nn.Conv2d(in_channels = 1, out_channels = 128, kernel_size = (10, 1))
x = conv(x)
x.shape
conv2 = nn.Conv2d(in_channels = 128, out_channels = 256, kernel_size = (3, 2))
x = conv2(x)
x.shape
# Out:
# torch.Size([4, 256, 1189, 1])

# %%
# 256*1189

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(in_channels = 1, out_channels = 8, kernel_size = (1, 10))
        self.conv2 = nn.Conv2d(in_channels = 8, out_channels = 16, kernel_size = (2, 3))
        
        self.dropout1 = nn.Dropout(0.5)
        self.dropout2 = nn.Dropout(0.5)
        
        self.fc1 = nn.Linear(20304, 1024)
        self.fc2 = nn.Linear(1024, 500)
        self.fc3 = nn.Linear(500, 54)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 1)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 1)
    
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.dropout1(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.dropout2(x)
        x = self.fc3(x)
        output = F.log_softmax(x, dim=1)
        return output

# %%
# TensorBoard
# from tensorboardX import SummaryWriter
# net = Net()
# # writer = SummaryWriter('writer928') #建立一个保存数据用的东西
# dummy_input = torch.rand(2,160,400)  # 假设输入20张1*28*28的图片
# with SummaryWriter(comment='Net1') as w:
#     w.add_graph(net, (dummy_input,))

# %%
net = Net()

net = net.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(params=net.parameters(), lr=0.0001, momentum=0.9)

epochs = 1500
average_loss_series = []

# %%
for a, b in enumerate(train_loader):
    inputs, labels = b
    print(inputs.shape)
    break
# Out:
# torch.Size([4, 1, 2, 1280])

# %%
# %matplotlib inline


if __name__ == '__main__':
    for epoch in range(epochs):
        running_loss = 0.0
        running_acc = 0.0

        for i, data in enumerate(train_loader):
#             print("i:", i )
#             print("data: ", data[0])
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()

#             inputs = inputs.permute(0, 2, 1)
            
            inputs = torch.tensor(inputs, dtype=torch.float32, device = device)

            outputs = net(inputs)
            _, predicted = torch.max(outputs.data, dim=1)
            total = labels.size(0)
#             print('原来的值:{0}, 预测的值:{1}'.format(labels, predicted))
            running_correct = (predicted == labels).sum()
            running_acc += running_correct
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            loss.backward()
            optimizer.step()

            # 每loopNum个batch打印一次训练状态
            loopNum = 1000
            if i % loopNum == loopNum - 1:
                average_loss = running_loss / loopNum
                logger.info('[{0}, {1}] loss: {2}'.format(epoch + 1, i + 1, average_loss))
                logger.info('设备号为: {0}，预测的设备号为:{1}'.format(labels, predicted))
#                 logger.info(torch.cuda.current_device ())
                running_acc = running_acc.float()
                average_acc = running_acc / loopNum / total
                
                logger.info('[{0}, {1}] acc: {2}'.format(epoch + 1, i + 1, average_acc))
                average_loss_series.append(average_loss)
                running_loss = 0.0
                running_acc = 0.0

    x = range(0, len(average_loss_series))
    plt.figure()
    plt.plot(x, average_loss_series)
#     plt.savefig("Loss.png")
    plt.savefig("Loss.png", bbox_inches="tight")
    plt.show()
    

    # %%
    # 在测试集上测试
    realLabel = []
    predictedLabel = []

    def correct_rate(net, testloader):
        correct = 0.0
        total = 0.0
        count = 0
        correctpredict = 0

        for data in testloader:
            images, labels = data
            images, labels = images.to(device),labels.to(device)
            realLabel.append([int(label) for label in labels])
    
            tests = torch.tensor(images, dtype=torch.float32,device=device)
            outputs = net(tests)

            _, predicted = torch.max(outputs.data, dim=1)
            logger.info('设备号为: {0}，模型训练后得到的设备号为:{1}'.format(labels, predicted))
#             deviceNumber = torch.cuda.current_device ()
#             logger.info(deviceNumber)
            
            labelsn = labels.cpu().numpy()
            pn = predicted.cpu().numpy()
            count += len(labelsn)
            
            for i in range(len(labelsn)):
                if labelsn[i] == pn[i]:
                    correctpredict += 1
                
            
            logger.info('目前一共测试了{0}组，预测成功的一共有{1}组'.format(count, correctpredict))
            predictedLabel.append([int(label) for label in predicted])
            
            total += labels.size(0)
            correct += (predicted == labels).sum()

            
        logger.info("total的值为：{total}")
#         return 100 * correct  # / total
        return 100 * correct/ total 


    correct = correct_rate(net, test_loader)
    logger.info(f'{len(test_loader) * 3}张测试集中准确率为： {correct}%')

    # %%
    import itertools
    from sklearn.metrics import confusion_matrix

    realLabel = list(itertools.chain.from_iterable(realLabel))
    predictedLabel = list(itertools.chain.from_iterable(predictedLabel))

    cm = confusion_matrix(realLabel, predictedLabel)
    logger.info(cm)

#     logger.info('the running time is:{1}'.format(time.time() - startTime))
    torch.save(net.state_dict(), f'./model_10dB_省略最后三项_1.pkl')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# [1, 1000] loss: 3.9895728018283845
# 设备号为: tensor([13, 12, 42, 37], device='cuda:2')，预测的设备号为:tensor([23, 41, 23, 51], device='cuda:2')
# [1, 1000] acc: 0.020750001072883606
# [2, 1000] loss: 3.9876061639785765
# 设备号为: tensor([32, 43, 10, 22], device='cuda:2')，预测的设备号为:tensor([27, 23, 23, 37], device='cuda:2')
# [2, 1000] acc: 0.019500000402331352
# [3, 1000] loss: 3.986005336523056
# 设备号为: tensor([35, 23, 45, 21], device='cuda:2')，预测的设备号为:tensor([38, 45, 35, 34], device='cuda:2')
# [3, 1000] acc: 0.027000000700354576
# [4, 1000] loss: 3.981870210647583
# 设备号为: tensor([ 7,  5, 38, 50], device='cuda:2')，预测的设备号为:tensor([23, 34, 27, 13], device='cuda:2')
# [4, 1000] acc: 0.026750002056360245
# [5, 1000] loss: 3.9743825924396514
# 设备号为: tensor([31, 48, 48, 39], device='cuda:2')，预测的设备号为:tensor([38,  1,  9, 38], device='cuda:2')
# [5, 1000] acc: 0.036250002682209015
# [6, 1000] loss: 3.9598208343982697
# 设备号为: tensor([26, 36, 53, 53], device='cuda:2')，预测的设备号为:tensor([35,  1, 53, 53], device='cuda:2')
# [6, 1000] acc: 0.04350000247359276
# [7, 1000] loss: 3.901560553073883
# 设备号为: tensor([53, 36, 48,  3], device='cuda:2')，预测的设备号为:tensor([52,  1, 33,  1], device='cuda:2')
# [7, 1000] acc: 0.05325000360608101
# [8, 1000] loss: 3.6192358822822572
# 设备号为: tensor([17, 20, 49,  6], device='cuda:2')，预测的设备号为:tensor([40, 50, 53,  6], device='cuda:2')
# [8, 1000] acc: 0.06050000339746475
# [9, 1000] loss: 3.322414378404617
# 设备号为: tensor([21, 30, 49, 52], device='cuda:2')，预测的设备号为:tensor([50, 18, 50, 52], device='cuda:2')
# [9, 1000] acc: 0.07950000464916229
# [10, 1000] loss: 3.1537933156490325
# 设备号为: tensor([27, 53, 27, 14], device='cuda:2')，预测的设备号为:tensor([ 1, 45, 27, 13], device='cuda:2')
# [10, 1000] acc: 0.10000000149011612
# [11, 1000] loss: 3.0203893250226974
# 设备号为: tensor([23, 35, 21, 50], device='cuda:2')，预测的设备号为:tensor([20, 31, 43, 43], device='cuda:2')
# [11, 1000] acc: 0.11875000596046448
# [12, 1000] loss: 2.9035844893455507
# 设备号为: tensor([39, 51, 36,  6], device='cuda:2')，预测的设备号为:tensor([ 8, 19, 26,  1], device='cuda:2')
# [12, 1000] acc: 0.13199999928474426
# [13, 1000] loss: 2.8159974430799486
# 设备号为: tensor([44, 22, 34, 30], device='cuda:2')，预测的设备号为:tensor([44, 50, 27, 40], device='cuda:2')
# [13, 1000] acc: 0.1469999998807907
# [14, 1000] loss: 2.732860706448555
# 设备号为: tensor([53, 50, 36, 46], device='cuda:2')，预测的设备号为:tensor([53, 23, 27, 45], device='cuda:2')
# [14, 1000] acc: 0.16975000500679016
# [15, 1000] loss: 2.579040750026703
# 设备号为: tensor([15, 16, 50, 19], device='cuda:2')，预测的设备号为:tensor([45, 23, 41, 49], device='cuda:2')
# [15, 1000] acc: 0.19975000619888306
# [16, 1000] loss: 2.4389693534970283
# 设备号为: tensor([14,  5, 31, 24], device='cuda:2')，预测的设备号为:tensor([14,  9, 28, 23], device='cuda:2')
# [16, 1000] acc: 0.2237500101327896
# [17, 1000] loss: 2.308332508444786
# 设备号为: tensor([22, 53, 23, 48], device='cuda:2')，预测的设备号为:tensor([16, 53, 24, 48], device='cuda:2')
# [17, 1000] acc: 0.26075002551078796
# [18, 1000] loss: 2.21030602568388
# 设备号为: tensor([46, 17, 37, 21], device='cuda:2')，预测的设备号为:tensor([45, 17, 37, 41], device='cuda:2')
# [18, 1000] acc: 0.27775001525878906
# [19, 1000] loss: 2.1169820747375487
# 设备号为: tensor([15, 25, 30, 42], device='cuda:2')，预测的设备号为:tensor([15,  1, 49, 49], device='cuda:2')
# [19, 1000] acc: 0.30150002241134644
# [20, 1000] loss: 2.0758878909647467
# 设备号为: tensor([ 6, 53, 10,  2], device='cuda:2')，预测的设备号为:tensor([ 0, 53, 26,  2], device='cuda:2')
# [20, 1000] acc: 0.31300002336502075
# [21, 1000] loss: 2.017710258543491
# 设备号为: tensor([ 0, 45, 30, 12], device='cuda:2')，预测的设备号为:tensor([ 1, 44, 30, 24], device='cuda:2')
# [21, 1000] acc: 0.3215000033378601
# [22, 1000] loss: 1.9551345532685518
# 设备号为: tensor([40, 51, 27, 51], device='cuda:2')，预测的设备号为:tensor([40, 16, 29, 21], device='cuda:2')
# [22, 1000] acc: 0.335750013589859
# [23, 1000] loss: 1.9129941452741623
# 设备号为: tensor([38, 50, 40, 45], device='cuda:2')，预测的设备号为:tensor([38, 50, 20, 44], device='cuda:2')
# [23, 1000] acc: 0.3542500138282776
# [24, 1000] loss: 1.8373099402785302
# 设备号为: tensor([41,  7, 39, 51], device='cuda:2')，预测的设备号为:tensor([47, 10, 27, 51], device='cuda:2')
# [24, 1000] acc: 0.3737500309944153
# [25, 1000] loss: 1.7823598976433277
# 设备号为: tensor([18, 27, 35,  4], device='cuda:2')，预测的设备号为:tensor([47, 27, 35,  4], device='cuda:2')
# [25, 1000] acc: 0.39100003242492676
# [26, 1000] loss: 1.732550802409649
# 设备号为: tensor([23, 20, 35, 37], device='cuda:2')，预测的设备号为:tensor([14, 14, 35, 30], device='cuda:2')
# [26, 1000] acc: 0.41175001859664917
# [27, 1000] loss: 1.6918668996691704
# 设备号为: tensor([15, 20, 32, 33], device='cuda:2')，预测的设备号为:tensor([15, 41, 25, 36], device='cuda:2')
# [27, 1000] acc: 0.41850000619888306
# [28, 1000] loss: 1.6166456060111523
# 设备号为: tensor([21, 30, 22, 49], device='cuda:2')，预测的设备号为:tensor([51, 30, 47, 49], device='cuda:2')
# [28, 1000] acc: 0.44575002789497375
# [29, 1000] loss: 1.575265375494957
# 设备号为: tensor([53, 13, 22,  6], device='cuda:2')，预测的设备号为:tensor([45, 13, 23, 38], device='cuda:2')
# [29, 1000] acc: 0.452750027179718
# [30, 1000] loss: 1.543399025708437
# 设备号为: tensor([48,  1, 38, 46], device='cuda:2')，预测的设备号为:tensor([48,  6,  9, 46], device='cuda:2')
# [30, 1000] acc: 0.47575002908706665
# [31, 1000] loss: 1.50320650357008
# 设备号为: tensor([47, 49, 18,  3], device='cuda:2')，预测的设备号为:tensor([43, 49, 40,  7], device='cuda:2')
# [31, 1000] acc: 0.4870000183582306
# [32, 1000] loss: 1.5033834368139505
# 设备号为: tensor([19,  5, 51, 52], device='cuda:2')，预测的设备号为:tensor([47,  9, 41, 45], device='cuda:2')
# [32, 1000] acc: 0.47825002670288086
# [33, 1000] loss: 1.4425967900380492
# 设备号为: tensor([ 5, 44, 53,  0], device='cuda:2')，预测的设备号为:tensor([25, 44, 53,  0], device='cuda:2')
# [33, 1000] acc: 0.5017500519752502
# [34, 1000] loss: 1.4103788619861006
# 设备号为: tensor([36, 14, 21, 44], device='cuda:2')，预测的设备号为:tensor([36, 14, 20, 44], device='cuda:2')
# [34, 1000] acc: 0.5227500200271606
# [35, 1000] loss: 1.3497326267808676
# 设备号为: tensor([35,  2, 43,  0], device='cuda:2')，预测的设备号为:tensor([35, 35, 43,  0], device='cuda:2')
# [35, 1000] acc: 0.5360000133514404
# [36, 1000] loss: 1.35981719019264
# 设备号为: tensor([38, 43, 51, 44], device='cuda:2')，预测的设备号为:tensor([ 9, 51, 18, 46], device='cuda:2')
# [36, 1000] acc: 0.5352500081062317
# [37, 1000] loss: 1.3284087738841772
# 设备号为: tensor([29, 25, 36,  1], device='cuda:2')，预测的设备号为:tensor([29, 25, 36,  1], device='cuda:2')
# [37, 1000] acc: 0.5437500476837158
# [38, 1000] loss: 1.322046191200614
# 设备号为: tensor([18, 41, 26, 11], device='cuda:2')，预测的设备号为:tensor([47, 40, 26, 11], device='cuda:2')
# [38, 1000] acc: 0.5410000085830688
# [39, 1000] loss: 1.2521240040399133
# 设备号为: tensor([12, 47, 35, 32], device='cuda:2')，预测的设备号为:tensor([12, 18, 35, 32], device='cuda:2')
# [39, 1000] acc: 0.5610000491142273
# [40, 1000] loss: 1.2405018663369118
# 设备号为: tensor([ 4, 53, 16, 33], device='cuda:2')，预测的设备号为:tensor([ 4, 53, 20,  9], device='cuda:2')
# [40, 1000] acc: 0.5677500367164612
# [41, 1000] loss: 1.2233150401413442
# 设备号为: tensor([39,  6, 24, 51], device='cuda:2')，预测的设备号为:tensor([39,  6, 24, 51], device='cuda:2')
# [41, 1000] acc: 0.5705000162124634
# [42, 1000] loss: 1.2019311954267322
# 设备号为: tensor([41, 23,  0, 26], device='cuda:2')，预测的设备号为:tensor([19, 14,  1, 26], device='cuda:2')
# [42, 1000] acc: 0.5845000147819519
# [43, 1000] loss: 1.1796208655238152
# 设备号为: tensor([36, 31,  7, 22], device='cuda:2')，预测的设备号为:tensor([36, 31,  7, 18], device='cuda:2')
# [43, 1000] acc: 0.5890000462532043
# [44, 1000] loss: 1.153362572396174
# 设备号为: tensor([18,  0,  1, 44], device='cuda:2')，预测的设备号为:tensor([22,  6,  1, 24], device='cuda:2')
# [44, 1000] acc: 0.5992500185966492
# [45, 1000] loss: 1.1159344791844488
# 设备号为: tensor([ 7, 19, 30, 53], device='cuda:2')，预测的设备号为:tensor([28, 19, 30, 23], device='cuda:2')
# [45, 1000] acc: 0.6007500290870667
# [46, 1000] loss: 1.1221971925348044
# 设备号为: tensor([12, 26, 52, 21], device='cuda:2')，预测的设备号为:tensor([12, 26, 52, 21], device='cuda:2')
# [46, 1000] acc: 0.612000048160553
# [47, 1000] loss: 1.0767735844813286
# 设备号为: tensor([36, 39, 32, 29], device='cuda:2')，预测的设备号为:tensor([36, 11, 32, 39], device='cuda:2')
# [47, 1000] acc: 0.612250030040741
# [48, 1000] loss: 1.088039198666811
# 设备号为: tensor([13, 41, 25,  9], device='cuda:2')，预测的设备号为:tensor([13, 20, 25, 36], device='cuda:2')
# [48, 1000] acc: 0.6152500510215759
# [49, 1000] loss: 1.0801975390892475
# 设备号为: tensor([24,  7, 27, 47], device='cuda:2')，预测的设备号为:tensor([24,  7, 27, 43], device='cuda:2')
# [49, 1000] acc: 0.6147500276565552
# [50, 1000] loss: 1.0359697799365968
# 设备号为: tensor([47, 46, 12, 10], device='cuda:2')，预测的设备号为:tensor([47, 46, 12, 10], device='cuda:2')
# [50, 1000] acc: 0.6342500448226929
# [51, 1000] loss: 1.0435763809848577
# 设备号为: tensor([27, 31, 12,  2], device='cuda:2')，预测的设备号为:tensor([ 7, 31, 12,  2], device='cuda:2')
# [51, 1000] acc: 0.6290000081062317
# [52, 1000] loss: 1.0474395376439207
# 设备号为: tensor([41, 23, 15,  3], device='cuda:2')，预测的设备号为:tensor([50, 15, 12, 29], device='cuda:2')
# [52, 1000] acc: 0.6265000104904175
# [53, 1000] loss: 0.9746265716440976
# 设备号为: tensor([42, 29, 27, 19], device='cuda:2')，预测的设备号为:tensor([43, 29, 27, 47], device='cuda:2')
# [53, 1000] acc: 0.6570000052452087
# [54, 1000] loss: 0.9814850202875678
# 设备号为: tensor([24,  4, 11, 24], device='cuda:2')，预测的设备号为:tensor([24,  2, 11, 24], device='cuda:2')
# [54, 1000] acc: 0.6540000438690186
# [55, 1000] loss: 0.9713667419832199
# 设备号为: tensor([48, 19, 12, 10], device='cuda:2')，预测的设备号为:tensor([17, 20, 12,  9], device='cuda:2')
# [55, 1000] acc: 0.6537500023841858
# [56, 1000] loss: 0.9513136234618723
# 设备号为: tensor([14, 16,  2, 26], device='cuda:2')，预测的设备号为:tensor([14, 49,  2, 26], device='cuda:2')
# [56, 1000] acc: 0.6642500162124634
# [57, 1000] loss: 0.9218444545688108
# 设备号为: tensor([12, 51, 47, 32], device='cuda:2')，预测的设备号为:tensor([12, 42, 19, 32], device='cuda:2')
# [57, 1000] acc: 0.6700000166893005
# [58, 1000] loss: 0.8948200960899704
# 设备号为: tensor([20, 19,  9,  2], device='cuda:2')，预测的设备号为:tensor([22, 18,  9,  2], device='cuda:2')
# [58, 1000] acc: 0.6810000538825989
# [59, 1000] loss: 0.9324588217362761
# 设备号为: tensor([29, 26, 16, 50], device='cuda:2')，预测的设备号为:tensor([29, 26, 13, 50], device='cuda:2')
# [59, 1000] acc: 0.6697500348091125
# [60, 1000] loss: 0.896965883792378
# 设备号为: tensor([52, 45, 41, 32], device='cuda:2')，预测的设备号为:tensor([52, 45, 51, 32], device='cuda:2')
# [60, 1000] acc: 0.6770000457763672
# [61, 1000] loss: 0.8650341390445828
# 设备号为: tensor([21, 37, 29, 21], device='cuda:2')，预测的设备号为:tensor([21, 37, 29, 18], device='cuda:2')
# [61, 1000] acc: 0.6990000605583191
# [62, 1000] loss: 0.8596495596719905
# 设备号为: tensor([40, 20, 24, 19], device='cuda:2')，预测的设备号为:tensor([42, 21, 24, 21], device='cuda:2')
# [62, 1000] acc: 0.6890000104904175
# [63, 1000] loss: 0.8543147482089698
# 设备号为: tensor([37, 42, 44, 45], device='cuda:2')，预测的设备号为:tensor([37, 21, 44, 45], device='cuda:2')
# [63, 1000] acc: 0.6885000467300415
# [64, 1000] loss: 0.8182109462646767
# 设备号为: tensor([24, 51, 48, 15], device='cuda:2')，预测的设备号为:tensor([24, 42, 48, 15], device='cuda:2')
# [64, 1000] acc: 0.7017500400543213
# [65, 1000] loss: 0.8273186936434358
# 设备号为: tensor([16,  5,  0, 21], device='cuda:2')，预测的设备号为:tensor([14,  5,  0, 21], device='cuda:2')
# [65, 1000] acc: 0.6962500214576721
# [66, 1000] loss: 0.7997559481041971
# 设备号为: tensor([18, 37, 19, 23], device='cuda:2')，预测的设备号为:tensor([18, 37, 20, 22], device='cuda:2')
# [66, 1000] acc: 0.7140000462532043
# [67, 1000] loss: 0.7868534728735685
# 设备号为: tensor([12, 41, 37,  3], device='cuda:2')，预测的设备号为:tensor([12, 49, 37,  3], device='cuda:2')
# [67, 1000] acc: 0.7187500596046448
# [68, 1000] loss: 0.7922520629363135
# 设备号为: tensor([49, 48, 47, 21], device='cuda:2')，预测的设备号为:tensor([49, 48, 47, 51], device='cuda:2')
# [68, 1000] acc: 0.7095000147819519
# [69, 1000] loss: 0.7613961789961904
# 设备号为: tensor([29, 30, 22,  4], device='cuda:2')，预测的设备号为:tensor([29, 30, 19,  4], device='cuda:2')
# [69, 1000] acc: 0.7210000157356262
# [70, 1000] loss: 0.763193947663065
# 设备号为: tensor([16,  3, 37, 15], device='cuda:2')，预测的设备号为:tensor([14, 27, 37, 15], device='cuda:2')
# [70, 1000] acc: 0.7210000157356262
# [71, 1000] loss: 0.7565635147988796
# 设备号为: tensor([ 8, 41, 43, 14], device='cuda:2')，预测的设备号为:tensor([ 6, 19, 17, 16], device='cuda:2')
# [71, 1000] acc: 0.7327500581741333
# [72, 1000] loss: 0.7404757066201418
# 设备号为: tensor([33, 26, 43,  1], device='cuda:2')，预测的设备号为:tensor([33, 26, 43,  1], device='cuda:2')
# [72, 1000] acc: 0.7290000319480896
# [73, 1000] loss: 0.6946036195401102
# 设备号为: tensor([22, 11,  0, 21], device='cuda:2')，预测的设备号为:tensor([20, 11,  0, 51], device='cuda:2')
# [73, 1000] acc: 0.7570000290870667
# [74, 1000] loss: 0.6900164468082658
# 设备号为: tensor([36, 41,  8, 43], device='cuda:2')，预测的设备号为:tensor([36, 51,  8, 43], device='cuda:2')
# [74, 1000] acc: 0.7482500076293945
# [75, 1000] loss: 0.7032718275724911
# 设备号为: tensor([11, 52, 31, 49], device='cuda:2')，预测的设备号为:tensor([11, 53, 31, 49], device='cuda:2')
# [75, 1000] acc: 0.7502500414848328
# [76, 1000] loss: 0.6844441740186885
# 设备号为: tensor([22, 19, 32,  7], device='cuda:2')，预测的设备号为:tensor([16, 19, 32,  7], device='cuda:2')
# [76, 1000] acc: 0.7550000548362732
# [77, 1000] loss: 0.6781707643449773
# 设备号为: tensor([53, 25, 23, 17], device='cuda:2')，预测的设备号为:tensor([53, 25, 23, 17], device='cuda:2')
# [77, 1000] acc: 0.7605000138282776
# [78, 1000] loss: 0.6484241464552469
# 设备号为: tensor([14,  7, 18,  8], device='cuda:2')，预测的设备号为:tensor([14,  7, 18,  8], device='cuda:2')
# [78, 1000] acc: 0.7705000638961792
# [79, 1000] loss: 0.6619869684500154
# 设备号为: tensor([44, 16, 41,  1], device='cuda:2')，预测的设备号为:tensor([44, 14, 47,  1], device='cuda:2')
# [79, 1000] acc: 0.7582500576972961
# [80, 1000] loss: 0.6431678525921889
# 设备号为: tensor([ 8,  7, 47, 40], device='cuda:2')，预测的设备号为:tensor([ 8,  7, 47, 40], device='cuda:2')
# [80, 1000] acc: 0.768250048160553
# [81, 1000] loss: 0.631137078271524
# 设备号为: tensor([27, 20,  1, 53], device='cuda:2')，预测的设备号为:tensor([ 4, 41,  9, 53], device='cuda:2')
# [81, 1000] acc: 0.7732500433921814
# [82, 1000] loss: 0.6219174160506227
# 设备号为: tensor([14, 19, 24, 40], device='cuda:2')，预测的设备号为:tensor([14, 19, 24, 50], device='cuda:2')
# [82, 1000] acc: 0.7772500514984131
# [83, 1000] loss: 0.6028075230218237
# 设备号为: tensor([12, 16, 45, 48], device='cuda:2')，预测的设备号为:tensor([15, 16, 45, 48], device='cuda:2')
# [83, 1000] acc: 0.7835000157356262
# [84, 1000] loss: 0.5957902733718511
# 设备号为: tensor([ 3, 12, 34, 48], device='cuda:2')，预测的设备号为:tensor([ 3, 12, 34, 48], device='cuda:2')
# [84, 1000] acc: 0.7780000567436218
# [85, 1000] loss: 0.5919019259337801
# 设备号为: tensor([17,  6, 30, 32], device='cuda:2')，预测的设备号为:tensor([17,  6, 30, 32], device='cuda:2')
# [85, 1000] acc: 0.7857500314712524
# [86, 1000] loss: 0.5768061761155259
# 设备号为: tensor([30, 45, 51, 11], device='cuda:2')，预测的设备号为:tensor([30, 45, 51, 11], device='cuda:2')
# [86, 1000] acc: 0.7910000085830688
# [87, 1000] loss: 0.5508198443024593
# 设备号为: tensor([35, 35,  2,  7], device='cuda:2')，预测的设备号为:tensor([35, 35,  2,  7], device='cuda:2')
# [87, 1000] acc: 0.8027500510215759
# [88, 1000] loss: 0.5273726853146218
# 设备号为: tensor([ 3, 26, 32, 42], device='cuda:2')，预测的设备号为:tensor([ 3, 26, 32, 42], device='cuda:2')
# [88, 1000] acc: 0.8107500672340393
# [89, 1000] loss: 0.562115562023042
# 设备号为: tensor([31, 18,  2, 26], device='cuda:2')，预测的设备号为:tensor([31, 20,  4, 26], device='cuda:2')
# [89, 1000] acc: 0.7920000553131104
# [90, 1000] loss: 0.5201167940056184
# 设备号为: tensor([17, 14, 26, 24], device='cuda:2')，预测的设备号为:tensor([17, 14, 26, 24], device='cuda:2')
# [90, 1000] acc: 0.8082500100135803
# [91, 1000] loss: 0.5353201046500471
# 设备号为: tensor([26, 52, 34, 17], device='cuda:2')，预测的设备号为:tensor([26, 52, 34, 17], device='cuda:2')
# [91, 1000] acc: 0.8067500591278076
# [92, 1000] loss: 0.506594669001468
# 设备号为: tensor([15, 29,  5, 34], device='cuda:2')，预测的设备号为:tensor([15, 29,  5, 34], device='cuda:2')
# [92, 1000] acc: 0.8145000338554382
# [93, 1000] loss: 0.5184453951696923
# 设备号为: tensor([42,  2, 50, 15], device='cuda:2')，预测的设备号为:tensor([42,  2, 50, 15], device='cuda:2')
# [93, 1000] acc: 0.8090000152587891
# [94, 1000] loss: 0.5026506442810642
# 设备号为: tensor([22, 29,  8, 53], device='cuda:2')，预测的设备号为:tensor([16, 29,  8, 53], device='cuda:2')
# [94, 1000] acc: 0.815000057220459
# [95, 1000] loss: 0.5117304724515416
# 设备号为: tensor([51, 21, 50, 10], device='cuda:2')，预测的设备号为:tensor([41, 41, 50, 10], device='cuda:2')
# [95, 1000] acc: 0.8075000643730164
# [96, 1000] loss: 0.49511437999765623
# 设备号为: tensor([15, 14, 52, 40], device='cuda:2')，预测的设备号为:tensor([15, 23, 52, 40], device='cuda:2')
# [96, 1000] acc: 0.8195000290870667
# [97, 1000] loss: 0.47249796872909067
# 设备号为: tensor([ 3, 21, 35, 15], device='cuda:2')，预测的设备号为:tensor([ 8, 21, 35, 12], device='cuda:2')
# [97, 1000] acc: 0.8212500214576721
# [98, 1000] loss: 0.45311274390616746
# 设备号为: tensor([38, 35, 13,  1], device='cuda:2')，预测的设备号为:tensor([38, 35, 13,  1], device='cuda:2')
# [98, 1000] acc: 0.8337500691413879
# [99, 1000] loss: 0.46441367446328513
# 设备号为: tensor([24, 41, 10,  8], device='cuda:2')，预测的设备号为:tensor([24, 41, 10,  8], device='cuda:2')
# [99, 1000] acc: 0.8290000557899475
# [100, 1000] loss: 0.4505816842924469
# 设备号为: tensor([12, 37, 17, 28], device='cuda:2')，预测的设备号为:tensor([12, 37, 17, 28], device='cuda:2')
# [100, 1000] acc: 0.8365000486373901
# [101, 1000] loss: 0.42671737245368424
# 设备号为: tensor([19, 12, 27,  6], device='cuda:2')，预测的设备号为:tensor([47, 49, 27,  6], device='cuda:2')
# [101, 1000] acc: 0.8497500419616699
# [102, 1000] loss: 0.4388459873611864
# 设备号为: tensor([15, 46, 46, 24], device='cuda:2')，预测的设备号为:tensor([15, 46, 46, 24], device='cuda:2')
# [102, 1000] acc: 0.8440000414848328
# [103, 1000] loss: 0.4153488526581496
# 设备号为: tensor([26,  6,  6, 46], device='cuda:2')，预测的设备号为:tensor([26,  6,  6, 46], device='cuda:2')
# [103, 1000] acc: 0.8510000109672546
# [104, 1000] loss: 0.42704945668729305
# 设备号为: tensor([53, 50, 13, 10], device='cuda:2')，预测的设备号为:tensor([53, 50, 13, 10], device='cuda:2')
# [104, 1000] acc: 0.8457500338554382
# [105, 1000] loss: 0.4188872037185356
# 设备号为: tensor([ 2, 20,  0, 16], device='cuda:2')，预测的设备号为:tensor([ 2, 20,  0, 20], device='cuda:2')
# [105, 1000] acc: 0.8472500443458557
# [106, 1000] loss: 0.4038045920640143
# 设备号为: tensor([14, 24, 53, 41], device='cuda:2')，预测的设备号为:tensor([14, 24, 53, 49], device='cuda:2')
# [106, 1000] acc: 0.8527500629425049
# [107, 1000] loss: 0.37670553461118833
# 设备号为: tensor([37, 25, 37, 16], device='cuda:2')，预测的设备号为:tensor([37, 25, 37, 14], device='cuda:2')
# [107, 1000] acc: 0.862000048160553
# [108, 1000] loss: 0.38412289699408575
# 设备号为: tensor([38,  4, 23, 44], device='cuda:2')，预测的设备号为:tensor([38,  4, 23, 44], device='cuda:2')
# [108, 1000] acc: 0.8557500243186951
# [109, 1000] loss: 0.35303385734579207
# 设备号为: tensor([22, 50,  1, 50], device='cuda:2')，预测的设备号为:tensor([18, 50,  1, 50], device='cuda:2')
# [109, 1000] acc: 0.8720000386238098
# [110, 1000] loss: 0.3755648235687404
# 设备号为: tensor([40, 36, 33, 11], device='cuda:2')，预测的设备号为:tensor([50, 36, 33, 11], device='cuda:2')
# [110, 1000] acc: 0.8612500429153442
# [111, 1000] loss: 0.3442286382673592
# 设备号为: tensor([43, 18, 15, 34], device='cuda:2')，预测的设备号为:tensor([43, 18, 15, 34], device='cuda:2')
# [111, 1000] acc: 0.8820000290870667
# [112, 1000] loss: 0.35375762723950904
# 设备号为: tensor([34, 46, 35, 46], device='cuda:2')，预测的设备号为:tensor([34, 46, 35, 46], device='cuda:2')
# [112, 1000] acc: 0.8705000281333923
# [113, 1000] loss: 0.33394710525603294
# 设备号为: tensor([20, 20, 45, 45], device='cuda:2')，预测的设备号为:tensor([20, 20, 45, 45], device='cuda:2')
# [113, 1000] acc: 0.8840000629425049
# [114, 1000] loss: 0.3364830258277943
# 设备号为: tensor([ 4, 30, 18, 37], device='cuda:2')，预测的设备号为:tensor([ 4, 30, 20, 37], device='cuda:2')
# [114, 1000] acc: 0.8827500343322754
# [115, 1000] loss: 0.3084684098892358
# 设备号为: tensor([47, 40, 46, 48], device='cuda:2')，预测的设备号为:tensor([47, 49, 46, 48], device='cuda:2')
# [115, 1000] acc: 0.890250027179718
# [116, 1000] loss: 0.325323201761159
# 设备号为: tensor([16, 14, 47, 17], device='cuda:2')，预测的设备号为:tensor([16, 14, 47, 17], device='cuda:2')
# [116, 1000] acc: 0.8845000267028809
# [117, 1000] loss: 0.31013422054621037
# 设备号为: tensor([45, 14, 20,  3], device='cuda:2')，预测的设备号为:tensor([45, 16, 20,  3], device='cuda:2')
# [117, 1000] acc: 0.8920000195503235
# [118, 1000] loss: 0.31837370900588574
# 设备号为: tensor([ 6,  0, 19,  4], device='cuda:2')，预测的设备号为:tensor([ 6,  0, 19, 24], device='cuda:2')
# [118, 1000] acc: 0.893250048160553
# [119, 1000] loss: 0.29486492171349166
# 设备号为: tensor([16, 39, 27, 51], device='cuda:2')，预测的设备号为:tensor([16, 39, 27, 51], device='cuda:2')
# [119, 1000] acc: 0.8960000276565552
# [120, 1000] loss: 0.2685264403700094
# 设备号为: tensor([ 2, 13, 45,  6], device='cuda:2')，预测的设备号为:tensor([ 2, 15, 45,  6], device='cuda:2')
# [120, 1000] acc: 0.9097500443458557
# [121, 1000] loss: 0.2822135616623855
# 设备号为: tensor([51, 35, 33, 37], device='cuda:2')，预测的设备号为:tensor([51, 35, 25, 37], device='cuda:2')
# [121, 1000] acc: 0.8990000486373901
# [122, 1000] loss: 0.28132063398235185
# 设备号为: tensor([ 0, 38,  4, 48], device='cuda:2')，预测的设备号为:tensor([ 0, 38,  4, 31], device='cuda:2')
# [122, 1000] acc: 0.8945000171661377
# [123, 1000] loss: 0.2796374065080745
# 设备号为: tensor([ 8, 45, 40, 40], device='cuda:2')，预测的设备号为:tensor([ 8, 45, 40, 40], device='cuda:2')
# [123, 1000] acc: 0.9020000696182251
# [124, 1000] loss: 0.2719691513156868
# 设备号为: tensor([30, 51, 32,  3], device='cuda:2')，预测的设备号为:tensor([30, 51, 32,  3], device='cuda:2')
# [124, 1000] acc: 0.909250020980835
# [125, 1000] loss: 0.2551300001533127
# 设备号为: tensor([48, 28, 53,  9], device='cuda:2')，预测的设备号为:tensor([48, 28, 53,  9], device='cuda:2')
# [125, 1000] acc: 0.9132500290870667
# [126, 1000] loss: 0.2359517021123338
# 设备号为: tensor([49, 18, 49, 29], device='cuda:2')，预测的设备号为:tensor([49, 18, 49, 29], device='cuda:2')
# [126, 1000] acc: 0.9182500243186951
# [127, 1000] loss: 0.228039821758779
# 设备号为: tensor([15, 40, 12, 28], device='cuda:2')，预测的设备号为:tensor([15, 41, 12, 28], device='cuda:2')
# [127, 1000] acc: 0.9222500324249268
# [128, 1000] loss: 0.25577131567095784
# 设备号为: tensor([12, 32, 15,  5], device='cuda:2')，预测的设备号为:tensor([12, 32, 15,  5], device='cuda:2')
# [128, 1000] acc: 0.9102500677108765
# [129, 1000] loss: 0.2137614907522784
# 设备号为: tensor([12, 10, 39,  9], device='cuda:2')，预测的设备号为:tensor([12, 10, 39,  9], device='cuda:2')
# [129, 1000] acc: 0.9255000352859497
# [130, 1000] loss: 0.23970481553404396
# 设备号为: tensor([49,  9, 17, 11], device='cuda:2')，预测的设备号为:tensor([49,  9, 17, 11], device='cuda:2')
# [130, 1000] acc: 0.9137500524520874
# [131, 1000] loss: 0.21750538454987145
# 设备号为: tensor([42, 24, 50, 28], device='cuda:2')，预测的设备号为:tensor([42, 24, 50, 28], device='cuda:2')
# [131, 1000] acc: 0.9257500171661377
# [132, 1000] loss: 0.221783801591582
# 设备号为: tensor([48, 23, 13,  5], device='cuda:2')，预测的设备号为:tensor([48, 23, 13,  5], device='cuda:2')
# [132, 1000] acc: 0.9240000247955322
# [133, 1000] loss: 0.21911269833529515
# 设备号为: tensor([20, 21,  2, 24], device='cuda:2')，预测的设备号为:tensor([22, 21,  2, 24], device='cuda:2')
# [133, 1000] acc: 0.9235000610351562
# [134, 1000] loss: 0.21796685618851835
# 设备号为: tensor([13, 25,  8, 22], device='cuda:2')，预测的设备号为:tensor([13, 25,  8, 22], device='cuda:2')
# [134, 1000] acc: 0.9202500581741333
# [135, 1000] loss: 0.19759057299156121
# 设备号为: tensor([12, 52,  4, 22], device='cuda:2')，预测的设备号为:tensor([12, 52,  4, 22], device='cuda:2')
# [135, 1000] acc: 0.9360000491142273
# [136, 1000] loss: 0.1851384087428032
# 设备号为: tensor([43, 12, 33, 46], device='cuda:2')，预测的设备号为:tensor([43, 12, 33, 46], device='cuda:2')
# [136, 1000] acc: 0.936750054359436
# [137, 1000] loss: 0.18419892628540402
# 设备号为: tensor([34, 28,  6, 23], device='cuda:2')，预测的设备号为:tensor([34, 28,  6, 23], device='cuda:2')
# [137, 1000] acc: 0.9420000314712524
# [138, 1000] loss: 0.16830886816305793
# 设备号为: tensor([ 6,  6, 51, 23], device='cuda:2')，预测的设备号为:tensor([ 6,  6, 51, 23], device='cuda:2')
# [138, 1000] acc: 0.9445000290870667
# [139, 1000] loss: 0.18141675442562336
# 设备号为: tensor([43, 47, 20, 48], device='cuda:2')，预测的设备号为:tensor([43, 47, 20, 48], device='cuda:2')
# [139, 1000] acc: 0.9422500729560852
# [140, 1000] loss: 0.17623363500813138
# 设备号为: tensor([37, 49, 44, 29], device='cuda:2')，预测的设备号为:tensor([37, 49, 44, 29], device='cuda:2')
# [140, 1000] acc: 0.940250039100647
# [141, 1000] loss: 0.179292294489612
# 设备号为: tensor([44, 33, 53, 53], device='cuda:2')，预测的设备号为:tensor([44, 38, 53, 53], device='cuda:2')
# [141, 1000] acc: 0.936500072479248
# [142, 1000] loss: 0.1729028733590967
# 设备号为: tensor([17, 37, 21,  2], device='cuda:2')，预测的设备号为:tensor([17, 37, 21,  2], device='cuda:2')
# [142, 1000] acc: 0.9452500343322754
# [143, 1000] loss: 0.17142903738480164
# 设备号为: tensor([24, 28, 22, 25], device='cuda:2')，预测的设备号为:tensor([24, 28, 22, 25], device='cuda:2')
# [143, 1000] acc: 0.9417500495910645
# [144, 1000] loss: 0.17361660188150016
# 设备号为: tensor([ 4,  4, 16, 49], device='cuda:2')，预测的设备号为:tensor([ 4,  4, 16, 49], device='cuda:2')
# [144, 1000] acc: 0.940250039100647
# [145, 1000] loss: 0.15852818911936992
# 设备号为: tensor([29, 33, 51, 17], device='cuda:2')，预测的设备号为:tensor([ 3, 33, 51, 17], device='cuda:2')
# [145, 1000] acc: 0.9487500190734863
# [146, 1000] loss: 0.16541294646654933
# 设备号为: tensor([50,  9, 17, 52], device='cuda:2')，预测的设备号为:tensor([50,  9, 17, 52], device='cuda:2')
# [146, 1000] acc: 0.9447500705718994
# [147, 1000] loss: 0.1542203346762717
# 设备号为: tensor([ 9, 45, 38, 42], device='cuda:2')，预测的设备号为:tensor([ 9, 45, 38, 42], device='cuda:2')
# [147, 1000] acc: 0.9470000267028809
# [148, 1000] loss: 0.1489075342552096
# 设备号为: tensor([ 6,  1, 11, 37], device='cuda:2')，预测的设备号为:tensor([ 6,  1, 11, 37], device='cuda:2')
# [148, 1000] acc: 0.952250063419342
# [149, 1000] loss: 0.1304344277546437
# 设备号为: tensor([28, 25,  8, 20], device='cuda:2')，预测的设备号为:tensor([28, 25,  8, 20], device='cuda:2')
# [149, 1000] acc: 0.9550000429153442
# [150, 1000] loss: 0.14614004730135366
# 设备号为: tensor([21, 53, 41, 16], device='cuda:2')，预测的设备号为:tensor([21, 53, 41, 16], device='cuda:2')
# [150, 1000] acc: 0.9500000476837158
# [151, 1000] loss: 0.14535615357333712
# 设备号为: tensor([51, 33, 15,  9], device='cuda:2')，预测的设备号为:tensor([51, 33, 15,  9], device='cuda:2')
# [151, 1000] acc: 0.9497500658035278
# [152, 1000] loss: 0.1377991581411834
# 设备号为: tensor([23, 39, 18, 39], device='cuda:2')，预测的设备号为:tensor([23, 39, 18, 39], device='cuda:2')
# [152, 1000] acc: 0.9520000219345093
# [153, 1000] loss: 0.12143561076586525
# 设备号为: tensor([21, 21, 32,  5], device='cuda:2')，预测的设备号为:tensor([21, 21, 32,  5], device='cuda:2')
# [153, 1000] acc: 0.9635000228881836
# [154, 1000] loss: 0.12802475776165262
# 设备号为: tensor([ 7, 24,  7, 31], device='cuda:2')，预测的设备号为:tensor([ 7, 24, 38, 31], device='cuda:2')
# [154, 1000] acc: 0.9552500247955322
# [155, 1000] loss: 0.11585573095870859
# 设备号为: tensor([ 9, 51, 47, 20], device='cuda:2')，预测的设备号为:tensor([ 9, 51, 19, 20], device='cuda:2')
# [155, 1000] acc: 0.9617500305175781
# [156, 1000] loss: 0.13978512420711287
# 设备号为: tensor([37, 11,  7, 11], device='cuda:2')，预测的设备号为:tensor([37, 11,  7, 11], device='cuda:2')
# [156, 1000] acc: 0.9532500505447388
# [157, 1000] loss: 0.1311212404954481
# 设备号为: tensor([35, 44, 22, 25], device='cuda:2')，预测的设备号为:tensor([35, 44, 49, 25], device='cuda:2')
# [157, 1000] acc: 0.9552500247955322
# [158, 1000] loss: 0.13094957164568838
# 设备号为: tensor([44, 20, 12, 36], device='cuda:2')，预测的设备号为:tensor([44, 20, 20, 36], device='cuda:2')
# [158, 1000] acc: 0.9567500352859497
# [159, 1000] loss: 0.12217774298851782
# 设备号为: tensor([20, 20, 35, 52], device='cuda:2')，预测的设备号为:tensor([20, 20, 35, 52], device='cuda:2')
# [159, 1000] acc: 0.9620000720024109
# [160, 1000] loss: 0.1182772527410798
# 设备号为: tensor([16, 53, 15, 52], device='cuda:2')，预测的设备号为:tensor([16, 53, 15, 52], device='cuda:2')
# [160, 1000] acc: 0.9645000696182251
# [161, 1000] loss: 0.1256541822384247
# 设备号为: tensor([44,  4, 28, 15], device='cuda:2')，预测的设备号为:tensor([44,  4, 28, 15], device='cuda:2')
# [161, 1000] acc: 0.9567500352859497

# %%
torch.cuda.current_device ()

# %%
aa = iter(train_loader)
a, b = aa.next()
print(a[0].shape)
print(a)

# %%
input = torch.randn(20, 16, 50, 100)
input.shape

# %%
m2=nn.Conv2d(16,33,(3,5),stride=(2,1),padding=(4,2))
inpu1=Variable(torch.randn(20,16,50,100))
print(inpu1.shape)
output=m2(inpu1)
print(output.shape)

# %%
total

# %%
torch.cuda.current_device ()

# %%
x = range(0, len(average_loss_series))
plt.figure()
plt.plot(x, average_loss_series)
plt.savefig("Loss-省略最后三项-1.png", bbox_inches="tight")
plt.show()
