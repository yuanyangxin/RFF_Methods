# %%
import matplotlib.pyplot as plt
import torchvision as tv
from torchvision import transforms, utils


import torch.nn.functional as F
import torch 
import torch.nn as nn
from torch.autograd import Variable
import torchvision.models as models
# from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader
# from PIL import Image
# import numpy as np
import torch.optim as optim
# import os
import time

import loadData

# %%
device = torch.device("cuda:1")

# %%
# 日志记录模块2
import logging
logger = logging.getLogger(__name__)
logger.setLevel(level = logging.INFO)
handler = logging.FileHandler("./10dB-FFT-4个0一组-1500epoches")
handler.setLevel(logging.INFO)
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

console = logging.StreamHandler()
console.setLevel(logging.INFO)

logger.addHandler(handler)
logger.addHandler(console)

# %%
startTime = time.time()

# %%
transforms = tv.transforms.Compose([
    transforms.ToTensor(),
])


numOfBatch = 9
pixel = 64
flag = 0
root = f'./{numOfBatch}/data'
batchSize = 4
train_data = loadData.MyDataset(txt=f'files_train-10dB.txt', transform=None)
test_data = loadData.MyDataset(txt=f'files_test-10dB.txt', transform=None)



train_loader = DataLoader(dataset=train_data, batch_size=batchSize, shuffle=True, num_workers=2)
test_loader = DataLoader(dataset=test_data, batch_size=batchSize, shuffle=True, num_workers=2)


print(train_loader)
print(test_loader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7f60215e1fd0>
# <torch.utils.data.dataloader.DataLoader object at 0x7f6109ca3f90>

# %%
print(len(train_data))
print(len(test_loader))
# Out:
# 10530
# 756

# %%
# data = iter(train_loader)

# # print(type(data))
# # print(len(data))
# data_, label = data.next()
# print(train_loader.batch_size)
# print(data_.shape)
# # print(label)
# # print(data_, label)

# %%
x = torch.randn(4, 1, 1200, 2).float()
conv = nn.Conv2d(in_channels = 1, out_channels = 128, kernel_size = (10, 1))
x = conv(x)
x.shape
conv2 = nn.Conv2d(in_channels = 128, out_channels = 256, kernel_size = (3, 2))
x = conv2(x)
x.shape
# Out:
# torch.Size([4, 256, 1189, 1])

# %%
# 256*1189

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(in_channels = 1, out_channels = 8, kernel_size = (1, 10))
        self.conv2 = nn.Conv2d(in_channels = 8, out_channels = 16, kernel_size = (2, 3))
        
        self.dropout1 = nn.Dropout(0.5)
        self.dropout2 = nn.Dropout(0.5)
        
        self.fc1 = nn.Linear(10064, 1024)
        self.fc2 = nn.Linear(1024, 500)
        self.fc3 = nn.Linear(500, 54)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 1)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 1)
    
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.dropout1(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.dropout2(x)
        x = self.fc3(x)
        output = F.log_softmax(x, dim=1)
        return output

# %%
# TensorBoard
# from tensorboardX import SummaryWriter
# net = Net()
# # writer = SummaryWriter('writer928') #建立一个保存数据用的东西
# dummy_input = torch.rand(2,160,400)  # 假设输入20张1*28*28的图片
# with SummaryWriter(comment='Net1') as w:
#     w.add_graph(net, (dummy_input,))

# %%
net = Net()

net = net.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(params=net.parameters(), lr=0.0001, momentum=0.9)

epochs = 1500
average_loss_series = []

# %%
for a, b in enumerate(train_loader):
    inputs, labels = b
    print(inputs.shape)
    break
# Out:
# torch.Size([4, 1, 2, 640])

# %%
# %matplotlib inline


if __name__ == '__main__':
    for epoch in range(epochs):
        running_loss = 0.0
        running_acc = 0.0

        for i, data in enumerate(train_loader):
#             print("i:", i )
#             print("data: ", data[0])
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()

#             inputs = inputs.permute(0, 2, 1)
            
            inputs = torch.tensor(inputs, dtype=torch.float32, device = device)

            outputs = net(inputs)
            _, predicted = torch.max(outputs.data, dim=1)
            total = labels.size(0)
#             print('原来的值:{0}, 预测的值:{1}'.format(labels, predicted))
            running_correct = (predicted == labels).sum()
            running_acc += running_correct
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            loss.backward()
            optimizer.step()

            # 每loopNum个batch打印一次训练状态
            loopNum = 1000
            if i % loopNum == loopNum - 1:
                average_loss = running_loss / loopNum
                logger.info('[{0}, {1}] loss: {2}'.format(epoch + 1, i + 1, average_loss))
                logger.info('设备号为: {0}，预测的设备号为:{1}'.format(labels, predicted))
#                 logger.info(torch.cuda.current_device ())
                running_acc = running_acc.float()
                average_acc = running_acc / loopNum / total
                
                logger.info('[{0}, {1}] acc: {2}'.format(epoch + 1, i + 1, average_acc))
                average_loss_series.append(average_loss)
                running_loss = 0.0
                running_acc = 0.0

    x = range(0, len(average_loss_series))
    plt.figure()
    plt.plot(x, average_loss_series)
#     plt.savefig("Loss.png")
    plt.savefig("Loss.png", bbox_inches="tight")
    plt.show()
    

    # %%
    # 在测试集上测试
    realLabel = []
    predictedLabel = []

    def correct_rate(net, testloader):
        correct = 0.0
        total = 0.0
        count = 0
        correctpredict = 0

        for data in testloader:
            images, labels = data
            images, labels = images.to(device),labels.to(device)
            realLabel.append([int(label) for label in labels])
    
            tests = torch.tensor(images, dtype=torch.float32,device=device)
            outputs = net(tests)

            _, predicted = torch.max(outputs.data, dim=1)
            logger.info('设备号为: {0}，模型训练后得到的设备号为:{1}'.format(labels, predicted))
#             deviceNumber = torch.cuda.current_device ()
#             logger.info(deviceNumber)
            
            labelsn = labels.cpu().numpy()
            pn = predicted.cpu().numpy()
            count += len(labelsn)
            
            for i in range(len(labelsn)):
                if labelsn[i] == pn[i]:
                    correctpredict += 1
                
            
            logger.info('目前一共测试了{0}组，预测成功的一共有{1}组'.format(count, correctpredict))
            predictedLabel.append([int(label) for label in predicted])
            
            total += labels.size(0)
            correct += (predicted == labels).sum()

            
        logger.info("total的值为：{total}")
#         return 100 * correct  # / total
        return 100 * correct/ total 


    correct = correct_rate(net, test_loader)
    logger.info(f'{len(test_loader) * 3}张测试集中准确率为： {correct}%')

    # %%
    import itertools
    from sklearn.metrics import confusion_matrix

    realLabel = list(itertools.chain.from_iterable(realLabel))
    predictedLabel = list(itertools.chain.from_iterable(predictedLabel))

    cm = confusion_matrix(realLabel, predictedLabel)
    logger.info(cm)

#     logger.info('the running time is:{1}'.format(time.time() - startTime))
    torch.save(net.state_dict(), f'./model_10dB_4个0_0.pkl')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# [1, 1000] loss: 4.017028631210327
# 设备号为: tensor([ 8, 19, 23, 53], device='cuda:1')，预测的设备号为:tensor([ 3, 20, 13, 19], device='cuda:1')
# [1, 1000] acc: 0.03125
# [1, 2000] loss: 3.7558916420936583
# 设备号为: tensor([11, 17,  0, 42], device='cuda:1')，预测的设备号为:tensor([27, 41, 33, 12], device='cuda:1')
# [1, 2000] acc: 0.0495000034570694
# [2, 1000] loss: 3.3331466691493987
# 设备号为: tensor([33, 51, 42, 41], device='cuda:1')，预测的设备号为:tensor([32, 21, 16, 43], device='cuda:1')
# [2, 1000] acc: 0.07650000602006912
# [2, 2000] loss: 3.204772713661194
# 设备号为: tensor([19, 42, 25, 26], device='cuda:1')，预测的设备号为:tensor([37,  4, 26,  6], device='cuda:1')
# [2, 2000] acc: 0.09775000810623169
# [3, 1000] loss: 2.974756758928299
# 设备号为: tensor([25, 27, 24, 24], device='cuda:1')，预测的设备号为:tensor([ 9, 34, 37, 12], device='cuda:1')
# [3, 1000] acc: 0.1340000033378601
# [3, 2000] loss: 2.9015336195230486
# 设备号为: tensor([39, 52,  3,  1], device='cuda:1')，预测的设备号为:tensor([33, 45,  6,  5], device='cuda:1')
# [3, 2000] acc: 0.13625000417232513
# [4, 1000] loss: 2.72748375248909
# 设备号为: tensor([53, 48,  5, 30], device='cuda:1')，预测的设备号为:tensor([44,  4,  1, 30], device='cuda:1')
# [4, 1000] acc: 0.17275001108646393
# [4, 2000] loss: 2.596223277568817
# 设备号为: tensor([30, 45, 21, 26], device='cuda:1')，预测的设备号为:tensor([30, 46, 20, 38], device='cuda:1')
# [4, 2000] acc: 0.19875000417232513
# [5, 1000] loss: 2.4472039028406143
# 设备号为: tensor([ 0, 35, 35,  5], device='cuda:1')，预测的设备号为:tensor([38, 35,  4,  5], device='cuda:1')
# [5, 1000] acc: 0.22425000369548798
# [5, 2000] loss: 2.3544738312363624
# 设备号为: tensor([27, 44, 38, 48], device='cuda:1')，预测的设备号为:tensor([34, 44, 36, 48], device='cuda:1')
# [5, 2000] acc: 0.2422500103712082
# [6, 1000] loss: 2.233735755801201
# 设备号为: tensor([18, 35, 15,  5], device='cuda:1')，预测的设备号为:tensor([41,  4, 44,  6], device='cuda:1')
# [6, 1000] acc: 0.2632500231266022
# [6, 2000] loss: 2.1667763813734053
# 设备号为: tensor([43, 42, 51, 40], device='cuda:1')，预测的设备号为:tensor([49, 42, 16, 16], device='cuda:1')
# [6, 2000] acc: 0.29625001549720764
# [7, 1000] loss: 2.0869984987974166
# 设备号为: tensor([49, 28, 42, 46], device='cuda:1')，预测的设备号为:tensor([13, 31, 28, 46], device='cuda:1')
# [7, 1000] acc: 0.30775001645088196
# [7, 2000] loss: 2.0198870537281035
# 设备号为: tensor([ 9, 39, 10, 13], device='cuda:1')，预测的设备号为:tensor([38,  3, 31, 13], device='cuda:1')
# [7, 2000] acc: 0.32500001788139343
# [8, 1000] loss: 1.9697284266352653
# 设备号为: tensor([31, 40, 50, 14], device='cuda:1')，预测的设备号为:tensor([28, 23, 43, 14], device='cuda:1')
# [8, 1000] acc: 0.3387500047683716
# [8, 2000] loss: 1.8856706517040729
# 设备号为: tensor([19, 10, 18, 39], device='cuda:1')，预测的设备号为:tensor([24, 32, 22, 34], device='cuda:1')
# [8, 2000] acc: 0.36650002002716064
# [9, 1000] loss: 1.8348612171113492
# 设备号为: tensor([34, 29,  3, 28], device='cuda:1')，预测的设备号为:tensor([34, 29,  3, 31], device='cuda:1')
# [9, 1000] acc: 0.38050001859664917
# [9, 2000] loss: 1.804799936041236
# 设备号为: tensor([ 9, 34, 48, 49], device='cuda:1')，预测的设备号为:tensor([ 1, 34, 48, 50], device='cuda:1')
# [9, 2000] acc: 0.398250013589859
# [10, 1000] loss: 1.7326955131292343
# 设备号为: tensor([18, 11, 28, 35], device='cuda:1')，预测的设备号为:tensor([18, 36, 28, 35], device='cuda:1')
# [10, 1000] acc: 0.41450002789497375
# [10, 2000] loss: 1.707181861191988
# 设备号为: tensor([19, 48, 28,  2], device='cuda:1')，预测的设备号为:tensor([22, 48, 10,  2], device='cuda:1')
# [10, 2000] acc: 0.4165000319480896
# [11, 1000] loss: 1.6456481104493141
# 设备号为: tensor([ 3, 12, 40, 44], device='cuda:1')，预测的设备号为:tensor([ 3, 12, 41, 46], device='cuda:1')
# [11, 1000] acc: 0.44475001096725464
# [11, 2000] loss: 1.6511095459461211
# 设备号为: tensor([41,  5,  8, 12], device='cuda:1')，预测的设备号为:tensor([41,  0, 10, 15], device='cuda:1')
# [11, 2000] acc: 0.4377500116825104
# [12, 1000] loss: 1.5322879287004472
# 设备号为: tensor([ 1, 27, 51, 47], device='cuda:1')，预测的设备号为:tensor([ 1, 33, 51, 41], device='cuda:1')
# [12, 1000] acc: 0.476250022649765
# [12, 2000] loss: 1.5468234634548426
# 设备号为: tensor([ 0, 21, 22, 38], device='cuda:1')，预测的设备号为:tensor([ 0, 47, 19, 36], device='cuda:1')
# [12, 2000] acc: 0.4780000150203705
# [13, 1000] loss: 1.4918920829743147
# 设备号为: tensor([14, 18, 22, 28], device='cuda:1')，预测的设备号为:tensor([18, 18, 14, 31], device='cuda:1')
# [13, 1000] acc: 0.4985000193119049
# [13, 2000] loss: 1.466295313358307
# 设备号为: tensor([49, 33, 39, 34], device='cuda:1')，预测的设备号为:tensor([49, 32, 32, 34], device='cuda:1')
# [13, 2000] acc: 0.49775001406669617
# [14, 1000] loss: 1.403903803832829
# 设备号为: tensor([40, 23,  6, 15], device='cuda:1')，预测的设备号为:tensor([19, 23,  0, 44], device='cuda:1')
# [14, 1000] acc: 0.5160000324249268
# [14, 2000] loss: 1.4208646500706672
# 设备号为: tensor([23, 42, 39, 13], device='cuda:1')，预测的设备号为:tensor([23, 48, 27, 13], device='cuda:1')
# [14, 2000] acc: 0.518750011920929
# [15, 1000] loss: 1.3383549461737274
# 设备号为: tensor([35, 53, 34, 22], device='cuda:1')，预测的设备号为:tensor([ 4, 53, 34, 16], device='cuda:1')
# [15, 1000] acc: 0.5442500114440918
# [15, 2000] loss: 1.3296416812036187
# 设备号为: tensor([32, 33, 17, 14], device='cuda:1')，预测的设备号为:tensor([32, 38, 17, 14], device='cuda:1')
# [15, 2000] acc: 0.546500027179718
# [16, 1000] loss: 1.3013783287554979
# 设备号为: tensor([17,  2, 40, 35], device='cuda:1')，预测的设备号为:tensor([17,  2, 49, 35], device='cuda:1')
# [16, 1000] acc: 0.5647500157356262
# [16, 2000] loss: 1.2831112097352744
# 设备号为: tensor([17, 44, 40, 50], device='cuda:1')，预测的设备号为:tensor([17, 46, 50, 20], device='cuda:1')
# [16, 2000] acc: 0.5575000047683716
# [17, 1000] loss: 1.1998101995699109
# 设备号为: tensor([16, 17,  8, 50], device='cuda:1')，预测的设备号为:tensor([22, 17,  3, 40], device='cuda:1')
# [17, 1000] acc: 0.5955000519752502
# [17, 2000] loss: 1.217100957479328
# 设备号为: tensor([39, 25, 25, 52], device='cuda:1')，预测的设备号为:tensor([39, 26, 10, 52], device='cuda:1')
# [17, 2000] acc: 0.5827500224113464
# [18, 1000] loss: 1.212577863888815
# 设备号为: tensor([28, 26,  8,  6], device='cuda:1')，预测的设备号为:tensor([28, 26,  6,  6], device='cuda:1')
# [18, 1000] acc: 0.5885000228881836
# [18, 2000] loss: 1.189027792416513
# 设备号为: tensor([ 5, 36, 37, 21], device='cuda:1')，预测的设备号为:tensor([ 5, 36, 30, 21], device='cuda:1')
# [18, 2000] acc: 0.5902500152587891
# [19, 1000] loss: 1.1176143253035844
# 设备号为: tensor([12,  5, 19, 31], device='cuda:1')，预测的设备号为:tensor([15,  5, 18, 31], device='cuda:1')
# [19, 1000] acc: 0.6210000514984131
# [19, 2000] loss: 1.129249571600929
# 设备号为: tensor([36, 14,  6, 19], device='cuda:1')，预测的设备号为:tensor([36, 12,  6, 14], device='cuda:1')
# [19, 2000] acc: 0.6165000200271606
# [20, 1000] loss: 1.0540251329801977
# 设备号为: tensor([ 4, 15, 35, 31], device='cuda:1')，预测的设备号为:tensor([ 4, 44, 35, 26], device='cuda:1')
# [20, 1000] acc: 0.6342500448226929
# [20, 2000] loss: 1.0885491751749068
# 设备号为: tensor([15,  4, 53, 34], device='cuda:1')，预测的设备号为:tensor([15,  4, 53,  4], device='cuda:1')
# [20, 2000] acc: 0.6237500309944153
# [21, 1000] loss: 1.003495450824499
# 设备号为: tensor([46, 14,  5, 18], device='cuda:1')，预测的设备号为:tensor([46, 20,  5, 18], device='cuda:1')
# [21, 1000] acc: 0.6507500410079956
# [21, 2000] loss: 1.0374001923026517
# 设备号为: tensor([49, 26, 16, 38], device='cuda:1')，预测的设备号为:tensor([51, 26, 51,  6], device='cuda:1')
# [21, 2000] acc: 0.6360000371932983
# [22, 1000] loss: 0.9947939454168081
# 设备号为: tensor([21, 48, 39,  8], device='cuda:1')，预测的设备号为:tensor([19, 48, 39,  9], device='cuda:1')
# [22, 1000] acc: 0.6502500176429749
# [22, 2000] loss: 0.9717527198495809
# 设备号为: tensor([48, 32, 34, 20], device='cuda:1')，预测的设备号为:tensor([48, 32, 34, 16], device='cuda:1')
# [22, 2000] acc: 0.6615000367164612
# [23, 1000] loss: 0.9182741792760789
# 设备号为: tensor([32,  7, 12, 45], device='cuda:1')，预测的设备号为:tensor([32,  7, 12, 45], device='cuda:1')
# [23, 1000] acc: 0.6765000224113464
# [23, 2000] loss: 0.9497797989747487
# 设备号为: tensor([23,  8, 24, 24], device='cuda:1')，预测的设备号为:tensor([12,  8, 24, 24], device='cuda:1')
# [23, 2000] acc: 0.6700000166893005
# [24, 1000] loss: 0.8925736838059966
# 设备号为: tensor([10, 50, 23, 25], device='cuda:1')，预测的设备号为:tensor([10, 50, 23, 25], device='cuda:1')
# [24, 1000] acc: 0.6897500157356262
# [24, 2000] loss: 0.901894283760339
# 设备号为: tensor([40, 22, 25,  8], device='cuda:1')，预测的设备号为:tensor([18, 22,  3,  5], device='cuda:1')
# [24, 2000] acc: 0.6877500414848328
# [25, 1000] loss: 0.8339241626644507
# 设备号为: tensor([10, 46, 26, 12], device='cuda:1')，预测的设备号为:tensor([10, 46, 26, 15], device='cuda:1')
# [25, 1000] acc: 0.7095000147819519
# [25, 2000] loss: 0.8615209380993619
# 设备号为: tensor([41, 31,  8, 26], device='cuda:1')，预测的设备号为:tensor([41, 31, 28, 26], device='cuda:1')
# [25, 2000] acc: 0.7005000114440918
# [26, 1000] loss: 0.7881554247869644
# 设备号为: tensor([ 9, 40, 18,  6], device='cuda:1')，预测的设备号为:tensor([26, 51, 18,  6], device='cuda:1')
# [26, 1000] acc: 0.7305000424385071
# [26, 2000] loss: 0.8210439660540433
# 设备号为: tensor([43, 53, 24, 29], device='cuda:1')，预测的设备号为:tensor([43, 53, 24,  4], device='cuda:1')
# [26, 2000] acc: 0.7115000486373901
# [27, 1000] loss: 0.7836307466858998
# 设备号为: tensor([ 3, 22, 48, 22], device='cuda:1')，预测的设备号为:tensor([ 3, 13, 48, 22], device='cuda:1')
# [27, 1000] acc: 0.7290000319480896
# [27, 2000] loss: 0.7992497491938994
# 设备号为: tensor([ 8, 14, 46, 13], device='cuda:1')，预测的设备号为:tensor([ 8, 14, 46, 13], device='cuda:1')
# [27, 2000] acc: 0.718250036239624
# [28, 1000] loss: 0.7406860860356829
# 设备号为: tensor([30, 35, 25, 44], device='cuda:1')，预测的设备号为:tensor([30, 29,  7, 44], device='cuda:1')
# [28, 1000] acc: 0.7405000329017639
# [28, 2000] loss: 0.7632332724558655
# 设备号为: tensor([ 7,  5, 24, 30], device='cuda:1')，预测的设备号为:tensor([33,  5, 23, 30], device='cuda:1')
# [28, 2000] acc: 0.7330000400543213
# [29, 1000] loss: 0.7208266004552133
# 设备号为: tensor([19,  0, 28, 30], device='cuda:1')，预测的设备号为:tensor([19,  8, 25, 30], device='cuda:1')
# [29, 1000] acc: 0.7520000338554382
# [29, 2000] loss: 0.7299119706545025
# 设备号为: tensor([29,  3, 41, 22], device='cuda:1')，预测的设备号为:tensor([ 2,  3, 41, 22], device='cuda:1')
# [29, 2000] acc: 0.7462500333786011
# [30, 1000] loss: 0.684919699310296
# 设备号为: tensor([27, 11, 47, 52], device='cuda:1')，预测的设备号为:tensor([27, 11, 21, 52], device='cuda:1')
# [30, 1000] acc: 0.7667500376701355
# [30, 2000] loss: 0.699313446541084
# 设备号为: tensor([26, 45, 52,  3], device='cuda:1')，预测的设备号为:tensor([26, 45, 52,  3], device='cuda:1')
# [30, 2000] acc: 0.7615000605583191
# [31, 1000] loss: 0.6563818060534541
# 设备号为: tensor([30,  1, 45, 40], device='cuda:1')，预测的设备号为:tensor([30,  1, 45, 40], device='cuda:1')
# [31, 1000] acc: 0.7750000357627869
# [31, 2000] loss: 0.6704876236004056
# 设备号为: tensor([31, 33, 12, 45], device='cuda:1')，预测的设备号为:tensor([31, 33, 12, 45], device='cuda:1')
# [31, 2000] acc: 0.7630000114440918
# [32, 1000] loss: 0.6203698461898602
# 设备号为: tensor([45, 43, 26, 44], device='cuda:1')，预测的设备号为:tensor([45, 43, 26, 12], device='cuda:1')
# [32, 1000] acc: 0.7872500419616699
# [32, 2000] loss: 0.624346291984024
# 设备号为: tensor([35, 22, 30, 30], device='cuda:1')，预测的设备号为:tensor([29, 22, 30, 30], device='cuda:1')
# [32, 2000] acc: 0.7790000438690186
# [33, 1000] loss: 0.5928313610538607
# 设备号为: tensor([23, 31, 17, 49], device='cuda:1')，预测的设备号为:tensor([23, 26, 17, 42], device='cuda:1')
# [33, 1000] acc: 0.796500027179718
# [33, 2000] loss: 0.6435161421474768
# 设备号为: tensor([40, 31, 11, 52], device='cuda:1')，预测的设备号为:tensor([40, 31, 11, 52], device='cuda:1')
# [33, 2000] acc: 0.7717500329017639
# [34, 1000] loss: 0.556052873023902
# 设备号为: tensor([23, 20, 48, 44], device='cuda:1')，预测的设备号为:tensor([23, 20, 48, 44], device='cuda:1')
# [34, 1000] acc: 0.8060000538825989
# [34, 2000] loss: 0.5581814909849782
# 设备号为: tensor([51,  6, 23, 18], device='cuda:1')，预测的设备号为:tensor([40,  6, 23, 23], device='cuda:1')
# [34, 2000] acc: 0.800000011920929
# [35, 1000] loss: 0.5442992973952787
# 设备号为: tensor([ 8, 32,  3, 23], device='cuda:1')，预测的设备号为:tensor([ 8, 33,  8, 19], device='cuda:1')
# [35, 1000] acc: 0.8132500648498535
# [35, 2000] loss: 0.556719715804793
# 设备号为: tensor([14,  0,  7, 20], device='cuda:1')，预测的设备号为:tensor([14,  0,  7, 20], device='cuda:1')
# [35, 2000] acc: 0.8142500519752502
# [36, 1000] loss: 0.5071310447253053
# 设备号为: tensor([16, 24, 27,  8], device='cuda:1')，预测的设备号为:tensor([20, 24, 27,  8], device='cuda:1')
# [36, 1000] acc: 0.8200000524520874
# [36, 2000] loss: 0.5109239378002239
# 设备号为: tensor([46, 12, 33,  5], device='cuda:1')，预测的设备号为:tensor([46, 15, 33,  5], device='cuda:1')
# [36, 2000] acc: 0.8185000419616699
# [37, 1000] loss: 0.5153159835117985
# 设备号为: tensor([35, 16, 16, 19], device='cuda:1')，预测的设备号为:tensor([ 4, 16, 16, 19], device='cuda:1')
# [37, 1000] acc: 0.8205000162124634
# [37, 2000] loss: 0.4954982491781702
# 设备号为: tensor([ 6, 52,  1, 18], device='cuda:1')，预测的设备号为:tensor([ 6, 52,  1, 18], device='cuda:1')
# [37, 2000] acc: 0.8210000395774841
# [38, 1000] loss: 0.47345747749344447
# 设备号为: tensor([15,  8, 14,  9], device='cuda:1')，预测的设备号为:tensor([15,  8, 14, 10], device='cuda:1')
# [38, 1000] acc: 0.8332500457763672
# [38, 2000] loss: 0.4476679114201688
# 设备号为: tensor([47, 45, 25, 53], device='cuda:1')，预测的设备号为:tensor([47, 45, 25, 53], device='cuda:1')
# [38, 2000] acc: 0.8450000286102295
# [39, 1000] loss: 0.4658516729400726
# 设备号为: tensor([11, 47,  5,  8], device='cuda:1')，预测的设备号为:tensor([27, 47,  5,  3], device='cuda:1')
# [39, 1000] acc: 0.8425000309944153
# [39, 2000] loss: 0.46060970389000433
# 设备号为: tensor([33, 34, 42,  6], device='cuda:1')，预测的设备号为:tensor([33, 34, 47,  6], device='cuda:1')
# [39, 2000] acc: 0.8355000615119934
# [40, 1000] loss: 0.41910935277305544
# 设备号为: tensor([12, 49, 24, 35], device='cuda:1')，预测的设备号为:tensor([16, 49, 24, 35], device='cuda:1')
# [40, 1000] acc: 0.8525000214576721
# [40, 2000] loss: 0.449408067285025
# 设备号为: tensor([19, 43, 36, 19], device='cuda:1')，预测的设备号为:tensor([19, 43, 36, 18], device='cuda:1')
# [40, 2000] acc: 0.8437500596046448
# [41, 1000] loss: 0.39680932553439924
# 设备号为: tensor([ 3, 31, 20,  1], device='cuda:1')，预测的设备号为:tensor([39, 31, 20,  1], device='cuda:1')
# [41, 1000] acc: 0.8642500638961792
# [41, 2000] loss: 0.4040194939879584
# 设备号为: tensor([28, 46, 17, 48], device='cuda:1')，预测的设备号为:tensor([28, 46, 17, 48], device='cuda:1')
# [41, 2000] acc: 0.8670000433921814
# [42, 1000] loss: 0.37316692946001423
# 设备号为: tensor([42, 25, 39, 11], device='cuda:1')，预测的设备号为:tensor([49, 25, 27, 11], device='cuda:1')
# [42, 1000] acc: 0.8707500696182251
# [42, 2000] loss: 0.3967138903001978
# 设备号为: tensor([22, 26, 48, 42], device='cuda:1')，预测的设备号为:tensor([22, 26, 48, 42], device='cuda:1')
# [42, 2000] acc: 0.8640000224113464

# %%
torch.cuda.current_device ()

# %%
aa = iter(train_loader)
a, b = aa.next()
print(a[0].shape)
print(a)

# %%
input = torch.randn(20, 16, 50, 100)
input.shape

# %%
m2=nn.Conv2d(16,33,(3,5),stride=(2,1),padding=(4,2))
inpu1=Variable(torch.randn(20,16,50,100))
print(inpu1.shape)
output=m2(inpu1)
print(output.shape)

# %%
total

# %%
torch.cuda.current_device ()

# %%
x = range(0, len(average_loss_series))
plt.figure()
plt.plot(x, average_loss_series)
plt.savefig("Loss1.png", bbox_inches="tight")
plt.show()
