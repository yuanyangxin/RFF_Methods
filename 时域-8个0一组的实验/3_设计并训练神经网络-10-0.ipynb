# %%
import matplotlib.pyplot as plt
import torchvision as tv
from torchvision import transforms, utils


import torch.nn.functional as F
import torch 
import torch.nn as nn
from torch.autograd import Variable
import torchvision.models as models
# from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader
# from PIL import Image
# import numpy as np
import torch.optim as optim
# import os
import time

import loadData

# %%
device = torch.device("cuda:0")

# %%
# 日志记录模块2
import logging
logger = logging.getLogger(__name__)
logger.setLevel(level = logging.INFO)
handler = logging.FileHandler("./10dB-时域识别-8个0一组-1500epoches-0")
handler.setLevel(logging.INFO)
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

console = logging.StreamHandler()
console.setLevel(logging.INFO)

logger.addHandler(handler)
logger.addHandler(console)

# %%
startTime = time.time()

# %%
transforms = tv.transforms.Compose([
    transforms.ToTensor(),
])


numOfBatch = 9
pixel = 64
flag = 0
root = f'./{numOfBatch}/data'
batchSize = 4
train_data = loadData.MyDataset(txt=f'files_train10.txt', transform=None)
test_data = loadData.MyDataset(txt=f'files_test10.txt', transform=None)



train_loader = DataLoader(dataset=train_data, batch_size=batchSize, shuffle=True, num_workers=2)
test_loader = DataLoader(dataset=test_data, batch_size=batchSize, shuffle=True, num_workers=2)


print(train_loader)
print(test_loader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7f8a60372550>
# <torch.utils.data.dataloader.DataLoader object at 0x7f8a603d5f10>

# %%
print(len(train_data))
print(len(test_loader))
# Out:
# 6426
# 419

# %%
# data = iter(train_loader)

# # print(type(data))
# # print(len(data))
# data_, label = data.next()
# print(train_loader.batch_size)
# print(data_.shape)
# # print(label)
# # print(data_, label)

# %%
x = torch.randn(4, 1, 1200, 2).float()
conv = nn.Conv2d(in_channels = 1, out_channels = 128, kernel_size = (10, 1))
x = conv(x)
x.shape
conv2 = nn.Conv2d(in_channels = 128, out_channels = 256, kernel_size = (3, 2))
x = conv2(x)
x.shape
# Out:
# torch.Size([4, 256, 1189, 1])

# %%
# 256*1189

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(in_channels = 1, out_channels = 8, kernel_size = (1, 10))
        self.conv2 = nn.Conv2d(in_channels = 8, out_channels = 16, kernel_size = (2, 3))
        
        self.dropout1 = nn.Dropout(0.5)
        self.dropout2 = nn.Dropout(0.5)
        
        self.fc1 = nn.Linear(20304, 1024)
        self.fc2 = nn.Linear(1024, 500)
        self.fc3 = nn.Linear(500, 54)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 1)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 1)
    
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.dropout1(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.dropout2(x)
        x = self.fc3(x)
        output = F.log_softmax(x, dim=1)
        return output

# %%
# TensorBoard
# from tensorboardX import SummaryWriter
# net = Net()
# # writer = SummaryWriter('writer928') #建立一个保存数据用的东西
# dummy_input = torch.rand(2,160,400)  # 假设输入20张1*28*28的图片
# with SummaryWriter(comment='Net1') as w:
#     w.add_graph(net, (dummy_input,))

# %%
net = Net()

net = net.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(params=net.parameters(), lr=0.0001, momentum=0.9)

epochs = 1500
average_loss_series = []

# %%
for a, b in enumerate(train_loader):
    inputs, labels = b
    print(inputs.shape)
    break
# Out:
# torch.Size([4, 1, 2, 1280])

# %%
# %matplotlib inline


if __name__ == '__main__':
    for epoch in range(epochs):
        running_loss = 0.0
        running_acc = 0.0

        for i, data in enumerate(train_loader):
#             print("i:", i )
#             print("data: ", data[0])
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()

#             inputs = inputs.permute(0, 2, 1)
            
            inputs = torch.tensor(inputs, dtype=torch.float32, device = device)

            outputs = net(inputs)
            _, predicted = torch.max(outputs.data, dim=1)
            total = labels.size(0)
#             print('原来的值:{0}, 预测的值:{1}'.format(labels, predicted))
            running_correct = (predicted == labels).sum()
            running_acc += running_correct
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            loss.backward()
            optimizer.step()

            # 每loopNum个batch打印一次训练状态
            loopNum = 1000
            if i % loopNum == loopNum - 1:
                average_loss = running_loss / loopNum
                logger.info('[{0}, {1}] loss: {2}'.format(epoch + 1, i + 1, average_loss))
                logger.info('设备号为: {0}，预测的设备号为:{1}'.format(labels, predicted))
#                 logger.info(torch.cuda.current_device ())
                running_acc = running_acc.float()
                average_acc = running_acc / loopNum / total
                
                logger.info('[{0}, {1}] acc: {2}'.format(epoch + 1, i + 1, average_acc))
                average_loss_series.append(average_loss)
                running_loss = 0.0
                running_acc = 0.0

    x = range(0, len(average_loss_series))
    plt.figure()
    plt.plot(x, average_loss_series)
#     plt.savefig("Loss.png")
    plt.savefig("Loss.png", bbox_inches="tight")
    plt.show()
    

    # %%
    # 在测试集上测试
    realLabel = []
    predictedLabel = []

    def correct_rate(net, testloader):
        correct = 0.0
        total = 0.0
        count = 0
        correctpredict = 0

        for data in testloader:
            images, labels = data
            images, labels = images.to(device),labels.to(device)
            realLabel.append([int(label) for label in labels])
    
            tests = torch.tensor(images, dtype=torch.float32,device=device)
            outputs = net(tests)

            _, predicted = torch.max(outputs.data, dim=1)
            logger.info('设备号为: {0}，模型训练后得到的设备号为:{1}'.format(labels, predicted))
#             deviceNumber = torch.cuda.current_device ()
#             logger.info(deviceNumber)
            
            labelsn = labels.cpu().numpy()
            pn = predicted.cpu().numpy()
            count += len(labelsn)
            
            for i in range(len(labelsn)):
                if labelsn[i] == pn[i]:
                    correctpredict += 1
                
            
            logger.info('目前一共测试了{0}组，预测成功的一共有{1}组'.format(count, correctpredict))
            predictedLabel.append([int(label) for label in predicted])
            
            total += labels.size(0)
            correct += (predicted == labels).sum()

            
        logger.info("total的值为：{total}")
#         return 100 * correct  # / total
        return 100 * correct/ total 


    correct = correct_rate(net, test_loader)
    logger.info(f'{len(test_loader) * 3}张测试集中准确率为： {correct}%')

    # %%
    import itertools
    from sklearn.metrics import confusion_matrix

    realLabel = list(itertools.chain.from_iterable(realLabel))
    predictedLabel = list(itertools.chain.from_iterable(predictedLabel))

    cm = confusion_matrix(realLabel, predictedLabel)
    logger.info(cm)

#     logger.info('the running time is:{1}'.format(time.time() - startTime))
    torch.save(net.state_dict(), f'./model_10dB_8个0_0.pkl')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# [1, 1000] loss: 3.9894047076702117
# 设备号为: tensor([31, 25,  4, 36], device='cuda:0')，预测的设备号为:tensor([21,  6, 35, 35], device='cuda:0')
# [1, 1000] acc: 0.021000001579523087
# [2, 1000] loss: 3.9868089926242827
# 设备号为: tensor([ 4,  1, 41, 10], device='cuda:0')，预测的设备号为:tensor([35, 35, 35, 22], device='cuda:0')
# [2, 1000] acc: 0.024000000208616257
# [3, 1000] loss: 3.9854501955509187
# 设备号为: tensor([17, 47, 28,  7], device='cuda:0')，预测的设备号为:tensor([43, 46, 35, 38], device='cuda:0')
# [3, 1000] acc: 0.023750001564621925
# [4, 1000] loss: 3.9815200171470644
# 设备号为: tensor([50,  2,  6, 50], device='cuda:0')，预测的设备号为:tensor([40, 20, 20, 20], device='cuda:0')
# [4, 1000] acc: 0.03150000050663948
# [5, 1000] loss: 3.976416352748871
# 设备号为: tensor([36, 47, 38,  2], device='cuda:0')，预测的设备号为:tensor([ 6, 24,  5, 50], device='cuda:0')
# [5, 1000] acc: 0.027500001713633537
# [6, 1000] loss: 3.9660571613311766
# 设备号为: tensor([47, 12, 39, 42], device='cuda:0')，预测的设备号为:tensor([10, 52,  9, 10], device='cuda:0')
# [6, 1000] acc: 0.033250000327825546
# [7, 1000] loss: 3.9378133215904234
# 设备号为: tensor([43, 45, 47, 51], device='cuda:0')，预测的设备号为:tensor([22, 24, 37, 20], device='cuda:0')
# [7, 1000] acc: 0.04400000348687172
# [8, 1000] loss: 3.8279883782863617
# 设备号为: tensor([50, 24, 35, 52], device='cuda:0')，预测的设备号为:tensor([12, 46,  7, 44], device='cuda:0')
# [8, 1000] acc: 0.06275000423192978
# [9, 1000] loss: 3.466076026201248
# 设备号为: tensor([48,  9, 22, 15], device='cuda:0')，预测的设备号为:tensor([ 2,  9, 14, 44], device='cuda:0')
# [9, 1000] acc: 0.07200000435113907
# [10, 1000] loss: 3.192358277320862
# 设备号为: tensor([20, 52, 38, 26], device='cuda:0')，预测的设备号为:tensor([46, 52, 29,  0], device='cuda:0')
# [10, 1000] acc: 0.10425000637769699
# [11, 1000] loss: 3.088360867500305
# 设备号为: tensor([16, 51,  9, 37], device='cuda:0')，预测的设备号为:tensor([14, 41, 28, 52], device='cuda:0')
# [11, 1000] acc: 0.10900000482797623
# [12, 1000] loss: 2.9563817538022996
# 设备号为: tensor([ 5, 51, 39, 43], device='cuda:0')，预测的设备号为:tensor([34, 40, 28, 48], device='cuda:0')
# [12, 1000] acc: 0.13125000894069672
# [13, 1000] loss: 2.8660378512144087
# 设备号为: tensor([10,  4, 29,  7], device='cuda:0')，预测的设备号为:tensor([ 8,  4, 39,  8], device='cuda:0')
# [13, 1000] acc: 0.1495000123977661
# [14, 1000] loss: 2.780344038724899
# 设备号为: tensor([12, 34, 50, 23], device='cuda:0')，预测的设备号为:tensor([12, 11, 24, 30], device='cuda:0')
# [14, 1000] acc: 0.16250000894069672
# [15, 1000] loss: 2.643264507174492
# 设备号为: tensor([26, 16, 13, 39], device='cuda:0')，预测的设备号为:tensor([31, 49, 13,  4], device='cuda:0')
# [15, 1000] acc: 0.18950000405311584
# [16, 1000] loss: 2.492302926838398
# 设备号为: tensor([17, 14, 11, 16], device='cuda:0')，预测的设备号为:tensor([17, 16,  5, 50], device='cuda:0')
# [16, 1000] acc: 0.21900001168251038
# [17, 1000] loss: 2.3369197486639024
# 设备号为: tensor([ 5, 50,  2, 53], device='cuda:0')，预测的设备号为:tensor([ 6, 23,  2, 53], device='cuda:0')
# [17, 1000] acc: 0.25425001978874207
# [18, 1000] loss: 2.23441281491518
# 设备号为: tensor([23,  0, 10,  8], device='cuda:0')，预测的设备号为:tensor([50, 26, 26, 10], device='cuda:0')
# [18, 1000] acc: 0.2670000195503235
# [19, 1000] loss: 2.130470673561096
# 设备号为: tensor([33, 23, 33, 41], device='cuda:0')，预测的设备号为:tensor([33, 13, 33, 40], device='cuda:0')
# [19, 1000] acc: 0.30650001764297485
# [20, 1000] loss: 2.0474203644692897
# 设备号为: tensor([ 4, 49, 22, 43], device='cuda:0')，预测的设备号为:tensor([ 4, 13, 42, 13], device='cuda:0')
# [20, 1000] acc: 0.3135000169277191
# [21, 1000] loss: 1.9873996287286282
# 设备号为: tensor([ 6, 36, 46,  5], device='cuda:0')，预测的设备号为:tensor([ 6, 36, 46,  6], device='cuda:0')
# [21, 1000] acc: 0.32225000858306885
# [22, 1000] loss: 1.914279821485281
# 设备号为: tensor([27, 39, 14, 14], device='cuda:0')，预测的设备号为:tensor([27,  3, 14, 14], device='cuda:0')
# [22, 1000] acc: 0.3475000262260437
# [23, 1000] loss: 1.842640849530697
# 设备号为: tensor([50,  4, 36, 22], device='cuda:0')，预测的设备号为:tensor([18,  4, 36, 16], device='cuda:0')
# [23, 1000] acc: 0.374750018119812
# [24, 1000] loss: 1.797118321299553
# 设备号为: tensor([27, 47,  0, 41], device='cuda:0')，预测的设备号为:tensor([27, 47,  6, 51], device='cuda:0')
# [24, 1000] acc: 0.38475000858306885
# [25, 1000] loss: 1.7121049693524837
# 设备号为: tensor([27, 39, 49, 17], device='cuda:0')，预测的设备号为:tensor([11, 39, 13, 17], device='cuda:0')
# [25, 1000] acc: 0.4220000207424164
# [26, 1000] loss: 1.6341337790191173
# 设备号为: tensor([19, 10, 46, 44], device='cuda:0')，预测的设备号为:tensor([47, 10, 44, 52], device='cuda:0')
# [26, 1000] acc: 0.44300001859664917
# [27, 1000] loss: 1.6031591508686542
# 设备号为: tensor([10, 52, 15,  1], device='cuda:0')，预测的设备号为:tensor([10, 53, 12,  1], device='cuda:0')
# [27, 1000] acc: 0.46000000834465027
# [28, 1000] loss: 1.5323125021904707
# 设备号为: tensor([13, 15, 20, 35], device='cuda:0')，预测的设备号为:tensor([13, 12, 50, 35], device='cuda:0')
# [28, 1000] acc: 0.47450003027915955
# [29, 1000] loss: 1.480130113951862
# 设备号为: tensor([ 3,  0, 51, 28], device='cuda:0')，预测的设备号为:tensor([27,  0, 41, 28], device='cuda:0')
# [29, 1000] acc: 0.49425002932548523
# [30, 1000] loss: 1.4495287811532616
# 设备号为: tensor([33, 24, 10,  1], device='cuda:0')，预测的设备号为:tensor([33, 24, 10,  1], device='cuda:0')
# [30, 1000] acc: 0.499500036239624
# [31, 1000] loss: 1.3815731302388012
# 设备号为: tensor([48, 25, 29, 51], device='cuda:0')，预测的设备号为:tensor([48, 28, 29, 51], device='cuda:0')
# [31, 1000] acc: 0.5282500386238098
# [32, 1000] loss: 1.3497654960341752
# 设备号为: tensor([19, 37, 30, 48], device='cuda:0')，预测的设备号为:tensor([13, 37, 37, 48], device='cuda:0')
# [32, 1000] acc: 0.5287500023841858
# [33, 1000] loss: 1.3081150441765785
# 设备号为: tensor([53, 51,  0,  9], device='cuda:0')，预测的设备号为:tensor([53, 42,  8, 28], device='cuda:0')
# [33, 1000] acc: 0.5392500162124634
# [34, 1000] loss: 1.2716704143323003
# 设备号为: tensor([44, 39, 39, 32], device='cuda:0')，预测的设备号为:tensor([46, 27,  7, 32], device='cuda:0')
# [34, 1000] acc: 0.5597500205039978
# [35, 1000] loss: 1.2539240771755575
# 设备号为: tensor([19, 35, 18, 22], device='cuda:0')，预测的设备号为:tensor([22, 29, 22, 43], device='cuda:0')
# [35, 1000] acc: 0.5575000047683716
# [36, 1000] loss: 1.2045711326487363
# 设备号为: tensor([27,  7, 18, 22], device='cuda:0')，预测的设备号为:tensor([27, 38, 18, 16], device='cuda:0')
# [36, 1000] acc: 0.577750027179718
# [37, 1000] loss: 1.1629668327867986
# 设备号为: tensor([51, 37,  3, 12], device='cuda:0')，预测的设备号为:tensor([43, 37,  3, 12], device='cuda:0')
# [37, 1000] acc: 0.5927500128746033
# [38, 1000] loss: 1.1458837183341384
# 设备号为: tensor([15,  2, 11,  6], device='cuda:0')，预测的设备号为:tensor([46,  2, 11,  6], device='cuda:0')
# [38, 1000] acc: 0.5960000157356262
# [39, 1000] loss: 1.1300956387799233
# 设备号为: tensor([ 7, 19, 14, 44], device='cuda:0')，预测的设备号为:tensor([ 7, 43, 20, 44], device='cuda:0')
# [39, 1000] acc: 0.6095000505447388
# [40, 1000] loss: 1.0696601983383298
# 设备号为: tensor([52, 23, 22, 45], device='cuda:0')，预测的设备号为:tensor([52, 24, 20, 52], device='cuda:0')
# [40, 1000] acc: 0.6310000419616699
# [41, 1000] loss: 1.056172296368517
# 设备号为: tensor([15,  8, 40, 45], device='cuda:0')，预测的设备号为:tensor([15,  6, 42, 45], device='cuda:0')
# [41, 1000] acc: 0.6235000491142273
# [42, 1000] loss: 1.0427282198928296
# 设备号为: tensor([25, 45, 21, 32], device='cuda:0')，预测的设备号为:tensor([25, 45, 42, 32], device='cuda:0')
# [42, 1000] acc: 0.6345000267028809
# [43, 1000] loss: 1.0203329772874712
# 设备号为: tensor([45, 35,  6, 22], device='cuda:0')，预测的设备号为:tensor([45, 35,  5, 16], device='cuda:0')
# [43, 1000] acc: 0.6445000171661377
# [44, 1000] loss: 1.0067694858536125
# 设备号为: tensor([49, 36, 13, 45], device='cuda:0')，预测的设备号为:tensor([50, 11, 13, 45], device='cuda:0')
# [44, 1000] acc: 0.6390000581741333
# [45, 1000] loss: 0.9575371663523838
# 设备号为: tensor([19, 31, 43, 40], device='cuda:0')，预测的设备号为:tensor([20, 31, 43, 14], device='cuda:0')
# [45, 1000] acc: 0.6575000286102295
# [46, 1000] loss: 0.9617100064232945
# 设备号为: tensor([ 7, 37, 23, 17], device='cuda:0')，预测的设备号为:tensor([ 3, 37, 13, 17], device='cuda:0')
# [46, 1000] acc: 0.6577500104904175
# [47, 1000] loss: 0.9544925193614326
# 设备号为: tensor([19, 40, 26,  1], device='cuda:0')，预测的设备号为:tensor([47, 40, 26,  1], device='cuda:0')
# [47, 1000] acc: 0.6707500219345093
# [48, 1000] loss: 0.8967933240062557
# 设备号为: tensor([15, 24, 20, 45], device='cuda:0')，预测的设备号为:tensor([15, 24, 18, 45], device='cuda:0')
# [48, 1000] acc: 0.6830000281333923
# [49, 1000] loss: 0.904336546458304
# 设备号为: tensor([53, 16, 31,  8], device='cuda:0')，预测的设备号为:tensor([44, 41, 31,  8], device='cuda:0')
# [49, 1000] acc: 0.6710000038146973
# [50, 1000] loss: 0.8827572230584919
# 设备号为: tensor([ 6,  7, 18, 50], device='cuda:0')，预测的设备号为:tensor([ 6,  7, 14, 50], device='cuda:0')
# [50, 1000] acc: 0.6880000233650208
# [51, 1000] loss: 0.8637358125094324
# 设备号为: tensor([ 5,  0, 45, 12], device='cuda:0')，预测的设备号为:tensor([ 0,  0, 52, 12], device='cuda:0')
# [51, 1000] acc: 0.6917500495910645
# [52, 1000] loss: 0.8444588004425168
# 设备号为: tensor([27, 11, 47, 25], device='cuda:0')，预测的设备号为:tensor([27, 11, 21, 25], device='cuda:0')
# [52, 1000] acc: 0.6960000395774841
# [53, 1000] loss: 0.8517213538270444
# 设备号为: tensor([30, 43, 33, 38], device='cuda:0')，预测的设备号为:tensor([30, 43,  9, 38], device='cuda:0')
# [53, 1000] acc: 0.6927500367164612
# [54, 1000] loss: 0.83692268836312
# 设备号为: tensor([18, 26, 30, 46], device='cuda:0')，预测的设备号为:tensor([18, 26, 30, 46], device='cuda:0')
# [54, 1000] acc: 0.6982500553131104
# [55, 1000] loss: 0.8105493641139474
# 设备号为: tensor([10, 13,  0, 20], device='cuda:0')，预测的设备号为:tensor([10, 13,  5, 20], device='cuda:0')
# [55, 1000] acc: 0.7152500152587891
# [56, 1000] loss: 0.7966741721164435
# 设备号为: tensor([48, 35, 25, 17], device='cuda:0')，预测的设备号为:tensor([48, 35,  0, 17], device='cuda:0')
# [56, 1000] acc: 0.7120000123977661
# [57, 1000] loss: 0.7698812706529862
# 设备号为: tensor([20, 30, 19, 40], device='cuda:0')，预测的设备号为:tensor([41, 30, 47, 40], device='cuda:0')
# [57, 1000] acc: 0.7247500419616699
# [58, 1000] loss: 0.7509661528686993
# 设备号为: tensor([24, 16, 52, 26], device='cuda:0')，预测的设备号为:tensor([24, 22, 52, 26], device='cuda:0')
# [58, 1000] acc: 0.7317500114440918
# [59, 1000] loss: 0.761048056077212
# 设备号为: tensor([36, 13, 12, 34], device='cuda:0')，预测的设备号为:tensor([36, 13, 15, 34], device='cuda:0')
# [59, 1000] acc: 0.7267500162124634
# [60, 1000] loss: 0.7301864528167061
# 设备号为: tensor([ 2, 19,  4, 27], device='cuda:0')，预测的设备号为:tensor([ 2, 19,  4, 27], device='cuda:0')
# [60, 1000] acc: 0.7290000319480896
# [61, 1000] loss: 0.7282137223497266
# 设备号为: tensor([49, 11, 13, 36], device='cuda:0')，预测的设备号为:tensor([40, 27, 13, 36], device='cuda:0')
# [61, 1000] acc: 0.7360000610351562
# [62, 1000] loss: 0.6935918331032154
# 设备号为: tensor([37, 15, 28, 52], device='cuda:0')，预测的设备号为:tensor([37, 15, 31, 52], device='cuda:0')
# [62, 1000] acc: 0.749250054359436
# [63, 1000] loss: 0.7016518719969317
# 设备号为: tensor([26, 15, 21, 18], device='cuda:0')，预测的设备号为:tensor([26, 15, 21, 23], device='cuda:0')
# [63, 1000] acc: 0.7465000152587891
# [64, 1000] loss: 0.6656351960902103
# 设备号为: tensor([ 2, 45, 13,  6], device='cuda:0')，预测的设备号为:tensor([ 2, 45, 13,  6], device='cuda:0')
# [64, 1000] acc: 0.7552500367164612
# [65, 1000] loss: 0.6529493450706358
# 设备号为: tensor([17, 52, 22, 15], device='cuda:0')，预测的设备号为:tensor([17, 52, 16, 44], device='cuda:0')
# [65, 1000] acc: 0.7640000581741333
# [66, 1000] loss: 0.6591954440182308
# 设备号为: tensor([13,  1, 12, 32], device='cuda:0')，预测的设备号为:tensor([49,  1, 23, 32], device='cuda:0')
# [66, 1000] acc: 0.7657500505447388
# [67, 1000] loss: 0.6424526420854964
# 设备号为: tensor([35, 48, 44, 16], device='cuda:0')，预测的设备号为:tensor([35, 48, 44, 16], device='cuda:0')
# [67, 1000] acc: 0.7667500376701355
# [68, 1000] loss: 0.6243719766177237
# 设备号为: tensor([51, 42, 50, 49], device='cuda:0')，预测的设备号为:tensor([43, 42, 50, 49], device='cuda:0')
# [68, 1000] acc: 0.7830000519752502
# [69, 1000] loss: 0.595470297683496
# 设备号为: tensor([35, 29, 44, 52], device='cuda:0')，预测的设备号为:tensor([35, 29, 44, 52], device='cuda:0')
# [69, 1000] acc: 0.7830000519752502
# [70, 1000] loss: 0.5839490699910093
# 设备号为: tensor([17, 38, 27, 24], device='cuda:0')，预测的设备号为:tensor([17, 38, 27, 24], device='cuda:0')
# [70, 1000] acc: 0.7912500500679016
# [71, 1000] loss: 0.5839629678648489
# 设备号为: tensor([47, 17, 45,  9], device='cuda:0')，预测的设备号为:tensor([47, 17, 45,  9], device='cuda:0')
# [71, 1000] acc: 0.7912500500679016
# [72, 1000] loss: 0.5451045234014745
# 设备号为: tensor([22,  0,  0, 22], device='cuda:0')，预测的设备号为:tensor([47,  0,  0, 22], device='cuda:0')
# [72, 1000] acc: 0.8017500638961792
# [73, 1000] loss: 0.5392968047349713
# 设备号为: tensor([14,  0, 20, 11], device='cuda:0')，预测的设备号为:tensor([16,  0, 20, 11], device='cuda:0')
# [73, 1000] acc: 0.8095000386238098
# [74, 1000] loss: 0.5172342211831128
# 设备号为: tensor([ 1, 21, 10, 27], device='cuda:0')，预测的设备号为:tensor([ 1, 21, 10, 27], device='cuda:0')
# [74, 1000] acc: 0.8172500133514404
# [75, 1000] loss: 0.5123949382990831
# 设备号为: tensor([31, 19, 10,  3], device='cuda:0')，预测的设备号为:tensor([31, 16, 10,  3], device='cuda:0')
# [75, 1000] acc: 0.8127500414848328
# [76, 1000] loss: 0.5081981524790609
# 设备号为: tensor([10, 20, 15, 29], device='cuda:0')，预测的设备号为:tensor([10, 20, 15, 29], device='cuda:0')
# [76, 1000] acc: 0.8212500214576721
# [77, 1000] loss: 0.49467203379969577
# 设备号为: tensor([18,  7, 15, 52], device='cuda:0')，预测的设备号为:tensor([20,  7, 53, 52], device='cuda:0')
# [77, 1000] acc: 0.8232500553131104
# [78, 1000] loss: 0.4885589665209409
# 设备号为: tensor([41, 27, 42,  8], device='cuda:0')，预测的设备号为:tensor([41, 27, 42,  8], device='cuda:0')
# [78, 1000] acc: 0.8232500553131104
# [79, 1000] loss: 0.47632253407037933
# 设备号为: tensor([12, 42, 15, 30], device='cuda:0')，预测的设备号为:tensor([12, 42, 15, 30], device='cuda:0')
# [79, 1000] acc: 0.8215000629425049
# [80, 1000] loss: 0.43509061047038994
# 设备号为: tensor([32, 23, 14, 23], device='cuda:0')，预测的设备号为:tensor([32, 23, 14, 23], device='cuda:0')
# [80, 1000] acc: 0.8452500104904175
# [81, 1000] loss: 0.42875394479191165
# 设备号为: tensor([51,  0,  9, 53], device='cuda:0')，预测的设备号为:tensor([51,  0,  9, 53], device='cuda:0')
# [81, 1000] acc: 0.8425000309944153
# [82, 1000] loss: 0.43015253885663696
# 设备号为: tensor([19, 20,  2, 19], device='cuda:0')，预测的设备号为:tensor([22, 20,  2, 18], device='cuda:0')
# [82, 1000] acc: 0.8442500233650208
# [83, 1000] loss: 0.40473162374080857
# 设备号为: tensor([46,  2, 22,  0], device='cuda:0')，预测的设备号为:tensor([46,  2, 16,  0], device='cuda:0')
# [83, 1000] acc: 0.8575000166893005
# [84, 1000] loss: 0.4127818450165214
# 设备号为: tensor([ 3, 10, 16,  5], device='cuda:0')，预测的设备号为:tensor([ 3, 10, 20, 26], device='cuda:0')
# [84, 1000] acc: 0.8545000553131104
# [85, 1000] loss: 0.4049135279433103
# 设备号为: tensor([33,  7, 10, 17], device='cuda:0')，预测的设备号为:tensor([33,  7, 10, 17], device='cuda:0')
# [85, 1000] acc: 0.8547500371932983
# [86, 1000] loss: 0.3738114367402159
# 设备号为: tensor([29, 14, 16, 45], device='cuda:0')，预测的设备号为:tensor([29, 14, 16, 45], device='cuda:0')
# [86, 1000] acc: 0.8702500462532043
# [87, 1000] loss: 0.3527833402631804
# 设备号为: tensor([30,  3, 38,  0], device='cuda:0')，预测的设备号为:tensor([30,  3, 38,  0], device='cuda:0')
# [87, 1000] acc: 0.8705000281333923
# [88, 1000] loss: 0.34362043916538826
# 设备号为: tensor([28, 39, 11, 45], device='cuda:0')，预测的设备号为:tensor([28, 39, 11, 45], device='cuda:0')
# [88, 1000] acc: 0.874250054359436
# [89, 1000] loss: 0.34928778156876794
# 设备号为: tensor([48, 21, 30, 43], device='cuda:0')，预测的设备号为:tensor([48, 21, 30, 43], device='cuda:0')
# [89, 1000] acc: 0.8765000700950623
# [90, 1000] loss: 0.33732660781475715
# 设备号为: tensor([49, 32, 10,  0], device='cuda:0')，预测的设备号为:tensor([49, 32, 10,  0], device='cuda:0')
# [90, 1000] acc: 0.8805000185966492
# [91, 1000] loss: 0.3214960898886784
# 设备号为: tensor([13, 36, 46, 35], device='cuda:0')，预测的设备号为:tensor([13, 36, 46, 35], device='cuda:0')
# [91, 1000] acc: 0.8827500343322754
# [92, 1000] loss: 0.31900772810365563
# 设备号为: tensor([ 3, 26, 25, 23], device='cuda:0')，预测的设备号为:tensor([ 3, 26, 25, 23], device='cuda:0')
# [92, 1000] acc: 0.8885000348091125
# [93, 1000] loss: 0.2973443338220241
# 设备号为: tensor([51, 31,  3, 11], device='cuda:0')，预测的设备号为:tensor([51, 31,  3, 11], device='cuda:0')
# [93, 1000] acc: 0.893500030040741
# [94, 1000] loss: 0.30493413197121116
# 设备号为: tensor([39, 22, 50, 41], device='cuda:0')，预测的设备号为:tensor([39, 19, 50, 41], device='cuda:0')
# [94, 1000] acc: 0.8922500610351562
# [95, 1000] loss: 0.30491900921637716
# 设备号为: tensor([31, 38, 27,  8], device='cuda:0')，预测的设备号为:tensor([31, 38, 27,  8], device='cuda:0')
# [95, 1000] acc: 0.8952500224113464
# [96, 1000] loss: 0.25806376913821444
# 设备号为: tensor([52, 45, 27, 34], device='cuda:0')，预测的设备号为:tensor([52, 45, 27, 34], device='cuda:0')
# [96, 1000] acc: 0.9132500290870667
# [97, 1000] loss: 0.2777155010168935
# 设备号为: tensor([45, 30, 45, 26], device='cuda:0')，预测的设备号为:tensor([45, 30, 45, 26], device='cuda:0')
# [97, 1000] acc: 0.9047500491142273

# %%
torch.cuda.current_device ()

# %%
aa = iter(train_loader)
a, b = aa.next()
print(a[0].shape)
print(a)

# %%
input = torch.randn(20, 16, 50, 100)
input.shape

# %%
m2=nn.Conv2d(16,33,(3,5),stride=(2,1),padding=(4,2))
inpu1=Variable(torch.randn(20,16,50,100))
print(inpu1.shape)
output=m2(inpu1)
print(output.shape)

# %%
total

# %%
torch.cuda.current_device ()

# %%
x = range(0, len(average_loss_series))
plt.figure()
plt.plot(x, average_loss_series)
plt.savefig("Loss1.png", bbox_inches="tight")
plt.show()
