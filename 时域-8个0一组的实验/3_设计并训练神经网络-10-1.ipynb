# %%
import matplotlib.pyplot as plt
import torchvision as tv
from torchvision import transforms, utils


import torch.nn.functional as F
import torch 
import torch.nn as nn
from torch.autograd import Variable
import torchvision.models as models
# from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader
# from PIL import Image
# import numpy as np
import torch.optim as optim
# import os
import time

import loadData

# %%
device = torch.device("cuda:1")

# %%
# 日志记录模块2
import logging
logger = logging.getLogger(__name__)
logger.setLevel(level = logging.INFO)
handler = logging.FileHandler("./10dB-时域识别-8个0一组-1000epoches-1")
handler.setLevel(logging.INFO)
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

console = logging.StreamHandler()
console.setLevel(logging.INFO)

logger.addHandler(handler)
logger.addHandler(console)

# %%
startTime = time.time()

# %%
transforms = tv.transforms.Compose([
    transforms.ToTensor(),
])


numOfBatch = 9
pixel = 64
flag = 0
root = f'./{numOfBatch}/data'
batchSize = 4
train_data = loadData.MyDataset(txt=f'files_train10.txt', transform=None)
test_data = loadData.MyDataset(txt=f'files_test10.txt', transform=None)



train_loader = DataLoader(dataset=train_data, batch_size=batchSize, shuffle=True, num_workers=2)
test_loader = DataLoader(dataset=test_data, batch_size=batchSize, shuffle=True, num_workers=2)


print(train_loader)
print(test_loader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7f76953fb7d0>
# <torch.utils.data.dataloader.DataLoader object at 0x7f7694f2acd0>

# %%
print(len(train_data))
print(len(test_loader))
# Out:
# 6426
# 419

# %%
# data = iter(train_loader)

# # print(type(data))
# # print(len(data))
# data_, label = data.next()
# print(train_loader.batch_size)
# print(data_.shape)
# # print(label)
# # print(data_, label)

# %%
x = torch.randn(4, 1, 1200, 2).float()
conv = nn.Conv2d(in_channels = 1, out_channels = 128, kernel_size = (10, 1))
x = conv(x)
x.shape
conv2 = nn.Conv2d(in_channels = 128, out_channels = 256, kernel_size = (3, 2))
x = conv2(x)
x.shape
# Out:
# torch.Size([4, 256, 1189, 1])

# %%
# 256*1189

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(in_channels = 1, out_channels = 8, kernel_size = (1, 10))
        self.conv2 = nn.Conv2d(in_channels = 8, out_channels = 16, kernel_size = (2, 3))
        
        self.dropout1 = nn.Dropout(0.5)
        self.dropout2 = nn.Dropout(0.5)
        
        self.fc1 = nn.Linear(20304, 1024)
        self.fc2 = nn.Linear(1024, 500)
        self.fc3 = nn.Linear(500, 54)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 1)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 1)
    
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.dropout1(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.dropout2(x)
        x = self.fc3(x)
        output = F.log_softmax(x, dim=1)
        return output

# %%
# TensorBoard
# from tensorboardX import SummaryWriter
# net = Net()
# # writer = SummaryWriter('writer928') #建立一个保存数据用的东西
# dummy_input = torch.rand(2,160,400)  # 假设输入20张1*28*28的图片
# with SummaryWriter(comment='Net1') as w:
#     w.add_graph(net, (dummy_input,))

# %%
net = Net()

net = net.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(params=net.parameters(), lr=0.0001, momentum=0.9)

epochs = 1000
average_loss_series = []

# %%
for a, b in enumerate(train_loader):
    inputs, labels = b
    print(inputs.shape)
    break
# Out:
# torch.Size([4, 1, 2, 1280])

# %%
# %matplotlib inline


if __name__ == '__main__':
    for epoch in range(epochs):
        running_loss = 0.0
        running_acc = 0.0

        for i, data in enumerate(train_loader):
#             print("i:", i )
#             print("data: ", data[0])
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()

#             inputs = inputs.permute(0, 2, 1)
            
            inputs = torch.tensor(inputs, dtype=torch.float32, device = device)

            outputs = net(inputs)
            _, predicted = torch.max(outputs.data, dim=1)
            total = labels.size(0)
#             print('原来的值:{0}, 预测的值:{1}'.format(labels, predicted))
            running_correct = (predicted == labels).sum()
            running_acc += running_correct
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            loss.backward()
            optimizer.step()

            # 每loopNum个batch打印一次训练状态
            loopNum = 1000
            if i % loopNum == loopNum - 1:
                average_loss = running_loss / loopNum
                logger.info('[{0}, {1}] loss: {2}'.format(epoch + 1, i + 1, average_loss))
                logger.info('设备号为: {0}，预测的设备号为:{1}'.format(labels, predicted))
#                 logger.info(torch.cuda.current_device ())
                running_acc = running_acc.float()
                average_acc = running_acc / loopNum / total
                
                logger.info('[{0}, {1}] acc: {2}'.format(epoch + 1, i + 1, average_acc))
                average_loss_series.append(average_loss)
                running_loss = 0.0
                running_acc = 0.0

    x = range(0, len(average_loss_series))
    plt.figure()
    plt.plot(x, average_loss_series)
#     plt.savefig("Loss.png")
    plt.savefig("Loss.png", bbox_inches="tight")
    plt.show()
    

    # %%
    # 在测试集上测试
    realLabel = []
    predictedLabel = []

    def correct_rate(net, testloader):
        correct = 0.0
        total = 0.0
        count = 0
        correctpredict = 0

        for data in testloader:
            images, labels = data
            images, labels = images.to(device),labels.to(device)
            realLabel.append([int(label) for label in labels])
    
            tests = torch.tensor(images, dtype=torch.float32,device=device)
            outputs = net(tests)

            _, predicted = torch.max(outputs.data, dim=1)
            logger.info('设备号为: {0}，模型训练后得到的设备号为:{1}'.format(labels, predicted))
#             deviceNumber = torch.cuda.current_device ()
#             logger.info(deviceNumber)
            
            labelsn = labels.cpu().numpy()
            pn = predicted.cpu().numpy()
            count += len(labelsn)
            
            for i in range(len(labelsn)):
                if labelsn[i] == pn[i]:
                    correctpredict += 1
                
            
            logger.info('目前一共测试了{0}组，预测成功的一共有{1}组'.format(count, correctpredict))
            predictedLabel.append([int(label) for label in predicted])
            
            total += labels.size(0)
            correct += (predicted == labels).sum()

            
        logger.info("total的值为：{total}")
#         return 100 * correct  # / total
        return 100 * correct/ total 


    correct = correct_rate(net, test_loader)
    logger.info(f'{len(test_loader) * 3}张测试集中准确率为： {correct}%')

    # %%
    import itertools
    from sklearn.metrics import confusion_matrix

    realLabel = list(itertools.chain.from_iterable(realLabel))
    predictedLabel = list(itertools.chain.from_iterable(predictedLabel))

    cm = confusion_matrix(realLabel, predictedLabel)
    logger.info(cm)

#     logger.info('the running time is:{1}'.format(time.time() - startTime))
    torch.save(net, f'./model_10dB_8个0_1.pkl')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# [1, 1000] loss: 3.9892095050811767
# 设备号为: tensor([14, 18, 28, 16], device='cuda:1')，预测的设备号为:tensor([ 9, 25,  0, 23], device='cuda:1')
# [1, 1000] acc: 0.018000001087784767
# [2, 1000] loss: 3.9868256373405457
# 设备号为: tensor([44, 38,  2, 33], device='cuda:1')，预测的设备号为:tensor([20,  0,  0, 37], device='cuda:1')
# [2, 1000] acc: 0.02225000038743019
# [3, 1000] loss: 3.9856060781478884
# 设备号为: tensor([43, 20, 33, 45], device='cuda:1')，预测的设备号为:tensor([37, 20, 23, 30], device='cuda:1')
# [3, 1000] acc: 0.02175000123679638
# [4, 1000] loss: 3.9836691863536835
# 设备号为: tensor([43, 16, 41, 34], device='cuda:1')，预测的设备号为:tensor([23, 29, 28, 25], device='cuda:1')
# [4, 1000] acc: 0.026000000536441803
# [5, 1000] loss: 3.979201585531235
# 设备号为: tensor([ 1, 53, 36, 50], device='cuda:1')，预测的设备号为:tensor([40, 23,  8, 16], device='cuda:1')
# [5, 1000] acc: 0.03225000202655792
# [6, 1000] loss: 3.972451620101929
# 设备号为: tensor([10,  4, 41, 18], device='cuda:1')，预测的设备号为:tensor([11, 50, 15, 23], device='cuda:1')
# [6, 1000] acc: 0.03225000202655792
# [7, 1000] loss: 3.9603686521053314
# 设备号为: tensor([40,  6, 21, 19], device='cuda:1')，预测的设备号为:tensor([12, 42, 37, 19], device='cuda:1')
# [7, 1000] acc: 0.03825000301003456
# [8, 1000] loss: 3.9271805441379546
# 设备号为: tensor([37, 32,  8, 34], device='cuda:1')，预测的设备号为:tensor([37, 28,  1,  1], device='cuda:1')
# [8, 1000] acc: 0.05100000277161598
# [9, 1000] loss: 3.804150236606598
# 设备号为: tensor([25, 37, 30, 21], device='cuda:1')，预测的设备号为:tensor([ 1, 40, 45, 53], device='cuda:1')
# [9, 1000] acc: 0.05425000190734863
# [10, 1000] loss: 3.44681015753746
# 设备号为: tensor([35,  4,  6, 20], device='cuda:1')，预测的设备号为:tensor([32, 39,  7, 14], device='cuda:1')
# [10, 1000] acc: 0.07725000381469727
# [11, 1000] loss: 3.200227751493454
# 设备号为: tensor([ 1, 40, 44,  3], device='cuda:1')，预测的设备号为:tensor([ 1, 43, 52, 38], device='cuda:1')
# [11, 1000] acc: 0.10000000149011612
# [12, 1000] loss: 3.073881643533707
# 设备号为: tensor([ 7, 31, 18, 12], device='cuda:1')，预测的设备号为:tensor([31,  2, 15, 15], device='cuda:1')
# [12, 1000] acc: 0.11400000751018524
# [13, 1000] loss: 2.955897736787796
# 设备号为: tensor([48, 16,  1,  2], device='cuda:1')，预测的设备号为:tensor([ 4, 30,  0,  2], device='cuda:1')
# [13, 1000] acc: 0.1262499988079071
# [14, 1000] loss: 2.846754081130028
# 设备号为: tensor([22, 42, 16, 46], device='cuda:1')，预测的设备号为:tensor([23, 47, 49, 53], device='cuda:1')
# [14, 1000] acc: 0.15050001442432404
# [15, 1000] loss: 2.7245435812473295
# 设备号为: tensor([48, 35, 49, 47], device='cuda:1')，预测的设备号为:tensor([48, 34, 23,  4], device='cuda:1')
# [15, 1000] acc: 0.15800000727176666
# [16, 1000] loss: 2.6149966803193094
# 设备号为: tensor([20,  3, 28, 48], device='cuda:1')，预测的设备号为:tensor([40,  3, 38, 48], device='cuda:1')
# [16, 1000] acc: 0.1990000158548355
# [17, 1000] loss: 2.4898374519348145
# 设备号为: tensor([22,  9, 14,  4], device='cuda:1')，预测的设备号为:tensor([24,  6, 43,  4], device='cuda:1')
# [17, 1000] acc: 0.21525001525878906
# [18, 1000] loss: 2.331692082643509
# 设备号为: tensor([51, 49, 46, 20], device='cuda:1')，预测的设备号为:tensor([47, 50, 46, 20], device='cuda:1')
# [18, 1000] acc: 0.24625001847743988
# [19, 1000] loss: 2.1836464067697525
# 设备号为: tensor([ 9, 50, 52, 21], device='cuda:1')，预测的设备号为:tensor([38, 40, 45, 42], device='cuda:1')
# [19, 1000] acc: 0.27925002574920654
# [20, 1000] loss: 2.0938759459853173
# 设备号为: tensor([17, 31, 32, 40], device='cuda:1')，预测的设备号为:tensor([17, 28, 31, 19], device='cuda:1')
# [20, 1000] acc: 0.3032500147819519
# [21, 1000] loss: 1.9932471237778664
# 设备号为: tensor([11, 36, 40, 40], device='cuda:1')，预测的设备号为:tensor([29, 33, 48, 47], device='cuda:1')
# [21, 1000] acc: 0.3345000147819519
# [22, 1000] loss: 1.9138664160370826
# 设备号为: tensor([ 5, 17,  3,  1], device='cuda:1')，预测的设备号为:tensor([ 5, 17,  8,  0], device='cuda:1')
# [22, 1000] acc: 0.35075002908706665
# [23, 1000] loss: 1.8358837328106166
# 设备号为: tensor([40, 14,  3,  4], device='cuda:1')，预测的设备号为:tensor([14, 16, 28,  4], device='cuda:1')
# [23, 1000] acc: 0.36525002121925354
# [24, 1000] loss: 1.7679295766353607
# 设备号为: tensor([ 0,  9,  0, 51], device='cuda:1')，预测的设备号为:tensor([ 5,  9,  0, 21], device='cuda:1')
# [24, 1000] acc: 0.39625000953674316
# [25, 1000] loss: 1.699967790812254
# 设备号为: tensor([21,  7, 36, 10], device='cuda:1')，预测的设备号为:tensor([47, 28,  6, 10], device='cuda:1')
# [25, 1000] acc: 0.4130000174045563
# [26, 1000] loss: 1.6214652897268533
# 设备号为: tensor([36, 25, 52, 49], device='cuda:1')，预测的设备号为:tensor([36,  9, 45, 51], device='cuda:1')
# [26, 1000] acc: 0.42900002002716064
# [27, 1000] loss: 1.5207011574208738
# 设备号为: tensor([ 4, 47,  9,  6], device='cuda:1')，预测的设备号为:tensor([29, 21,  9,  5], device='cuda:1')
# [27, 1000] acc: 0.4697500169277191
# [28, 1000] loss: 1.4567250832617282
# 设备号为: tensor([ 1, 33, 25, 38], device='cuda:1')，预测的设备号为:tensor([ 1, 33, 10, 38], device='cuda:1')
# [28, 1000] acc: 0.4895000159740448
# [29, 1000] loss: 1.3778425422608853
# 设备号为: tensor([18, 48, 33, 17], device='cuda:1')，预测的设备号为:tensor([18, 17, 36, 17], device='cuda:1')
# [29, 1000] acc: 0.5170000195503235
# [30, 1000] loss: 1.3327660008650273
# 设备号为: tensor([41, 48,  2, 18], device='cuda:1')，预测的设备号为:tensor([41, 48,  2, 18], device='cuda:1')
# [30, 1000] acc: 0.5257500410079956
# [31, 1000] loss: 1.268436384420842
# 设备号为: tensor([ 3, 39, 31, 49], device='cuda:1')，预测的设备号为:tensor([39, 39, 31, 22], device='cuda:1')
# [31, 1000] acc: 0.562250018119812
# [32, 1000] loss: 1.221638578105718
# 设备号为: tensor([20,  5, 44, 45], device='cuda:1')，预测的设备号为:tensor([14,  5, 44, 44], device='cuda:1')
# [32, 1000] acc: 0.5755000114440918
# [33, 1000] loss: 1.1859012415986507
# 设备号为: tensor([45,  9, 14,  5], device='cuda:1')，预测的设备号为:tensor([52,  1, 14,  5], device='cuda:1')
# [33, 1000] acc: 0.5860000252723694
# [34, 1000] loss: 1.131321020886302
# 设备号为: tensor([ 3, 42, 15, 44], device='cuda:1')，预测的设备号为:tensor([28, 42, 15, 44], device='cuda:1')
# [34, 1000] acc: 0.6070000529289246
# [35, 1000] loss: 1.1133181608878076
# 设备号为: tensor([38, 45, 41,  6], device='cuda:1')，预测的设备号为:tensor([38, 45, 43,  6], device='cuda:1')
# [35, 1000] acc: 0.6072500348091125
# [36, 1000] loss: 1.06419222416915
# 设备号为: tensor([41, 35, 14, 27], device='cuda:1')，预测的设备号为:tensor([41, 29, 12, 27], device='cuda:1')
# [36, 1000] acc: 0.6237500309944153
# [37, 1000] loss: 1.0034585594851524
# 设备号为: tensor([ 3, 36, 13, 14], device='cuda:1')，预测的设备号为:tensor([ 3, 36, 13, 12], device='cuda:1')
# [37, 1000] acc: 0.6425000429153442
# [38, 1000] loss: 0.9759301736252383
# 设备号为: tensor([26, 26, 44, 35], device='cuda:1')，预测的设备号为:tensor([26, 26, 44, 35], device='cuda:1')
# [38, 1000] acc: 0.659250020980835
# [39, 1000] loss: 0.9659741580523551
# 设备号为: tensor([50, 24, 38, 42], device='cuda:1')，预测的设备号为:tensor([50, 23, 38, 42], device='cuda:1')
# [39, 1000] acc: 0.6597500443458557
# [40, 1000] loss: 0.9220380625799298
# 设备号为: tensor([31, 42, 20,  4], device='cuda:1')，预测的设备号为:tensor([31, 51, 40,  4], device='cuda:1')
# [40, 1000] acc: 0.6727500557899475
# [41, 1000] loss: 0.8595763116916642
# 设备号为: tensor([14, 26, 50,  2], device='cuda:1')，预测的设备号为:tensor([14, 26, 50,  2], device='cuda:1')
# [41, 1000] acc: 0.6940000057220459
# [42, 1000] loss: 0.8835421632528305
# 设备号为: tensor([36, 42, 29, 22], device='cuda:1')，预测的设备号为:tensor([11, 43, 35, 22], device='cuda:1')
# [42, 1000] acc: 0.6857500076293945
# [43, 1000] loss: 0.8692350716926157
# 设备号为: tensor([ 1,  0, 51,  5], device='cuda:1')，预测的设备号为:tensor([ 1,  0, 41,  5], device='cuda:1')
# [43, 1000] acc: 0.6912500262260437
# [44, 1000] loss: 0.8071178967943415
# 设备号为: tensor([50, 18, 22, 15], device='cuda:1')，预测的设备号为:tensor([49, 18, 21, 44], device='cuda:1')
# [44, 1000] acc: 0.7135000228881836
# [45, 1000] loss: 0.7476891380120069
# 设备号为: tensor([25, 23, 27, 13], device='cuda:1')，预测的设备号为:tensor([33, 23,  7, 13], device='cuda:1')
# [45, 1000] acc: 0.7352500557899475
# [46, 1000] loss: 0.7353704714952036
# 设备号为: tensor([49,  8, 13, 39], device='cuda:1')，预测的设备号为:tensor([41,  8, 49, 39], device='cuda:1')
# [46, 1000] acc: 0.7462500333786011
# [47, 1000] loss: 0.7201410586247221
# 设备号为: tensor([ 5, 35, 38, 30], device='cuda:1')，预测的设备号为:tensor([ 5, 35, 38, 30], device='cuda:1')
# [47, 1000] acc: 0.7452500462532043
# [48, 1000] loss: 0.6749081371179781
# 设备号为: tensor([22, 18, 38,  5], device='cuda:1')，预测的设备号为:tensor([22, 18, 38,  8], device='cuda:1')
# [48, 1000] acc: 0.7582500576972961
# [49, 1000] loss: 0.6584802769366652
# 设备号为: tensor([18, 22, 29,  7], device='cuda:1')，预测的设备号为:tensor([18, 22, 29, 38], device='cuda:1')
# [49, 1000] acc: 0.7675000429153442
# [50, 1000] loss: 0.6464500981958118
# 设备号为: tensor([14, 29, 38, 35], device='cuda:1')，预测的设备号为:tensor([14, 29, 38, 35], device='cuda:1')
# [50, 1000] acc: 0.7710000276565552
# [51, 1000] loss: 0.6408022041781806
# 设备号为: tensor([35, 39,  7, 38], device='cuda:1')，预测的设备号为:tensor([35, 34,  7, 38], device='cuda:1')
# [51, 1000] acc: 0.7700000405311584
# [52, 1000] loss: 0.5905434380886145
# 设备号为: tensor([39, 35, 47, 52], device='cuda:1')，预测的设备号为:tensor([39, 35, 41, 52], device='cuda:1')
# [52, 1000] acc: 0.7885000109672546
# [53, 1000] loss: 0.5575856355685973
# 设备号为: tensor([39, 42, 32, 36], device='cuda:1')，预测的设备号为:tensor([29, 21, 32, 36], device='cuda:1')
# [53, 1000] acc: 0.8025000095367432
# [54, 1000] loss: 0.5557064274875447
# 设备号为: tensor([30, 34, 41, 19], device='cuda:1')，预测的设备号为:tensor([30, 11, 41, 19], device='cuda:1')
# [54, 1000] acc: 0.8022500276565552
# [55, 1000] loss: 0.5285993225062267
# 设备号为: tensor([23, 39, 35, 42], device='cuda:1')，预测的设备号为:tensor([23, 39, 35, 21], device='cuda:1')
# [55, 1000] acc: 0.8165000677108765
# [56, 1000] loss: 0.5315081885079853
# 设备号为: tensor([50, 32, 19, 28], device='cuda:1')，预测的设备号为:tensor([50, 32, 20, 28], device='cuda:1')
# [56, 1000] acc: 0.8087500333786011
# [57, 1000] loss: 0.4996223982493393
# 设备号为: tensor([21,  2,  8, 12], device='cuda:1')，预测的设备号为:tensor([21,  2,  8, 12], device='cuda:1')
# [57, 1000] acc: 0.8210000395774841
# [58, 1000] loss: 0.47126357299438676
# 设备号为: tensor([40, 23, 41, 17], device='cuda:1')，预测的设备号为:tensor([50, 23, 41, 17], device='cuda:1')
# [58, 1000] acc: 0.8325000405311584
# [59, 1000] loss: 0.478530676695751
# 设备号为: tensor([16, 50, 52, 30], device='cuda:1')，预测的设备号为:tensor([20, 50, 52, 30], device='cuda:1')
# [59, 1000] acc: 0.827250063419342
# [60, 1000] loss: 0.4111071112952195
# 设备号为: tensor([45, 48, 15,  5], device='cuda:1')，预测的设备号为:tensor([52, 48, 15,  5], device='cuda:1')
# [60, 1000] acc: 0.8522500395774841
# [61, 1000] loss: 0.4270808309003478
# 设备号为: tensor([ 7, 15, 28, 18], device='cuda:1')，预测的设备号为:tensor([ 7, 15, 28, 18], device='cuda:1')
# [61, 1000] acc: 0.8457500338554382
# [62, 1000] loss: 0.4126132674547844
# 设备号为: tensor([18, 45, 24, 53], device='cuda:1')，预测的设备号为:tensor([18, 45, 24, 53], device='cuda:1')
# [62, 1000] acc: 0.8525000214576721
# [63, 1000] loss: 0.3977992751551792
# 设备号为: tensor([41, 16, 16, 44], device='cuda:1')，预测的设备号为:tensor([41, 14, 23, 44], device='cuda:1')
# [63, 1000] acc: 0.8602500557899475
# [64, 1000] loss: 0.3719641113783873
# 设备号为: tensor([22, 20, 34, 44], device='cuda:1')，预测的设备号为:tensor([19, 16, 34, 44], device='cuda:1')
# [64, 1000] acc: 0.8690000176429749
# [65, 1000] loss: 0.3482128671449609
# 设备号为: tensor([40, 26,  0,  1], device='cuda:1')，预测的设备号为:tensor([41, 26,  0,  1], device='cuda:1')
# [65, 1000] acc: 0.8820000290870667
# [66, 1000] loss: 0.33818643625976985
# 设备号为: tensor([24, 31,  7, 39], device='cuda:1')，预测的设备号为:tensor([24, 31,  7, 39], device='cuda:1')
# [66, 1000] acc: 0.8822500705718994
# [67, 1000] loss: 0.3419886076609837
# 设备号为: tensor([27,  2,  7, 30], device='cuda:1')，预测的设备号为:tensor([27,  2,  7, 30], device='cuda:1')
# [67, 1000] acc: 0.8760000467300415
# [68, 1000] loss: 0.3311444259144919
# 设备号为: tensor([ 7, 16, 40, 34], device='cuda:1')，预测的设备号为:tensor([ 7, 16, 40, 34], device='cuda:1')
# [68, 1000] acc: 0.8832500576972961
# [69, 1000] loss: 0.3239423657479056
# 设备号为: tensor([ 4, 22, 16, 22], device='cuda:1')，预测的设备号为:tensor([ 4, 22, 16, 49], device='cuda:1')
# [69, 1000] acc: 0.8842500448226929
# [70, 1000] loss: 0.31380515059747266
# 设备号为: tensor([48, 42, 38,  0], device='cuda:1')，预测的设备号为:tensor([48, 42, 38,  0], device='cuda:1')
# [70, 1000] acc: 0.8887500166893005
# [71, 1000] loss: 0.2975339431212633
# 设备号为: tensor([10, 11, 52, 16], device='cuda:1')，预测的设备号为:tensor([10, 11, 52, 16], device='cuda:1')
# [71, 1000] acc: 0.9002500176429749
# [72, 1000] loss: 0.2672483426198014
# 设备号为: tensor([21, 30, 32, 28], device='cuda:1')，预测的设备号为:tensor([21, 30, 32, 28], device='cuda:1')
# [72, 1000] acc: 0.9080000519752502
# [73, 1000] loss: 0.2870742022790364
# 设备号为: tensor([24, 33, 38, 10], device='cuda:1')，预测的设备号为:tensor([24, 33, 38, 10], device='cuda:1')
# [73, 1000] acc: 0.8982500433921814
# [74, 1000] loss: 0.2557511241211178
# 设备号为: tensor([13, 48, 41, 15], device='cuda:1')，预测的设备号为:tensor([13, 48, 41, 15], device='cuda:1')
# [74, 1000] acc: 0.9125000238418579
# [75, 1000] loss: 0.26060933964618743
# 设备号为: tensor([30, 48, 43,  6], device='cuda:1')，预测的设备号为:tensor([30, 48, 43,  6], device='cuda:1')
# [75, 1000] acc: 0.9062500596046448
# [76, 1000] loss: 0.24517598850906872
# 设备号为: tensor([ 3, 12, 48, 23], device='cuda:1')，预测的设备号为:tensor([ 3, 12, 48, 23], device='cuda:1')
# [76, 1000] acc: 0.9105000495910645
# [77, 1000] loss: 0.23594601246126695
# 设备号为: tensor([20,  3, 21,  2], device='cuda:1')，预测的设备号为:tensor([16, 39, 21,  2], device='cuda:1')
# [77, 1000] acc: 0.9155000448226929
# [78, 1000] loss: 0.2072388805112132
# 设备号为: tensor([26,  3, 39, 38], device='cuda:1')，预测的设备号为:tensor([26,  3, 39, 38], device='cuda:1')
# [78, 1000] acc: 0.9290000200271606
# [79, 1000] loss: 0.22421774627812557
# 设备号为: tensor([41, 24,  1, 44], device='cuda:1')，预测的设备号为:tensor([41, 24,  1, 44], device='cuda:1')
# [79, 1000] acc: 0.9225000143051147
# [80, 1000] loss: 0.21059117141171738
# 设备号为: tensor([27, 43, 17, 24], device='cuda:1')，预测的设备号为:tensor([39, 43, 17, 24], device='cuda:1')
# [80, 1000] acc: 0.9282500147819519
# [81, 1000] loss: 0.2019569771918759
# 设备号为: tensor([29, 44, 24, 12], device='cuda:1')，预测的设备号为:tensor([29, 53, 24, 12], device='cuda:1')
# [81, 1000] acc: 0.9295000433921814
# [82, 1000] loss: 0.17529217620751297
# 设备号为: tensor([ 6, 46, 14, 28], device='cuda:1')，预测的设备号为:tensor([ 6, 46, 22, 28], device='cuda:1')
# [82, 1000] acc: 0.9420000314712524
# [83, 1000] loss: 0.16964148992424316
# 设备号为: tensor([49, 43,  3, 35], device='cuda:1')，预测的设备号为:tensor([49, 43,  3, 35], device='cuda:1')
# [83, 1000] acc: 0.937250018119812

# %%
torch.cuda.current_device ()

# %%
aa = iter(train_loader)
a, b = aa.next()
print(a[0].shape)
print(a)

# %%
input = torch.randn(20, 16, 50, 100)
input.shape

# %%
m2=nn.Conv2d(16,33,(3,5),stride=(2,1),padding=(4,2))
inpu1=Variable(torch.randn(20,16,50,100))
print(inpu1.shape)
output=m2(inpu1)
print(output.shape)

# %%
total

# %%
torch.cuda.current_device ()

# %%
x = range(0, len(average_loss_series))
plt.figure()
plt.plot(x, average_loss_series)
plt.savefig("Loss1.png", bbox_inches="tight")
plt.show()
