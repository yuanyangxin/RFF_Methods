# %%
import matplotlib.pyplot as plt
import torchvision as tv
from torchvision import transforms, utils


import torch.nn.functional as F
import torch 
import torch.nn as nn
from torch.autograd import Variable
import torchvision.models as models
# from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader
# from PIL import Image
# import numpy as np
import torch.optim as optim
# import os
import time

import loadData

# %%
device = torch.device("cuda:0")

# %%
# 日志记录模块2
import logging
logger = logging.getLogger(__name__)
logger.setLevel(level = logging.INFO)
handler = logging.FileHandler("./train-2.log")
handler.setLevel(logging.INFO)
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

console = logging.StreamHandler()
console.setLevel(logging.INFO)

logger.addHandler(handler)
logger.addHandler(console)

# %%
startTime = time.time()

# %%
transforms = tv.transforms.Compose([
    transforms.ToTensor(),
])


numOfBatch = 9
pixel = 64
flag = 0
root = f'./{numOfBatch}/data'
batchSize = 4
train_data = loadData.MyDataset(txt=f'files_train.txt', transform=None)
test_data = loadData.MyDataset(txt=f'files_test.txt', transform=None)



train_loader = DataLoader(dataset=train_data, batch_size=batchSize, shuffle=True, num_workers=2)
test_loader = DataLoader(dataset=test_data, batch_size=batchSize, shuffle=True, num_workers=2)


print(train_loader)
print(test_loader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7f2240630350>
# <torch.utils.data.dataloader.DataLoader object at 0x7f2240630950>

# %%
print(len(train_data))
print(len(test_loader))
# Out:
# 487
# 486

# %%
# data = iter(train_loader)

# # print(type(data))
# # print(len(data))
# data_, label = data.next()
# print(train_loader.batch_size)
# print(data_.shape)
# # print(label)
# # print(data_, label)

# %%
# x = torch.randn(4, 1, 1200, 2).float()
# conv = nn.Conv2d(in_channels = 1, out_channels = 128, kernel_size = (10, 1))
# x = conv(x)
# x.shape
# conv2 = nn.Conv2d(in_channels = 128, out_channels = 256, kernel_size = (3, 2))
# x = conv2(x)
# x.shape

# %%
# 256*1189

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(in_channels = 1, out_channels = 16, kernel_size = (99, 99))
        self.conv2 = nn.Conv2d(in_channels = 16, out_channels = 32, kernel_size = (99, 99))
        
        self.dropout1 = nn.Dropout(0.5)
        self.dropout2 = nn.Dropout(0.5)
        
        self.fc1 = nn.Linear(1152, 256) 
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 54)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 1)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 1)
    
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.dropout1(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.dropout2(x)
        x = self.fc3(x)
        output = F.log_softmax(x, dim=1)
        return output

# %%
# TensorBoard
# from tensorboardX import SummaryWriter
# net = Net()
# # writer = SummaryWriter('writer928') #建立一个保存数据用的东西
# dummy_input = torch.rand(2,160,400)  # 假设输入20张1*28*28的图片
# with SummaryWriter(comment='Net1') as w:
#     w.add_graph(net, (dummy_input,))

# %%
net = Net()

net = net.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(params=net.parameters(), lr=0.0001, momentum=0.9)

epochs = 1000
average_loss_series = []

# %%
# for a, b in enumerate(train_loader):
#     inputs, labels = b
#     print(inputs.shape)
#     break

# %%
# %matplotlib inline


if __name__ == '__main__':
    for epoch in range(epochs):
        running_loss = 0.0
        running_acc = 0.0

        for i, data in enumerate(train_loader):
#             print("i:", i )
#             print("data: ", data[0])
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()

#             inputs = inputs.permute(0, 2, 1)
            
            inputs = torch.tensor(inputs, dtype=torch.float32, device = device)

            outputs = net(inputs)
            _, predicted = torch.max(outputs.data, dim=1)
            total = labels.size(0)
#             print('原来的值:{0}, 预测的值:{1}'.format(labels, predicted))
            running_correct = (predicted == labels).sum()
            running_acc += running_correct
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            loss.backward()
            optimizer.step()

            # 每loopNum个batch打印一次训练状态
            loopNum = 100
            if i % loopNum == loopNum - 1:
                average_loss = running_loss / loopNum
                logger.info('[{0}, {1}] loss: {2}'.format(epoch + 1, i + 1, average_loss))
                logger.info('设备号为: {0}，预测的设备号为:{1}'.format(labels, predicted))
#                 logger.info(torch.cuda.current_device ())
                running_acc = running_acc.float()
                average_acc = running_acc / loopNum / total
                
                logger.info('[{0}, {1}] acc: {2}'.format(epoch + 1, i + 1, average_acc))
                average_loss_series.append(average_loss)
                running_loss = 0.0
                running_acc = 0.0

    x = range(0, len(average_loss_series))
    plt.figure()
    plt.plot(x, average_loss_series)
#     plt.savefig("Loss.png")
    plt.savefig("Loss.png", bbox_inches="tight")
    plt.show()
    

    # %%
    # 在测试集上测试
    realLabel = []
    predictedLabel = []

    def correct_rate(net, testloader):
        correct = 0.0
        total = 0.0
        count = 0
        correctpredict = 0

        for data in testloader:
            images, labels = data
            images, labels = images.to(device),labels.to(device)
            realLabel.append([int(label) for label in labels])
    
            tests = torch.tensor(images, dtype=torch.float32,device=device)
            outputs = net(tests)

            _, predicted = torch.max(outputs.data, dim=1)
            logger.info('设备号为: {0}，模型训练后得到的设备号为:{1}'.format(labels, predicted))
#             deviceNumber = torch.cuda.current_device ()
#             logger.info(deviceNumber)
            
            labelsn = labels.cpu().numpy()
            pn = predicted.cpu().numpy()
            count += len(labelsn)
            
            for i in range(len(labelsn)):
                if labelsn[i] == pn[i]:
                    correctpredict += 1
                
            
            logger.info('目前一共测试了{0}组，预测成功的一共有{1}组'.format(count, correctpredict))
            predictedLabel.append([int(label) for label in predicted])
            
            total += labels.size(0)
            correct += (predicted == labels).sum()

            
        logger.info("total的值为：{total}")
#         return 100 * correct  # / total
        return 100 * correct/ total 


    correct = correct_rate(net, test_loader)
    logger.info(f'{len(test_loader) * 3}张测试集中准确率为： {correct}%')

    # %%
    import itertools
    from sklearn.metrics import confusion_matrix

    realLabel = list(itertools.chain.from_iterable(realLabel))
    predictedLabel = list(itertools.chain.from_iterable(predictedLabel))

    cm = confusion_matrix(realLabel, predictedLabel)
    logger.info(cm)

#     logger.info('the running time is:{1}'.format(time.time() - startTime))
    torch.save(net, f'./model_10dB.pkl')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# [1, 100] loss: 3.9870715165138244
# 设备号为: tensor([ 1, 27, 51, 25], device='cuda:0')，预测的设备号为:tensor([ 6, 27, 25, 19], device='cuda:0')
# [1, 100] acc: 0.019999999552965164
# [2, 100] loss: 3.9793658208847047
# 设备号为: tensor([47, 22,  8, 47], device='cuda:0')，预测的设备号为:tensor([27,  6, 46, 21], device='cuda:0')
# [2, 100] acc: 0.022499999031424522
# [3, 100] loss: 3.974236259460449
# 设备号为: tensor([46, 36, 35, 42], device='cuda:0')，预测的设备号为:tensor([21, 21, 38, 27], device='cuda:0')
# [3, 100] acc: 0.042500000447034836
# [4, 100] loss: 3.961182610988617
# 设备号为: tensor([10, 30, 34, 15], device='cuda:0')，预测的设备号为:tensor([27, 25, 25, 21], device='cuda:0')
# [4, 100] acc: 0.054999999701976776
# [5, 100] loss: 3.9473891258239746
# 设备号为: tensor([47, 46,  1,  9], device='cuda:0')，预测的设备号为:tensor([ 6, 25,  1,  9], device='cuda:0')
# [5, 100] acc: 0.08500000089406967
# [6, 100] loss: 3.931634066104889
# 设备号为: tensor([26, 44, 33, 48], device='cuda:0')，预测的设备号为:tensor([26, 25, 25, 27], device='cuda:0')
# [6, 100] acc: 0.07999999821186066
# [7, 100] loss: 3.903227562904358
# 设备号为: tensor([53, 14, 42, 10], device='cuda:0')，预测的设备号为:tensor([ 6,  6, 27,  9], device='cuda:0')
# [7, 100] acc: 0.11249999701976776
# [8, 100] loss: 3.9001208782196044
# 设备号为: tensor([49, 12, 20, 41], device='cuda:0')，预测的设备号为:tensor([25,  6, 25, 21], device='cuda:0')
# [8, 100] acc: 0.08249999582767487
# [9, 100] loss: 3.8403656220436098
# 设备号为: tensor([31, 25, 37, 16], device='cuda:0')，预测的设备号为:tensor([3, 6, 4, 6], device='cuda:0')
# [9, 100] acc: 0.0949999988079071
# [10, 100] loss: 3.7747622203826903
# 设备号为: tensor([25, 50, 44,  0], device='cuda:0')，预测的设备号为:tensor([6, 6, 6, 6], device='cuda:0')
# [10, 100] acc: 0.08249999582767487
# [11, 100] loss: 3.759617278575897
# 设备号为: tensor([31, 53, 12, 24], device='cuda:0')，预测的设备号为:tensor([6, 3, 6, 6], device='cuda:0')
# [11, 100] acc: 0.08249999582767487
# [12, 100] loss: 3.6910194325447083
# 设备号为: tensor([22, 43,  0, 45], device='cuda:0')，预测的设备号为:tensor([ 6,  3, 26,  6], device='cuda:0')
# [12, 100] acc: 0.07499999552965164
# [13, 100] loss: 3.602665293216705
# 设备号为: tensor([ 9, 13, 47, 25], device='cuda:0')，预测的设备号为:tensor([ 9,  3, 25,  4], device='cuda:0')
# [13, 100] acc: 0.10999999940395355
# [14, 100] loss: 3.533807752132416
# 设备号为: tensor([29, 26,  2, 48], device='cuda:0')，预测的设备号为:tensor([4, 4, 3, 6], device='cuda:0')
# [14, 100] acc: 0.12999999523162842
# [15, 100] loss: 3.512274363040924
# 设备号为: tensor([33, 41, 27,  8], device='cuda:0')，预测的设备号为:tensor([ 3, 25,  0, 25], device='cuda:0')
# [15, 100] acc: 0.1274999976158142
# [16, 100] loss: 3.41139652967453
# 设备号为: tensor([28, 25, 43, 23], device='cuda:0')，预测的设备号为:tensor([28,  9,  6,  6], device='cuda:0')
# [16, 100] acc: 0.14499999582767487
# [17, 100] loss: 3.386384274959564
# 设备号为: tensor([32, 46, 41, 52], device='cuda:0')，预测的设备号为:tensor([ 6, 25,  6, 21], device='cuda:0')
# [17, 100] acc: 0.16499999165534973
# [18, 100] loss: 3.3148283910751344
# 设备号为: tensor([11, 27, 15, 10], device='cuda:0')，预测的设备号为:tensor([11,  0,  4, 10], device='cuda:0')
# [18, 100] acc: 0.1850000023841858
# [19, 100] loss: 3.2250929033756255
# 设备号为: tensor([15, 25, 51, 36], device='cuda:0')，预测的设备号为:tensor([ 4,  4, 25,  3], device='cuda:0')
# [19, 100] acc: 0.2224999964237213
# [20, 100] loss: 3.189683668613434
# 设备号为: tensor([ 2,  8, 26, 18], device='cuda:0')，预测的设备号为:tensor([ 1, 25, 26, 11], device='cuda:0')
# [20, 100] acc: 0.19999998807907104
# [21, 100] loss: 3.1662279200553893
# 设备号为: tensor([23, 43, 23, 46], device='cuda:0')，预测的设备号为:tensor([25, 25, 25, 31], device='cuda:0')
# [21, 100] acc: 0.23499999940395355
# [22, 100] loss: 3.060891845226288
# 设备号为: tensor([21, 51,  2, 18], device='cuda:0')，预测的设备号为:tensor([25,  6, 10, 25], device='cuda:0')
# [22, 100] acc: 0.2474999874830246
# [23, 100] loss: 2.9418684995174407
# 设备号为: tensor([14, 53, 23,  0], device='cuda:0')，预测的设备号为:tensor([25,  6, 46, 26], device='cuda:0')
# [23, 100] acc: 0.2849999964237213
# [24, 100] loss: 2.916967148780823
# 设备号为: tensor([15, 20,  0, 39], device='cuda:0')，预测的设备号为:tensor([2, 3, 0, 4], device='cuda:0')
# [24, 100] acc: 0.29749998450279236
# [25, 100] loss: 2.923462859392166
# 设备号为: tensor([ 2, 30, 42, 52], device='cuda:0')，预测的设备号为:tensor([ 2, 25, 27, 25], device='cuda:0')
# [25, 100] acc: 0.2874999940395355
# [26, 100] loss: 2.8628090861439706
# 设备号为: tensor([12, 18, 20,  6], device='cuda:0')，预测的设备号为:tensor([ 1, 25, 27,  6], device='cuda:0')
# [26, 100] acc: 0.3075000047683716
# [27, 100] loss: 2.787707201242447
# 设备号为: tensor([ 4, 45, 18,  7], device='cuda:0')，预测的设备号为:tensor([ 4, 25, 27,  7], device='cuda:0')
# [27, 100] acc: 0.32999998331069946
# [28, 100] loss: 2.705827371478081
# 设备号为: tensor([38,  9, 31, 19], device='cuda:0')，预测的设备号为:tensor([38,  9, 31, 25], device='cuda:0')
# [28, 100] acc: 0.32999998331069946
# [29, 100] loss: 2.6966254514455796
# 设备号为: tensor([53,  5, 12, 53], device='cuda:0')，预测的设备号为:tensor([25,  5,  1,  6], device='cuda:0')
# [29, 100] acc: 0.35249999165534973
# [30, 100] loss: 2.6939566606283187
# 设备号为: tensor([33, 21, 19, 51], device='cuda:0')，预测的设备号为:tensor([33, 38, 21, 27], device='cuda:0')
# [30, 100] acc: 0.367499977350235
# [31, 100] loss: 2.6040647268295287
# 设备号为: tensor([35, 15, 24, 18], device='cuda:0')，预测的设备号为:tensor([35,  4, 25, 29], device='cuda:0')
# [31, 100] acc: 0.367499977350235
# [32, 100] loss: 2.5611531275510786
# 设备号为: tensor([28, 44, 35, 15], device='cuda:0')，预测的设备号为:tensor([28, 29, 35, 35], device='cuda:0')
# [32, 100] acc: 0.39249998331069946
# [33, 100] loss: 2.491793210580945
# 设备号为: tensor([33,  8, 26, 36], device='cuda:0')，预测的设备号为:tensor([39,  8, 26, 25], device='cuda:0')
# [33, 100] acc: 0.39249998331069946
# [34, 100] loss: 2.5533228028193116
# 设备号为: tensor([40, 28, 17, 35], device='cuda:0')，预测的设备号为:tensor([38, 28, 27, 35], device='cuda:0')
# [34, 100] acc: 0.38999998569488525
# [35, 100] loss: 2.480038957297802
# 设备号为: tensor([13, 35, 28, 21], device='cuda:0')，预测的设备号为:tensor([38, 35, 28, 27], device='cuda:0')
# [35, 100] acc: 0.3999999761581421
# [36, 100] loss: 2.5432881885766982
# 设备号为: tensor([ 2, 49,  9, 10], device='cuda:0')，预测的设备号为:tensor([ 2,  2,  9, 10], device='cuda:0')
# [36, 100] acc: 0.38499999046325684
# [37, 100] loss: 2.4386772889783606
# 设备号为: tensor([23, 31, 43, 16], device='cuda:0')，预测的设备号为:tensor([21, 31, 25, 27], device='cuda:0')
# [37, 100] acc: 0.42499998211860657
# [38, 100] loss: 2.4889310191618277
# 设备号为: tensor([40, 11, 30, 17], device='cuda:0')，预测的设备号为:tensor([36, 11, 32, 27], device='cuda:0')
# [38, 100] acc: 0.38999998569488525
# [39, 100] loss: 2.344993266053498
# 设备号为: tensor([27, 12, 43, 53], device='cuda:0')，预测的设备号为:tensor([34, 25, 25, 32], device='cuda:0')
# [39, 100] acc: 0.42499998211860657
# [40, 100] loss: 2.353481382057071
# 设备号为: tensor([13, 51, 15, 24], device='cuda:0')，预测的设备号为:tensor([27, 27, 15, 27], device='cuda:0')
# [40, 100] acc: 0.4399999976158142
# [41, 100] loss: 2.3215327307581903
# 设备号为: tensor([25,  1, 20, 10], device='cuda:0')，预测的设备号为:tensor([35,  1, 25, 10], device='cuda:0')
# [41, 100] acc: 0.4274999797344208
# [42, 100] loss: 2.248914797634352
# 设备号为: tensor([34, 19, 51, 23], device='cuda:0')，预测的设备号为:tensor([34, 27, 32, 27], device='cuda:0')
# [42, 100] acc: 0.4699999988079071
# [43, 100] loss: 2.385418434627354
# 设备号为: tensor([26, 30,  8, 43], device='cuda:0')，预测的设备号为:tensor([26, 27,  8, 36], device='cuda:0')
# [43, 100] acc: 0.4325000047683716
# [44, 100] loss: 2.3003210607916116
# 设备号为: tensor([40, 38, 20, 26], device='cuda:0')，预测的设备号为:tensor([38, 38, 38, 26], device='cuda:0')
# [44, 100] acc: 0.45749998092651367
# [45, 100] loss: 2.332239191532135
# 设备号为: tensor([ 9,  9, 26,  6], device='cuda:0')，预测的设备号为:tensor([ 9,  9, 26,  6], device='cuda:0')
# [45, 100] acc: 0.4375
# [46, 100] loss: 2.296136400150135
# 设备号为: tensor([24, 23, 39, 27], device='cuda:0')，预测的设备号为:tensor([27, 25, 39, 27], device='cuda:0')
# [46, 100] acc: 0.4375
# [47, 100] loss: 2.2253983598272318
# 设备号为: tensor([51, 22, 25, 13], device='cuda:0')，预测的设备号为:tensor([ 5, 25, 25, 39], device='cuda:0')
# [47, 100] acc: 0.4650000035762787
# [48, 100] loss: 2.1477141196386946
# 设备号为: tensor([30, 32, 31, 29], device='cuda:0')，预测的设备号为:tensor([30, 33, 31, 29], device='cuda:0')
# [48, 100] acc: 0.47999998927116394
# [49, 100] loss: 2.2407620185613633
# 设备号为: tensor([ 6, 10, 23, 22], device='cuda:0')，预测的设备号为:tensor([ 6, 10, 27, 21], device='cuda:0')
# [49, 100] acc: 0.4724999964237213
# [50, 100] loss: 2.1387421751953664
# 设备号为: tensor([45, 35,  5, 35], device='cuda:0')，预测的设备号为:tensor([25, 35,  5, 35], device='cuda:0')
# [50, 100] acc: 0.48749998211860657
# [51, 100] loss: 2.1786535427719356
# 设备号为: tensor([39, 19, 50, 52], device='cuda:0')，预测的设备号为:tensor([39, 27, 27, 27], device='cuda:0')
# [51, 100] acc: 0.48499998450279236
# [52, 100] loss: 2.142717293279711
# 设备号为: tensor([23, 40, 47, 32], device='cuda:0')，预测的设备号为:tensor([27, 27,  5, 32], device='cuda:0')
# [52, 100] acc: 0.47749999165534973
# [53, 100] loss: 2.14529934191145
# 设备号为: tensor([37, 51, 28, 28], device='cuda:0')，预测的设备号为:tensor([46, 27, 28, 28], device='cuda:0')
# [53, 100] acc: 0.4949999749660492
# [54, 100] loss: 2.1883989433199167
# 设备号为: tensor([23, 16, 13, 29], device='cuda:0')，预测的设备号为:tensor([22,  5, 25, 29], device='cuda:0')
# [54, 100] acc: 0.4899999797344208
# [55, 100] loss: 2.147885106652975
# 设备号为: tensor([49, 43, 38, 18], device='cuda:0')，预测的设备号为:tensor([25,  7, 38, 21], device='cuda:0')
# [55, 100] acc: 0.48249998688697815
# [56, 100] loss: 2.0176537679787727
# 设备号为: tensor([14, 15, 45,  8], device='cuda:0')，预测的设备号为:tensor([37, 15, 21,  8], device='cuda:0')
# [56, 100] acc: 0.5274999737739563
# [57, 100] loss: 2.0381541746109724
# 设备号为: tensor([ 6, 33, 12, 34], device='cuda:0')，预测的设备号为:tensor([ 6, 33, 25, 34], device='cuda:0')
# [57, 100] acc: 0.5174999833106995
# [58, 100] loss: 2.0453167264768854
# 设备号为: tensor([29, 23, 26, 25], device='cuda:0')，预测的设备号为:tensor([29, 37, 26, 25], device='cuda:0')
# [58, 100] acc: 0.5
# [59, 100] loss: 2.1120116737484933
# 设备号为: tensor([24, 49,  4, 10], device='cuda:0')，预测的设备号为:tensor([37, 27,  4, 10], device='cuda:0')
# [59, 100] acc: 0.5
# [60, 100] loss: 2.0118867046758533
# 设备号为: tensor([35, 24, 17, 14], device='cuda:0')，预测的设备号为:tensor([35,  5, 32, 38], device='cuda:0')
# [60, 100] acc: 0.5399999618530273
# [61, 100] loss: 2.0206889848015273
# 设备号为: tensor([29, 16, 44, 49], device='cuda:0')，预测的设备号为:tensor([29, 32, 29, 37], device='cuda:0')
# [61, 100] acc: 0.5324999690055847
# [62, 100] loss: 1.9925299472734332
# 设备号为: tensor([13, 16, 44, 27], device='cuda:0')，预测的设备号为:tensor([30, 20, 44, 27], device='cuda:0')
# [62, 100] acc: 0.5224999785423279
# [63, 100] loss: 2.0610011413725444
# 设备号为: tensor([22,  1, 18, 39], device='cuda:0')，预测的设备号为:tensor([21,  1, 21, 39], device='cuda:0')
# [63, 100] acc: 0.5174999833106995
# [64, 100] loss: 1.9616250012116507
# 设备号为: tensor([44, 13, 43, 41], device='cuda:0')，预测的设备号为:tensor([27, 15, 25, 29], device='cuda:0')
# [64, 100] acc: 0.5424999594688416
# [65, 100] loss: 1.9836251356080175
# 设备号为: tensor([35, 46, 44,  2], device='cuda:0')，预测的设备号为:tensor([35, 27, 44,  2], device='cuda:0')
# [65, 100] acc: 0.5074999928474426
# [66, 100] loss: 1.9707552427263
# 设备号为: tensor([18, 42, 34,  6], device='cuda:0')，预测的设备号为:tensor([37, 46, 34,  6], device='cuda:0')
# [66, 100] acc: 0.5399999618530273
# [67, 100] loss: 1.923759469985962
# 设备号为: tensor([28, 16,  3, 37], device='cuda:0')，预测的设备号为:tensor([28, 15,  3, 37], device='cuda:0')
# [67, 100] acc: 0.5475000143051147
# [68, 100] loss: 1.8868697068095208
# 设备号为: tensor([ 9, 23,  9, 32], device='cuda:0')，预测的设备号为:tensor([ 9, 32,  9, 32], device='cuda:0')
# [68, 100] acc: 0.5774999856948853
# [69, 100] loss: 1.8743220468657091
# 设备号为: tensor([47, 48, 36, 30], device='cuda:0')，预测的设备号为:tensor([21, 48, 36, 30], device='cuda:0')
# [69, 100] acc: 0.5699999928474426
# [70, 100] loss: 1.8411842718784464
# 设备号为: tensor([53,  3,  1, 46], device='cuda:0')，预测的设备号为:tensor([12,  3,  1, 46], device='cuda:0')
# [70, 100] acc: 0.574999988079071
# [71, 100] loss: 1.8540387213230018
# 设备号为: tensor([43,  7, 16, 44], device='cuda:0')，预测的设备号为:tensor([49,  7,  4, 44], device='cuda:0')
# [71, 100] acc: 0.5874999761581421
# [72, 100] loss: 1.8160675902602088
# 设备号为: tensor([31, 16, 49, 19], device='cuda:0')，预测的设备号为:tensor([31, 27, 16, 44], device='cuda:0')
# [72, 100] acc: 0.5824999809265137
# [73, 100] loss: 1.8561371282488108
# 设备号为: tensor([32, 42, 44,  6], device='cuda:0')，预测的设备号为:tensor([32, 25, 44,  6], device='cuda:0')
# [73, 100] acc: 0.5949999690055847
# [74, 100] loss: 1.8557250979542732
# 设备号为: tensor([43, 48, 41, 23], device='cuda:0')，预测的设备号为:tensor([46, 22, 29, 32], device='cuda:0')
# [74, 100] acc: 0.5575000047683716
# [75, 100] loss: 1.769365404242999
# 设备号为: tensor([18,  7, 45, 29], device='cuda:0')，预测的设备号为:tensor([40,  7, 41, 41], device='cuda:0')
# [75, 100] acc: 0.5974999666213989
# [76, 100] loss: 1.717811791103759
# 设备号为: tensor([41, 41, 31, 51], device='cuda:0')，预测的设备号为:tensor([29, 20, 31, 44], device='cuda:0')
# [76, 100] acc: 0.6074999570846558
# [77, 100] loss: 1.6727787252818234
# 设备号为: tensor([24, 33, 30, 10], device='cuda:0')，预测的设备号为:tensor([17, 33, 30, 10], device='cuda:0')
# [77, 100] acc: 0.6274999976158142
# [78, 100] loss: 1.7591913029365243
# 设备号为: tensor([42, 23, 17,  2], device='cuda:0')，预测的设备号为:tensor([ 1, 50, 13,  2], device='cuda:0')
# [78, 100] acc: 0.6175000071525574
# [79, 100] loss: 1.6571982347918675
# 设备号为: tensor([48, 12, 51, 45], device='cuda:0')，预测的设备号为:tensor([49,  2, 51, 23], device='cuda:0')
# [79, 100] acc: 0.6324999928474426
# [80, 100] loss: 1.733864592271857
# 设备号为: tensor([ 6, 39, 16, 29], device='cuda:0')，预测的设备号为:tensor([ 6, 39, 49, 29], device='cuda:0')
# [80, 100] acc: 0.5799999833106995
# [81, 100] loss: 1.6157840358564863
# 设备号为: tensor([44, 36, 40, 23], device='cuda:0')，预测的设备号为:tensor([44, 36, 11, 40], device='cuda:0')
# [81, 100] acc: 0.6324999928474426
# [82, 100] loss: 1.6453780566900968
# 设备号为: tensor([11, 12, 32, 16], device='cuda:0')，预测的设备号为:tensor([11, 12, 32, 24], device='cuda:0')
# [82, 100] acc: 0.6150000095367432
# [83, 100] loss: 1.5470070334870252
# 设备号为: tensor([20,  1, 46, 48], device='cuda:0')，预测的设备号为:tensor([44,  1, 46, 48], device='cuda:0')
# [83, 100] acc: 0.6449999809265137
# [84, 100] loss: 1.5668367361783748
# 设备号为: tensor([41, 33,  9, 41], device='cuda:0')，预测的设备号为:tensor([41, 33,  9, 41], device='cuda:0')
# [84, 100] acc: 0.6449999809265137
# [85, 100] loss: 1.5064501965510135
# 设备号为: tensor([14, 43, 17, 49], device='cuda:0')，预测的设备号为:tensor([19,  4,  7, 24], device='cuda:0')
# [85, 100] acc: 0.6524999737739563
# [86, 100] loss: 1.452921278361173
# 设备号为: tensor([51, 22, 25, 40], device='cuda:0')，预测的设备号为:tensor([51, 18, 25, 43], device='cuda:0')
# [86, 100] acc: 0.6574999690055847
# [87, 100] loss: 1.417630754562997
# 设备号为: tensor([18, 47, 11, 40], device='cuda:0')，预测的设备号为:tensor([22, 22, 11, 50], device='cuda:0')
# [87, 100] acc: 0.6574999690055847
# [88, 100] loss: 1.4355779357091523
# 设备号为: tensor([44, 28, 48, 11], device='cuda:0')，预测的设备号为:tensor([44, 28, 13, 11], device='cuda:0')
# [88, 100] acc: 0.6949999928474426
# [89, 100] loss: 1.3317445292358752
# 设备号为: tensor([ 5, 16, 35, 49], device='cuda:0')，预测的设备号为:tensor([ 5, 24, 35, 24], device='cuda:0')
# [89, 100] acc: 0.6800000071525574
# [90, 100] loss: 1.3495898691684125
# 设备号为: tensor([38, 20, 35, 15], device='cuda:0')，预测的设备号为:tensor([38, 20, 35, 15], device='cuda:0')
# [90, 100] acc: 0.6899999976158142
# [91, 100] loss: 1.3189794607547811
# 设备号为: tensor([ 8, 46, 11, 24], device='cuda:0')，预测的设备号为:tensor([ 8, 15, 11, 24], device='cuda:0')
# [91, 100] acc: 0.6949999928474426
# [92, 100] loss: 1.3483780645020307
# 设备号为: tensor([53, 23, 33, 51], device='cuda:0')，预测的设备号为:tensor([47, 16, 33, 51], device='cuda:0')
# [92, 100] acc: 0.6899999976158142
# [93, 100] loss: 1.1806271203728103
# 设备号为: tensor([21, 44,  6, 19], device='cuda:0')，预测的设备号为:tensor([21, 41,  6, 14], device='cuda:0')
# [93, 100] acc: 0.7174999713897705
# [94, 100] loss: 1.1749070486950222
# 设备号为: tensor([19, 34, 17, 50], device='cuda:0')，预测的设备号为:tensor([49, 34, 17, 50], device='cuda:0')
# [94, 100] acc: 0.7149999737739563
# [95, 100] loss: 1.1811934065446257
# 设备号为: tensor([36,  3, 27, 26], device='cuda:0')，预测的设备号为:tensor([36,  3, 27, 26], device='cuda:0')
# [95, 100] acc: 0.7174999713897705
# [96, 100] loss: 1.083388529488875
# 设备号为: tensor([12, 33,  8, 14], device='cuda:0')，预测的设备号为:tensor([12, 33,  8, 14], device='cuda:0')
# [96, 100] acc: 0.73499995470047
# [97, 100] loss: 1.054932661744242
# 设备号为: tensor([35, 22,  5, 44], device='cuda:0')，预测的设备号为:tensor([35, 50,  5, 44], device='cuda:0')
# [97, 100] acc: 0.7425000071525574
# [98, 100] loss: 0.9896098274190445
# 设备号为: tensor([ 0, 34, 47, 22], device='cuda:0')，预测的设备号为:tensor([ 0, 28, 22, 14], device='cuda:0')
# [98, 100] acc: 0.7475000023841858
# [99, 100] loss: 0.9225921776425093
# 设备号为: tensor([11, 20, 35, 23], device='cuda:0')，预测的设备号为:tensor([11, 20, 35, 32], device='cuda:0')
# [99, 100] acc: 0.7674999833106995
# [100, 100] loss: 0.928076735944851
# 设备号为: tensor([11, 11, 35, 47], device='cuda:0')，预测的设备号为:tensor([11, 11, 35, 17], device='cuda:0')
# [100, 100] acc: 0.7824999690055847

# %%
torch.cuda.current_device ()

# %%
aa = iter(train_loader)
a, b = aa.next()
print(a[0].shape)
print(a)

# %%
input = torch.randn(20, 16, 50, 100)
input.shape

# %%
m2=nn.Conv2d(16,33,(3,5),stride=(2,1),padding=(4,2))
inpu1=Variable(torch.randn(20,16,50,100))
print(inpu1.shape)
output=m2(inpu1)
print(output.shape)

# %%
total

# %%
torch.cuda.current_device ()

# %%
x = range(0, len(average_loss_series))
plt.figure()
plt.plot(x, average_loss_series)
plt.savefig("Loss10dB.png", bbox_inches="tight")
plt.show()
