# %%
import matplotlib.pyplot as plt
import torchvision as tv
from torchvision import transforms, utils


import torch.nn.functional as F
import torch 
import torch.nn as nn
from torch.autograd import Variable
import torchvision.models as models
# from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader
# from PIL import Image
# import numpy as np
import torch.optim as optim
# import os
import time

import loadData

# %%
device = torch.device("cuda:3")

# %%
# 日志记录模块2
import logging
logger = logging.getLogger(__name__)
logger.setLevel(level = logging.INFO)
handler = logging.FileHandler("./10dB-HHT最后四个没加-1500epoches-1")
handler.setLevel(logging.INFO)
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

console = logging.StreamHandler()
console.setLevel(logging.INFO)

logger.addHandler(handler)
logger.addHandler(console)

# %%
startTime = time.time()

# %%
transforms = tv.transforms.Compose([
    transforms.ToTensor(),
])


numOfBatch = 9
pixel = 64
flag = 0
root = f'./{numOfBatch}/data'
batchSize = 4
train_data = loadData.MyDataset(txt=f'files_train10-舍弃最后4个.txt', transform=None)
test_data = loadData.MyDataset(txt=f'files_test10-舍弃最后4个.txt', transform=None)



train_loader = DataLoader(dataset=train_data, batch_size=batchSize, shuffle=True, num_workers=2)
test_loader = DataLoader(dataset=test_data, batch_size=batchSize, shuffle=True, num_workers=2)


print(train_loader)
print(test_loader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7fd66704ad90>
# <torch.utils.data.dataloader.DataLoader object at 0x7fd6672247d0>

# %%
print(len(train_data))
print(len(test_loader))
# Out:
# 6426
# 419

# %%
# data = iter(train_loader)

# # print(type(data))
# # print(len(data))
# data_, label = data.next()
# print(train_loader.batch_size)
# print(data_.shape)
# # print(label)
# # print(data_, label)

# %%
x = torch.randn(4, 1, 1200, 2).float()
conv = nn.Conv2d(in_channels = 1, out_channels = 128, kernel_size = (10, 1))
x = conv(x)
x.shape
conv2 = nn.Conv2d(in_channels = 128, out_channels = 256, kernel_size = (3, 2))
x = conv2(x)
x.shape
# Out:
# torch.Size([4, 256, 1189, 1])

# %%
# 256*1189

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(in_channels = 1, out_channels = 8, kernel_size = (1, 10))
        self.conv2 = nn.Conv2d(in_channels = 8, out_channels = 16, kernel_size = (2, 3))
        
        self.dropout1 = nn.Dropout(0.5)
        self.dropout2 = nn.Dropout(0.5)
        
        self.fc1 = nn.Linear(20304, 1024)
        self.fc2 = nn.Linear(1024, 500)
        self.fc3 = nn.Linear(500, 54)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 1)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 1)
    
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.dropout1(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.dropout2(x)
        x = self.fc3(x)
        output = F.log_softmax(x, dim=1)
        return output

# %%
# TensorBoard
# from tensorboardX import SummaryWriter
# net = Net()
# # writer = SummaryWriter('writer928') #建立一个保存数据用的东西
# dummy_input = torch.rand(2,160,400)  # 假设输入20张1*28*28的图片
# with SummaryWriter(comment='Net1') as w:
#     w.add_graph(net, (dummy_input,))

# %%
net = Net()

net = net.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(params=net.parameters(), lr=0.0001, momentum=0.9)

epochs = 1500
average_loss_series = []

# %%
for a, b in enumerate(train_loader):
    inputs, labels = b
    print(inputs.shape)
    break
# Out:
# torch.Size([4, 1, 2, 1280])

# %%
# %matplotlib inline


if __name__ == '__main__':
    for epoch in range(epochs):
        running_loss = 0.0
        running_acc = 0.0

        for i, data in enumerate(train_loader):
#             print("i:", i )
#             print("data: ", data[0])
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()

#             inputs = inputs.permute(0, 2, 1)
            
            inputs = torch.tensor(inputs, dtype=torch.float32, device = device)

            outputs = net(inputs)
            _, predicted = torch.max(outputs.data, dim=1)
            total = labels.size(0)
#             print('原来的值:{0}, 预测的值:{1}'.format(labels, predicted))
            running_correct = (predicted == labels).sum()
            running_acc += running_correct
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            loss.backward()
            optimizer.step()

            # 每loopNum个batch打印一次训练状态
            loopNum = 1000
            if i % loopNum == loopNum - 1:
                average_loss = running_loss / loopNum
                logger.info('[{0}, {1}] loss: {2}'.format(epoch + 1, i + 1, average_loss))
                logger.info('设备号为: {0}，预测的设备号为:{1}'.format(labels, predicted))
#                 logger.info(torch.cuda.current_device ())
                running_acc = running_acc.float()
                average_acc = running_acc / loopNum / total
                
                logger.info('[{0}, {1}] acc: {2}'.format(epoch + 1, i + 1, average_acc))
                average_loss_series.append(average_loss)
                running_loss = 0.0
                running_acc = 0.0

    x = range(0, len(average_loss_series))
    plt.figure()
    plt.plot(x, average_loss_series)
#     plt.savefig("Loss.png")
    plt.savefig("Loss.png", bbox_inches="tight")
    plt.show()
    

    # %%
    # 在测试集上测试
    realLabel = []
    predictedLabel = []

    def correct_rate(net, testloader):
        correct = 0.0
        total = 0.0
        count = 0
        correctpredict = 0

        for data in testloader:
            images, labels = data
            images, labels = images.to(device),labels.to(device)
            realLabel.append([int(label) for label in labels])
    
            tests = torch.tensor(images, dtype=torch.float32,device=device)
            outputs = net(tests)

            _, predicted = torch.max(outputs.data, dim=1)
            logger.info('设备号为: {0}，模型训练后得到的设备号为:{1}'.format(labels, predicted))
#             deviceNumber = torch.cuda.current_device ()
#             logger.info(deviceNumber)
            
            labelsn = labels.cpu().numpy()
            pn = predicted.cpu().numpy()
            count += len(labelsn)
            
            for i in range(len(labelsn)):
                if labelsn[i] == pn[i]:
                    correctpredict += 1
                
            
            logger.info('目前一共测试了{0}组，预测成功的一共有{1}组'.format(count, correctpredict))
            predictedLabel.append([int(label) for label in predicted])
            
            total += labels.size(0)
            correct += (predicted == labels).sum()

            
        logger.info("total的值为：{total}")
#         return 100 * correct  # / total
        return 100 * correct/ total 


    correct = correct_rate(net, test_loader)
    logger.info(f'{len(test_loader) * 3}张测试集中准确率为： {correct}%')

    # %%
    import itertools
    from sklearn.metrics import confusion_matrix

    realLabel = list(itertools.chain.from_iterable(realLabel))
    predictedLabel = list(itertools.chain.from_iterable(predictedLabel))

    cm = confusion_matrix(realLabel, predictedLabel)
    logger.info(cm)

#     logger.info('the running time is:{1}'.format(time.time() - startTime))
    torch.save(net.state_dict(), f'./model_10dB_最后4个没加_1.pkl')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# [1, 1000] loss: 3.9890915706157686
# 设备号为: tensor([41,  4, 34, 30], device='cuda:3')，预测的设备号为:tensor([48, 51, 16, 51], device='cuda:3')
# [1, 1000] acc: 0.018250001594424248
# [2, 1000] loss: 3.9836384592056273
# 设备号为: tensor([45, 43,  5, 39], device='cuda:3')，预测的设备号为:tensor([20, 51, 36, 23], device='cuda:3')
# [2, 1000] acc: 0.026250001043081284
# [3, 1000] loss: 3.974081615924835
# 设备号为: tensor([17, 16, 29, 45], device='cuda:3')，预测的设备号为:tensor([ 3, 12, 50, 23], device='cuda:3')
# [3, 1000] acc: 0.030000001192092896
# [4, 1000] loss: 3.9502834153175352
# 设备号为: tensor([18, 14, 18, 37], device='cuda:3')，预测的设备号为:tensor([44, 22, 31, 24], device='cuda:3')
# [4, 1000] acc: 0.04700000211596489
# [5, 1000] loss: 3.865249157190323
# 设备号为: tensor([14, 18, 19, 24], device='cuda:3')，预测的设备号为:tensor([12, 14, 52, 45], device='cuda:3')
# [5, 1000] acc: 0.0507500022649765
# [6, 1000] loss: 3.5508981153964996
# 设备号为: tensor([37, 52, 45, 29], device='cuda:3')，预测的设备号为:tensor([46, 46, 52, 32], device='cuda:3')
# [6, 1000] acc: 0.057500001043081284
# [7, 1000] loss: 3.262386408805847
# 设备号为: tensor([52, 47, 37, 22], device='cuda:3')，预测的设备号为:tensor([12, 14, 52, 49], device='cuda:3')
# [7, 1000] acc: 0.08550000190734863
# [8, 1000] loss: 3.104497541308403
# 设备号为: tensor([12, 35, 16, 52], device='cuda:3')，预测的设备号为:tensor([23,  7, 51, 46], device='cuda:3')
# [8, 1000] acc: 0.11175000667572021
# [9, 1000] loss: 2.9780014488697053
# 设备号为: tensor([ 6, 39, 42, 14], device='cuda:3')，预测的设备号为:tensor([26,  0, 49, 14], device='cuda:3')
# [9, 1000] acc: 0.132750004529953
# [10, 1000] loss: 2.89047522521019
# 设备号为: tensor([27, 35, 15, 28], device='cuda:3')，预测的设备号为:tensor([ 7, 17, 46,  1], device='cuda:3')
# [10, 1000] acc: 0.13650000095367432
# [11, 1000] loss: 2.784303794026375
# 设备号为: tensor([42, 39,  7, 35], device='cuda:3')，预测的设备号为:tensor([51,  9,  9, 11], device='cuda:3')
# [11, 1000] acc: 0.1665000021457672
# [12, 1000] loss: 2.7181427035331724
# 设备号为: tensor([42, 22, 52, 31], device='cuda:3')，预测的设备号为:tensor([42, 42, 53,  4], device='cuda:3')
# [12, 1000] acc: 0.17150001227855682
# [13, 1000] loss: 2.6352086403369905
# 设备号为: tensor([13, 19, 52, 12], device='cuda:3')，预测的设备号为:tensor([51, 40, 53, 53], device='cuda:3')
# [13, 1000] acc: 0.18250000476837158
# [14, 1000] loss: 2.5335429641008376
# 设备号为: tensor([19, 22, 12, 26], device='cuda:3')，预测的设备号为:tensor([51, 18, 37, 26], device='cuda:3')
# [14, 1000] acc: 0.1980000138282776
# [15, 1000] loss: 2.4447328592538833
# 设备号为: tensor([45,  6,  6, 29], device='cuda:3')，预测的设备号为:tensor([46,  6,  6, 35], device='cuda:3')
# [15, 1000] acc: 0.23075000941753387
# [16, 1000] loss: 2.3018422442674638
# 设备号为: tensor([38, 26, 53,  1], device='cuda:3')，预测的设备号为:tensor([25, 26, 53,  6], device='cuda:3')
# [16, 1000] acc: 0.25200000405311584
# [17, 1000] loss: 2.178679473221302
# 设备号为: tensor([14, 48,  0,  1], device='cuda:3')，预测的设备号为:tensor([51, 48,  1,  1], device='cuda:3')
# [17, 1000] acc: 0.28675001859664917
# [18, 1000] loss: 2.075448340892792
# 设备号为: tensor([44, 30, 23, 47], device='cuda:3')，预测的设备号为:tensor([15, 30, 14, 14], device='cuda:3')
# [18, 1000] acc: 0.3147500157356262
# [19, 1000] loss: 2.0024026384949685
# 设备号为: tensor([12, 46,  4, 52], device='cuda:3')，预测的设备号为:tensor([12, 45,  4, 52], device='cuda:3')
# [19, 1000] acc: 0.33150002360343933
# [20, 1000] loss: 1.891547686457634
# 设备号为: tensor([16, 41,  0, 31], device='cuda:3')，预测的设备号为:tensor([23, 51,  0, 28], device='cuda:3')
# [20, 1000] acc: 0.3472500145435333
# [21, 1000] loss: 1.8948795792460442
# 设备号为: tensor([40,  2, 11,  6], device='cuda:3')，预测的设备号为:tensor([49,  4, 36,  6], device='cuda:3')
# [21, 1000] acc: 0.35750001668930054
# [22, 1000] loss: 1.8153278669714927
# 设备号为: tensor([ 7, 14, 27, 48], device='cuda:3')，预测的设备号为:tensor([39, 20,  3, 48], device='cuda:3')
# [22, 1000] acc: 0.3737500309944153
# [23, 1000] loss: 1.7397559152543545
# 设备号为: tensor([27, 11, 11,  5], device='cuda:3')，预测的设备号为:tensor([28, 11, 11,  5], device='cuda:3')
# [23, 1000] acc: 0.39650002121925354
# [24, 1000] loss: 1.6797441225349903
# 设备号为: tensor([17,  3, 43,  4], device='cuda:3')，预测的设备号为:tensor([42, 11, 42,  4], device='cuda:3')
# [24, 1000] acc: 0.42750000953674316
# [25, 1000] loss: 1.6496455661952496
# 设备号为: tensor([28, 46, 18,  0], device='cuda:3')，预测的设备号为:tensor([28, 46, 49,  5], device='cuda:3')
# [25, 1000] acc: 0.42250001430511475
# [26, 1000] loss: 1.582383573293686
# 设备号为: tensor([46, 40, 20, 34], device='cuda:3')，预测的设备号为:tensor([46, 19, 14, 34], device='cuda:3')
# [26, 1000] acc: 0.460500031709671
# [27, 1000] loss: 1.4957519549801945
# 设备号为: tensor([44, 29, 30, 32], device='cuda:3')，预测的设备号为:tensor([53, 35, 30, 31], device='cuda:3')
# [27, 1000] acc: 0.48625001311302185
# [28, 1000] loss: 1.479595455482602
# 设备号为: tensor([26, 51, 48, 24], device='cuda:3')，预测的设备号为:tensor([26, 47, 48, 23], device='cuda:3')
# [28, 1000] acc: 0.4817500114440918
# [29, 1000] loss: 1.4405553172826766
# 设备号为: tensor([38, 12, 18, 48], device='cuda:3')，预测的设备号为:tensor([ 1, 15, 47, 48], device='cuda:3')
# [29, 1000] acc: 0.5002500414848328
# [30, 1000] loss: 1.375324490197003
# 设备号为: tensor([ 7, 47, 10, 50], device='cuda:3')，预测的设备号为:tensor([ 7, 18, 28, 51], device='cuda:3')
# [30, 1000] acc: 0.5097500085830688
# [31, 1000] loss: 1.3493890436664224
# 设备号为: tensor([12, 45, 10, 49], device='cuda:3')，预测的设备号为:tensor([12, 45,  8, 18], device='cuda:3')
# [31, 1000] acc: 0.5245000123977661
# [32, 1000] loss: 1.2972594641447068
# 设备号为: tensor([44, 21, 35, 53], device='cuda:3')，预测的设备号为:tensor([52, 51, 29, 53], device='cuda:3')
# [32, 1000] acc: 0.550000011920929
# [33, 1000] loss: 1.2673636304088869
# 设备号为: tensor([12, 34, 30,  5], device='cuda:3')，预测的设备号为:tensor([24, 34, 30,  5], device='cuda:3')
# [33, 1000] acc: 0.5625
# [34, 1000] loss: 1.230488941233605
# 设备号为: tensor([38, 11, 42, 40], device='cuda:3')，预测的设备号为:tensor([38, 11, 42, 50], device='cuda:3')
# [34, 1000] acc: 0.5757500529289246
# [35, 1000] loss: 1.2129184395936319
# 设备号为: tensor([11, 45, 40, 39], device='cuda:3')，预测的设备号为:tensor([34, 45, 18, 34], device='cuda:3')
# [35, 1000] acc: 0.5752500295639038
# [36, 1000] loss: 1.1618827799297868
# 设备号为: tensor([25, 37, 42, 19], device='cuda:3')，预测的设备号为:tensor([25, 37, 41, 19], device='cuda:3')
# [36, 1000] acc: 0.6002500057220459
# [37, 1000] loss: 1.1616127406992018
# 设备号为: tensor([44, 31,  1, 40], device='cuda:3')，预测的设备号为:tensor([46, 31,  1, 18], device='cuda:3')
# [37, 1000] acc: 0.5990000367164612
# [38, 1000] loss: 1.1169217812232672
# 设备号为: tensor([ 1,  9, 16, 45], device='cuda:3')，预测的设备号为:tensor([ 1,  9, 14, 45], device='cuda:3')
# [38, 1000] acc: 0.6082500219345093
# [39, 1000] loss: 1.0998814674206079
# 设备号为: tensor([ 7, 25, 13, 10], device='cuda:3')，预测的设备号为:tensor([ 7, 25, 13, 10], device='cuda:3')
# [39, 1000] acc: 0.60875004529953
# [40, 1000] loss: 1.076261345891282
# 设备号为: tensor([14,  2, 39,  9], device='cuda:3')，预测的设备号为:tensor([14,  2, 39,  9], device='cuda:3')
# [40, 1000] acc: 0.6212500333786011
# [41, 1000] loss: 1.0649419439453631
# 设备号为: tensor([48, 28, 19, 52], device='cuda:3')，预测的设备号为:tensor([48, 28, 47, 45], device='cuda:3')
# [41, 1000] acc: 0.6160000562667847
# [42, 1000] loss: 1.0511274045086465
# 设备号为: tensor([ 3, 14, 12, 26], device='cuda:3')，预测的设备号为:tensor([ 3, 14, 23, 26], device='cuda:3')
# [42, 1000] acc: 0.6310000419616699
# [43, 1000] loss: 1.015715347532183
# 设备号为: tensor([ 0, 18, 19,  9], device='cuda:3')，预测的设备号为:tensor([ 0, 47, 20,  1], device='cuda:3')
# [43, 1000] acc: 0.6480000019073486
# [44, 1000] loss: 1.0053320769127458
# 设备号为: tensor([21,  0, 39, 32], device='cuda:3')，预测的设备号为:tensor([40,  0,  3, 32], device='cuda:3')
# [44, 1000] acc: 0.6562500596046448
# [45, 1000] loss: 0.996017458293587
# 设备号为: tensor([ 5, 29, 53, 36], device='cuda:3')，预测的设备号为:tensor([ 6, 35, 53, 11], device='cuda:3')
# [45, 1000] acc: 0.6500000357627869
# [46, 1000] loss: 0.9743516261884942
# 设备号为: tensor([ 2, 10,  2, 47], device='cuda:3')，预测的设备号为:tensor([35, 10, 35, 43], device='cuda:3')
# [46, 1000] acc: 0.6542500257492065
# [47, 1000] loss: 0.9207334400175605
# 设备号为: tensor([43, 17, 38,  9], device='cuda:3')，预测的设备号为:tensor([41, 17, 33, 33], device='cuda:3')
# [47, 1000] acc: 0.6832500100135803
# [48, 1000] loss: 0.9340199728552252
# 设备号为: tensor([14, 45,  0, 15], device='cuda:3')，预测的设备号为:tensor([14, 45,  0, 15], device='cuda:3')
# [48, 1000] acc: 0.6687500476837158
# [49, 1000] loss: 0.9439227399267256
# 设备号为: tensor([25,  1, 36, 16], device='cuda:3')，预测的设备号为:tensor([25,  1, 36, 20], device='cuda:3')
# [49, 1000] acc: 0.6702500581741333
# [50, 1000] loss: 0.9069219675813801
# 设备号为: tensor([ 1, 47, 51, 31], device='cuda:3')，预测的设备号为:tensor([ 1, 47, 42, 31], device='cuda:3')
# [50, 1000] acc: 0.6850000619888306
# [51, 1000] loss: 0.9189319665748626
# 设备号为: tensor([12, 13, 51,  0], device='cuda:3')，预测的设备号为:tensor([14, 49, 16,  0], device='cuda:3')
# [51, 1000] acc: 0.6757500171661377
# [52, 1000] loss: 0.8860157359261066
# 设备号为: tensor([19, 41, 45, 15], device='cuda:3')，预测的设备号为:tensor([18, 20, 45, 53], device='cuda:3')
# [52, 1000] acc: 0.687250018119812
# [53, 1000] loss: 0.8827660868680105
# 设备号为: tensor([33, 48,  7, 20], device='cuda:3')，预测的设备号为:tensor([38, 48,  7, 22], device='cuda:3')
# [53, 1000] acc: 0.6840000152587891
# [54, 1000] loss: 0.8396728094546124
# 设备号为: tensor([32, 10,  5, 40], device='cuda:3')，预测的设备号为:tensor([32,  9,  5, 40], device='cuda:3')
# [54, 1000] acc: 0.6962500214576721
# [55, 1000] loss: 0.8527278736121953
# 设备号为: tensor([23, 25, 25, 13], device='cuda:3')，预测的设备号为:tensor([24, 25, 31, 13], device='cuda:3')
# [55, 1000] acc: 0.7000000476837158
# [56, 1000] loss: 0.8253365302500315
# 设备号为: tensor([ 6, 37, 30, 13], device='cuda:3')，预测的设备号为:tensor([ 6, 37, 30, 13], device='cuda:3')
# [56, 1000] acc: 0.7120000123977661
# [57, 1000] loss: 0.829497865180485
# 设备号为: tensor([45,  9, 52, 16], device='cuda:3')，预测的设备号为:tensor([45,  9, 52, 22], device='cuda:3')
# [57, 1000] acc: 0.7072500586509705
# [58, 1000] loss: 0.8185926027791575
# 设备号为: tensor([35, 51, 24, 18], device='cuda:3')，预测的设备号为:tensor([35, 19, 24, 19], device='cuda:3')
# [58, 1000] acc: 0.7070000171661377
# [59, 1000] loss: 0.7797128405491821
# 设备号为: tensor([41,  4, 51, 36], device='cuda:3')，预测的设备号为:tensor([42,  4, 41, 36], device='cuda:3')
# [59, 1000] acc: 0.7225000262260437
# [60, 1000] loss: 0.7869932135888376
# 设备号为: tensor([22,  5, 53, 46], device='cuda:3')，预测的设备号为:tensor([22,  5, 53, 46], device='cuda:3')
# [60, 1000] acc: 0.7327500581741333
# [61, 1000] loss: 0.7896112753772176
# 设备号为: tensor([11,  6, 32,  3], device='cuda:3')，预测的设备号为:tensor([11,  6, 32, 36], device='cuda:3')
# [61, 1000] acc: 0.7117500305175781
# [62, 1000] loss: 0.7545482683326118
# 设备号为: tensor([ 0,  0, 50, 22], device='cuda:3')，预测的设备号为:tensor([ 0,  0, 50, 19], device='cuda:3')
# [62, 1000] acc: 0.7260000109672546
# [63, 1000] loss: 0.7412505030524917
# 设备号为: tensor([28, 10,  5, 25], device='cuda:3')，预测的设备号为:tensor([28, 33,  5, 25], device='cuda:3')
# [63, 1000] acc: 0.7287500500679016
# [64, 1000] loss: 0.7123441934816074
# 设备号为: tensor([37,  1, 20, 36], device='cuda:3')，预测的设备号为:tensor([37,  1, 14, 36], device='cuda:3')
# [64, 1000] acc: 0.7442500591278076
# [65, 1000] loss: 0.7242379970187321
# 设备号为: tensor([ 6, 11, 40, 40], device='cuda:3')，预测的设备号为:tensor([ 6, 11, 51, 21], device='cuda:3')
# [65, 1000] acc: 0.7360000610351562
# [66, 1000] loss: 0.7080103445458226
# 设备号为: tensor([27, 10, 30,  1], device='cuda:3')，预测的设备号为:tensor([ 3, 10, 30,  1], device='cuda:3')
# [66, 1000] acc: 0.752750039100647
# [67, 1000] loss: 0.714807327444607
# 设备号为: tensor([ 7, 33,  5, 38], device='cuda:3')，预测的设备号为:tensor([ 7, 33,  5, 38], device='cuda:3')
# [67, 1000] acc: 0.7457500100135803
# [68, 1000] loss: 0.6895921373697929
# 设备号为: tensor([ 0, 30,  2, 30], device='cuda:3')，预测的设备号为:tensor([ 0, 30,  2, 30], device='cuda:3')
# [68, 1000] acc: 0.7605000138282776
# [69, 1000] loss: 0.6865694471178576
# 设备号为: tensor([38, 11,  2, 22], device='cuda:3')，预测的设备号为:tensor([38, 36,  2, 20], device='cuda:3')
# [69, 1000] acc: 0.7637500166893005
# [70, 1000] loss: 0.6783163404129445
# 设备号为: tensor([47, 17,  7, 33], device='cuda:3')，预测的设备号为:tensor([19, 17,  7, 33], device='cuda:3')
# [70, 1000] acc: 0.7630000114440918
# [71, 1000] loss: 0.6578562143580057
# 设备号为: tensor([ 7, 34, 20, 39], device='cuda:3')，预测的设备号为:tensor([ 7,  4, 20, 34], device='cuda:3')
# [71, 1000] acc: 0.7662500143051147
# [72, 1000] loss: 0.6505918691148982
# 设备号为: tensor([19, 16, 37, 48], device='cuda:3')，预测的设备号为:tensor([18, 20, 37, 48], device='cuda:3')
# [72, 1000] acc: 0.7690000534057617
# [73, 1000] loss: 0.6236058635483496
# 设备号为: tensor([36, 25, 51, 46], device='cuda:3')，预测的设备号为:tensor([36, 25, 21, 46], device='cuda:3')
# [73, 1000] acc: 0.7777500152587891
# [74, 1000] loss: 0.5953512152918556
# 设备号为: tensor([26, 47,  0, 20], device='cuda:3')，预测的设备号为:tensor([26, 43,  0, 19], device='cuda:3')
# [74, 1000] acc: 0.7830000519752502
# [75, 1000] loss: 0.6195262271059618
# 设备号为: tensor([18, 44,  3, 29], device='cuda:3')，预测的设备号为:tensor([18, 44,  3, 29], device='cuda:3')
# [75, 1000] acc: 0.7817500233650208
# [76, 1000] loss: 0.6131219014271337
# 设备号为: tensor([24, 16, 39, 41], device='cuda:3')，预测的设备号为:tensor([12, 20,  2, 49], device='cuda:3')
# [76, 1000] acc: 0.7830000519752502
# [77, 1000] loss: 0.574171301746479
# 设备号为: tensor([25, 32, 35, 46], device='cuda:3')，预测的设备号为:tensor([25, 32, 29, 46], device='cuda:3')
# [77, 1000] acc: 0.7952500581741333
# [78, 1000] loss: 0.5926869398720446
# 设备号为: tensor([48, 46, 11, 16], device='cuda:3')，预测的设备号为:tensor([48, 46, 11, 49], device='cuda:3')
# [78, 1000] acc: 0.7912500500679016
# [79, 1000] loss: 0.557486746679293
# 设备号为: tensor([44, 43, 30, 26], device='cuda:3')，预测的设备号为:tensor([44, 43, 30, 26], device='cuda:3')
# [79, 1000] acc: 0.7980000376701355
# [80, 1000] loss: 0.5529744016053737
# 设备号为: tensor([17, 42, 21,  7], device='cuda:3')，预测的设备号为:tensor([17, 42, 21,  7], device='cuda:3')
# [80, 1000] acc: 0.7975000143051147
# [81, 1000] loss: 0.5580620906654512
# 设备号为: tensor([10, 45, 19, 22], device='cuda:3')，预测的设备号为:tensor([10, 45, 47, 20], device='cuda:3')
# [81, 1000] acc: 0.7975000143051147
# [82, 1000] loss: 0.5413642624402418
# 设备号为: tensor([24,  5, 26,  6], device='cuda:3')，预测的设备号为:tensor([24,  5, 26,  6], device='cuda:3')
# [82, 1000] acc: 0.7985000610351562
# [83, 1000] loss: 0.5458252951049944
# 设备号为: tensor([45,  6, 11, 36], device='cuda:3')，预测的设备号为:tensor([45,  6, 39, 36], device='cuda:3')
# [83, 1000] acc: 0.8050000667572021
# [84, 1000] loss: 0.5352079852267634
# 设备号为: tensor([27, 46,  1, 31], device='cuda:3')，预测的设备号为:tensor([27, 46,  1, 31], device='cuda:3')
# [84, 1000] acc: 0.8092500567436218
# [85, 1000] loss: 0.5210622957164888
# 设备号为: tensor([39, 49, 46, 49], device='cuda:3')，预测的设备号为:tensor([11, 49, 44, 50], device='cuda:3')
# [85, 1000] acc: 0.8142500519752502
# [86, 1000] loss: 0.4951637335902778
# 设备号为: tensor([40,  8, 18, 40], device='cuda:3')，预测的设备号为:tensor([40,  6, 18, 40], device='cuda:3')
# [86, 1000] acc: 0.8247500658035278
# [87, 1000] loss: 0.4913470750564884
# 设备号为: tensor([22, 12, 49,  3], device='cuda:3')，预测的设备号为:tensor([23, 12, 49,  3], device='cuda:3')
# [87, 1000] acc: 0.827750027179718
# [88, 1000] loss: 0.4838319150984171
# 设备号为: tensor([43, 46,  0,  1], device='cuda:3')，预测的设备号为:tensor([43, 46,  0,  1], device='cuda:3')
# [88, 1000] acc: 0.82750004529953
# [89, 1000] loss: 0.4646153180528199
# 设备号为: tensor([26, 16, 14, 29], device='cuda:3')，预测的设备号为:tensor([26, 16, 14, 29], device='cuda:3')
# [89, 1000] acc: 0.8327500224113464
# [90, 1000] loss: 0.4828280221402529
# 设备号为: tensor([40, 32, 28, 45], device='cuda:3')，预测的设备号为:tensor([40, 32, 28, 45], device='cuda:3')
# [90, 1000] acc: 0.8270000219345093
# [91, 1000] loss: 0.46590924889734014
# 设备号为: tensor([ 6, 36, 26, 20], device='cuda:3')，预测的设备号为:tensor([ 6, 36, 26, 22], device='cuda:3')
# [91, 1000] acc: 0.8325000405311584
# [92, 1000] loss: 0.4444755617653427
# 设备号为: tensor([38,  2, 21, 36], device='cuda:3')，预测的设备号为:tensor([38,  2, 41, 36], device='cuda:3')
# [92, 1000] acc: 0.8410000205039978
# [93, 1000] loss: 0.44652688954689074
# 设备号为: tensor([50, 40, 12, 21], device='cuda:3')，预测的设备号为:tensor([50, 49, 12, 51], device='cuda:3')
# [93, 1000] acc: 0.8452500104904175
# [94, 1000] loss: 0.4346947637175617
# 设备号为: tensor([22, 24,  4, 39], device='cuda:3')，预测的设备号为:tensor([20, 24,  4, 39], device='cuda:3')
# [94, 1000] acc: 0.8402500152587891
# [95, 1000] loss: 0.40645974205018137
# 设备号为: tensor([36, 35, 38, 18], device='cuda:3')，预测的设备号为:tensor([36, 35, 38, 18], device='cuda:3')
# [95, 1000] acc: 0.8517500162124634
# [96, 1000] loss: 0.43167448474356207
# 设备号为: tensor([30, 43, 40, 24], device='cuda:3')，预测的设备号为:tensor([30, 43, 40, 24], device='cuda:3')
# [96, 1000] acc: 0.8485000133514404
# [97, 1000] loss: 0.41948866123090556
# 设备号为: tensor([ 3, 29, 13,  0], device='cuda:3')，预测的设备号为:tensor([ 3, 29, 13,  0], device='cuda:3')
# [97, 1000] acc: 0.8497500419616699
# [98, 1000] loss: 0.416481840055465
# 设备号为: tensor([37, 18, 53, 51], device='cuda:3')，预测的设备号为:tensor([37, 18, 53, 21], device='cuda:3')
# [98, 1000] acc: 0.8517500162124634
# [99, 1000] loss: 0.39979638927121414
# 设备号为: tensor([46, 42, 10, 43], device='cuda:3')，预测的设备号为:tensor([46, 42, 10, 43], device='cuda:3')
# [99, 1000] acc: 0.8642500638961792
# [100, 1000] loss: 0.39559630526340334
# 设备号为: tensor([31, 40, 36,  2], device='cuda:3')，预测的设备号为:tensor([31, 40, 36,  2], device='cuda:3')
# [100, 1000] acc: 0.8600000143051147
# [101, 1000] loss: 0.38292696674214677
# 设备号为: tensor([ 4, 14, 52, 51], device='cuda:3')，预测的设备号为:tensor([ 4, 14, 52, 51], device='cuda:3')
# [101, 1000] acc: 0.8637500405311584
# [102, 1000] loss: 0.3694684123954357
# 设备号为: tensor([22, 48, 32, 41], device='cuda:3')，预测的设备号为:tensor([20, 48, 32, 49], device='cuda:3')
# [102, 1000] acc: 0.8705000281333923
# [103, 1000] loss: 0.3599418395863904
# 设备号为: tensor([45, 29, 52, 48], device='cuda:3')，预测的设备号为:tensor([45, 29, 52, 48], device='cuda:3')
# [103, 1000] acc: 0.8692500591278076
# [104, 1000] loss: 0.3538284000270942
# 设备号为: tensor([39, 46, 30, 27], device='cuda:3')，预测的设备号为:tensor([39, 46, 30, 27], device='cuda:3')
# [104, 1000] acc: 0.8697500228881836
# [105, 1000] loss: 0.36144111332151807
# 设备号为: tensor([12, 48,  6, 11], device='cuda:3')，预测的设备号为:tensor([12, 48,  6, 34], device='cuda:3')
# [105, 1000] acc: 0.8697500228881836
# [106, 1000] loss: 0.3484965958374669
# 设备号为: tensor([33,  2, 38, 24], device='cuda:3')，预测的设备号为:tensor([25,  2, 36, 24], device='cuda:3')
# [106, 1000] acc: 0.8820000290870667
# [107, 1000] loss: 0.3164848833133874
# 设备号为: tensor([44, 30, 37, 15], device='cuda:3')，预测的设备号为:tensor([44, 30, 37, 15], device='cuda:3')
# [107, 1000] acc: 0.8855000138282776
# [108, 1000] loss: 0.3055086511686386
# 设备号为: tensor([22,  2,  8, 29], device='cuda:3')，预测的设备号为:tensor([20,  2,  5, 29], device='cuda:3')
# [108, 1000] acc: 0.8887500166893005
# [109, 1000] loss: 0.3088051332390678
# 设备号为: tensor([ 2, 10, 41, 18], device='cuda:3')，预测的设备号为:tensor([ 2, 10, 41, 20], device='cuda:3')
# [109, 1000] acc: 0.8865000605583191
# [110, 1000] loss: 0.30820491379985654
# 设备号为: tensor([27, 36,  8, 21], device='cuda:3')，预测的设备号为:tensor([27, 36,  8, 21], device='cuda:3')
# [110, 1000] acc: 0.8885000348091125
# [111, 1000] loss: 0.3079342461643828
# 设备号为: tensor([22, 15, 26, 22], device='cuda:3')，预测的设备号为:tensor([20, 15, 26, 22], device='cuda:3')
# [111, 1000] acc: 0.8877500295639038
# [112, 1000] loss: 0.286597646277507
# 设备号为: tensor([48, 20, 32,  9], device='cuda:3')，预测的设备号为:tensor([48, 22, 32,  9], device='cuda:3')
# [112, 1000] acc: 0.9000000357627869
# [113, 1000] loss: 0.28028675687007854
# 设备号为: tensor([21, 44, 40, 32], device='cuda:3')，预测的设备号为:tensor([51, 44, 49, 32], device='cuda:3')
# [113, 1000] acc: 0.9000000357627869
# [114, 1000] loss: 0.2717117606908578
# 设备号为: tensor([19, 53, 34, 51], device='cuda:3')，预测的设备号为:tensor([47, 53, 34, 51], device='cuda:3')
# [114, 1000] acc: 0.9105000495910645
# [115, 1000] loss: 0.2700820444880301
# 设备号为: tensor([40, 32, 17, 52], device='cuda:3')，预测的设备号为:tensor([40, 32, 17, 52], device='cuda:3')
# [115, 1000] acc: 0.905250072479248
# [116, 1000] loss: 0.26581620163374464
# 设备号为: tensor([48, 47,  0, 42], device='cuda:3')，预测的设备号为:tensor([48, 47,  0, 42], device='cuda:3')
# [116, 1000] acc: 0.9002500176429749
# [117, 1000] loss: 0.26879083227846423
# 设备号为: tensor([29, 30,  6, 39], device='cuda:3')，预测的设备号为:tensor([29, 30,  6, 39], device='cuda:3')
# [117, 1000] acc: 0.9072500467300415
# [118, 1000] loss: 0.2536159343269612
# 设备号为: tensor([ 2, 44, 10, 53], device='cuda:3')，预测的设备号为:tensor([29, 15, 10, 53], device='cuda:3')
# [118, 1000] acc: 0.9112500548362732
# [119, 1000] loss: 0.2670047187449454
# 设备号为: tensor([33, 25, 26, 19], device='cuda:3')，预测的设备号为:tensor([33, 33, 26, 19], device='cuda:3')
# [119, 1000] acc: 0.9030000567436218
# [120, 1000] loss: 0.2490281202320839
# 设备号为: tensor([23, 39, 38, 23], device='cuda:3')，预测的设备号为:tensor([23,  4, 38, 23], device='cuda:3')
# [120, 1000] acc: 0.9160000681877136
# [121, 1000] loss: 0.23331334206693283
# 设备号为: tensor([ 1,  0, 25, 44], device='cuda:3')，预测的设备号为:tensor([ 0,  0, 25, 44], device='cuda:3')
# [121, 1000] acc: 0.9205000400543213
# [122, 1000] loss: 0.22388970966867056
# 设备号为: tensor([ 3, 24,  3, 17], device='cuda:3')，预测的设备号为:tensor([ 3, 24,  3, 17], device='cuda:3')
# [122, 1000] acc: 0.9207500219345093
# [123, 1000] loss: 0.23798595085745727
# 设备号为: tensor([19, 40, 13, 40], device='cuda:3')，预测的设备号为:tensor([19, 40, 13, 40], device='cuda:3')
# [123, 1000] acc: 0.9167500138282776
# [124, 1000] loss: 0.21777571003457705
# 设备号为: tensor([36, 23, 23, 42], device='cuda:3')，预测的设备号为:tensor([36, 23, 23, 42], device='cuda:3')
# [124, 1000] acc: 0.9230000376701355
# [125, 1000] loss: 0.21767401409693343
# 设备号为: tensor([36, 11, 20, 16], device='cuda:3')，预测的设备号为:tensor([36, 11, 18, 16], device='cuda:3')
# [125, 1000] acc: 0.9287500381469727
# [126, 1000] loss: 0.21295200861545163
# 设备号为: tensor([16, 29, 20, 42], device='cuda:3')，预测的设备号为:tensor([16, 29, 20, 42], device='cuda:3')
# [126, 1000] acc: 0.9267500638961792
# [127, 1000] loss: 0.2221060331356075
# 设备号为: tensor([16, 20, 42,  6], device='cuda:3')，预测的设备号为:tensor([16, 51, 42,  6], device='cuda:3')
# [127, 1000] acc: 0.9230000376701355
# [128, 1000] loss: 0.20990428531156793
# 设备号为: tensor([25, 31, 39, 26], device='cuda:3')，预测的设备号为:tensor([25, 31, 39, 26], device='cuda:3')
# [128, 1000] acc: 0.9300000667572021
# [129, 1000] loss: 0.1892229388318574
# 设备号为: tensor([23, 51, 25, 32], device='cuda:3')，预测的设备号为:tensor([23, 51, 25, 32], device='cuda:3')
# [129, 1000] acc: 0.9347500205039978
# [130, 1000] loss: 0.18804604955519608
# 设备号为: tensor([52, 34, 13, 25], device='cuda:3')，预测的设备号为:tensor([45, 34, 13, 25], device='cuda:3')
# [130, 1000] acc: 0.9352500438690186
# [131, 1000] loss: 0.1902459791878573
# 设备号为: tensor([41, 36, 42, 38], device='cuda:3')，预测的设备号为:tensor([21, 36, 42, 38], device='cuda:3')
# [131, 1000] acc: 0.9335000514984131
# [132, 1000] loss: 0.18062815823927303
# 设备号为: tensor([53, 26, 15, 36], device='cuda:3')，预测的设备号为:tensor([53, 26, 15, 36], device='cuda:3')
# [132, 1000] acc: 0.9337500333786011
# [133, 1000] loss: 0.19488398699803655
# 设备号为: tensor([21, 11, 37,  7], device='cuda:3')，预测的设备号为:tensor([21, 11, 37, 27], device='cuda:3')
# [133, 1000] acc: 0.9337500333786011
# [134, 1000] loss: 0.151723896054762
# 设备号为: tensor([39, 14, 16, 42], device='cuda:3')，预测的设备号为:tensor([39, 14, 16, 42], device='cuda:3')
# [134, 1000] acc: 0.9470000267028809
# [135, 1000] loss: 0.16733753408185204
# 设备号为: tensor([37, 18, 11, 17], device='cuda:3')，预测的设备号为:tensor([37, 18, 11, 17], device='cuda:3')
# [135, 1000] acc: 0.9440000653266907
# [136, 1000] loss: 0.18091829942857657
# 设备号为: tensor([ 7, 36, 40, 26], device='cuda:3')，预测的设备号为:tensor([ 7, 36, 42, 26], device='cuda:3')
# [136, 1000] acc: 0.936750054359436
# [137, 1000] loss: 0.1653612959293668
# 设备号为: tensor([44,  7, 22, 43], device='cuda:3')，预测的设备号为:tensor([44,  7, 22, 43], device='cuda:3')
# [137, 1000] acc: 0.9457500576972961
# [138, 1000] loss: 0.15901773693665383
# 设备号为: tensor([47, 24,  2,  9], device='cuda:3')，预测的设备号为:tensor([47, 24,  2,  9], device='cuda:3')
# [138, 1000] acc: 0.9485000371932983
# [139, 1000] loss: 0.15321318101858605
# 设备号为: tensor([44, 47,  4, 28], device='cuda:3')，预测的设备号为:tensor([44, 47,  4, 28], device='cuda:3')
# [139, 1000] acc: 0.9480000734329224
# [140, 1000] loss: 0.13448052734410884
# 设备号为: tensor([39, 53, 34, 14], device='cuda:3')，预测的设备号为:tensor([39, 53, 34, 14], device='cuda:3')
# [140, 1000] acc: 0.956000030040741
# [141, 1000] loss: 0.15476887631420322
# 设备号为: tensor([30,  1, 35,  3], device='cuda:3')，预测的设备号为:tensor([30,  1, 35,  3], device='cuda:3')
# [141, 1000] acc: 0.9500000476837158
# [142, 1000] loss: 0.1490390851263046
# 设备号为: tensor([43, 24, 15, 24], device='cuda:3')，预测的设备号为:tensor([43, 24, 15, 24], device='cuda:3')
# [142, 1000] acc: 0.9485000371932983
# [143, 1000] loss: 0.14208779788772607
# 设备号为: tensor([12, 35, 38, 13], device='cuda:3')，预测的设备号为:tensor([12, 35, 38, 13], device='cuda:3')
# [143, 1000] acc: 0.9542500376701355
# [144, 1000] loss: 0.14515966628154275
# 设备号为: tensor([23, 13, 10,  7], device='cuda:3')，预测的设备号为:tensor([23, 13, 10,  7], device='cuda:3')
# [144, 1000] acc: 0.9477500319480896
# [145, 1000] loss: 0.14417622291901033
# 设备号为: tensor([39, 48, 52,  6], device='cuda:3')，预测的设备号为:tensor([39, 48, 52,  6], device='cuda:3')
# [145, 1000] acc: 0.9520000219345093
# [146, 1000] loss: 0.14044747263391535
# 设备号为: tensor([52, 26, 16, 18], device='cuda:3')，预测的设备号为:tensor([52, 26, 40, 18], device='cuda:3')
# [146, 1000] acc: 0.9552500247955322
# [147, 1000] loss: 0.11827447234991814
# 设备号为: tensor([35, 49, 37, 30], device='cuda:3')，预测的设备号为:tensor([35, 49, 37, 30], device='cuda:3')
# [147, 1000] acc: 0.9602500200271606
# [148, 1000] loss: 0.10633403125100899
# 设备号为: tensor([51, 16, 22, 10], device='cuda:3')，预测的设备号为:tensor([51, 16, 22, 10], device='cuda:3')
# [148, 1000] acc: 0.9690000414848328
# [149, 1000] loss: 0.10708940710556512
# 设备号为: tensor([39, 15,  2, 48], device='cuda:3')，预测的设备号为:tensor([39, 15,  2, 48], device='cuda:3')
# [149, 1000] acc: 0.9657500386238098
# [150, 1000] loss: 0.12906360484910329
# 设备号为: tensor([40, 33, 25, 27], device='cuda:3')，预测的设备号为:tensor([40, 33, 25, 27], device='cuda:3')
# [150, 1000] acc: 0.9575000405311584
# [151, 1000] loss: 0.11115398259726499
# 设备号为: tensor([47, 45,  6, 52], device='cuda:3')，预测的设备号为:tensor([47, 45,  0, 52], device='cuda:3')
# [151, 1000] acc: 0.9657500386238098
# [152, 1000] loss: 0.12244194878419512
# 设备号为: tensor([41, 51, 26, 52], device='cuda:3')，预测的设备号为:tensor([41, 51, 26, 52], device='cuda:3')
# [152, 1000] acc: 0.9577500224113464
# [153, 1000] loss: 0.11493664185119906
# 设备号为: tensor([14, 36, 14, 18], device='cuda:3')，预测的设备号为:tensor([14, 36, 14, 18], device='cuda:3')
# [153, 1000] acc: 0.9640000462532043
# [154, 1000] loss: 0.10402700490593451
# 设备号为: tensor([19, 27, 40, 27], device='cuda:3')，预测的设备号为:tensor([22, 27, 40, 27], device='cuda:3')
# [154, 1000] acc: 0.967750072479248
# [155, 1000] loss: 0.11397339927795475
# 设备号为: tensor([41,  7, 34,  6], device='cuda:3')，预测的设备号为:tensor([41,  7, 34,  6], device='cuda:3')
# [155, 1000] acc: 0.9615000486373901
# [156, 1000] loss: 0.10441193466655932
# 设备号为: tensor([17, 27, 48, 32], device='cuda:3')，预测的设备号为:tensor([17, 27, 48, 32], device='cuda:3')
# [156, 1000] acc: 0.9655000567436218
# [157, 1000] loss: 0.10724429829078144
# 设备号为: tensor([49, 23, 16, 27], device='cuda:3')，预测的设备号为:tensor([49, 12, 16, 27], device='cuda:3')
# [157, 1000] acc: 0.9630000591278076
# [158, 1000] loss: 0.09923258719471233
# 设备号为: tensor([50, 13, 15, 26], device='cuda:3')，预测的设备号为:tensor([50, 13, 15, 26], device='cuda:3')
# [158, 1000] acc: 0.9647500514984131
# [159, 1000] loss: 0.10216375646792823
# 设备号为: tensor([14, 30, 26, 10], device='cuda:3')，预测的设备号为:tensor([14, 30, 26, 10], device='cuda:3')
# [159, 1000] acc: 0.967750072479248
# [160, 1000] loss: 0.1185622140013686
# 设备号为: tensor([46, 16, 21, 46], device='cuda:3')，预测的设备号为:tensor([46, 16, 21, 46], device='cuda:3')
# [160, 1000] acc: 0.9572500586509705
# [161, 1000] loss: 0.10781740843255466
# 设备号为: tensor([28, 25, 46,  9], device='cuda:3')，预测的设备号为:tensor([28, 25, 46,  9], device='cuda:3')
# [161, 1000] acc: 0.9642500281333923
# [162, 1000] loss: 0.08301739407845025
# 设备号为: tensor([12,  5, 16, 22], device='cuda:3')，预测的设备号为:tensor([12,  5, 16, 22], device='cuda:3')
# [162, 1000] acc: 0.9762500524520874
# [163, 1000] loss: 0.09916924576950532
# 设备号为: tensor([11, 44, 33, 25], device='cuda:3')，预测的设备号为:tensor([11, 44, 33, 25], device='cuda:3')
# [163, 1000] acc: 0.9660000205039978
# [164, 1000] loss: 0.09259540835032476
# 设备号为: tensor([34,  0, 48, 33], device='cuda:3')，预测的设备号为:tensor([34,  0, 48, 33], device='cuda:3')
# [164, 1000] acc: 0.9697500467300415
# [165, 1000] loss: 0.08513471203831088
# 设备号为: tensor([51, 32, 10, 23], device='cuda:3')，预测的设备号为:tensor([51, 32, 10, 12], device='cuda:3')
# [165, 1000] acc: 0.9730000495910645
# [166, 1000] loss: 0.08233417271389126
# 设备号为: tensor([30, 48, 40, 43], device='cuda:3')，预测的设备号为:tensor([30, 48, 40, 43], device='cuda:3')
# [166, 1000] acc: 0.9757500290870667
# [167, 1000] loss: 0.0785126805854486
# 设备号为: tensor([39, 33, 48, 14], device='cuda:3')，预测的设备号为:tensor([39, 33, 48, 14], device='cuda:3')
# [167, 1000] acc: 0.9735000729560852
# [168, 1000] loss: 0.09025614411463811
# 设备号为: tensor([ 5, 36, 19, 43], device='cuda:3')，预测的设备号为:tensor([ 5, 36, 19, 43], device='cuda:3')
# [168, 1000] acc: 0.9700000286102295
# [169, 1000] loss: 0.07877641762117944
# 设备号为: tensor([25, 51, 12, 18], device='cuda:3')，预测的设备号为:tensor([25, 51, 12, 18], device='cuda:3')
# [169, 1000] acc: 0.9742500185966492
# [170, 1000] loss: 0.08779236319729375
# 设备号为: tensor([29, 41, 31, 16], device='cuda:3')，预测的设备号为:tensor([29, 41, 31, 16], device='cuda:3')
# [170, 1000] acc: 0.9697500467300415
# [171, 1000] loss: 0.0804826576329624
# 设备号为: tensor([12, 45, 36, 41], device='cuda:3')，预测的设备号为:tensor([12, 45, 36, 41], device='cuda:3')
# [171, 1000] acc: 0.9777500629425049
# [172, 1000] loss: 0.07964866471263451
# 设备号为: tensor([50, 47, 27, 13], device='cuda:3')，预测的设备号为:tensor([50, 47, 27, 13], device='cuda:3')
# [172, 1000] acc: 0.9745000600814819
# [173, 1000] loss: 0.07087809959810874
# 设备号为: tensor([48, 39, 27, 41], device='cuda:3')，预测的设备号为:tensor([48, 39, 27, 41], device='cuda:3')
# [173, 1000] acc: 0.9762500524520874
# [174, 1000] loss: 0.07763749358007851
# 设备号为: tensor([34,  3, 41, 27], device='cuda:3')，预测的设备号为:tensor([34,  3, 41, 27], device='cuda:3')
# [174, 1000] acc: 0.9755000472068787
# [175, 1000] loss: 0.08984469357592315
# 设备号为: tensor([ 8, 47, 25, 33], device='cuda:3')，预测的设备号为:tensor([ 8, 47, 25, 33], device='cuda:3')
# [175, 1000] acc: 0.9722500443458557
# [176, 1000] loss: 0.07799233524589545
# 设备号为: tensor([10,  3, 13, 19], device='cuda:3')，预测的设备号为:tensor([10,  3, 13, 19], device='cuda:3')
# [176, 1000] acc: 0.9755000472068787
# [177, 1000] loss: 0.06581120316496208
# 设备号为: tensor([39, 14, 34, 39], device='cuda:3')，预测的设备号为:tensor([39, 14, 34, 39], device='cuda:3')
# [177, 1000] acc: 0.9762500524520874
# [178, 1000] loss: 0.09174266318599007
# 设备号为: tensor([ 1, 32, 45, 15], device='cuda:3')，预测的设备号为:tensor([ 1, 32, 45, 15], device='cuda:3')
# [178, 1000] acc: 0.9705000519752502
# [179, 1000] loss: 0.07030525046785692
# 设备号为: tensor([13, 21, 18, 24], device='cuda:3')，预测的设备号为:tensor([13, 21, 18, 24], device='cuda:3')
# [179, 1000] acc: 0.9752500653266907
# [180, 1000] loss: 0.06761674459394658
# 设备号为: tensor([38, 52, 32, 11], device='cuda:3')，预测的设备号为:tensor([38, 52, 32, 11], device='cuda:3')
# [180, 1000] acc: 0.9775000214576721
# [181, 1000] loss: 0.07369520210847486
# 设备号为: tensor([13, 13, 26, 39], device='cuda:3')，预测的设备号为:tensor([13, 13, 26, 39], device='cuda:3')
# [181, 1000] acc: 0.9757500290870667
# [182, 1000] loss: 0.06324845509830061
# 设备号为: tensor([34, 28, 40,  0], device='cuda:3')，预测的设备号为:tensor([34, 28, 40,  0], device='cuda:3')
# [182, 1000] acc: 0.9810000658035278
# [183, 1000] loss: 0.07932978790901314
# 设备号为: tensor([ 6, 36, 29, 18], device='cuda:3')，预测的设备号为:tensor([ 6, 36, 29, 18], device='cuda:3')
# [183, 1000] acc: 0.9725000262260437
# [184, 1000] loss: 0.06309065007070692
# 设备号为: tensor([17, 31, 48, 19], device='cuda:3')，预测的设备号为:tensor([17, 31, 48, 19], device='cuda:3')
# [184, 1000] acc: 0.984000027179718
# [185, 1000] loss: 0.07685502973601971
# 设备号为: tensor([27, 25, 30, 13], device='cuda:3')，预测的设备号为:tensor([27, 25, 30, 13], device='cuda:3')
# [185, 1000] acc: 0.9747500419616699
# [186, 1000] loss: 0.06580321569836815
# 设备号为: tensor([ 0, 25, 37, 34], device='cuda:3')，预测的设备号为:tensor([ 0, 25, 37, 34], device='cuda:3')
# [186, 1000] acc: 0.9797500371932983
# [187, 1000] loss: 0.06338292991756296
# 设备号为: tensor([43, 16,  7, 28], device='cuda:3')，预测的设备号为:tensor([43, 16,  7, 28], device='cuda:3')
# [187, 1000] acc: 0.9785000681877136
# [188, 1000] loss: 0.06246921591173588
# 设备号为: tensor([39,  4, 52,  6], device='cuda:3')，预测的设备号为:tensor([39,  4, 52,  6], device='cuda:3')
# [188, 1000] acc: 0.9802500605583191
# [189, 1000] loss: 0.066889083422125
# 设备号为: tensor([18,  6, 23, 48], device='cuda:3')，预测的设备号为:tensor([18,  6, 23, 48], device='cuda:3')
# [189, 1000] acc: 0.9785000681877136
# [190, 1000] loss: 0.05427208533695963
# 设备号为: tensor([37,  6, 25, 53], device='cuda:3')，预测的设备号为:tensor([37,  6, 25, 53], device='cuda:3')
# [190, 1000] acc: 0.9825000762939453
# [191, 1000] loss: 0.06838295340110562
# 设备号为: tensor([ 4, 21, 38,  6], device='cuda:3')，预测的设备号为:tensor([ 4, 21, 38,  6], device='cuda:3')
# [191, 1000] acc: 0.9782500267028809
# [192, 1000] loss: 0.05576603011483144
# 设备号为: tensor([ 1, 43, 42,  4], device='cuda:3')，预测的设备号为:tensor([ 1, 43, 42,  4], device='cuda:3')
# [192, 1000] acc: 0.9810000658035278
# [193, 1000] loss: 0.05753015201178004
# 设备号为: tensor([38, 34, 35, 36], device='cuda:3')，预测的设备号为:tensor([38, 34, 35, 36], device='cuda:3')
# [193, 1000] acc: 0.9827500581741333
# [194, 1000] loss: 0.06108178456448741
# 设备号为: tensor([19, 33, 17, 41], device='cuda:3')，预测的设备号为:tensor([19, 33, 17, 41], device='cuda:3')
# [194, 1000] acc: 0.9797500371932983
# [195, 1000] loss: 0.0557758926747797
# 设备号为: tensor([ 4, 21,  8, 11], device='cuda:3')，预测的设备号为:tensor([ 4, 21,  8, 11], device='cuda:3')
# [195, 1000] acc: 0.9815000295639038
# [196, 1000] loss: 0.06868116409028129
# 设备号为: tensor([48, 30, 53, 40], device='cuda:3')，预测的设备号为:tensor([48, 30, 53, 40], device='cuda:3')
# [196, 1000] acc: 0.9785000681877136
# [197, 1000] loss: 0.040608840996265314
# 设备号为: tensor([39,  9, 49, 47], device='cuda:3')，预测的设备号为:tensor([39,  9, 50, 47], device='cuda:3')
# [197, 1000] acc: 0.987000048160553
# [198, 1000] loss: 0.054172539560034524
# 设备号为: tensor([39, 10, 48, 23], device='cuda:3')，预测的设备号为:tensor([39, 10, 48, 23], device='cuda:3')
# [198, 1000] acc: 0.9827500581741333
# [199, 1000] loss: 0.05795666908443104
# 设备号为: tensor([27, 16, 13, 24], device='cuda:3')，预测的设备号为:tensor([27, 16, 13, 24], device='cuda:3')
# [199, 1000] acc: 0.9807500243186951
# [200, 1000] loss: 0.04855937967394266
# 设备号为: tensor([30, 21, 38, 16], device='cuda:3')，预测的设备号为:tensor([30, 21, 38, 16], device='cuda:3')
# [200, 1000] acc: 0.9842500686645508
# [201, 1000] loss: 0.04779842474021603
# 设备号为: tensor([ 9, 25,  3, 32], device='cuda:3')，预测的设备号为:tensor([ 9, 25,  3, 32], device='cuda:3')
# [201, 1000] acc: 0.9832500219345093
# [202, 1000] loss: 0.04217098869954748
# 设备号为: tensor([10, 53, 18, 20], device='cuda:3')，预测的设备号为:tensor([10, 53, 18, 20], device='cuda:3')
# [202, 1000] acc: 0.9885000586509705
# [203, 1000] loss: 0.04274824113673599
# 设备号为: tensor([10, 16, 11,  7], device='cuda:3')，预测的设备号为:tensor([10, 16, 11,  7], device='cuda:3')
# [203, 1000] acc: 0.9877500534057617
# [204, 1000] loss: 0.048018414213212395
# 设备号为: tensor([10, 40, 21, 27], device='cuda:3')，预测的设备号为:tensor([10, 40, 21, 27], device='cuda:3')
# [204, 1000] acc: 0.98375004529953
# [205, 1000] loss: 0.0491215210849075
# 设备号为: tensor([29, 10, 25, 21], device='cuda:3')，预测的设备号为:tensor([29, 10, 25, 21], device='cuda:3')
# [205, 1000] acc: 0.9850000739097595
# [206, 1000] loss: 0.052004094906439265
# 设备号为: tensor([27, 33, 31, 33], device='cuda:3')，预测的设备号为:tensor([27, 33, 31, 33], device='cuda:3')
# [206, 1000] acc: 0.9825000762939453
# [207, 1000] loss: 0.049210955243633406
# 设备号为: tensor([ 4, 44, 30, 32], device='cuda:3')，预测的设备号为:tensor([ 4, 44, 30, 32], device='cuda:3')
# [207, 1000] acc: 0.983500063419342
# [208, 1000] loss: 0.06521936097301134
# 设备号为: tensor([37, 40, 26, 27], device='cuda:3')，预测的设备号为:tensor([37, 40, 26, 27], device='cuda:3')
# [208, 1000] acc: 0.9772500395774841
# [209, 1000] loss: 0.04594765782046272
# 设备号为: tensor([ 3, 43, 26, 17], device='cuda:3')，预测的设备号为:tensor([ 3, 43, 26, 17], device='cuda:3')
# [209, 1000] acc: 0.9862500429153442
# [210, 1000] loss: 0.046362382287987655
# 设备号为: tensor([41, 47, 11, 49], device='cuda:3')，预测的设备号为:tensor([41, 47, 11, 49], device='cuda:3')
# [210, 1000] acc: 0.9855000376701355
# [211, 1000] loss: 0.04476457598084755
# 设备号为: tensor([43, 44, 27, 11], device='cuda:3')，预测的设备号为:tensor([43, 44, 27, 11], device='cuda:3')
# [211, 1000] acc: 0.9855000376701355
# [212, 1000] loss: 0.0494184348759735
# 设备号为: tensor([25, 16, 20,  2], device='cuda:3')，预测的设备号为:tensor([25, 16, 20,  2], device='cuda:3')
# [212, 1000] acc: 0.984000027179718
# [213, 1000] loss: 0.03546021436624722
# 设备号为: tensor([53, 26, 25, 29], device='cuda:3')，预测的设备号为:tensor([53, 26, 25, 29], device='cuda:3')
# [213, 1000] acc: 0.9907500743865967
# [214, 1000] loss: 0.05358072732792407
# 设备号为: tensor([42,  0, 20, 38], device='cuda:3')，预测的设备号为:tensor([42,  0, 20, 38], device='cuda:3')
# [214, 1000] acc: 0.984000027179718
# [215, 1000] loss: 0.04619190766800624
# 设备号为: tensor([43, 24, 11, 33], device='cuda:3')，预测的设备号为:tensor([43, 24, 11, 33], device='cuda:3')
# [215, 1000] acc: 0.9850000739097595
# [216, 1000] loss: 0.038924942405923105
# 设备号为: tensor([14, 45, 44, 13], device='cuda:3')，预测的设备号为:tensor([14, 45, 44, 13], device='cuda:3')
# [216, 1000] acc: 0.9875000715255737
# [217, 1000] loss: 0.039696663241812584
# 设备号为: tensor([21, 35,  4, 42], device='cuda:3')，预测的设备号为:tensor([21, 35,  4, 42], device='cuda:3')
# [217, 1000] acc: 0.9882500171661377
# [218, 1000] loss: 0.03905954855384274
# 设备号为: tensor([32, 51, 28, 47], device='cuda:3')，预测的设备号为:tensor([32, 51, 28, 47], device='cuda:3')
# [218, 1000] acc: 0.9877500534057617
# [219, 1000] loss: 0.04035927246493287
# 设备号为: tensor([32, 49, 27, 12], device='cuda:3')，预测的设备号为:tensor([32, 49, 27, 12], device='cuda:3')
# [219, 1000] acc: 0.9882500171661377
# [220, 1000] loss: 0.04577560086521056
# 设备号为: tensor([43, 45, 40, 28], device='cuda:3')，预测的设备号为:tensor([43, 45, 40, 28], device='cuda:3')
# [220, 1000] acc: 0.9857500195503235
# [221, 1000] loss: 0.03223614264620244
# 设备号为: tensor([20, 38, 11,  3], device='cuda:3')，预测的设备号为:tensor([20, 38, 11,  3], device='cuda:3')
# [221, 1000] acc: 0.9895000457763672
# [222, 1000] loss: 0.04601162151790811
# 设备号为: tensor([51, 25, 17, 16], device='cuda:3')，预测的设备号为:tensor([51, 25, 17, 16], device='cuda:3')
# [222, 1000] acc: 0.9852500557899475
# [223, 1000] loss: 0.03834444173642753
# 设备号为: tensor([ 9,  4, 47,  7], device='cuda:3')，预测的设备号为:tensor([ 9,  4, 47,  7], device='cuda:3')
# [223, 1000] acc: 0.9882500171661377
# [224, 1000] loss: 0.04092810862720659
# 设备号为: tensor([19, 28, 19, 50], device='cuda:3')，预测的设备号为:tensor([19, 28, 19, 50], device='cuda:3')
# [224, 1000] acc: 0.9865000247955322
# [225, 1000] loss: 0.031034792688561255
# 设备号为: tensor([50, 38, 45, 32], device='cuda:3')，预测的设备号为:tensor([50, 38, 45, 32], device='cuda:3')
# [225, 1000] acc: 0.9900000691413879
# [226, 1000] loss: 0.045209205415408744
# 设备号为: tensor([ 1, 13, 24, 31], device='cuda:3')，预测的设备号为:tensor([ 1, 13, 24, 31], device='cuda:3')
# [226, 1000] acc: 0.9850000739097595
# [227, 1000] loss: 0.0400188241408016
# 设备号为: tensor([36, 30, 10, 30], device='cuda:3')，预测的设备号为:tensor([36, 30, 10, 30], device='cuda:3')
# [227, 1000] acc: 0.987250030040741
# [228, 1000] loss: 0.044440207366083284
# 设备号为: tensor([ 2, 51, 51, 19], device='cuda:3')，预测的设备号为:tensor([ 2, 51, 51, 19], device='cuda:3')
# [228, 1000] acc: 0.9857500195503235
# [229, 1000] loss: 0.034217736058349116
# 设备号为: tensor([46, 19, 16, 29], device='cuda:3')，预测的设备号为:tensor([46, 19, 16, 29], device='cuda:3')
# [229, 1000] acc: 0.9882500171661377
# [230, 1000] loss: 0.041450530636506985
# 设备号为: tensor([ 2, 45, 29, 17], device='cuda:3')，预测的设备号为:tensor([ 2, 45, 29, 17], device='cuda:3')
# [230, 1000] acc: 0.986750066280365
# [231, 1000] loss: 0.03503836496636271
# 设备号为: tensor([ 7, 25, 28, 38], device='cuda:3')，预测的设备号为:tensor([ 7, 25, 28, 38], device='cuda:3')
# [231, 1000] acc: 0.9905000329017639
# [232, 1000] loss: 0.03517502522413864
# 设备号为: tensor([31, 28, 34,  6], device='cuda:3')，预测的设备号为:tensor([31, 28, 34,  6], device='cuda:3')
# [232, 1000] acc: 0.9887500405311584
# [233, 1000] loss: 0.02906842352031704
# 设备号为: tensor([47, 28, 12, 16], device='cuda:3')，预测的设备号为:tensor([47, 28, 12, 16], device='cuda:3')
# [233, 1000] acc: 0.9905000329017639
# [234, 1000] loss: 0.0312503354231138
# 设备号为: tensor([53, 44, 33, 52], device='cuda:3')，预测的设备号为:tensor([53, 44, 33, 52], device='cuda:3')
# [234, 1000] acc: 0.9907500743865967
# [235, 1000] loss: 0.04443218981535298
# 设备号为: tensor([ 0, 41, 20,  6], device='cuda:3')，预测的设备号为:tensor([ 0, 41, 20,  6], device='cuda:3')
# [235, 1000] acc: 0.9847500324249268
# [236, 1000] loss: 0.04610519281254865
# 设备号为: tensor([24, 48, 23, 37], device='cuda:3')，预测的设备号为:tensor([24, 48, 23, 37], device='cuda:3')
# [236, 1000] acc: 0.9875000715255737
# [237, 1000] loss: 0.02641632629254238
# 设备号为: tensor([26, 26, 46, 10], device='cuda:3')，预测的设备号为:tensor([26, 26, 46, 10], device='cuda:3')
# [237, 1000] acc: 0.9917500615119934
# [238, 1000] loss: 0.029832094186808277
# 设备号为: tensor([31, 13, 32, 41], device='cuda:3')，预测的设备号为:tensor([31, 13, 32, 41], device='cuda:3')
# [238, 1000] acc: 0.9910000562667847
# [239, 1000] loss: 0.037012133284259646
# 设备号为: tensor([26, 38, 44, 46], device='cuda:3')，预测的设备号为:tensor([26, 38, 44, 46], device='cuda:3')
# [239, 1000] acc: 0.9890000224113464
# [240, 1000] loss: 0.03266600172291299
# 设备号为: tensor([13, 31, 25,  5], device='cuda:3')，预测的设备号为:tensor([13, 31, 25,  5], device='cuda:3')
# [240, 1000] acc: 0.9912500381469727
# [241, 1000] loss: 0.031447196515480384
# 设备号为: tensor([ 6,  0, 10, 46], device='cuda:3')，预测的设备号为:tensor([ 6,  0, 10, 46], device='cuda:3')
# [241, 1000] acc: 0.9915000200271606
# [242, 1000] loss: 0.04139051878152102
# 设备号为: tensor([21,  8, 48, 43], device='cuda:3')，预测的设备号为:tensor([21,  8, 48, 43], device='cuda:3')
# [242, 1000] acc: 0.9865000247955322
# [243, 1000] loss: 0.03461770085823056
# 设备号为: tensor([49, 36, 38, 41], device='cuda:3')，预测的设备号为:tensor([49, 36, 38, 41], device='cuda:3')
# [243, 1000] acc: 0.9890000224113464
# [244, 1000] loss: 0.027239881030743783
# 设备号为: tensor([26, 49, 20, 33], device='cuda:3')，预测的设备号为:tensor([26, 49, 20, 33], device='cuda:3')
# [244, 1000] acc: 0.9907500743865967
# [245, 1000] loss: 0.03006652086608551
# 设备号为: tensor([ 6, 15, 52, 41], device='cuda:3')，预测的设备号为:tensor([ 6, 15, 52, 41], device='cuda:3')
# [245, 1000] acc: 0.9910000562667847
# [246, 1000] loss: 0.026379519271596052
# 设备号为: tensor([ 9,  0, 43,  3], device='cuda:3')，预测的设备号为:tensor([ 9,  0, 43,  3], device='cuda:3')
# [246, 1000] acc: 0.9915000200271606
# [247, 1000] loss: 0.02212161256637934
# 设备号为: tensor([26, 37, 43, 31], device='cuda:3')，预测的设备号为:tensor([26, 37, 43, 31], device='cuda:3')
# [247, 1000] acc: 0.9927500486373901
# [248, 1000] loss: 0.03596155907708071
# 设备号为: tensor([26, 46, 16, 31], device='cuda:3')，预测的设备号为:tensor([26, 46, 16, 31], device='cuda:3')
# [248, 1000] acc: 0.987000048160553
# [249, 1000] loss: 0.03448680940168866
# 设备号为: tensor([10,  9,  7,  5], device='cuda:3')，预测的设备号为:tensor([10,  9,  7,  5], device='cuda:3')
# [249, 1000] acc: 0.9880000352859497
# [250, 1000] loss: 0.04286441694378732
# 设备号为: tensor([42, 46, 11, 14], device='cuda:3')，预测的设备号为:tensor([42, 46, 11, 14], device='cuda:3')
# [250, 1000] acc: 0.9862500429153442
# [251, 1000] loss: 0.02588370527189427
# 设备号为: tensor([ 4, 29,  2, 29], device='cuda:3')，预测的设备号为:tensor([ 4, 29,  2, 29], device='cuda:3')
# [251, 1000] acc: 0.9912500381469727
# [252, 1000] loss: 0.04156431173761662
# 设备号为: tensor([12, 13, 25,  7], device='cuda:3')，预测的设备号为:tensor([12, 13, 25, 27], device='cuda:3')
# [252, 1000] acc: 0.9850000739097595
# [253, 1000] loss: 0.02849180723415765
# 设备号为: tensor([48, 33, 27,  6], device='cuda:3')，预测的设备号为:tensor([48, 33, 27,  6], device='cuda:3')
# [253, 1000] acc: 0.9930000305175781
# [254, 1000] loss: 0.0430584754027727
# 设备号为: tensor([51,  1, 45, 11], device='cuda:3')，预测的设备号为:tensor([51,  1, 45, 11], device='cuda:3')
# [254, 1000] acc: 0.9862500429153442
# [255, 1000] loss: 0.026097381595376133
# 设备号为: tensor([ 8, 34, 41,  3], device='cuda:3')，预测的设备号为:tensor([ 8, 34, 41,  3], device='cuda:3')
# [255, 1000] acc: 0.9925000667572021
# [256, 1000] loss: 0.024281617921559133
# 设备号为: tensor([53, 23, 51, 32], device='cuda:3')，预测的设备号为:tensor([53, 23, 51, 32], device='cuda:3')
# [256, 1000] acc: 0.9922500252723694
# [257, 1000] loss: 0.030855755114218654
# 设备号为: tensor([42, 20, 19,  2], device='cuda:3')，预测的设备号为:tensor([42, 20, 19,  2], device='cuda:3')
# [257, 1000] acc: 0.9902500510215759
# [258, 1000] loss: 0.02789556518676852
# 设备号为: tensor([17,  7, 25,  9], device='cuda:3')，预测的设备号为:tensor([17,  7, 25,  9], device='cuda:3')
# [258, 1000] acc: 0.9912500381469727
# [259, 1000] loss: 0.029126923490987746
# 设备号为: tensor([18, 45, 16, 32], device='cuda:3')，预测的设备号为:tensor([18, 45, 16, 32], device='cuda:3')
# [259, 1000] acc: 0.9902500510215759
# [260, 1000] loss: 0.038080987746330716
# 设备号为: tensor([32, 35, 38,  0], device='cuda:3')，预测的设备号为:tensor([32, 35, 38,  0], device='cuda:3')
# [260, 1000] acc: 0.9880000352859497
# [261, 1000] loss: 0.023251607664817
# 设备号为: tensor([28,  3, 18, 37], device='cuda:3')，预测的设备号为:tensor([28,  3, 18, 37], device='cuda:3')
# [261, 1000] acc: 0.9920000433921814
# [262, 1000] loss: 0.026406157759871013
# 设备号为: tensor([27, 42, 42, 46], device='cuda:3')，预测的设备号为:tensor([27, 42, 42, 46], device='cuda:3')
# [262, 1000] acc: 0.9915000200271606
# [263, 1000] loss: 0.029727034769126782
# 设备号为: tensor([ 0, 30, 51, 52], device='cuda:3')，预测的设备号为:tensor([ 0, 30, 51, 52], device='cuda:3')
# [263, 1000] acc: 0.9912500381469727
# [264, 1000] loss: 0.022187546171890588
# 设备号为: tensor([ 1, 33, 29, 21], device='cuda:3')，预测的设备号为:tensor([ 1, 33, 29, 21], device='cuda:3')
# [264, 1000] acc: 0.9937500357627869
# [265, 1000] loss: 0.023052496567977806
# 设备号为: tensor([25, 17, 32, 39], device='cuda:3')，预测的设备号为:tensor([25, 17, 32, 39], device='cuda:3')
# [265, 1000] acc: 0.9912500381469727
# [266, 1000] loss: 0.024756758937976926
# 设备号为: tensor([ 8, 52, 24, 33], device='cuda:3')，预测的设备号为:tensor([ 8, 52, 24, 33], device='cuda:3')
# [266, 1000] acc: 0.9925000667572021
# [267, 1000] loss: 0.02717876987590328
# 设备号为: tensor([12, 28, 34, 24], device='cuda:3')，预测的设备号为:tensor([12, 28, 34, 24], device='cuda:3')
# [267, 1000] acc: 0.9915000200271606
# [268, 1000] loss: 0.034999030532854546
# 设备号为: tensor([31, 50, 53, 10], device='cuda:3')，预测的设备号为:tensor([31, 50, 53, 10], device='cuda:3')
# [268, 1000] acc: 0.9875000715255737
# [269, 1000] loss: 0.02408890166710445
# 设备号为: tensor([30, 51,  0,  0], device='cuda:3')，预测的设备号为:tensor([30, 51,  0,  0], device='cuda:3')
# [269, 1000] acc: 0.9935000538825989
# [270, 1000] loss: 0.037823956567361726
# 设备号为: tensor([10, 52, 34, 27], device='cuda:3')，预测的设备号为:tensor([10, 52, 34, 27], device='cuda:3')
# [270, 1000] acc: 0.9890000224113464
# [271, 1000] loss: 0.02377369388722403
# 设备号为: tensor([ 8, 31, 42, 46], device='cuda:3')，预测的设备号为:tensor([ 8, 31, 42, 46], device='cuda:3')
# [271, 1000] acc: 0.9920000433921814
# [272, 1000] loss: 0.032960414234822814
# 设备号为: tensor([ 3, 36, 48,  4], device='cuda:3')，预测的设备号为:tensor([ 3, 36, 48,  4], device='cuda:3')
# [272, 1000] acc: 0.9907500743865967
# [273, 1000] loss: 0.02703688785648942
# 设备号为: tensor([53, 30, 52, 43], device='cuda:3')，预测的设备号为:tensor([53, 30, 52, 43], device='cuda:3')
# [273, 1000] acc: 0.9932500720024109
# [274, 1000] loss: 0.02977707009088435
# 设备号为: tensor([ 0, 48, 22, 53], device='cuda:3')，预测的设备号为:tensor([ 0, 48, 22, 53], device='cuda:3')
# [274, 1000] acc: 0.9912500381469727
# [275, 1000] loss: 0.02799806138368436
# 设备号为: tensor([48, 45, 28, 22], device='cuda:3')，预测的设备号为:tensor([48, 45, 28, 22], device='cuda:3')
# [275, 1000] acc: 0.9905000329017639
# [276, 1000] loss: 0.020374128058000488
# 设备号为: tensor([12,  5, 49, 51], device='cuda:3')，预测的设备号为:tensor([12,  5, 49, 51], device='cuda:3')
# [276, 1000] acc: 0.9937500357627869
# [277, 1000] loss: 0.01904784277695276
# 设备号为: tensor([20,  6, 21, 22], device='cuda:3')，预测的设备号为:tensor([20,  6, 21, 22], device='cuda:3')
# [277, 1000] acc: 0.9940000176429749
# [278, 1000] loss: 0.026640658806199525
# 设备号为: tensor([25, 37, 14,  5], device='cuda:3')，预测的设备号为:tensor([25, 37, 14,  5], device='cuda:3')
# [278, 1000] acc: 0.9920000433921814
# [279, 1000] loss: 0.029285840379373863
# 设备号为: tensor([37, 29, 40, 15], device='cuda:3')，预测的设备号为:tensor([37, 29, 40, 15], device='cuda:3')
# [279, 1000] acc: 0.9900000691413879
# [280, 1000] loss: 0.023864609869440438
# ...
# 目前一共测试了1188组，预测成功的一共有784组
# 设备号为: tensor([53, 46, 36, 37], device='cuda:3')，模型训练后得到的设备号为:tensor([53, 46, 36, 37], device='cuda:3')
# 目前一共测试了1192组，预测成功的一共有788组
# 设备号为: tensor([13, 19, 31, 23], device='cuda:3')，模型训练后得到的设备号为:tensor([13, 19, 31, 23], device='cuda:3')
# 目前一共测试了1196组，预测成功的一共有792组
# 设备号为: tensor([34, 44, 48,  9], device='cuda:3')，模型训练后得到的设备号为:tensor([39, 44, 48,  9], device='cuda:3')
# 目前一共测试了1200组，预测成功的一共有795组
# 设备号为: tensor([11, 30, 47, 52], device='cuda:3')，模型训练后得到的设备号为:tensor([ 4, 30, 20, 45], device='cuda:3')
# 目前一共测试了1204组，预测成功的一共有796组
# 设备号为: tensor([30, 18, 41, 16], device='cuda:3')，模型训练后得到的设备号为:tensor([30, 19, 22, 16], device='cuda:3')
# 目前一共测试了1208组，预测成功的一共有798组
# 设备号为: tensor([41, 26, 21, 46], device='cuda:3')，模型训练后得到的设备号为:tensor([21, 26, 47, 46], device='cuda:3')
# 目前一共测试了1212组，预测成功的一共有800组
# 设备号为: tensor([ 0, 25,  4, 13], device='cuda:3')，模型训练后得到的设备号为:tensor([ 8,  9,  4, 13], device='cuda:3')
# 目前一共测试了1216组，预测成功的一共有802组
# 设备号为: tensor([42, 33,  0,  3], device='cuda:3')，模型训练后得到的设备号为:tensor([42, 38,  0, 39], device='cuda:3')
# 目前一共测试了1220组，预测成功的一共有804组
# 设备号为: tensor([46, 36, 12, 44], device='cuda:3')，模型训练后得到的设备号为:tensor([46, 36, 12, 44], device='cuda:3')
# 目前一共测试了1224组，预测成功的一共有808组
# 设备号为: tensor([47, 37, 39, 14], device='cuda:3')，模型训练后得到的设备号为:tensor([43, 37, 39, 16], device='cuda:3')
# 目前一共测试了1228组，预测成功的一共有810组
# 设备号为: tensor([ 2, 43, 31, 51], device='cuda:3')，模型训练后得到的设备号为:tensor([29, 47, 31, 21], device='cuda:3')
# 目前一共测试了1232组，预测成功的一共有811组
# 设备号为: tensor([ 1, 19, 36, 13], device='cuda:3')，模型训练后得到的设备号为:tensor([ 9, 19, 36, 13], device='cuda:3')
# 目前一共测试了1236组，预测成功的一共有814组
# 设备号为: tensor([31, 43, 38, 29], device='cuda:3')，模型训练后得到的设备号为:tensor([31, 43, 38, 29], device='cuda:3')
# 目前一共测试了1240组，预测成功的一共有818组
# 设备号为: tensor([23, 29, 48, 48], device='cuda:3')，模型训练后得到的设备号为:tensor([23, 29, 48, 48], device='cuda:3')
# 目前一共测试了1244组，预测成功的一共有822组
# 设备号为: tensor([36, 11,  0, 22], device='cuda:3')，模型训练后得到的设备号为:tensor([36, 11,  0, 18], device='cuda:3')
# 目前一共测试了1248组，预测成功的一共有825组
# 设备号为: tensor([42, 32,  1, 30], device='cuda:3')，模型训练后得到的设备号为:tensor([42, 32,  1, 30], device='cuda:3')
# 目前一共测试了1252组，预测成功的一共有829组
# 设备号为: tensor([ 3, 30, 33, 52], device='cuda:3')，模型训练后得到的设备号为:tensor([33, 30, 33, 45], device='cuda:3')
# 目前一共测试了1256组，预测成功的一共有831组
# 设备号为: tensor([ 9,  5, 46, 50], device='cuda:3')，模型训练后得到的设备号为:tensor([ 9,  1, 46, 51], device='cuda:3')
# 目前一共测试了1260组，预测成功的一共有833组
# 设备号为: tensor([ 7,  2, 51,  3], device='cuda:3')，模型训练后得到的设备号为:tensor([ 7, 29, 21, 39], device='cuda:3')
# 目前一共测试了1264组，预测成功的一共有834组
# 设备号为: tensor([ 7, 44, 43, 53], device='cuda:3')，模型训练后得到的设备号为:tensor([ 7, 44, 43, 53], device='cuda:3')
# 目前一共测试了1268组，预测成功的一共有838组
# 设备号为: tensor([ 4, 40, 15, 46], device='cuda:3')，模型训练后得到的设备号为:tensor([ 4, 41, 44, 46], device='cuda:3')
# 目前一共测试了1272组，预测成功的一共有840组
# 设备号为: tensor([18, 45, 32, 41], device='cuda:3')，模型训练后得到的设备号为:tensor([18, 45, 36, 51], device='cuda:3')
# 目前一共测试了1276组，预测成功的一共有842组
# 设备号为: tensor([26, 17, 38, 26], device='cuda:3')，模型训练后得到的设备号为:tensor([26, 17,  9, 26], device='cuda:3')
# 目前一共测试了1280组，预测成功的一共有845组
# 设备号为: tensor([11, 42, 13, 48], device='cuda:3')，模型训练后得到的设备号为:tensor([11, 40, 13, 31], device='cuda:3')
# 目前一共测试了1284组，预测成功的一共有847组
# 设备号为: tensor([10, 21, 26, 25], device='cuda:3')，模型训练后得到的设备号为:tensor([10, 21, 26, 25], device='cuda:3')
# 目前一共测试了1288组，预测成功的一共有851组
# 设备号为: tensor([26, 52,  9, 26], device='cuda:3')，模型训练后得到的设备号为:tensor([26, 52,  9, 26], device='cuda:3')
# 目前一共测试了1292组，预测成功的一共有855组
# 设备号为: tensor([11, 41, 48, 39], device='cuda:3')，模型训练后得到的设备号为:tensor([11, 20, 48, 39], device='cuda:3')
# 目前一共测试了1296组，预测成功的一共有858组
# 设备号为: tensor([26,  4, 21, 33], device='cuda:3')，模型训练后得到的设备号为:tensor([26,  4, 51, 33], device='cuda:3')
# 目前一共测试了1300组，预测成功的一共有861组
# 设备号为: tensor([21, 50, 23, 18], device='cuda:3')，模型训练后得到的设备号为:tensor([43, 50, 23, 22], device='cuda:3')
# 目前一共测试了1304组，预测成功的一共有863组
# 设备号为: tensor([50, 25, 47, 26], device='cuda:3')，模型训练后得到的设备号为:tensor([50, 32, 47, 26], device='cuda:3')
# 目前一共测试了1308组，预测成功的一共有866组
# 设备号为: tensor([18, 42,  5,  6], device='cuda:3')，模型训练后得到的设备号为:tensor([20, 42,  5,  6], device='cuda:3')
# 目前一共测试了1312组，预测成功的一共有869组
# 设备号为: tensor([50, 26, 23,  5], device='cuda:3')，模型训练后得到的设备号为:tensor([50, 26, 15,  5], device='cuda:3')
# 目前一共测试了1316组，预测成功的一共有872组
# 设备号为: tensor([14, 18, 14, 27], device='cuda:3')，模型训练后得到的设备号为:tensor([13, 18, 16,  2], device='cuda:3')
# 目前一共测试了1320组，预测成功的一共有873组
# 设备号为: tensor([24,  1, 36, 12], device='cuda:3')，模型训练后得到的设备号为:tensor([24,  1, 36, 24], device='cuda:3')
# 目前一共测试了1324组，预测成功的一共有876组
# 设备号为: tensor([29,  9, 24, 23], device='cuda:3')，模型训练后得到的设备号为:tensor([29, 32, 24, 16], device='cuda:3')
# 目前一共测试了1328组，预测成功的一共有878组
# 设备号为: tensor([22, 43, 21, 45], device='cuda:3')，模型训练后得到的设备号为:tensor([14, 43, 41, 45], device='cuda:3')
# 目前一共测试了1332组，预测成功的一共有880组
# 设备号为: tensor([ 9, 17, 27, 52], device='cuda:3')，模型训练后得到的设备号为:tensor([ 9, 17, 33, 45], device='cuda:3')
# 目前一共测试了1336组，预测成功的一共有882组
# 设备号为: tensor([25, 50,  3, 22], device='cuda:3')，模型训练后得到的设备号为:tensor([25, 50,  3, 14], device='cuda:3')
# 目前一共测试了1340组，预测成功的一共有885组
# 设备号为: tensor([ 3, 47, 23, 21], device='cuda:3')，模型训练后得到的设备号为:tensor([33, 47, 24, 14], device='cuda:3')
# 目前一共测试了1344组，预测成功的一共有886组
# 设备号为: tensor([53, 33, 46, 19], device='cuda:3')，模型训练后得到的设备号为:tensor([53, 39, 46, 19], device='cuda:3')
# 目前一共测试了1348组，预测成功的一共有889组
# 设备号为: tensor([15, 13, 37, 24], device='cuda:3')，模型训练后得到的设备号为:tensor([15, 13, 37, 24], device='cuda:3')
# 目前一共测试了1352组，预测成功的一共有893组
# 设备号为: tensor([ 8, 52, 21,  5], device='cuda:3')，模型训练后得到的设备号为:tensor([ 5, 52, 21,  5], device='cuda:3')
# 目前一共测试了1356组，预测成功的一共有896组
# 设备号为: tensor([20, 33, 53, 19], device='cuda:3')，模型训练后得到的设备号为:tensor([16, 33, 53, 19], device='cuda:3')
# 目前一共测试了1360组，预测成功的一共有899组
# 设备号为: tensor([51, 10, 21,  2], device='cuda:3')，模型训练后得到的设备号为:tensor([49, 10, 21,  2], device='cuda:3')
# 目前一共测试了1364组，预测成功的一共有902组
# 设备号为: tensor([24, 33, 21, 28], device='cuda:3')，模型训练后得到的设备号为:tensor([24, 25, 51, 10], device='cuda:3')
# 目前一共测试了1368组，预测成功的一共有903组
# 设备号为: tensor([29, 51, 33, 30], device='cuda:3')，模型训练后得到的设备号为:tensor([29, 49,  9, 30], device='cuda:3')
# 目前一共测试了1372组，预测成功的一共有905组
# 设备号为: tensor([29, 44, 15, 18], device='cuda:3')，模型训练后得到的设备号为:tensor([29, 44, 12, 18], device='cuda:3')
# 目前一共测试了1376组，预测成功的一共有908组
# 设备号为: tensor([19, 37,  9, 13], device='cuda:3')，模型训练后得到的设备号为:tensor([19, 37,  9, 13], device='cuda:3')
# 目前一共测试了1380组，预测成功的一共有912组
# 设备号为: tensor([ 0, 25, 37, 50], device='cuda:3')，模型训练后得到的设备号为:tensor([ 0, 25, 37, 50], device='cuda:3')
# 目前一共测试了1384组，预测成功的一共有916组
# 设备号为: tensor([19, 18,  9, 29], device='cuda:3')，模型训练后得到的设备号为:tensor([19, 18,  9, 29], device='cuda:3')
# 目前一共测试了1388组，预测成功的一共有920组
# 设备号为: tensor([ 3, 52, 51,  7], device='cuda:3')，模型训练后得到的设备号为:tensor([ 7, 52, 21,  7], device='cuda:3')
# 目前一共测试了1392组，预测成功的一共有922组
# 设备号为: tensor([26, 46, 46, 53], device='cuda:3')，模型训练后得到的设备号为:tensor([26, 46, 46, 53], device='cuda:3')
# 目前一共测试了1396组，预测成功的一共有926组
# 设备号为: tensor([ 3,  1, 32,  6], device='cuda:3')，模型训练后得到的设备号为:tensor([28,  9, 32,  6], device='cuda:3')
# 目前一共测试了1400组，预测成功的一共有928组
# 设备号为: tensor([49, 50, 21, 45], device='cuda:3')，模型训练后得到的设备号为:tensor([50, 50, 21, 45], device='cuda:3')
# 目前一共测试了1404组，预测成功的一共有931组
# 设备号为: tensor([33, 33,  5, 25], device='cuda:3')，模型训练后得到的设备号为:tensor([ 3, 33,  5, 25], device='cuda:3')
# 目前一共测试了1408组，预测成功的一共有934组
# 设备号为: tensor([ 3, 10, 31, 34], device='cuda:3')，模型训练后得到的设备号为:tensor([ 3, 10, 48, 11], device='cuda:3')
# 目前一共测试了1412组，预测成功的一共有936组
# 设备号为: tensor([ 1, 39, 27, 38], device='cuda:3')，模型训练后得到的设备号为:tensor([ 5, 39, 27, 38], device='cuda:3')
# 目前一共测试了1416组，预测成功的一共有939组
# 设备号为: tensor([52, 53, 19, 25], device='cuda:3')，模型训练后得到的设备号为:tensor([45, 53, 19, 13], device='cuda:3')
# 目前一共测试了1420组，预测成功的一共有941组
# 设备号为: tensor([44, 42, 18, 51], device='cuda:3')，模型训练后得到的设备号为:tensor([52, 42, 18, 16], device='cuda:3')
# 目前一共测试了1424组，预测成功的一共有943组
# 设备号为: tensor([ 2, 15, 40, 38], device='cuda:3')，模型训练后得到的设备号为:tensor([ 2, 15, 50, 38], device='cuda:3')
# 目前一共测试了1428组，预测成功的一共有946组
# 设备号为: tensor([ 2,  1,  1, 38], device='cuda:3')，模型训练后得到的设备号为:tensor([2, 5, 1, 8], device='cuda:3')
# 目前一共测试了1432组，预测成功的一共有948组
# 设备号为: tensor([47,  4, 33, 27], device='cuda:3')，模型训练后得到的设备号为:tensor([47, 27, 33, 27], device='cuda:3')
# 目前一共测试了1436组，预测成功的一共有951组
# 设备号为: tensor([11, 43, 30, 43], device='cuda:3')，模型训练后得到的设备号为:tensor([11, 43, 30, 40], device='cuda:3')
# 目前一共测试了1440组，预测成功的一共有954组
# 设备号为: tensor([23, 29, 26, 11], device='cuda:3')，模型训练后得到的设备号为:tensor([23, 29, 26, 11], device='cuda:3')
# 目前一共测试了1444组，预测成功的一共有958组
# 设备号为: tensor([16, 41,  7, 24], device='cuda:3')，模型训练后得到的设备号为:tensor([49, 41, 33, 24], device='cuda:3')
# 目前一共测试了1448组，预测成功的一共有960组
# 设备号为: tensor([24, 15,  8,  9], device='cuda:3')，模型训练后得到的设备号为:tensor([24, 44,  8,  9], device='cuda:3')
# 目前一共测试了1452组，预测成功的一共有963组
# 设备号为: tensor([15, 50,  2, 53], device='cuda:3')，模型训练后得到的设备号为:tensor([15, 50,  2, 53], device='cuda:3')
# 目前一共测试了1456组，预测成功的一共有967组
# 设备号为: tensor([35,  0,  8,  6], device='cuda:3')，模型训练后得到的设备号为:tensor([35,  3,  0,  6], device='cuda:3')
# 目前一共测试了1460组，预测成功的一共有969组
# 设备号为: tensor([ 9, 22, 41, 35], device='cuda:3')，模型训练后得到的设备号为:tensor([ 9, 20, 21, 35], device='cuda:3')
# 目前一共测试了1464组，预测成功的一共有971组
# 设备号为: tensor([16, 49, 24, 39], device='cuda:3')，模型训练后得到的设备号为:tensor([51, 49, 24, 39], device='cuda:3')
# 目前一共测试了1468组，预测成功的一共有974组
# 设备号为: tensor([14, 51, 41, 14], device='cuda:3')，模型训练后得到的设备号为:tensor([15, 50, 51, 23], device='cuda:3')
# 目前一共测试了1472组，预测成功的一共有974组
# 设备号为: tensor([46, 31, 22, 34], device='cuda:3')，模型训练后得到的设备号为:tensor([46, 31, 20, 39], device='cuda:3')
# 目前一共测试了1476组，预测成功的一共有976组
# 设备号为: tensor([29,  8, 12, 14], device='cuda:3')，模型训练后得到的设备号为:tensor([29, 25, 24, 49], device='cuda:3')
# 目前一共测试了1480组，预测成功的一共有977组
# 设备号为: tensor([34, 49, 37, 36], device='cuda:3')，模型训练后得到的设备号为:tensor([34, 49, 37, 36], device='cuda:3')
# 目前一共测试了1484组，预测成功的一共有981组
# 设备号为: tensor([25, 51,  1, 46], device='cuda:3')，模型训练后得到的设备号为:tensor([25, 51,  9, 46], device='cuda:3')
# 目前一共测试了1488组，预测成功的一共有984组
# 设备号为: tensor([ 4, 28, 21, 45], device='cuda:3')，模型训练后得到的设备号为:tensor([ 4, 47, 16, 45], device='cuda:3')
# 目前一共测试了1492组，预测成功的一共有986组
# 设备号为: tensor([28,  6,  0, 15], device='cuda:3')，模型训练后得到的设备号为:tensor([28,  6,  5, 12], device='cuda:3')
# 目前一共测试了1496组，预测成功的一共有988组
# 设备号为: tensor([ 5, 24, 48, 15], device='cuda:3')，模型训练后得到的设备号为:tensor([ 5, 24, 48, 44], device='cuda:3')
# 目前一共测试了1500组，预测成功的一共有991组
# 设备号为: tensor([21, 50, 31, 49], device='cuda:3')，模型训练后得到的设备号为:tensor([17, 50, 31, 49], device='cuda:3')
# 目前一共测试了1504组，预测成功的一共有994组
# 设备号为: tensor([12, 34, 29, 48], device='cuda:3')，模型训练后得到的设备号为:tensor([12, 34, 29, 48], device='cuda:3')
# 目前一共测试了1508组，预测成功的一共有998组
# 设备号为: tensor([ 5,  8,  0, 22], device='cuda:3')，模型训练后得到的设备号为:tensor([ 0,  8,  0, 51], device='cuda:3')
# 目前一共测试了1512组，预测成功的一共有1000组
# 设备号为: tensor([13, 44,  9, 36], device='cuda:3')，模型训练后得到的设备号为:tensor([13, 44,  9, 36], device='cuda:3')
# 目前一共测试了1516组，预测成功的一共有1004组
# 设备号为: tensor([18, 49,  1, 52], device='cuda:3')，模型训练后得到的设备号为:tensor([18, 49,  9, 45], device='cuda:3')
# 目前一共测试了1520组，预测成功的一共有1006组
# 设备号为: tensor([43, 15, 53, 24], device='cuda:3')，模型训练后得到的设备号为:tensor([43, 44, 52, 24], device='cuda:3')
# 目前一共测试了1524组，预测成功的一共有1008组
# 设备号为: tensor([ 4, 28, 50, 29], device='cuda:3')，模型训练后得到的设备号为:tensor([ 2, 28, 50, 29], device='cuda:3')
# 目前一共测试了1528组，预测成功的一共有1011组
# 设备号为: tensor([33, 36, 32, 23], device='cuda:3')，模型训练后得到的设备号为:tensor([ 3, 36, 32, 12], device='cuda:3')
# 目前一共测试了1532组，预测成功的一共有1013组
# 设备号为: tensor([ 4, 29, 18, 53], device='cuda:3')，模型训练后得到的设备号为:tensor([ 2, 29, 18, 52], device='cuda:3')
# 目前一共测试了1536组，预测成功的一共有1015组
# 设备号为: tensor([41, 42,  5, 11], device='cuda:3')，模型训练后得到的设备号为:tensor([41, 42,  8, 27], device='cuda:3')
# 目前一共测试了1540组，预测成功的一共有1017组
# 设备号为: tensor([51, 12, 12, 50], device='cuda:3')，模型训练后得到的设备号为:tensor([51, 12, 12, 50], device='cuda:3')
# 目前一共测试了1544组，预测成功的一共有1021组
# 设备号为: tensor([24, 22, 50, 39], device='cuda:3')，模型训练后得到的设备号为:tensor([24, 14, 50, 34], device='cuda:3')
# 目前一共测试了1548组，预测成功的一共有1023组
# 设备号为: tensor([23, 49, 41, 34], device='cuda:3')，模型训练后得到的设备号为:tensor([23, 50, 51, 34], device='cuda:3')
# 目前一共测试了1552组，预测成功的一共有1025组
# 设备号为: tensor([43, 52, 40, 24], device='cuda:3')，模型训练后得到的设备号为:tensor([28, 45, 43, 24], device='cuda:3')
# 目前一共测试了1556组，预测成功的一共有1026组
# 设备号为: tensor([37, 21, 22, 28], device='cuda:3')，模型训练后得到的设备号为:tensor([37, 21, 14, 28], device='cuda:3')
# 目前一共测试了1560组，预测成功的一共有1029组
# 设备号为: tensor([28, 44, 42, 40], device='cuda:3')，模型训练后得到的设备号为:tensor([28, 46, 40, 40], device='cuda:3')
# 目前一共测试了1564组，预测成功的一共有1031组
# 设备号为: tensor([44, 49,  9, 14], device='cuda:3')，模型训练后得到的设备号为:tensor([44, 50,  9, 16], device='cuda:3')
# 目前一共测试了1568组，预测成功的一共有1033组
# 设备号为: tensor([ 4, 34, 11, 10], device='cuda:3')，模型训练后得到的设备号为:tensor([ 2, 39, 11, 10], device='cuda:3')
# 目前一共测试了1572组，预测成功的一共有1035组
# 设备号为: tensor([30, 41, 41,  2], device='cuda:3')，模型训练后得到的设备号为:tensor([30, 41, 41,  2], device='cuda:3')
# 目前一共测试了1576组，预测成功的一共有1039组
# 设备号为: tensor([43, 15, 42, 17], device='cuda:3')，模型训练后得到的设备号为:tensor([21, 52, 42, 17], device='cuda:3')
# 目前一共测试了1580组，预测成功的一共有1041组
# 设备号为: tensor([48,  5, 34, 18], device='cuda:3')，模型训练后得到的设备号为:tensor([48,  6, 34, 18], device='cuda:3')
# 目前一共测试了1584组，预测成功的一共有1044组
# 设备号为: tensor([22, 12, 21, 14], device='cuda:3')，模型训练后得到的设备号为:tensor([14, 12, 51, 14], device='cuda:3')
# 目前一共测试了1588组，预测成功的一共有1046组
# 设备号为: tensor([17, 13, 47, 46], device='cuda:3')，模型训练后得到的设备号为:tensor([17, 13, 19, 46], device='cuda:3')
# 目前一共测试了1592组，预测成功的一共有1049组
# 设备号为: tensor([11, 44, 16,  5], device='cuda:3')，模型训练后得到的设备号为:tensor([11, 44, 22,  0], device='cuda:3')
# 目前一共测试了1596组，预测成功的一共有1051组
# 设备号为: tensor([19, 50, 38, 42], device='cuda:3')，模型训练后得到的设备号为:tensor([19, 50,  1, 43], device='cuda:3')
# 目前一共测试了1600组，预测成功的一共有1053组
# 设备号为: tensor([46, 49,  7, 15], device='cuda:3')，模型训练后得到的设备号为:tensor([46, 50,  7, 44], device='cuda:3')
# 目前一共测试了1604组，预测成功的一共有1055组
# 设备号为: tensor([ 0, 36,  2, 43], device='cuda:3')，模型训练后得到的设备号为:tensor([25, 36,  2, 17], device='cuda:3')
# 目前一共测试了1608组，预测成功的一共有1057组
# 设备号为: tensor([27, 49, 48, 35], device='cuda:3')，模型训练后得到的设备号为:tensor([27, 50, 48, 35], device='cuda:3')
# 目前一共测试了1612组，预测成功的一共有1060组
# 设备号为: tensor([12, 34, 46, 17], device='cuda:3')，模型训练后得到的设备号为:tensor([12, 34, 46, 17], device='cuda:3')
# 目前一共测试了1616组，预测成功的一共有1064组
# 设备号为: tensor([17, 15, 16,  6], device='cuda:3')，模型训练后得到的设备号为:tensor([17, 44, 16,  6], device='cuda:3')
# 目前一共测试了1620组，预测成功的一共有1067组
# 设备号为: tensor([ 9, 40, 18, 38], device='cuda:3')，模型训练后得到的设备号为:tensor([10, 40, 22,  9], device='cuda:3')
# 目前一共测试了1624组，预测成功的一共有1068组
# 设备号为: tensor([ 1, 22, 37, 45], device='cuda:3')，模型训练后得到的设备号为:tensor([ 1, 14, 37, 45], device='cuda:3')
# 目前一共测试了1628组，预测成功的一共有1071组
# 设备号为: tensor([48, 16,  5, 31], device='cuda:3')，模型训练后得到的设备号为:tensor([48, 14,  5, 31], device='cuda:3')
# 目前一共测试了1632组，预测成功的一共有1074组
# 设备号为: tensor([19, 50, 22, 17], device='cuda:3')，模型训练后得到的设备号为:tensor([14, 50, 16, 17], device='cuda:3')
# 目前一共测试了1636组，预测成功的一共有1076组
# 设备号为: tensor([ 9,  7, 52, 34], device='cuda:3')，模型训练后得到的设备号为:tensor([ 9, 27, 45, 34], device='cuda:3')
# 目前一共测试了1640组，预测成功的一共有1078组
# 设备号为: tensor([27, 29, 14, 11], device='cuda:3')，模型训练后得到的设备号为:tensor([27, 29, 23, 39], device='cuda:3')
# 目前一共测试了1644组，预测成功的一共有1080组
# 设备号为: tensor([11, 30, 15, 36], device='cuda:3')，模型训练后得到的设备号为:tensor([11, 30, 15, 36], device='cuda:3')
# 目前一共测试了1648组，预测成功的一共有1084组
# 设备号为: tensor([ 9, 41, 40,  4], device='cuda:3')，模型训练后得到的设备号为:tensor([ 9, 51, 40,  4], device='cuda:3')
# 目前一共测试了1652组，预测成功的一共有1087组
# 设备号为: tensor([35,  3, 38, 20], device='cuda:3')，模型训练后得到的设备号为:tensor([ 2,  3, 38, 51], device='cuda:3')
# 目前一共测试了1656组，预测成功的一共有1089组
# 设备号为: tensor([47, 44, 20, 53], device='cuda:3')，模型训练后得到的设备号为:tensor([19, 44, 20, 53], device='cuda:3')
# 目前一共测试了1660组，预测成功的一共有1092组
# 设备号为: tensor([41, 24, 40, 45], device='cuda:3')，模型训练后得到的设备号为:tensor([43, 24, 51, 45], device='cuda:3')
# 目前一共测试了1664组，预测成功的一共有1094组
# 设备号为: tensor([42,  0, 14, 18], device='cuda:3')，模型训练后得到的设备号为:tensor([42,  0, 13, 51], device='cuda:3')
# 目前一共测试了1668组，预测成功的一共有1096组
# 设备号为: tensor([37, 49, 36,  0], device='cuda:3')，模型训练后得到的设备号为:tensor([37, 50, 36,  8], device='cuda:3')
# 目前一共测试了1672组，预测成功的一共有1098组
# 设备号为: tensor([ 5, 41], device='cuda:3')，模型训练后得到的设备号为:tensor([ 5, 42], device='cuda:3')
# 目前一共测试了1674组，预测成功的一共有1099组
# total的值为：{total}
# 1257张测试集中准确率为： 65.65113067626953%
# [[16  0  0 ...  0  0  0]
#  [ 0 20  0 ...  0  0  0]
#  [ 0  0 28 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  6  0  0]
#  [ 0  0  0 ...  0 14  0]
#  [ 0  0  0 ...  0  3 25]]

# %%
torch.cuda.current_device ()
# Out:
# 0

# %%
aa = iter(train_loader)
a, b = aa.next()
print(a[0].shape)
print(a)
# Out:
# torch.Size([1, 2, 1280])
# tensor([[[[-0.2813, -0.2396,  1.0199,  ...,  1.0420,  0.1690,  0.1003],
#           [-1.2226, -1.0558, -1.0100,  ..., -0.2768, -0.6791, -0.3961]]],
#
#
#         [[[-0.0294,  0.1368,  0.2899,  ...,  0.5585,  0.0643, -0.5200],
#           [-1.1346, -0.5584, -0.5057,  ..., -0.4793, -0.2001, -1.0565]]],
#
#
#         [[[-0.2430,  0.7691,  0.5989,  ..., -0.5311, -0.5601, -0.4967],
#           [-0.9318, -1.1387, -0.9038,  ..., -1.1647, -0.7636, -0.7748]]],
#
#
#         [[[ 0.3037,  0.8075,  0.7330,  ...,  0.5745,  0.3928, -0.2135],
#           [-1.4026, -1.5134, -1.3912,  ..., -0.3544, -0.9531, -0.9087]]]],
#        dtype=torch.float64)

# %%
input = torch.randn(20, 16, 50, 100)
input.shape
# Out:
# torch.Size([20, 16, 50, 100])

# %%
m2=nn.Conv2d(16,33,(3,5),stride=(2,1),padding=(4,2))
inpu1=Variable(torch.randn(20,16,50,100))
print(inpu1.shape)
output=m2(inpu1)
print(output.shape)
# Out:
# torch.Size([20, 16, 50, 100])
# torch.Size([20, 33, 28, 100])

# %%
total
# Out:
# 2

# %%
torch.cuda.current_device ()
# Out:
# 0

# %%
x = range(0, len(average_loss_series))
plt.figure()
plt.plot(x, average_loss_series)
plt.savefig("Loss1.png", bbox_inches="tight")
plt.show()
