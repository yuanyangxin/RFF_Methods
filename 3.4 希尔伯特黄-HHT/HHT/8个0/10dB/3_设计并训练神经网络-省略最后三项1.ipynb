# %%
import matplotlib.pyplot as plt
import torchvision as tv
from torchvision import transforms, utils


import torch.nn.functional as F
import torch 
import torch.nn as nn
from torch.autograd import Variable
import torchvision.models as models
# from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader
# from PIL import Image
# import numpy as np
import torch.optim as optim
# import os
import time

import loadData

# %%
device = torch.device("cuda:3")

# %%
# 日志记录模块2
import logging
logger = logging.getLogger(__name__)
logger.setLevel(level = logging.INFO)
handler = logging.FileHandler("./省略最后三项-1.log")
handler.setLevel(logging.INFO)
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

console = logging.StreamHandler()
console.setLevel(logging.INFO)

logger.addHandler(handler)
logger.addHandler(console)

# %%
startTime = time.time()

# %%
transforms = tv.transforms.Compose([
    transforms.ToTensor(),
])


numOfBatch = 9
pixel = 64
flag = 0
root = f'./{numOfBatch}/data'
batchSize = 4
train_data = loadData.MyDataset(txt=f'files_train10-省略最后三项.txt', transform=None)
test_data = loadData.MyDataset(txt=f'files_test10-省略最后三项.txt', transform=None)



train_loader = DataLoader(dataset=train_data, batch_size=batchSize, shuffle=True, num_workers=2)
test_loader = DataLoader(dataset=test_data, batch_size=batchSize, shuffle=True, num_workers=2)


print(train_loader)
print(test_loader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7f114462ec90>
# <torch.utils.data.dataloader.DataLoader object at 0x7f1144621a50>

# %%
print(len(train_data))
print(len(test_loader))
# Out:
# 6426
# 419

# %%
# data = iter(train_loader)

# # print(type(data))
# # print(len(data))
# data_, label = data.next()
# print(train_loader.batch_size)
# print(data_.shape)
# # print(label)
# # print(data_, label)

# %%
x = torch.randn(4, 1, 1200, 2).float()
conv = nn.Conv2d(in_channels = 1, out_channels = 128, kernel_size = (10, 1))
x = conv(x)
x.shape
conv2 = nn.Conv2d(in_channels = 128, out_channels = 256, kernel_size = (3, 2))
x = conv2(x)
x.shape
# Out:
# torch.Size([4, 256, 1189, 1])

# %%
# 256*1189

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(in_channels = 1, out_channels = 8, kernel_size = (1, 10))
        self.conv2 = nn.Conv2d(in_channels = 8, out_channels = 16, kernel_size = (2, 3))
        
        self.dropout1 = nn.Dropout(0.5)
        self.dropout2 = nn.Dropout(0.5)
        
        self.fc1 = nn.Linear(20304, 1024)
        self.fc2 = nn.Linear(1024, 500)
        self.fc3 = nn.Linear(500, 54)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 1)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 1)
    
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.dropout1(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.dropout2(x)
        x = self.fc3(x)
        output = F.log_softmax(x, dim=1)
        return output

# %%
# TensorBoard
# from tensorboardX import SummaryWriter
# net = Net()
# # writer = SummaryWriter('writer928') #建立一个保存数据用的东西
# dummy_input = torch.rand(2,160,400)  # 假设输入20张1*28*28的图片
# with SummaryWriter(comment='Net1') as w:
#     w.add_graph(net, (dummy_input,))

# %%
net = Net()

net = net.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(params=net.parameters(), lr=0.0001, momentum=0.9)

epochs = 1500
average_loss_series = []

# %%
for a, b in enumerate(train_loader):
    inputs, labels = b
    print(inputs.shape)
    break
# Out:
# torch.Size([4, 1, 2, 1280])

# %%
# %matplotlib inline


if __name__ == '__main__':
    for epoch in range(epochs):
        running_loss = 0.0
        running_acc = 0.0

        for i, data in enumerate(train_loader):
#             print("i:", i )
#             print("data: ", data[0])
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()

#             inputs = inputs.permute(0, 2, 1)
            
            inputs = torch.tensor(inputs, dtype=torch.float32, device = device)

            outputs = net(inputs)
            _, predicted = torch.max(outputs.data, dim=1)
            total = labels.size(0)
#             print('原来的值:{0}, 预测的值:{1}'.format(labels, predicted))
            running_correct = (predicted == labels).sum()
            running_acc += running_correct
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            loss.backward()
            optimizer.step()

            # 每loopNum个batch打印一次训练状态
            loopNum = 1000
            if i % loopNum == loopNum - 1:
                average_loss = running_loss / loopNum
                logger.info('[{0}, {1}] loss: {2}'.format(epoch + 1, i + 1, average_loss))
                logger.info('设备号为: {0}，预测的设备号为:{1}'.format(labels, predicted))
#                 logger.info(torch.cuda.current_device ())
                running_acc = running_acc.float()
                average_acc = running_acc / loopNum / total
                
                logger.info('[{0}, {1}] acc: {2}'.format(epoch + 1, i + 1, average_acc))
                average_loss_series.append(average_loss)
                running_loss = 0.0
                running_acc = 0.0

    x = range(0, len(average_loss_series))
    plt.figure()
    plt.plot(x, average_loss_series)
#     plt.savefig("Loss.png")
    plt.savefig("Loss.png", bbox_inches="tight")
    plt.show()
    

    # %%
    # 在测试集上测试
    realLabel = []
    predictedLabel = []

    def correct_rate(net, testloader):
        correct = 0.0
        total = 0.0
        count = 0
        correctpredict = 0

        for data in testloader:
            images, labels = data
            images, labels = images.to(device),labels.to(device)
            realLabel.append([int(label) for label in labels])
    
            tests = torch.tensor(images, dtype=torch.float32,device=device)
            outputs = net(tests)

            _, predicted = torch.max(outputs.data, dim=1)
            logger.info('设备号为: {0}，模型训练后得到的设备号为:{1}'.format(labels, predicted))
#             deviceNumber = torch.cuda.current_device ()
#             logger.info(deviceNumber)
            
            labelsn = labels.cpu().numpy()
            pn = predicted.cpu().numpy()
            count += len(labelsn)
            
            for i in range(len(labelsn)):
                if labelsn[i] == pn[i]:
                    correctpredict += 1
                
            
            logger.info('目前一共测试了{0}组，预测成功的一共有{1}组'.format(count, correctpredict))
            predictedLabel.append([int(label) for label in predicted])
            
            total += labels.size(0)
            correct += (predicted == labels).sum()

            
        logger.info("total的值为：{total}")
#         return 100 * correct  # / total
        return 100 * correct/ total 


    correct = correct_rate(net, test_loader)
    logger.info(f'{len(test_loader) * 3}张测试集中准确率为： {correct}%')

    # %%
    import itertools
    from sklearn.metrics import confusion_matrix

    realLabel = list(itertools.chain.from_iterable(realLabel))
    predictedLabel = list(itertools.chain.from_iterable(predictedLabel))

    cm = confusion_matrix(realLabel, predictedLabel)
    logger.info(cm)

#     logger.info('the running time is:{1}'.format(time.time() - startTime))
    torch.save(net.state_dict(), f'./model_10dB_省略最后三项_1.pkl')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# [1, 1000] loss: 3.9910399224758146
# 设备号为: tensor([29, 31, 40, 19], device='cuda:3')，预测的设备号为:tensor([53, 23, 46, 31], device='cuda:3')
# [1, 1000] acc: 0.020250000059604645
# [2, 1000] loss: 3.9889151380062104
# 设备号为: tensor([35, 19, 45, 13], device='cuda:3')，预测的设备号为:tensor([53, 41, 52, 48], device='cuda:3')
# [2, 1000] acc: 0.020500000566244125
# [3, 1000] loss: 3.9875642158985136
# 设备号为: tensor([17, 48, 21, 26], device='cuda:3')，预测的设备号为:tensor([38, 41, 53,  9], device='cuda:3')
# [3, 1000] acc: 0.0215000007301569
# [4, 1000] loss: 3.984481407880783
# 设备号为: tensor([41, 32, 40, 36], device='cuda:3')，预测的设备号为:tensor([10, 24,  3,  0], device='cuda:3')
# [4, 1000] acc: 0.021000001579523087
# [5, 1000] loss: 3.9810188386440277
# 设备号为: tensor([ 9, 11, 20, 28], device='cuda:3')，预测的设备号为:tensor([26, 10, 12, 22], device='cuda:3')
# [5, 1000] acc: 0.029750000685453415
# [6, 1000] loss: 3.972494484901428
# 设备号为: tensor([11, 47,  1, 45], device='cuda:3')，预测的设备号为:tensor([ 8,  5,  5, 28], device='cuda:3')
# [6, 1000] acc: 0.033250000327825546
# [7, 1000] loss: 3.950195200204849
# 设备号为: tensor([ 2, 44, 39, 13], device='cuda:3')，预测的设备号为:tensor([13, 45, 41, 23], device='cuda:3')
# [7, 1000] acc: 0.04125000163912773
# [8, 1000] loss: 3.8662243149280546
# 设备号为: tensor([30, 38, 26, 14], device='cuda:3')，预测的设备号为:tensor([52,  1,  9, 52], device='cuda:3')
# [8, 1000] acc: 0.06300000101327896
# [9, 1000] loss: 3.5440707659721373
# 设备号为: tensor([25, 52, 10, 47], device='cuda:3')，预测的设备号为:tensor([ 8, 52,  1, 50], device='cuda:3')
# [9, 1000] acc: 0.05900000408291817
# [10, 1000] loss: 3.269680910110474
# 设备号为: tensor([ 4, 48, 34, 42], device='cuda:3')，预测的设备号为:tensor([ 2, 28, 34, 51], device='cuda:3')
# [10, 1000] acc: 0.08675000071525574
# [11, 1000] loss: 3.111403095126152
# 设备号为: tensor([45,  5,  9, 35], device='cuda:3')，预测的设备号为:tensor([52,  8, 38, 28], device='cuda:3')
# [11, 1000] acc: 0.10900000482797623
# [12, 1000] loss: 2.997883128285408
# 设备号为: tensor([ 6, 19, 28, 14], device='cuda:3')，预测的设备号为:tensor([ 9, 21,  7, 51], device='cuda:3')
# [12, 1000] acc: 0.12425000220537186
# [13, 1000] loss: 2.915030673265457
# 设备号为: tensor([30, 13, 17,  5], device='cuda:3')，预测的设备号为:tensor([18, 13, 48, 26], device='cuda:3')
# [13, 1000] acc: 0.1392500102519989
# [14, 1000] loss: 2.8120907826423647
# 设备号为: tensor([25, 19,  0, 33], device='cuda:3')，预测的设备号为:tensor([ 5, 41,  0,  5], device='cuda:3')
# [14, 1000] acc: 0.14025001227855682
# [15, 1000] loss: 2.743245247721672
# 设备号为: tensor([17, 36, 19,  3], device='cuda:3')，预测的设备号为:tensor([ 2,  3, 42, 25], device='cuda:3')
# [15, 1000] acc: 0.15075001120567322
# [16, 1000] loss: 2.659868765950203
# 设备号为: tensor([36, 45,  2, 50], device='cuda:3')，预测的设备号为:tensor([10, 45, 17, 41], device='cuda:3')
# [16, 1000] acc: 0.16900001466274261
# [17, 1000] loss: 2.5895495889782905
# 设备号为: tensor([47, 28,  8, 18], device='cuda:3')，预测的设备号为:tensor([47, 28, 26, 23], device='cuda:3')
# [17, 1000] acc: 0.18150000274181366
# [18, 1000] loss: 2.5150252369642256
# 设备号为: tensor([34, 17, 38,  8], device='cuda:3')，预测的设备号为:tensor([34, 47, 26, 32], device='cuda:3')
# [18, 1000] acc: 0.19825001060962677
# [19, 1000] loss: 2.4070907938480377
# 设备号为: tensor([ 1, 47, 36, 46], device='cuda:3')，预测的设备号为:tensor([ 1, 21,  7, 52], device='cuda:3')
# [19, 1000] acc: 0.22675001621246338
# [20, 1000] loss: 2.280153210222721
# 设备号为: tensor([34,  2, 35, 29], device='cuda:3')，预测的设备号为:tensor([ 4,  4, 34, 29], device='cuda:3')
# [20, 1000] acc: 0.2522500157356262
# [21, 1000] loss: 2.1525102019906046
# 设备号为: tensor([34, 32,  9, 37], device='cuda:3')，预测的设备号为:tensor([34, 25,  9, 37], device='cuda:3')
# [21, 1000] acc: 0.2827500104904175
# [22, 1000] loss: 2.0572813158631327
# 设备号为: tensor([46, 22, 22, 33], device='cuda:3')，预测的设备号为:tensor([45, 23, 23, 33], device='cuda:3')
# [22, 1000] acc: 0.30300000309944153
# [23, 1000] loss: 2.000636923968792
# 设备号为: tensor([ 3, 23, 30, 26], device='cuda:3')，预测的设备号为:tensor([ 3, 24, 30, 26], device='cuda:3')
# [23, 1000] acc: 0.3177500069141388
# [24, 1000] loss: 1.8959107998013496
# 设备号为: tensor([51, 43, 23,  2], device='cuda:3')，预测的设备号为:tensor([40, 42, 23,  4], device='cuda:3')
# [24, 1000] acc: 0.3537500202655792
# [25, 1000] loss: 1.8599662660956382
# 设备号为: tensor([23, 47, 32, 43], device='cuda:3')，预测的设备号为:tensor([23, 18, 32, 49], device='cuda:3')
# [25, 1000] acc: 0.36250001192092896
# [26, 1000] loss: 1.797225619032979
# 设备号为: tensor([52, 43, 29, 32], device='cuda:3')，预测的设备号为:tensor([52, 17, 29, 32], device='cuda:3')
# [26, 1000] acc: 0.38225001096725464
# [27, 1000] loss: 1.7379397093951703
# 设备号为: tensor([22, 41, 41, 40], device='cuda:3')，预测的设备号为:tensor([22, 43, 43, 18], device='cuda:3')
# [27, 1000] acc: 0.4065000116825104
# [28, 1000] loss: 1.6995036438703537
# 设备号为: tensor([33, 22, 38, 27], device='cuda:3')，预测的设备号为:tensor([25, 21, 38, 34], device='cuda:3')
# [28, 1000] acc: 0.40925002098083496
# [29, 1000] loss: 1.617250080049038
# 设备号为: tensor([27,  8, 17, 47], device='cuda:3')，预测的设备号为:tensor([11,  8, 48, 47], device='cuda:3')
# [29, 1000] acc: 0.4347500205039978
# [30, 1000] loss: 1.5774740157872438
# 设备号为: tensor([34, 45, 39, 22], device='cuda:3')，预测的设备号为:tensor([34, 52,  3, 20], device='cuda:3')
# [30, 1000] acc: 0.4540000259876251
# [31, 1000] loss: 1.5326771907359362
# 设备号为: tensor([14, 53, 18, 47], device='cuda:3')，预测的设备号为:tensor([12, 53, 49, 21], device='cuda:3')
# [31, 1000] acc: 0.46425002813339233
# [32, 1000] loss: 1.4727155940458179
# 设备号为: tensor([ 4,  6, 32, 27], device='cuda:3')，预测的设备号为:tensor([ 4,  6, 26, 33], device='cuda:3')
# [32, 1000] acc: 0.4830000102519989
# [33, 1000] loss: 1.4371717025712132
# 设备号为: tensor([12,  3, 22,  3], device='cuda:3')，预测的设备号为:tensor([15, 39, 12, 25], device='cuda:3')
# [33, 1000] acc: 0.49400001764297485
# [34, 1000] loss: 1.3955469216555356
# 设备号为: tensor([27, 20, 14, 30], device='cuda:3')，预测的设备号为:tensor([39, 12, 16, 37], device='cuda:3')
# [34, 1000] acc: 0.5072500109672546
# [35, 1000] loss: 1.336147495508194
# 设备号为: tensor([18, 15, 47, 36], device='cuda:3')，预测的设备号为:tensor([41, 12, 43, 11], device='cuda:3')
# [35, 1000] acc: 0.5415000319480896
# [36, 1000] loss: 1.3366371330097317
# 设备号为: tensor([ 9,  8, 23, 45], device='cuda:3')，预测的设备号为:tensor([36,  8, 20, 45], device='cuda:3')
# [36, 1000] acc: 0.5337499976158142
# [37, 1000] loss: 1.2954866166710854
# 设备号为: tensor([10, 53, 21, 42], device='cuda:3')，预测的设备号为:tensor([26, 44, 43, 17], device='cuda:3')
# [37, 1000] acc: 0.5512500405311584
# [38, 1000] loss: 1.2800111516825854
# 设备号为: tensor([23, 35, 21, 30], device='cuda:3')，预测的设备号为:tensor([23, 35, 21, 30], device='cuda:3')
# [38, 1000] acc: 0.5477500557899475
# [39, 1000] loss: 1.2391631680876016
# 设备号为: tensor([38, 19, 52, 45], device='cuda:3')，预测的设备号为:tensor([10, 43, 52, 45], device='cuda:3')
# [39, 1000] acc: 0.5702500343322754
# [40, 1000] loss: 1.200759408980608
# 设备号为: tensor([11,  2, 35, 41], device='cuda:3')，预测的设备号为:tensor([11,  2, 35, 50], device='cuda:3')
# [40, 1000] acc: 0.5875000357627869
# [41, 1000] loss: 1.187404381211847
# 设备号为: tensor([17, 32, 52, 42], device='cuda:3')，预测的设备号为:tensor([17, 32, 52, 42], device='cuda:3')
# [41, 1000] acc: 0.5835000276565552
# [42, 1000] loss: 1.1540278979558498
# 设备号为: tensor([10, 51, 22, 33], device='cuda:3')，预测的设备号为:tensor([33, 42, 19, 33], device='cuda:3')
# [42, 1000] acc: 0.5882500410079956
# [43, 1000] loss: 1.148892365553882
# 设备号为: tensor([34, 12, 48, 19], device='cuda:3')，预测的设备号为:tensor([34, 12, 48, 13], device='cuda:3')
# [43, 1000] acc: 0.5980000495910645
# [44, 1000] loss: 1.1057986224563792
# 设备号为: tensor([38, 15, 30, 36], device='cuda:3')，预测的设备号为:tensor([ 3, 15, 30, 36], device='cuda:3')
# [44, 1000] acc: 0.6057500243186951
# [45, 1000] loss: 1.129577248983085
# 设备号为: tensor([38,  7, 35, 32], device='cuda:3')，预测的设备号为:tensor([ 1, 28, 35, 32], device='cuda:3')
# [45, 1000] acc: 0.6065000295639038
# [46, 1000] loss: 1.0924533099979161
# 设备号为: tensor([ 7,  4, 35, 27], device='cuda:3')，预测的设备号为:tensor([ 7, 34,  3, 27], device='cuda:3')
# [46, 1000] acc: 0.6190000176429749
# [47, 1000] loss: 1.0754237222950906
# 设备号为: tensor([52, 28,  9,  1], device='cuda:3')，预测的设备号为:tensor([44, 28,  9,  1], device='cuda:3')
# [47, 1000] acc: 0.6147500276565552
# [48, 1000] loss: 1.0493495582379402
# 设备号为: tensor([30, 21, 27,  4], device='cuda:3')，预测的设备号为:tensor([30, 43,  7,  4], device='cuda:3')
# [48, 1000] acc: 0.6317500472068787
# [49, 1000] loss: 1.0553433441780506
# 设备号为: tensor([53, 52, 12, 47], device='cuda:3')，预测的设备号为:tensor([15, 52, 12, 47], device='cuda:3')
# [49, 1000] acc: 0.6322500109672546
# [50, 1000] loss: 1.0529585091527551
# 设备号为: tensor([ 5,  4, 12, 13], device='cuda:3')，预测的设备号为:tensor([ 5,  4, 15, 13], device='cuda:3')
# [50, 1000] acc: 0.628000020980835
# [51, 1000] loss: 1.0133361535891892
# 设备号为: tensor([ 5, 33, 38, 18], device='cuda:3')，预测的设备号为:tensor([ 6,  8, 38, 18], device='cuda:3')
# [51, 1000] acc: 0.6345000267028809
# [52, 1000] loss: 1.003651646817103
# 设备号为: tensor([ 3, 35,  4, 50], device='cuda:3')，预测的设备号为:tensor([ 3, 35,  4, 49], device='cuda:3')
# [52, 1000] acc: 0.6445000171661377
# [53, 1000] loss: 0.9922830311264843
# 设备号为: tensor([ 8, 24, 37, 43], device='cuda:3')，预测的设备号为:tensor([ 5, 44, 37, 47], device='cuda:3')
# [53, 1000] acc: 0.6527500152587891
# [54, 1000] loss: 0.974381274310872
# 设备号为: tensor([51, 26, 35, 51], device='cuda:3')，预测的设备号为:tensor([18, 26, 35, 47], device='cuda:3')
# [54, 1000] acc: 0.6522500514984131
# [55, 1000] loss: 0.9527329268436879
# 设备号为: tensor([24, 14,  1, 19], device='cuda:3')，预测的设备号为:tensor([24, 14,  1, 47], device='cuda:3')
# [55, 1000] acc: 0.6612500548362732
# [56, 1000] loss: 0.9200946781756356
# 设备号为: tensor([12, 31, 45, 12], device='cuda:3')，预测的设备号为:tensor([12, 28, 45, 12], device='cuda:3')
# [56, 1000] acc: 0.6805000305175781
# [57, 1000] loss: 0.8967317883074284
# 设备号为: tensor([43,  2,  5, 32], device='cuda:3')，预测的设备号为:tensor([43,  2,  5, 32], device='cuda:3')
# [57, 1000] acc: 0.6827500462532043
# [58, 1000] loss: 0.9297150896633976
# 设备号为: tensor([45,  0,  2, 44], device='cuda:3')，预测的设备号为:tensor([45,  0,  2, 44], device='cuda:3')
# [58, 1000] acc: 0.6640000343322754
# [59, 1000] loss: 0.9005130356104346
# 设备号为: tensor([38, 53,  6, 26], device='cuda:3')，预测的设备号为:tensor([38, 53,  6, 26], device='cuda:3')
# [59, 1000] acc: 0.6805000305175781
# [60, 1000] loss: 0.8922171381348744
# 设备号为: tensor([40, 23, 42, 23], device='cuda:3')，预测的设备号为:tensor([40, 23, 42, 23], device='cuda:3')
# [60, 1000] acc: 0.6817500591278076
# [61, 1000] loss: 0.864682950175833
# 设备号为: tensor([29, 43, 34, 51], device='cuda:3')，预测的设备号为:tensor([29, 47, 34, 51], device='cuda:3')
# [61, 1000] acc: 0.6920000314712524
# [62, 1000] loss: 0.8554062732653692
# 设备号为: tensor([42, 40, 23, 33], device='cuda:3')，预测的设备号为:tensor([42, 40, 23, 33], device='cuda:3')
# [62, 1000] acc: 0.6955000162124634
# [63, 1000] loss: 0.8471786951059476
# 设备号为: tensor([31, 25,  1, 49], device='cuda:3')，预测的设备号为:tensor([48, 25,  1, 49], device='cuda:3')
# [63, 1000] acc: 0.6960000395774841
# [64, 1000] loss: 0.8503369753099977
# 设备号为: tensor([45, 53, 36, 51], device='cuda:3')，预测的设备号为:tensor([45, 53, 36, 51], device='cuda:3')
# [64, 1000] acc: 0.6932500600814819
# [65, 1000] loss: 0.816827609015163
# 设备号为: tensor([ 4, 31,  7, 26], device='cuda:3')，预测的设备号为:tensor([ 4, 31,  7, 26], device='cuda:3')
# [65, 1000] acc: 0.7140000462532043
# [66, 1000] loss: 0.8401350202541799
# 设备号为: tensor([47,  2, 32,  7], device='cuda:3')，预测的设备号为:tensor([19,  2, 32,  7], device='cuda:3')
# [66, 1000] acc: 0.706000030040741
# [67, 1000] loss: 0.7875054910443723
# 设备号为: tensor([36, 32, 50, 23], device='cuda:3')，预测的设备号为:tensor([36, 32, 49, 23], device='cuda:3')
# [67, 1000] acc: 0.7157500386238098
# [68, 1000] loss: 0.7949092377591879
# 设备号为: tensor([41,  9, 45, 41], device='cuda:3')，预测的设备号为:tensor([43,  9, 45, 41], device='cuda:3')
# [68, 1000] acc: 0.7140000462532043
# [69, 1000] loss: 0.7906858851311263
# 设备号为: tensor([41, 42, 42,  5], device='cuda:3')，预测的设备号为:tensor([41, 42, 42,  5], device='cuda:3')
# [69, 1000] acc: 0.7202500104904175
# [70, 1000] loss: 0.7874767497163266
# 设备号为: tensor([ 7,  2, 31, 18], device='cuda:3')，预测的设备号为:tensor([ 7,  2, 31, 18], device='cuda:3')
# [70, 1000] acc: 0.721500039100647
# [71, 1000] loss: 0.7461844186149538
# 设备号为: tensor([ 0, 12, 45, 38], device='cuda:3')，预测的设备号为:tensor([ 0, 12, 45, 38], device='cuda:3')
# [71, 1000] acc: 0.7302500605583191
# [72, 1000] loss: 0.7533141629309684
# 设备号为: tensor([21, 20, 46,  5], device='cuda:3')，预测的设备号为:tensor([51, 12, 46,  5], device='cuda:3')
# [72, 1000] acc: 0.7205000519752502
# [73, 1000] loss: 0.7269705505296588
# 设备号为: tensor([33, 38, 31, 47], device='cuda:3')，预测的设备号为:tensor([26, 38, 31, 47], device='cuda:3')
# [73, 1000] acc: 0.7367500066757202
# [74, 1000] loss: 0.7414382563873659
# 设备号为: tensor([22, 31, 36, 38], device='cuda:3')，预测的设备号为:tensor([22, 31, 36, 38], device='cuda:3')
# [74, 1000] acc: 0.7307500243186951
# [75, 1000] loss: 0.7346077410061844
# 设备号为: tensor([28, 14,  5, 16], device='cuda:3')，预测的设备号为:tensor([28, 14,  5, 16], device='cuda:3')
# [75, 1000] acc: 0.7517500519752502
# [76, 1000] loss: 0.734586077238433
# 设备号为: tensor([ 4, 31, 22,  7], device='cuda:3')，预测的设备号为:tensor([39, 31, 20,  7], device='cuda:3')
# [76, 1000] acc: 0.737500011920929
# [77, 1000] loss: 0.6979100013417192
# 设备号为: tensor([41, 19,  1, 52], device='cuda:3')，预测的设备号为:tensor([40, 19,  1, 45], device='cuda:3')
# [77, 1000] acc: 0.7420000433921814
# [78, 1000] loss: 0.694412919012364
# 设备号为: tensor([33, 52,  0, 19], device='cuda:3')，预测的设备号为:tensor([33, 52,  0, 19], device='cuda:3')
# [78, 1000] acc: 0.753000020980835

# %%
torch.cuda.current_device ()

# %%
aa = iter(train_loader)
a, b = aa.next()
print(a[0].shape)
print(a)

# %%
input = torch.randn(20, 16, 50, 100)
input.shape

# %%
m2=nn.Conv2d(16,33,(3,5),stride=(2,1),padding=(4,2))
inpu1=Variable(torch.randn(20,16,50,100))
print(inpu1.shape)
output=m2(inpu1)
print(output.shape)

# %%
total

# %%
torch.cuda.current_device ()

# %%
x = range(0, len(average_loss_series))
plt.figure()
plt.plot(x, average_loss_series)
plt.savefig("Loss-省略最后三项-1.png", bbox_inches="tight")
plt.show()
