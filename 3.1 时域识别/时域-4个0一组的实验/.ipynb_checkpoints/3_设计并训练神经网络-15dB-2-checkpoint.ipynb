# %%
import matplotlib.pyplot as plt
import torchvision as tv
from torchvision import transforms, utils


import torch.nn.functional as F
import torch 
import torch.nn as nn
from torch.autograd import Variable
import torchvision.models as models
# from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader
# from PIL import Image
# import numpy as np
import torch.optim as optim
# import os
import time

import loadData

# %%
device = torch.device("cuda:1")

# %%
# 日志记录模块2
import logging
logger = logging.getLogger(__name__)
logger.setLevel(level = logging.INFO)
handler = logging.FileHandler("./15dB-时域识别-4个0一组-1500epoches-1")
handler.setLevel(logging.INFO)
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

console = logging.StreamHandler()
console.setLevel(logging.INFO)

logger.addHandler(handler)
logger.addHandler(console)

# %%
startTime = time.time()

# %%
transforms = tv.transforms.Compose([
    transforms.ToTensor(),
])


numOfBatch = 9
pixel = 64
flag = 0
root = f'./{numOfBatch}/data'
batchSize = 4
train_data = loadData.MyDataset(txt=f'files_train15.txt', transform=None)
test_data = loadData.MyDataset(txt=f'files_test15.txt', transform=None)



train_loader = DataLoader(dataset=train_data, batch_size=batchSize, shuffle=True, num_workers=2)
test_loader = DataLoader(dataset=test_data, batch_size=batchSize, shuffle=True, num_workers=2)


print(train_loader)
print(test_loader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7f2292047c10>
# <torch.utils.data.dataloader.DataLoader object at 0x7f22e1431090>

# %%
print(len(train_data))
print(len(test_loader))
# Out:
# 10584
# 743

# %%
# data = iter(train_loader)

# # print(type(data))
# # print(len(data))
# data_, label = data.next()
# print(train_loader.batch_size)
# print(data_.shape)
# # print(label)
# # print(data_, label)

# %%
x = torch.randn(4, 1, 1200, 2).float()
conv = nn.Conv2d(in_channels = 1, out_channels = 128, kernel_size = (10, 1))
x = conv(x)
x.shape
conv2 = nn.Conv2d(in_channels = 128, out_channels = 256, kernel_size = (3, 2))
x = conv2(x)
x.shape
# Out:
# torch.Size([4, 256, 1189, 1])

# %%
# 256*1189

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(in_channels = 1, out_channels = 8, kernel_size = (1, 10))
        self.conv2 = nn.Conv2d(in_channels = 8, out_channels = 16, kernel_size = (2, 3))
        
        self.dropout1 = nn.Dropout(0.5)
        self.dropout2 = nn.Dropout(0.5)
        
        self.fc1 = nn.Linear(10064, 1024)
        self.fc2 = nn.Linear(1024, 500)
        self.fc3 = nn.Linear(500, 54)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 1)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 1)
    
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.dropout1(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.dropout2(x)
        x = self.fc3(x)
        output = F.log_softmax(x, dim=1)
        return output

# %%
# TensorBoard
# from tensorboardX import SummaryWriter
# net = Net()
# # writer = SummaryWriter('writer928') #建立一个保存数据用的东西
# dummy_input = torch.rand(2,160,400)  # 假设输入20张1*28*28的图片
# with SummaryWriter(comment='Net1') as w:
#     w.add_graph(net, (dummy_input,))

# %%
net = Net()

net = net.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(params=net.parameters(), lr=0.0001, momentum=0.9)

epochs = 1500
average_loss_series = []

# %%
for a, b in enumerate(train_loader):
    inputs, labels = b
    print(inputs.shape)
    break
# Out:
# torch.Size([4, 1, 2, 640])

# %%
# %matplotlib inline


if __name__ == '__main__':
    for epoch in range(epochs):
        running_loss = 0.0
        running_acc = 0.0

        for i, data in enumerate(train_loader):
#             print("i:", i )
#             print("data: ", data[0])
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()

#             inputs = inputs.permute(0, 2, 1)
            
            inputs = torch.tensor(inputs, dtype=torch.float32, device = device)

            outputs = net(inputs)
            _, predicted = torch.max(outputs.data, dim=1)
            total = labels.size(0)
#             print('原来的值:{0}, 预测的值:{1}'.format(labels, predicted))
            running_correct = (predicted == labels).sum()
            running_acc += running_correct
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            loss.backward()
            optimizer.step()

            # 每loopNum个batch打印一次训练状态
            loopNum = 1000
            if i % loopNum == loopNum - 1:
                average_loss = running_loss / loopNum
                logger.info('[{0}, {1}] loss: {2}'.format(epoch + 1, i + 1, average_loss))
                logger.info('设备号为: {0}，预测的设备号为:{1}'.format(labels, predicted))
#                 logger.info(torch.cuda.current_device ())
                running_acc = running_acc.float()
                average_acc = running_acc / loopNum / total
                
                logger.info('[{0}, {1}] acc: {2}'.format(epoch + 1, i + 1, average_acc))
                average_loss_series.append(average_loss)
                running_loss = 0.0
                running_acc = 0.0

    x = range(0, len(average_loss_series))
    plt.figure()
    plt.plot(x, average_loss_series)
#     plt.savefig("Loss.png")
    plt.savefig("Loss.png", bbox_inches="tight")
    plt.show()
    

    # %%
    # 在测试集上测试
    realLabel = []
    predictedLabel = []

    def correct_rate(net, testloader):
        correct = 0.0
        total = 0.0
        count = 0
        correctpredict = 0

        for data in testloader:
            images, labels = data
            images, labels = images.to(device),labels.to(device)
            realLabel.append([int(label) for label in labels])
    
            tests = torch.tensor(images, dtype=torch.float32,device=device)
            outputs = net(tests)

            _, predicted = torch.max(outputs.data, dim=1)
            logger.info('设备号为: {0}，模型训练后得到的设备号为:{1}'.format(labels, predicted))
#             deviceNumber = torch.cuda.current_device ()
#             logger.info(deviceNumber)
            
            labelsn = labels.cpu().numpy()
            pn = predicted.cpu().numpy()
            count += len(labelsn)
            
            for i in range(len(labelsn)):
                if labelsn[i] == pn[i]:
                    correctpredict += 1
                
            
            logger.info('目前一共测试了{0}组，预测成功的一共有{1}组'.format(count, correctpredict))
            predictedLabel.append([int(label) for label in predicted])
            
            total += labels.size(0)
            correct += (predicted == labels).sum()

            
        logger.info("total的值为：{total}")
#         return 100 * correct  # / total
        return 100 * correct/ total 


    correct = correct_rate(net, test_loader)
    logger.info(f'{len(test_loader) * 3}张测试集中准确率为： {correct}%')

    # %%
    import itertools
    from sklearn.metrics import confusion_matrix

    realLabel = list(itertools.chain.from_iterable(realLabel))
    predictedLabel = list(itertools.chain.from_iterable(predictedLabel))

    cm = confusion_matrix(realLabel, predictedLabel)
    logger.info(cm)

#     logger.info('the running time is:{1}'.format(time.time() - startTime))
    torch.save(net.state_dict(), f'./model_15dB_1.pkl')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# [1, 1000] loss: 3.9890654692649843
# 设备号为: tensor([21, 47, 53, 34], device='cuda:0')，预测的设备号为:tensor([23, 16,  7,  1], device='cuda:0')
# [1, 1000] acc: 0.016750000417232513
# [1, 2000] loss: 3.9870375010967254
# 设备号为: tensor([43,  0, 24, 34], device='cuda:0')，预测的设备号为:tensor([18, 49, 24, 10], device='cuda:0')
# [1, 2000] acc: 0.020500000566244125
# [2, 1000] loss: 3.9848078527450563
# 设备号为: tensor([25,  1, 32, 35], device='cuda:0')，预测的设备号为:tensor([ 1, 33, 32, 23], device='cuda:0')
# [2, 1000] acc: 0.027750002220273018
# [2, 2000] loss: 3.9835920617580416
# 设备号为: tensor([ 7,  7, 52,  4], device='cuda:0')，预测的设备号为:tensor([16, 24, 24, 18], device='cuda:0')
# [2, 2000] acc: 0.02500000037252903
# [3, 1000] loss: 3.976602894306183
# 设备号为: tensor([48, 49, 11, 21], device='cuda:0')，预测的设备号为:tensor([43, 40, 40, 40], device='cuda:0')
# [3, 1000] acc: 0.032750003039836884
# [3, 2000] loss: 3.973751735210419
# 设备号为: tensor([10, 28, 16, 30], device='cuda:0')，预测的设备号为:tensor([42, 14, 23, 32], device='cuda:0')
# [3, 2000] acc: 0.036000002175569534
# [4, 1000] loss: 3.957262828588486
# 设备号为: tensor([11, 37, 10, 13], device='cuda:0')，预测的设备号为:tensor([13, 16,  0, 21], device='cuda:0')
# [4, 1000] acc: 0.049000002443790436
# [4, 2000] loss: 3.942388155221939
# 设备号为: tensor([ 8, 41, 50, 16], device='cuda:0')，预测的设备号为:tensor([ 0, 19, 22, 22], device='cuda:0')
# [4, 2000] acc: 0.048250000923871994
# [5, 1000] loss: 3.850980895280838
# 设备号为: tensor([ 0, 20, 13, 18], device='cuda:0')，预测的设备号为:tensor([49, 15, 53, 44], device='cuda:0')
# [5, 1000] acc: 0.06350000202655792
# [5, 2000] loss: 3.6805616011619566
# 设备号为: tensor([11, 50,  2, 35], device='cuda:0')，预测的设备号为:tensor([ 6, 15,  0,  9], device='cuda:0')
# [5, 2000] acc: 0.06825000047683716
# [6, 1000] loss: 3.310893248319626
# 设备号为: tensor([13,  2, 42, 12], device='cuda:0')，预测的设备号为:tensor([24,  2, 53, 46], device='cuda:0')
# [6, 1000] acc: 0.08625000715255737
# [6, 2000] loss: 3.180506487607956
# 设备号为: tensor([52,  9, 47, 38], device='cuda:0')，预测的设备号为:tensor([52,  0, 22,  3], device='cuda:0')
# [6, 2000] acc: 0.10450000315904617
# [7, 1000] loss: 3.043879066348076
# 设备号为: tensor([21,  7, 39, 24], device='cuda:0')，预测的设备号为:tensor([41,  3,  0, 23], device='cuda:0')
# [7, 1000] acc: 0.11525000631809235
# [7, 2000] loss: 2.9725298644304274
# 设备号为: tensor([ 8, 26, 12, 44], device='cuda:0')，预测的设备号为:tensor([ 7,  9, 22, 44], device='cuda:0')
# [7, 2000] acc: 0.13850000500679016
# [8, 1000] loss: 2.86789954328537
# 设备号为: tensor([36, 52, 30, 43], device='cuda:0')，预测的设备号为:tensor([ 3, 53, 30, 17], device='cuda:0')
# [8, 1000] acc: 0.15200001001358032
# [8, 2000] loss: 2.802901226043701
# 设备号为: tensor([46, 29, 14, 21], device='cuda:0')，预测的设备号为:tensor([53, 27, 41, 14], device='cuda:0')
# [8, 2000] acc: 0.15900000929832458
# [9, 1000] loss: 2.6826075040102006
# 设备号为: tensor([50, 42, 46,  3], device='cuda:0')，预测的设备号为:tensor([22, 42, 52, 38], device='cuda:0')
# [9, 1000] acc: 0.18250000476837158
# [9, 2000] loss: 2.625790859937668
# 设备号为: tensor([37, 34, 22, 36], device='cuda:0')，预测的设备号为:tensor([30, 11, 51, 11], device='cuda:0')
# [9, 2000] acc: 0.1965000033378601
# [10, 1000] loss: 2.4793847498893737
# 设备号为: tensor([26,  9, 46, 20], device='cuda:0')，预测的设备号为:tensor([ 9, 36, 45, 19], device='cuda:0')
# [10, 1000] acc: 0.22850000858306885
# [10, 2000] loss: 2.379813066422939
# 设备号为: tensor([16, 30, 31, 10], device='cuda:0')，预测的设备号为:tensor([18, 37, 25, 26], device='cuda:0')
# [10, 2000] acc: 0.24525001645088196
# [11, 1000] loss: 2.276669411122799
# 设备号为: tensor([48, 31,  4, 43], device='cuda:0')，预测的设备号为:tensor([17, 31,  4, 42], device='cuda:0')
# [11, 1000] acc: 0.27674999833106995
# [11, 2000] loss: 2.2354875980615616
# 设备号为: tensor([39, 38, 11, 16], device='cuda:0')，预测的设备号为:tensor([ 7,  9,  4, 40], device='cuda:0')
# [11, 2000] acc: 0.2697499990463257
# [12, 1000] loss: 2.144783228099346
# 设备号为: tensor([45,  8, 14, 37], device='cuda:0')，预测的设备号为:tensor([46,  1, 16, 30], device='cuda:0')
# [12, 1000] acc: 0.2930000126361847
# [12, 2000] loss: 2.1600767005085943
# 设备号为: tensor([ 6,  1, 13,  1], device='cuda:0')，预测的设备号为:tensor([ 6,  0, 19,  0], device='cuda:0')
# [12, 2000] acc: 0.2902500033378601
# [13, 1000] loss: 2.0693305535316466
# 设备号为: tensor([18,  7,  0, 30], device='cuda:0')，预测的设备号为:tensor([22,  7,  0, 30], device='cuda:0')
# [13, 1000] acc: 0.3135000169277191
# [13, 2000] loss: 2.0409714903235434
# 设备号为: tensor([49,  5, 36, 19], device='cuda:0')，预测的设备号为:tensor([14,  0, 36, 16], device='cuda:0')
# [13, 2000] acc: 0.32375001907348633
# [14, 1000] loss: 1.980899610698223
# 设备号为: tensor([26, 19, 34, 37], device='cuda:0')，预测的设备号为:tensor([26, 22, 11, 37], device='cuda:0')
# [14, 1000] acc: 0.34200000762939453
# [14, 2000] loss: 1.9652593067586421
# 设备号为: tensor([ 2,  5, 46, 43], device='cuda:0')，预测的设备号为:tensor([29,  9, 44, 42], device='cuda:0')
# [14, 2000] acc: 0.34800001978874207
# [15, 1000] loss: 1.90110292750597
# 设备号为: tensor([44, 29, 39, 45], device='cuda:0')，预测的设备号为:tensor([45, 39, 11, 45], device='cuda:0')
# [15, 1000] acc: 0.36275002360343933
# [15, 2000] loss: 1.867724134027958
# 设备号为: tensor([46,  9, 24, 10], device='cuda:0')，预测的设备号为:tensor([53, 25, 37, 32], device='cuda:0')
# [15, 2000] acc: 0.3685000240802765
# [16, 1000] loss: 1.8104358306974173
# 设备号为: tensor([33, 51, 52,  7], device='cuda:0')，预测的设备号为:tensor([33, 14, 52, 34], device='cuda:0')
# [16, 1000] acc: 0.3945000171661377
# [16, 2000] loss: 1.7881578776240348
# 设备号为: tensor([30, 17, 32, 27], device='cuda:0')，预测的设备号为:tensor([29, 17, 32, 27], device='cuda:0')
# [16, 2000] acc: 0.39750000834465027
# [17, 1000] loss: 1.7254522246122361
# 设备号为: tensor([46, 30,  4, 19], device='cuda:0')，预测的设备号为:tensor([46, 37,  4, 19], device='cuda:0')
# [17, 1000] acc: 0.41725000739097595
# [17, 2000] loss: 1.7527928888350726
# 设备号为: tensor([13, 49, 50, 33], device='cuda:0')，预测的设备号为:tensor([13, 50, 42,  4], device='cuda:0')
# [17, 2000] acc: 0.40950003266334534
# [18, 1000] loss: 1.6533237358480692
# 设备号为: tensor([ 5, 46, 21, 50], device='cuda:0')，预测的设备号为:tensor([ 1, 53, 49, 50], device='cuda:0')
# [18, 1000] acc: 0.44225001335144043
# [18, 2000] loss: 1.6666918539851905
# 设备号为: tensor([31, 15, 24, 40], device='cuda:0')，预测的设备号为:tensor([26, 15, 24, 42], device='cuda:0')
# [18, 2000] acc: 0.4347500205039978
# [19, 1000] loss: 1.6366026314496993
# 设备号为: tensor([ 3, 18, 34,  4], device='cuda:0')，预测的设备号为:tensor([39, 41, 34,  4], device='cuda:0')
# [19, 1000] acc: 0.4467500150203705
# [19, 2000] loss: 1.6169505816400052
# 设备号为: tensor([ 9, 16, 27, 49], device='cuda:0')，预测的设备号为:tensor([ 9, 23, 27, 13], device='cuda:0')
# [19, 2000] acc: 0.4557500183582306
# [20, 1000] loss: 1.5584878694862128
# 设备号为: tensor([17, 51, 16, 15], device='cuda:0')，预测的设备号为:tensor([17, 21, 16, 12], device='cuda:0')
# [20, 1000] acc: 0.47300001978874207
# [20, 2000] loss: 1.6008859193325042
# 设备号为: tensor([30, 16,  1, 13], device='cuda:0')，预测的设备号为:tensor([37, 20,  1, 13], device='cuda:0')
# [20, 2000] acc: 0.45375001430511475
# [21, 1000] loss: 1.5416983859091997
# 设备号为: tensor([ 8, 39, 38, 27], device='cuda:0')，预测的设备号为:tensor([ 8, 34, 38, 36], device='cuda:0')
# [21, 1000] acc: 0.4752500355243683
# [21, 2000] loss: 1.5574127913415432
# 设备号为: tensor([27, 45, 41, 43], device='cuda:0')，预测的设备号为:tensor([ 3, 45, 42, 17], device='cuda:0')
# [21, 2000] acc: 0.46400001645088196
# [22, 1000] loss: 1.4747314161360263
# 设备号为: tensor([44, 45, 45, 43], device='cuda:0')，预测的设备号为:tensor([44, 45, 45, 42], device='cuda:0')
# [22, 1000] acc: 0.4910000264644623
# [22, 2000] loss: 1.5149836268574
# 设备号为: tensor([50, 19, 53, 44], device='cuda:0')，预测的设备号为:tensor([50, 19, 53, 46], device='cuda:0')
# [22, 2000] acc: 0.49000000953674316
# [23, 1000] loss: 1.4970226735770702
# 设备号为: tensor([20, 25, 42, 26], device='cuda:0')，预测的设备号为:tensor([49, 25, 42, 26], device='cuda:0')
# [23, 1000] acc: 0.4987500309944153
# [23, 2000] loss: 1.4786859864927828
# 设备号为: tensor([48, 26, 42, 27], device='cuda:0')，预测的设备号为:tensor([48, 26, 40, 27], device='cuda:0')
# [23, 2000] acc: 0.4982500374317169
# [24, 1000] loss: 1.434101715348661
# 设备号为: tensor([15, 45, 39, 22], device='cuda:0')，预测的设备号为:tensor([15, 45, 11, 43], device='cuda:0')
# [24, 1000] acc: 0.5060000419616699
# [24, 2000] loss: 1.4790548121551983
# 设备号为: tensor([52, 52,  6, 26], device='cuda:0')，预测的设备号为:tensor([45, 45,  8, 26], device='cuda:0')
# [24, 2000] acc: 0.4922500252723694
# [25, 1000] loss: 1.4371144507825375
# 设备号为: tensor([23, 17,  8,  4], device='cuda:0')，预测的设备号为:tensor([13, 17,  9,  4], device='cuda:0')
# [25, 1000] acc: 0.5072500109672546
# [25, 2000] loss: 1.4352914835512638
# 设备号为: tensor([31, 48, 41,  6], device='cuda:0')，预测的设备号为:tensor([31, 48, 50,  6], device='cuda:0')
# [25, 2000] acc: 0.5130000114440918
# [26, 1000] loss: 1.3877233918607235
# 设备号为: tensor([50, 15, 18, 33], device='cuda:0')，预测的设备号为:tensor([50, 53, 47,  5], device='cuda:0')
# [26, 1000] acc: 0.5295000076293945
# [26, 2000] loss: 1.4162235985845328
# 设备号为: tensor([32,  7, 21,  7], device='cuda:0')，预测的设备号为:tensor([32,  7, 43,  7], device='cuda:0')
# [26, 2000] acc: 0.515500009059906
# [27, 1000] loss: 1.4074933389704674
# 设备号为: tensor([38, 36, 44, 45], device='cuda:0')，预测的设备号为:tensor([25, 36, 44, 45], device='cuda:0')
# [27, 1000] acc: 0.5170000195503235
# [27, 2000] loss: 1.3550980609580874
# 设备号为: tensor([29, 45, 50, 37], device='cuda:0')，预测的设备号为:tensor([29, 45, 50, 37], device='cuda:0')
# [27, 2000] acc: 0.5445000529289246
# [28, 1000] loss: 1.374160685606301
# 设备号为: tensor([ 9, 34, 50, 33], device='cuda:0')，预测的设备号为:tensor([36, 11, 40,  1], device='cuda:0')
# [28, 1000] acc: 0.5367500185966492
# [28, 2000] loss: 1.3624984176307917
# 设备号为: tensor([44, 31,  5, 14], device='cuda:0')，预测的设备号为:tensor([12, 31,  5, 19], device='cuda:0')
# [28, 2000] acc: 0.5300000309944153
# [29, 1000] loss: 1.3473651106879114
# 设备号为: tensor([ 1, 23, 48, 47], device='cuda:0')，预测的设备号为:tensor([ 1, 23, 48, 47], device='cuda:0')
# [29, 1000] acc: 0.5432500243186951
# [29, 2000] loss: 1.3610339510068297
# 设备号为: tensor([25, 40, 17,  1], device='cuda:0')，预测的设备号为:tensor([ 5, 50, 17,  9], device='cuda:0')
# [29, 2000] acc: 0.5440000295639038
# [30, 1000] loss: 1.2975995113290846
# 设备号为: tensor([17, 10, 48, 19], device='cuda:0')，预测的设备号为:tensor([17, 10, 48, 14], device='cuda:0')
# [30, 1000] acc: 0.5582500100135803
# [30, 2000] loss: 1.3407839258611203
# 设备号为: tensor([27,  6, 52, 26], device='cuda:0')，预测的设备号为:tensor([27, 38, 45, 26], device='cuda:0')
# [30, 2000] acc: 0.5440000295639038
# [31, 1000] loss: 1.3291335044652224
# 设备号为: tensor([ 3,  7, 18, 46], device='cuda:0')，预测的设备号为:tensor([36, 28, 18, 46], device='cuda:0')
# [31, 1000] acc: 0.5425000190734863
# [31, 2000] loss: 1.2916173331663012
# 设备号为: tensor([53, 27, 27,  7], device='cuda:0')，预测的设备号为:tensor([53, 27, 27,  7], device='cuda:0')
# [31, 2000] acc: 0.5630000233650208
# [32, 1000] loss: 1.2764961104594403
# 设备号为: tensor([ 0, 11, 27, 32], device='cuda:0')，预测的设备号为:tensor([ 1, 11, 38, 36], device='cuda:0')
# [32, 1000] acc: 0.5632500052452087
# [32, 2000] loss: 1.267551949121058
# 设备号为: tensor([26, 26, 47, 44], device='cuda:0')，预测的设备号为:tensor([26, 26, 47, 24], device='cuda:0')
# [32, 2000] acc: 0.5635000467300415
# [33, 1000] loss: 1.2838744364455343
# 设备号为: tensor([ 3, 22,  4, 18], device='cuda:0')，预测的设备号为:tensor([ 3, 13,  4, 51], device='cuda:0')
# [33, 1000] acc: 0.5602500438690186
# [33, 2000] loss: 1.250505955092609
# 设备号为: tensor([17, 52, 43, 12], device='cuda:0')，预测的设备号为:tensor([17, 52, 43, 24], device='cuda:0')
# [33, 2000] acc: 0.5722500085830688
# [34, 1000] loss: 1.2585790273360908
# 设备号为: tensor([ 7, 50, 41,  4], device='cuda:0')，预测的设备号为:tensor([27, 40, 41,  4], device='cuda:0')
# [34, 1000] acc: 0.5667500495910645
# [34, 2000] loss: 1.2260631286632269
# 设备号为: tensor([49,  5, 29, 29], device='cuda:0')，预测的设备号为:tensor([42,  5,  2, 29], device='cuda:0')
# [34, 2000] acc: 0.5785000324249268
# [35, 1000] loss: 1.2287495281882583
# 设备号为: tensor([42, 42, 51, 33], device='cuda:0')，预测的设备号为:tensor([42, 21, 49,  9], device='cuda:0')
# [35, 1000] acc: 0.5827500224113464
# [35, 2000] loss: 1.2371969038378448
# 设备号为: tensor([43,  2, 43, 30], device='cuda:0')，预测的设备号为:tensor([31,  2, 43, 30], device='cuda:0')
# [35, 2000] acc: 0.5737500190734863
# [36, 1000] loss: 1.202081992506981
# 设备号为: tensor([10, 19, 33, 31], device='cuda:0')，预测的设备号为:tensor([33, 43,  3, 48], device='cuda:0')
# [36, 1000] acc: 0.5830000042915344
# [36, 2000] loss: 1.2351063610464335
# 设备号为: tensor([14, 10, 22, 40], device='cuda:0')，预测的设备号为:tensor([14,  9, 47, 42], device='cuda:0')
# [36, 2000] acc: 0.5712500214576721
# [37, 1000] loss: 1.2191426289491356
# 设备号为: tensor([34,  9, 41, 50], device='cuda:0')，预测的设备号为:tensor([34, 38, 47, 50], device='cuda:0')
# [37, 1000] acc: 0.5822499990463257
# [37, 2000] loss: 1.21232785012573
# 设备号为: tensor([23, 49, 53, 48], device='cuda:0')，预测的设备号为:tensor([14, 49, 53, 48], device='cuda:0')
# [37, 2000] acc: 0.5827500224113464
# [38, 1000] loss: 1.220289415538311
# 设备号为: tensor([45, 13,  5, 16], device='cuda:0')，预测的设备号为:tensor([45, 13,  8, 20], device='cuda:0')
# [38, 1000] acc: 0.5720000267028809
# [38, 2000] loss: 1.1833214978110045
# 设备号为: tensor([ 9, 33, 35, 49], device='cuda:0')，预测的设备号为:tensor([ 9,  3, 35, 49], device='cuda:0')
# [38, 2000] acc: 0.5890000462532043
# [39, 1000] loss: 1.209470623448491
# 设备号为: tensor([26, 47,  1, 26], device='cuda:0')，预测的设备号为:tensor([26, 41,  1, 26], device='cuda:0')
# [39, 1000] acc: 0.5815000534057617
# [39, 2000] loss: 1.1760387404523789
# 设备号为: tensor([24, 19, 32, 52], device='cuda:0')，预测的设备号为:tensor([24, 19, 32, 52], device='cuda:0')
# [39, 2000] acc: 0.6012500524520874
# [40, 1000] loss: 1.1285883589573205
# 设备号为: tensor([ 6, 14, 48,  3], device='cuda:0')，预测的设备号为:tensor([ 5, 12, 48,  8], device='cuda:0')
# [40, 1000] acc: 0.6165000200271606
# [40, 2000] loss: 1.1442331809327007
# 设备号为: tensor([ 1, 41, 32, 35], device='cuda:0')，预测的设备号为:tensor([ 1, 42, 32, 35], device='cuda:0')
# [40, 2000] acc: 0.6035000085830688
# [41, 1000] loss: 1.1469930168315767
# 设备号为: tensor([15, 43, 31, 21], device='cuda:0')，预测的设备号为:tensor([23, 42, 31, 51], device='cuda:0')
# [41, 1000] acc: 0.5980000495910645
# [41, 2000] loss: 1.1286640377268196
# 设备号为: tensor([ 6, 15, 48,  2], device='cuda:0')，预测的设备号为:tensor([ 6, 15, 48,  4], device='cuda:0')
# [41, 2000] acc: 0.612250030040741
# [42, 1000] loss: 1.132743087971583
# 设备号为: tensor([ 3, 50, 43,  2], device='cuda:0')，预测的设备号为:tensor([28, 50, 43, 39], device='cuda:0')
# [42, 1000] acc: 0.60875004529953
# [42, 2000] loss: 1.1232635055352003
# 设备号为: tensor([25,  3, 53, 36], device='cuda:0')，预测的设备号为:tensor([31, 33, 15, 36], device='cuda:0')
# [42, 2000] acc: 0.6127500534057617
# [43, 1000] loss: 1.1340956435091794
# 设备号为: tensor([39, 34, 11, 21], device='cuda:0')，预测的设备号为:tensor([ 3, 34, 27, 47], device='cuda:0')
# [43, 1000] acc: 0.6032500267028809
# [43, 2000] loss: 1.1107965227738024
# 设备号为: tensor([49, 32, 47, 23], device='cuda:0')，预测的设备号为:tensor([50, 32, 18, 23], device='cuda:0')
# [43, 2000] acc: 0.6137500405311584
# [44, 1000] loss: 1.1110956646054984
# 设备号为: tensor([31, 12, 35,  5], device='cuda:0')，预测的设备号为:tensor([31, 12, 35,  8], device='cuda:0')
# [44, 1000] acc: 0.6147500276565552
# [44, 2000] loss: 1.1072985553182662
# 设备号为: tensor([ 5, 39, 22,  8], device='cuda:0')，预测的设备号为:tensor([ 0, 39, 20,  8], device='cuda:0')
# [44, 2000] acc: 0.6205000281333923
# [45, 1000] loss: 1.0773489339556546
# 设备号为: tensor([53, 24, 40, 16], device='cuda:0')，预测的设备号为:tensor([12, 24, 40, 19], device='cuda:0')
# [45, 1000] acc: 0.628000020980835
# [45, 2000] loss: 1.1276673254650087
# 设备号为: tensor([11, 50, 30,  2], device='cuda:0')，预测的设备号为:tensor([36, 50, 30,  2], device='cuda:0')
# [45, 2000] acc: 0.6177500486373901
# [46, 1000] loss: 1.0780827143695206
# 设备号为: tensor([52,  6, 32, 14], device='cuda:0')，预测的设备号为:tensor([52,  0, 32, 14], device='cuda:0')
# [46, 1000] acc: 0.6265000104904175
# [46, 2000] loss: 1.106404506802559
# 设备号为: tensor([41, 16, 30, 42], device='cuda:0')，预测的设备号为:tensor([21, 14, 30, 42], device='cuda:0')
# [46, 2000] acc: 0.6137500405311584
# [47, 1000] loss: 1.0676936965314672
# 设备号为: tensor([49, 34, 28,  4], device='cuda:0')，预测的设备号为:tensor([49, 39, 28,  4], device='cuda:0')
# [47, 1000] acc: 0.6312500238418579
# [47, 2000] loss: 1.0686467070281505
# 设备号为: tensor([40,  9, 14, 21], device='cuda:0')，预测的设备号为:tensor([40, 33, 14, 21], device='cuda:0')
# [47, 2000] acc: 0.6317500472068787
# [48, 1000] loss: 1.0729808482900263
# 设备号为: tensor([16, 27, 34, 49], device='cuda:0')，预测的设备号为:tensor([14, 27, 34, 42], device='cuda:0')
# [48, 1000] acc: 0.6260000467300415
# [48, 2000] loss: 1.0890777927357704
# 设备号为: tensor([19, 14, 53, 13], device='cuda:0')，预测的设备号为:tensor([43, 14, 53, 40], device='cuda:0')
# [48, 2000] acc: 0.6235000491142273
# [49, 1000] loss: 1.0304921498997137
# 设备号为: tensor([14, 13, 19, 29], device='cuda:0')，预测的设备号为:tensor([14, 13, 20, 29], device='cuda:0')
# [49, 1000] acc: 0.6365000009536743
# [49, 2000] loss: 1.0504354894477874
# 设备号为: tensor([28, 47,  7, 19], device='cuda:0')，预测的设备号为:tensor([28, 47, 33, 19], device='cuda:0')
# [49, 2000] acc: 0.6330000162124634
# [50, 1000] loss: 1.030009993519634
# 设备号为: tensor([ 7, 12, 16, 38], device='cuda:0')，预测的设备号为:tensor([ 7, 12, 51, 38], device='cuda:0')
# [50, 1000] acc: 0.6547500491142273
# [50, 2000] loss: 1.0291964696636424
# 设备号为: tensor([44, 45, 13, 26], device='cuda:0')，预测的设备号为:tensor([44, 45, 13, 26], device='cuda:0')
# [50, 2000] acc: 0.6460000276565552
# [51, 1000] loss: 0.9999280984839425
# 设备号为: tensor([39, 35, 43, 14], device='cuda:0')，预测的设备号为:tensor([39, 35, 43, 14], device='cuda:0')
# [51, 1000] acc: 0.6530000567436218
# [51, 2000] loss: 1.0197096808971837
# 设备号为: tensor([16, 29, 22,  4], device='cuda:0')，预测的设备号为:tensor([16, 29, 16,  4], device='cuda:0')
# [51, 2000] acc: 0.6500000357627869
# [52, 1000] loss: 0.975701879880391
# 设备号为: tensor([17, 11, 31, 35], device='cuda:0')，预测的设备号为:tensor([17, 11, 31, 35], device='cuda:0')
# [52, 1000] acc: 0.6602500081062317
# [52, 2000] loss: 1.0287992442212999
# 设备号为: tensor([29, 37, 16, 27], device='cuda:0')，预测的设备号为:tensor([29, 37, 14, 27], device='cuda:0')
# [52, 2000] acc: 0.6372500061988831
# [53, 1000] loss: 0.9883614223971963
# 设备号为: tensor([ 8, 47, 38, 37], device='cuda:0')，预测的设备号为:tensor([ 8, 19,  6, 37], device='cuda:0')
# [53, 1000] acc: 0.6567500233650208
# [53, 2000] loss: 1.007377094502328
# 设备号为: tensor([37, 53,  2, 45], device='cuda:0')，预测的设备号为:tensor([37, 53,  2, 45], device='cuda:0')
# [53, 2000] acc: 0.6462500095367432
# [54, 1000] loss: 1.0000100582391023
# 设备号为: tensor([ 2, 52, 45, 30], device='cuda:0')，预测的设备号为:tensor([ 2, 52, 45, 30], device='cuda:0')
# [54, 1000] acc: 0.655750036239624
# [54, 2000] loss: 1.005536591171287
# 设备号为: tensor([34, 41, 31, 52], device='cuda:0')，预测的设备号为:tensor([34, 40, 31, 52], device='cuda:0')
# [54, 2000] acc: 0.6512500047683716
# [55, 1000] loss: 0.9816704026674852
# 设备号为: tensor([43,  6, 50,  0], device='cuda:0')，预测的设备号为:tensor([43,  6, 51,  0], device='cuda:0')
# [55, 1000] acc: 0.6510000228881836
# [55, 2000] loss: 0.9841776996180415
# 设备号为: tensor([28, 43, 47, 11], device='cuda:0')，预测的设备号为:tensor([28, 47, 35, 11], device='cuda:0')
# [55, 2000] acc: 0.6602500081062317
# [56, 1000] loss: 0.9621191161833703
# 设备号为: tensor([48, 29, 39,  9], device='cuda:0')，预测的设备号为:tensor([48, 29, 33,  9], device='cuda:0')
# [56, 1000] acc: 0.659500002861023
# [56, 2000] loss: 0.9567492805691435
# 设备号为: tensor([33, 11, 53, 18], device='cuda:0')，预测的设备号为:tensor([ 3, 39, 53, 18], device='cuda:0')
# [56, 2000] acc: 0.6775000095367432
# [57, 1000] loss: 0.9648688786998391
# 设备号为: tensor([46, 19, 49,  0], device='cuda:0')，预测的设备号为:tensor([46, 47, 40,  0], device='cuda:0')
# [57, 1000] acc: 0.6672500371932983
# [57, 2000] loss: 0.934114024666138
# 设备号为: tensor([ 2, 45, 35,  9], device='cuda:0')，预测的设备号为:tensor([ 2, 45, 35, 25], device='cuda:0')
# [57, 2000] acc: 0.6727500557899475
# [58, 1000] loss: 0.9229808035492897
# 设备号为: tensor([ 9, 36, 23, 19], device='cuda:0')，预测的设备号为:tensor([ 9, 36, 12, 19], device='cuda:0')
# [58, 1000] acc: 0.6805000305175781
# [58, 2000] loss: 0.9653919267123565
# 设备号为: tensor([32, 44, 42, 35], device='cuda:0')，预测的设备号为:tensor([32, 44, 42, 35], device='cuda:0')
# [58, 2000] acc: 0.6672500371932983
# [59, 1000] loss: 0.9285000796876848
# 设备号为: tensor([ 4, 51, 27, 23], device='cuda:0')，预测的设备号为:tensor([ 4, 51,  3, 23], device='cuda:0')
# [59, 1000] acc: 0.6775000095367432
# [59, 2000] loss: 0.9245505768656731
# 设备号为: tensor([ 6, 31, 32, 23], device='cuda:0')，预测的设备号为:tensor([ 6, 28, 32, 23], device='cuda:0')
# [59, 2000] acc: 0.6842500567436218
# [60, 1000] loss: 0.9227810756163671
# 设备号为: tensor([28,  2, 42,  5], device='cuda:0')，预测的设备号为:tensor([28,  2, 42,  5], device='cuda:0')
# [60, 1000] acc: 0.6772500276565552
# [60, 2000] loss: 0.9181567351305857
# 设备号为: tensor([ 4, 21,  0, 53], device='cuda:0')，预测的设备号为:tensor([ 4, 47,  0, 53], device='cuda:0')
# [60, 2000] acc: 0.6817500591278076
# [61, 1000] loss: 0.9126201926479116
# 设备号为: tensor([51, 31,  4, 52], device='cuda:0')，预测的设备号为:tensor([51, 31,  4, 52], device='cuda:0')
# [61, 1000] acc: 0.6865000128746033
# [61, 2000] loss: 0.8954894244782626
# 设备号为: tensor([50, 24, 17,  9], device='cuda:0')，预测的设备号为:tensor([49, 23, 17, 38], device='cuda:0')
# [61, 2000] acc: 0.6817500591278076
# [62, 1000] loss: 0.9019785392517224
# 设备号为: tensor([45, 18, 31, 29], device='cuda:0')，预测的设备号为:tensor([45, 18, 31, 29], device='cuda:0')
# [62, 1000] acc: 0.687000036239624
# [62, 2000] loss: 0.8909472494083457
# 设备号为: tensor([38, 37, 27,  1], device='cuda:0')，预测的设备号为:tensor([38, 37, 39,  1], device='cuda:0')
# [62, 2000] acc: 0.6845000386238098
# [63, 1000] loss: 0.8724225377915427
# 设备号为: tensor([35, 47, 19, 52], device='cuda:0')，预测的设备号为:tensor([ 4, 21, 19, 52], device='cuda:0')
# [63, 1000] acc: 0.6922500133514404
# [63, 2000] loss: 0.9008054027883335
# 设备号为: tensor([18, 36, 38, 25], device='cuda:0')，预测的设备号为:tensor([12, 36, 38,  9], device='cuda:0')
# [63, 2000] acc: 0.6835000514984131

# %%
torch.cuda.current_device ()

# %%
aa = iter(train_loader)
a, b = aa.next()
print(a[0].shape)
print(a)

# %%
input = torch.randn(20, 16, 50, 100)
input.shape

# %%
m2=nn.Conv2d(16,33,(3,5),stride=(2,1),padding=(4,2))
inpu1=Variable(torch.randn(20,16,50,100))
print(inpu1.shape)
output=m2(inpu1)
print(output.shape)

# %%
total

# %%
torch.cuda.current_device ()

# %%
x = range(0, len(average_loss_series))
plt.figure()
plt.plot(x, average_loss_series)
plt.savefig("Loss15-0.png", bbox_inches="tight")
plt.show()
