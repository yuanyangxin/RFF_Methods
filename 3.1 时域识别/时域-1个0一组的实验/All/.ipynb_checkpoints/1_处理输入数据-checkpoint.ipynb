# %% [markdown]
# step1: 对输入的I/O数据进行处理，I/O数据看作是nlp里面的文本数据

# %%
import os
import scipy.io as sio
import numpy as np
from shutil import copyfile

# %%
path = "/workspace/PytorchCnn/Data/Signal0-10dB-All"

# %%
files = os.listdir(path)
data = []
labels = []

# %%
def del_file(filepath):
    """
    删除某一目录下的所有文件或文件夹
    :param filepath: 路径
    :return:
    """
    import shutil
    del_list = os.listdir(filepath)
    for f in del_list:
        file_path = os.path.join(filepath, f)
        if os.path.isfile(file_path):
            os.remove(file_path)
        elif os.path.isdir(file_path):
            shutil.rmtree(file_path)

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
saveFolder = "/workspace/PytorchCnn/Data/后面的稳定0信号/10dB-All/"
del_file(saveFolder)
for file in files:
#     print(file)
    device = file.split('_')[2]
    y = int(device) - 1
    round = int(file.split('_')[3][0:-4])
    data = sio.loadmat(os.path.join(path, file))
    X = data["y"]
    a = X[0: len(X)]
    
    real = a.real 
    imag = a.imag
    
    real = real.transpose()
    imag = imag.transpose()
    real = real[0]
    imag = imag[0]
#     print(real)
#     print(len(real))
    
#     print(imag)
#     print(len(imag))

    result = real[0: 160]
    im = imag[0: 160]
    result = np.vstack((result, im))

    name = "10dBProcess_" + str("A_" + device) + "_" + str(round) + ".npy"
    path1 = saveFolder + name
    np.save(path1, result)

# %%
# %matplotlib inline

# import matplotlib.pyplot as plt

# for file in files:
# #     print(file)
#     device = file.split('_')[2]
#     y = int(device) - 1
#     round = int(file.split('_')[3][0:-4])
#     data = sio.loadmat(os.path.join(path, file))
#     X = data["Brush_Data_Temp"]
#     plt.figure()
#     plt.title(int(device))
#     for i in range(3, 7):
#         newX = X[160*i - 160 :160*i]   
#         x = [i for i in range(1, 161)]
#         plt.plot(x, newX)
#     plt.show()

# %%
import numpy as np
data = np.load("/workspace/PytorchCnn/Data/后面的稳定0信号/10dB-All/10dBProcess_A_26_9.npy")
print(data.shape)
# Out:
# (2, 160)

# %%
# %matplotlib inline

# import matplotlib.pyplot as plt

# for file in files:
# #     print(file)
#     device = file.split('_')[2]
#     y = int(device) - 1
#     round = int(file.split('_')[3][0:-4])
#     data = sio.loadmat(os.path.join(path, file))
#     X = data["Brush_Data_Temp"][0:1281]
#     x = [i for i in range(0, 1281)]
#     plt.figure()
#     plt.plot(x, X)
#     plt.show()
#     break

# %%
print(data)
# Out:
# [[ 2.00012435e-01  4.90686885e-01  8.52609977e-01  1.03369473e+00
#    1.02941952e+00  9.32915280e-01  9.81844981e-01  8.23184990e-01
#    5.18647603e-01  1.57313389e-01 -2.82000685e-02 -4.01234919e-01
#   -7.68035365e-01 -9.89963933e-01 -9.46939102e-01 -1.15503990e+00
#   -8.63615730e-01 -5.23140147e-01 -2.80311475e-01 -1.00807254e-01
#    7.57539135e-02  2.76809469e-01  6.72800363e-01  7.72017513e-01
#    1.16591074e+00  9.58885969e-01  8.07556382e-01  5.44626140e-01
#    2.35566940e-01  5.52225903e-02 -7.29485915e-02 -4.00250572e-01
