# %%
import matplotlib.pyplot as plt
import torchvision as tv
from torchvision import transforms, utils


import torch.nn.functional as F
import torch 
import torch.nn as nn
from torch.autograd import Variable
import torchvision.models as models
# from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader
# from PIL import Image
# import numpy as np
import torch.optim as optim
# import os
import time

import loadData

# %%
device = torch.device("cuda:2")

# %%
# 日志记录模块2
import logging
logger = logging.getLogger(__name__)
logger.setLevel(level = logging.INFO)
handler = logging.FileHandler("./10dB-HHT最后四个没加-1500epoches-0")
handler.setLevel(logging.INFO)
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

console = logging.StreamHandler()
console.setLevel(logging.INFO)

logger.addHandler(handler)
logger.addHandler(console)

# %%
startTime = time.time()

# %%
transforms = tv.transforms.Compose([
    transforms.ToTensor(),
])


numOfBatch = 9
pixel = 64
flag = 0
root = f'./{numOfBatch}/data'
batchSize = 4
train_data = loadData.MyDataset(txt=f'files_train10-舍弃最后4个.txt', transform=None)
test_data = loadData.MyDataset(txt=f'files_test10-舍弃最后4个.txt', transform=None)



train_loader = DataLoader(dataset=train_data, batch_size=batchSize, shuffle=True, num_workers=2)
test_loader = DataLoader(dataset=test_data, batch_size=batchSize, shuffle=True, num_workers=2)


print(train_loader)
print(test_loader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7fc761fa9f90>
# <torch.utils.data.dataloader.DataLoader object at 0x7fc845441e90>

# %%
print(len(train_data))
print(len(test_loader))
# Out:
# 6426
# 419

# %%
# data = iter(train_loader)

# # print(type(data))
# # print(len(data))
# data_, label = data.next()
# print(train_loader.batch_size)
# print(data_.shape)
# # print(label)
# # print(data_, label)

# %%
x = torch.randn(4, 1, 1200, 2).float()
conv = nn.Conv2d(in_channels = 1, out_channels = 128, kernel_size = (10, 1))
x = conv(x)
x.shape
conv2 = nn.Conv2d(in_channels = 128, out_channels = 256, kernel_size = (3, 2))
x = conv2(x)
x.shape
# Out:
# torch.Size([4, 256, 1189, 1])

# %%
# 256*1189

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(in_channels = 1, out_channels = 8, kernel_size = (1, 10))
        self.conv2 = nn.Conv2d(in_channels = 8, out_channels = 16, kernel_size = (2, 3))
        
        self.dropout1 = nn.Dropout(0.5)
        self.dropout2 = nn.Dropout(0.5)
        
        self.fc1 = nn.Linear(20304, 1024)
        self.fc2 = nn.Linear(1024, 500)
        self.fc3 = nn.Linear(500, 54)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 1)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 1)
    
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.dropout1(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.dropout2(x)
        x = self.fc3(x)
        output = F.log_softmax(x, dim=1)
        return output

# %%
# TensorBoard
# from tensorboardX import SummaryWriter
# net = Net()
# # writer = SummaryWriter('writer928') #建立一个保存数据用的东西
# dummy_input = torch.rand(2,160,400)  # 假设输入20张1*28*28的图片
# with SummaryWriter(comment='Net1') as w:
#     w.add_graph(net, (dummy_input,))

# %%
net = Net()

net = net.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(params=net.parameters(), lr=0.0001, momentum=0.9)

epochs = 1500
average_loss_series = []

# %%
for a, b in enumerate(train_loader):
    inputs, labels = b
    print(inputs.shape)
    break
# Out:
# torch.Size([4, 1, 2, 1280])

# %%
# %matplotlib inline


if __name__ == '__main__':
    for epoch in range(epochs):
        running_loss = 0.0
        running_acc = 0.0

        for i, data in enumerate(train_loader):
#             print("i:", i )
#             print("data: ", data[0])
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()

#             inputs = inputs.permute(0, 2, 1)
            
            inputs = torch.tensor(inputs, dtype=torch.float32, device = device)

            outputs = net(inputs)
            _, predicted = torch.max(outputs.data, dim=1)
            total = labels.size(0)
#             print('原来的值:{0}, 预测的值:{1}'.format(labels, predicted))
            running_correct = (predicted == labels).sum()
            running_acc += running_correct
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            loss.backward()
            optimizer.step()

            # 每loopNum个batch打印一次训练状态
            loopNum = 1000
            if i % loopNum == loopNum - 1:
                average_loss = running_loss / loopNum
                logger.info('[{0}, {1}] loss: {2}'.format(epoch + 1, i + 1, average_loss))
                logger.info('设备号为: {0}，预测的设备号为:{1}'.format(labels, predicted))
#                 logger.info(torch.cuda.current_device ())
                running_acc = running_acc.float()
                average_acc = running_acc / loopNum / total
                
                logger.info('[{0}, {1}] acc: {2}'.format(epoch + 1, i + 1, average_acc))
                average_loss_series.append(average_loss)
                running_loss = 0.0
                running_acc = 0.0

    x = range(0, len(average_loss_series))
    plt.figure()
    plt.plot(x, average_loss_series)
#     plt.savefig("Loss.png")
    plt.savefig("Loss.png", bbox_inches="tight")
    plt.show()
    

    # %%
    # 在测试集上测试
    realLabel = []
    predictedLabel = []

    def correct_rate(net, testloader):
        correct = 0.0
        total = 0.0
        count = 0
        correctpredict = 0

        for data in testloader:
            images, labels = data
            images, labels = images.to(device),labels.to(device)
            realLabel.append([int(label) for label in labels])
    
            tests = torch.tensor(images, dtype=torch.float32,device=device)
            outputs = net(tests)

            _, predicted = torch.max(outputs.data, dim=1)
            logger.info('设备号为: {0}，模型训练后得到的设备号为:{1}'.format(labels, predicted))
#             deviceNumber = torch.cuda.current_device ()
#             logger.info(deviceNumber)
            
            labelsn = labels.cpu().numpy()
            pn = predicted.cpu().numpy()
            count += len(labelsn)
            
            for i in range(len(labelsn)):
                if labelsn[i] == pn[i]:
                    correctpredict += 1
                
            
            logger.info('目前一共测试了{0}组，预测成功的一共有{1}组'.format(count, correctpredict))
            predictedLabel.append([int(label) for label in predicted])
            
            total += labels.size(0)
            correct += (predicted == labels).sum()

            
        logger.info("total的值为：{total}")
#         return 100 * correct  # / total
        return 100 * correct/ total 


    correct = correct_rate(net, test_loader)
    logger.info(f'{len(test_loader) * 3}张测试集中准确率为： {correct}%')

    # %%
    import itertools
    from sklearn.metrics import confusion_matrix

    realLabel = list(itertools.chain.from_iterable(realLabel))
    predictedLabel = list(itertools.chain.from_iterable(predictedLabel))

    cm = confusion_matrix(realLabel, predictedLabel)
    logger.info(cm)

#     logger.info('the running time is:{1}'.format(time.time() - startTime))
    torch.save(net.state_dict(), f'./model_10dB_最后4个没加_0.pkl')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# [1, 1000] loss: 3.988890793085098
# 设备号为: tensor([48, 18, 49, 21], device='cuda:2')，预测的设备号为:tensor([21, 50, 51, 26], device='cuda:2')
# [1, 1000] acc: 0.020500000566244125
# [2, 1000] loss: 3.9866481103897096
# 设备号为: tensor([47, 50, 40, 36], device='cuda:2')，预测的设备号为:tensor([47, 21, 35, 28], device='cuda:2')
# [2, 1000] acc: 0.01925000175833702
# [3, 1000] loss: 3.981469290971756
# 设备号为: tensor([21, 41,  2,  9], device='cuda:2')，预测的设备号为:tensor([51, 34, 51, 51], device='cuda:2')
# [3, 1000] acc: 0.029000001028180122
# [4, 1000] loss: 3.9712488877773287
# 设备号为: tensor([ 3,  9, 31, 16], device='cuda:2')，预测的设备号为:tensor([51,  3, 20, 37], device='cuda:2')
# [4, 1000] acc: 0.03400000184774399
# [5, 1000] loss: 3.942637351512909
# 设备号为: tensor([ 1, 12, 42, 35], device='cuda:2')，预测的设备号为:tensor([ 3, 45, 29, 39], device='cuda:2')
# [5, 1000] acc: 0.04000000283122063
# [6, 1000] loss: 3.7952726595401765
# 设备号为: tensor([44, 45,  2,  3], device='cuda:2')，预测的设备号为:tensor([15, 45,  0,  0], device='cuda:2')
# [6, 1000] acc: 0.05400000140070915
# [7, 1000] loss: 3.420534096956253
# 设备号为: tensor([20, 24, 25, 13], device='cuda:2')，预测的设备号为:tensor([15, 53, 26, 53], device='cuda:2')
# [7, 1000] acc: 0.07175000011920929
# [8, 1000] loss: 3.1972967967987063
# 设备号为: tensor([52,  1, 14, 13], device='cuda:2')，预测的设备号为:tensor([45, 38, 18, 13], device='cuda:2')
# [8, 1000] acc: 0.09700000286102295
# [9, 1000] loss: 3.057173016190529
# 设备号为: tensor([26, 37, 21, 18], device='cuda:2')，预测的设备号为:tensor([ 8, 24, 20, 20], device='cuda:2')
# [9, 1000] acc: 0.12150000780820847
# [10, 1000] loss: 2.9413146888017656
# 设备号为: tensor([ 5, 39, 26, 36], device='cuda:2')，预测的设备号为:tensor([ 6, 10,  8, 33], device='cuda:2')
# [10, 1000] acc: 0.12975001335144043
# [11, 1000] loss: 2.8682713286876678
# 设备号为: tensor([18, 26, 27, 33], device='cuda:2')，预测的设备号为:tensor([53, 28,  2, 33], device='cuda:2')
# [11, 1000] acc: 0.14300000667572021
# [12, 1000] loss: 2.7828139590024947
# 设备号为: tensor([ 3, 47, 13, 31], device='cuda:2')，预测的设备号为:tensor([36, 43, 13, 25], device='cuda:2')
# [12, 1000] acc: 0.15000000596046448
# [13, 1000] loss: 2.6977182046175003
# 设备号为: tensor([36, 50, 17, 38], device='cuda:2')，预测的设备号为:tensor([26, 22, 48, 27], device='cuda:2')
# [13, 1000] acc: 0.17075000703334808
# [14, 1000] loss: 2.6218663482666016
# 设备号为: tensor([26,  8, 53, 13], device='cuda:2')，预测的设备号为:tensor([26, 26, 53, 13], device='cuda:2')
# [14, 1000] acc: 0.17625001072883606
# [15, 1000] loss: 2.51387541615963
# 设备号为: tensor([25,  2, 36, 34], device='cuda:2')，预测的设备号为:tensor([31, 35, 32,  7], device='cuda:2')
# [15, 1000] acc: 0.21000000834465027
# [16, 1000] loss: 2.398023477435112
# 设备号为: tensor([40, 15,  1, 43], device='cuda:2')，预测的设备号为:tensor([40, 37,  0, 21], device='cuda:2')
# [16, 1000] acc: 0.234250009059906
# [17, 1000] loss: 2.290276454359293
# 设备号为: tensor([25, 29, 34,  2], device='cuda:2')，预测的设备号为:tensor([39, 29, 34,  2], device='cuda:2')
# [17, 1000] acc: 0.25475001335144043
# [18, 1000] loss: 2.195640231639147
# 设备号为: tensor([50, 46, 10, 25], device='cuda:2')，预测的设备号为:tensor([50, 46, 32,  3], device='cuda:2')
# [18, 1000] acc: 0.2750000059604645
# [19, 1000] loss: 2.1098371196985246
# 设备号为: tensor([37, 19,  6,  5], device='cuda:2')，预测的设备号为:tensor([37, 43,  6,  1], device='cuda:2')
# [19, 1000] acc: 0.2927500009536743
# [20, 1000] loss: 2.021463153719902
# 设备号为: tensor([ 3,  3,  4, 35], device='cuda:2')，预测的设备号为:tensor([39, 38,  4, 35], device='cuda:2')
# [20, 1000] acc: 0.31850001215934753
# [21, 1000] loss: 1.9838545562624932
# 设备号为: tensor([38,  5, 18, 15], device='cuda:2')，预测的设备号为:tensor([33,  8, 40, 52], device='cuda:2')
# [21, 1000] acc: 0.33275002241134644
# [22, 1000] loss: 1.9211103961765765
# 设备号为: tensor([53, 51, 23, 10], device='cuda:2')，预测的设备号为:tensor([15, 43, 23, 25], device='cuda:2')
# [22, 1000] acc: 0.33925002813339233
# [23, 1000] loss: 1.866699376285076
# 设备号为: tensor([17, 50,  0, 31], device='cuda:2')，预测的设备号为:tensor([48, 50,  6, 31], device='cuda:2')
# [23, 1000] acc: 0.36550000309944153
# [24, 1000] loss: 1.7984817340970038
# 设备号为: tensor([20, 40, 39,  4], device='cuda:2')，预测的设备号为:tensor([14, 13, 39, 34], device='cuda:2')
# [24, 1000] acc: 0.3915000259876251
# [25, 1000] loss: 1.748682523459196
# 设备号为: tensor([ 0, 18, 12, 50], device='cuda:2')，预测的设备号为:tensor([ 8, 13, 15, 47], device='cuda:2')
# [25, 1000] acc: 0.4072500169277191
# [26, 1000] loss: 1.7151489351391793
# 设备号为: tensor([51, 18, 26, 39], device='cuda:2')，预测的设备号为:tensor([50, 50, 26, 29], device='cuda:2')
# [26, 1000] acc: 0.4205000102519989
# [27, 1000] loss: 1.657839377105236
# 设备号为: tensor([21, 35, 11, 49], device='cuda:2')，预测的设备号为:tensor([42, 35, 11, 50], device='cuda:2')
# [27, 1000] acc: 0.4207500219345093
# [28, 1000] loss: 1.6303286274373532
# 设备号为: tensor([ 9, 47,  3,  5], device='cuda:2')，预测的设备号为:tensor([ 1, 19,  3,  5], device='cuda:2')
# [28, 1000] acc: 0.43800002336502075
# [29, 1000] loss: 1.5960265445411206
# 设备号为: tensor([28, 43,  1,  3], device='cuda:2')，预测的设备号为:tensor([28, 48, 26, 27], device='cuda:2')
# [29, 1000] acc: 0.4505000114440918
# [30, 1000] loss: 1.5474983625262975
# 设备号为: tensor([17,  4, 47, 45], device='cuda:2')，预测的设备号为:tensor([48, 37, 47, 45], device='cuda:2')
# [30, 1000] acc: 0.46425002813339233
# [31, 1000] loss: 1.512227251306176
# 设备号为: tensor([24,  5, 44,  2], device='cuda:2')，预测的设备号为:tensor([24,  6, 44,  2], device='cuda:2')
# [31, 1000] acc: 0.46375003457069397
# [32, 1000] loss: 1.483310453981161
# 设备号为: tensor([43, 53,  2, 26], device='cuda:2')，预测的设备号为:tensor([13, 53,  4, 26], device='cuda:2')
# [32, 1000] acc: 0.48750001192092896
# [33, 1000] loss: 1.4614290039390325
# 设备号为: tensor([46, 47, 46, 23], device='cuda:2')，预测的设备号为:tensor([44, 43, 46, 23], device='cuda:2')
# [33, 1000] acc: 0.4922500252723694
# [34, 1000] loss: 1.4267498797923326
# 设备号为: tensor([30, 33, 31, 29], device='cuda:2')，预测的设备号为:tensor([30,  9, 28, 29], device='cuda:2')
# [34, 1000] acc: 0.4960000216960907
# [35, 1000] loss: 1.3892524528354406
# 设备号为: tensor([43, 25, 49, 18], device='cuda:2')，预测的设备号为:tensor([40, 25, 49, 14], device='cuda:2')
# [35, 1000] acc: 0.5110000371932983
# [36, 1000] loss: 1.3878910461999476
# 设备号为: tensor([12, 46,  3, 41], device='cuda:2')，预测的设备号为:tensor([12, 53, 27, 15], device='cuda:2')
# [36, 1000] acc: 0.5162500143051147
# [37, 1000] loss: 1.322817187435925
# 设备号为: tensor([ 7, 13,  5, 16], device='cuda:2')，预测的设备号为:tensor([10, 51,  5, 18], device='cuda:2')
# [37, 1000] acc: 0.5315000414848328
# [38, 1000] loss: 1.3114112180694937
# 设备号为: tensor([ 6, 29, 28, 47], device='cuda:2')，预测的设备号为:tensor([ 1, 29, 25, 43], device='cuda:2')
# [38, 1000] acc: 0.5427500009536743
# [39, 1000] loss: 1.2968011147230865
# 设备号为: tensor([13, 53, 21, 47], device='cuda:2')，预测的设备号为:tensor([49, 52, 21, 47], device='cuda:2')
# [39, 1000] acc: 0.5447500348091125
# [40, 1000] loss: 1.2798931260444224
# 设备号为: tensor([34, 18,  3, 19], device='cuda:2')，预测的设备号为:tensor([34, 18,  0, 19], device='cuda:2')
# [40, 1000] acc: 0.5530000329017639
# [41, 1000] loss: 1.2594692436307668
# 设备号为: tensor([23, 37, 40, 45], device='cuda:2')，预测的设备号为:tensor([23, 37, 21, 45], device='cuda:2')
# [41, 1000] acc: 0.562250018119812
# [42, 1000] loss: 1.2078581625968219
# 设备号为: tensor([46, 29, 20, 10], device='cuda:2')，预测的设备号为:tensor([46, 29, 49, 10], device='cuda:2')
# [42, 1000] acc: 0.5697500109672546
# [43, 1000] loss: 1.221018066070974
# 设备号为: tensor([12, 28,  6, 16], device='cuda:2')，预测的设备号为:tensor([15, 28,  6, 14], device='cuda:2')
# [43, 1000] acc: 0.5720000267028809
# [44, 1000] loss: 1.1993405333831906
# 设备号为: tensor([43, 41,  0, 26], device='cuda:2')，预测的设备号为:tensor([43, 41,  6, 26], device='cuda:2')
# [44, 1000] acc: 0.5920000076293945
# [45, 1000] loss: 1.1482382875531911
# 设备号为: tensor([10, 19, 24, 49], device='cuda:2')，预测的设备号为:tensor([10, 19, 24, 16], device='cuda:2')
# [45, 1000] acc: 0.5995000004768372
# [46, 1000] loss: 1.1459929955918342
# 设备号为: tensor([41,  2, 53, 30], device='cuda:2')，预测的设备号为:tensor([47,  2, 53, 30], device='cuda:2')
# [46, 1000] acc: 0.5972500443458557
# [47, 1000] loss: 1.1196697693746538
# 设备号为: tensor([15, 41, 44, 24], device='cuda:2')，预测的设备号为:tensor([15, 51, 44, 12], device='cuda:2')
# [47, 1000] acc: 0.6007500290870667
# [48, 1000] loss: 1.1072766034379602
# 设备号为: tensor([42, 35, 40, 11], device='cuda:2')，预测的设备号为:tensor([51, 35, 51, 39], device='cuda:2')
# [48, 1000] acc: 0.6047500371932983
# [49, 1000] loss: 1.0840411945916713
# 设备号为: tensor([10, 24, 18, 21], device='cuda:2')，预测的设备号为:tensor([10, 24, 18, 47], device='cuda:2')
# [49, 1000] acc: 0.6115000247955322
# [50, 1000] loss: 1.0814315971881152
# 设备号为: tensor([22, 17, 47, 39], device='cuda:2')，预测的设备号为:tensor([18, 17, 35, 39], device='cuda:2')
# [50, 1000] acc: 0.612000048160553
# [51, 1000] loss: 1.0284799852799624
# 设备号为: tensor([47, 33, 33, 45], device='cuda:2')，预测的设备号为:tensor([47,  9,  7, 45], device='cuda:2')
# [51, 1000] acc: 0.640500009059906
# [52, 1000] loss: 1.0325095847016201
# 设备号为: tensor([27, 12, 23,  6], device='cuda:2')，预测的设备号为:tensor([ 3, 12, 12,  6], device='cuda:2')
# [52, 1000] acc: 0.6302500367164612
# [53, 1000] loss: 1.0125590340532362
# 设备号为: tensor([48, 19, 11, 44], device='cuda:2')，预测的设备号为:tensor([48, 14, 11, 44], device='cuda:2')
# [53, 1000] acc: 0.6407500505447388
# [54, 1000] loss: 1.0156584868524223
# 设备号为: tensor([11, 17,  0, 50], device='cuda:2')，预测的设备号为:tensor([27, 17,  3, 49], device='cuda:2')
# [54, 1000] acc: 0.6347500085830688
# [55, 1000] loss: 0.9459371174136176
# 设备号为: tensor([29, 52, 32, 13], device='cuda:2')，预测的设备号为:tensor([29, 52, 32, 19], device='cuda:2')
# [55, 1000] acc: 0.6607500314712524
# [56, 1000] loss: 0.9490818746462464
# 设备号为: tensor([ 1, 40, 33, 42], device='cuda:2')，预测的设备号为:tensor([ 1, 51, 33, 42], device='cuda:2')
# [56, 1000] acc: 0.656000018119812
# [57, 1000] loss: 0.9519614834003151
# 设备号为: tensor([ 0, 51, 18, 28], device='cuda:2')，预测的设备号为:tensor([ 5, 49, 20, 28], device='cuda:2')
# [57, 1000] acc: 0.658750057220459
# [58, 1000] loss: 0.9279914464000613
# 设备号为: tensor([52, 42, 53, 29], device='cuda:2')，预测的设备号为:tensor([52, 21, 53, 29], device='cuda:2')
# [58, 1000] acc: 0.6742500066757202
# [59, 1000] loss: 0.9289592195283621
# 设备号为: tensor([20,  8, 14, 11], device='cuda:2')，预测的设备号为:tensor([16,  8, 14, 11], device='cuda:2')
# [59, 1000] acc: 0.6730000376701355
# [60, 1000] loss: 0.9321391039714217
# 设备号为: tensor([16,  2, 11, 12], device='cuda:2')，预测的设备号为:tensor([16,  2, 11, 12], device='cuda:2')
# [60, 1000] acc: 0.6645000576972961
# [61, 1000] loss: 0.919891124822665
# 设备号为: tensor([33, 19, 27, 17], device='cuda:2')，预测的设备号为:tensor([ 8, 19,  7, 17], device='cuda:2')
# [61, 1000] acc: 0.6755000352859497
# [62, 1000] loss: 0.8622512961328029
# 设备号为: tensor([25, 19, 53, 33], device='cuda:2')，预测的设备号为:tensor([25, 19, 44,  0], device='cuda:2')
# [62, 1000] acc: 0.6955000162124634
# [63, 1000] loss: 0.9092979689100757
# 设备号为: tensor([12, 31,  9, 52], device='cuda:2')，预测的设备号为:tensor([23, 31, 33, 52], device='cuda:2')
# [63, 1000] acc: 0.6785000562667847
# [64, 1000] loss: 0.879332908260636
# 设备号为: tensor([38, 42, 16,  2], device='cuda:2')，预测的设备号为:tensor([38, 42, 16,  2], device='cuda:2')
# [64, 1000] acc: 0.6880000233650208
# [65, 1000] loss: 0.8593264121143147
# 设备号为: tensor([34, 44, 33, 14], device='cuda:2')，预测的设备号为:tensor([34, 44, 38, 14], device='cuda:2')
# [65, 1000] acc: 0.6925000548362732
# [66, 1000] loss: 0.8612513354355469
# 设备号为: tensor([ 1, 20, 26,  4], device='cuda:2')，预测的设备号为:tensor([ 1, 19, 26,  4], device='cuda:2')
# [66, 1000] acc: 0.6920000314712524
# [67, 1000] loss: 0.85128931243252
# 设备号为: tensor([41, 21, 48, 31], device='cuda:2')，预测的设备号为:tensor([40, 21, 48, 26], device='cuda:2')
# [67, 1000] acc: 0.6960000395774841
# [68, 1000] loss: 0.8265424956567585
# 设备号为: tensor([32, 46, 42, 51], device='cuda:2')，预测的设备号为:tensor([32, 46, 42, 51], device='cuda:2')
# [68, 1000] acc: 0.7080000042915344
# [69, 1000] loss: 0.8416612243733834
# 设备号为: tensor([14, 29, 41, 42], device='cuda:2')，预测的设备号为:tensor([14, 29, 41, 42], device='cuda:2')
# [69, 1000] acc: 0.6922500133514404
# [70, 1000] loss: 0.8134704546686262
# 设备号为: tensor([ 0, 19, 15, 19], device='cuda:2')，预测的设备号为:tensor([ 0, 19, 15, 19], device='cuda:2')
# [70, 1000] acc: 0.7100000381469727
# [71, 1000] loss: 0.7922270238454221
# 设备号为: tensor([ 1, 10, 25,  0], device='cuda:2')，预测的设备号为:tensor([ 1, 10, 25,  0], device='cuda:2')
# [71, 1000] acc: 0.7190000414848328
# [72, 1000] loss: 0.802965810239315
# 设备号为: tensor([20, 27, 11, 15], device='cuda:2')，预测的设备号为:tensor([20,  7, 11, 15], device='cuda:2')
# [72, 1000] acc: 0.7115000486373901
# [73, 1000] loss: 0.7850608215465036
# 设备号为: tensor([50, 14,  5, 23], device='cuda:2')，预测的设备号为:tensor([42, 14,  5, 14], device='cuda:2')
# [73, 1000] acc: 0.7172500491142273
# [74, 1000] loss: 0.7661567235630937
# 设备号为: tensor([29, 39, 40, 19], device='cuda:2')，预测的设备号为:tensor([29, 39, 18, 19], device='cuda:2')
# [74, 1000] acc: 0.7247500419616699
# [75, 1000] loss: 0.747164379332331
# 设备号为: tensor([45, 17, 40, 21], device='cuda:2')，预测的设备号为:tensor([45, 17, 42, 43], device='cuda:2')
# [75, 1000] acc: 0.7307500243186951
# [76, 1000] loss: 0.7298984059637879
# 设备号为: tensor([15, 20, 50, 38], device='cuda:2')，预测的设备号为:tensor([15, 12, 50, 38], device='cuda:2')
# [76, 1000] acc: 0.737500011920929
# [77, 1000] loss: 0.7535226496979595
# 设备号为: tensor([10, 40, 13, 52], device='cuda:2')，预测的设备号为:tensor([10, 40, 13, 52], device='cuda:2')
# [77, 1000] acc: 0.7405000329017639
# [78, 1000] loss: 0.7533580041917739
# 设备号为: tensor([20, 25, 43, 53], device='cuda:2')，预测的设备号为:tensor([18, 25, 17, 53], device='cuda:2')
# [78, 1000] acc: 0.737500011920929
# [79, 1000] loss: 0.7367990150721744
# 设备号为: tensor([23, 38,  2, 50], device='cuda:2')，预测的设备号为:tensor([12, 38,  2, 50], device='cuda:2')
# [79, 1000] acc: 0.7327500581741333
# [80, 1000] loss: 0.698399958465714
# 设备号为: tensor([16, 42, 20, 53], device='cuda:2')，预测的设备号为:tensor([14, 42, 18, 53], device='cuda:2')
# [80, 1000] acc: 0.7475000619888306
# [81, 1000] loss: 0.7066635114890524
# 设备号为: tensor([ 5, 14, 23, 27], device='cuda:2')，预测的设备号为:tensor([ 5, 23, 23, 27], device='cuda:2')
# [81, 1000] acc: 0.7467500567436218
# [82, 1000] loss: 0.6982261081114411
# 设备号为: tensor([25,  8, 36, 45], device='cuda:2')，预测的设备号为:tensor([25,  8, 36, 45], device='cuda:2')
# [82, 1000] acc: 0.7510000467300415
# [83, 1000] loss: 0.6909481476095388
# 设备号为: tensor([45, 47, 29, 29], device='cuda:2')，预测的设备号为:tensor([45, 43, 29, 29], device='cuda:2')
# [83, 1000] acc: 0.7535000443458557
# [84, 1000] loss: 0.7064428255967796
# 设备号为: tensor([36, 13,  5, 33], device='cuda:2')，预测的设备号为:tensor([36, 13,  5,  9], device='cuda:2')
# [84, 1000] acc: 0.7417500615119934
# [85, 1000] loss: 0.6680510010400321
# 设备号为: tensor([24, 53, 50, 31], device='cuda:2')，预测的设备号为:tensor([24, 53, 50, 28], device='cuda:2')
# [85, 1000] acc: 0.7550000548362732
# [86, 1000] loss: 0.6738345060942229
# 设备号为: tensor([25,  2, 20, 26], device='cuda:2')，预测的设备号为:tensor([25,  4, 20, 26], device='cuda:2')
# [86, 1000] acc: 0.7565000653266907
# [87, 1000] loss: 0.664087500337413
# 设备号为: tensor([ 9, 37, 37, 24], device='cuda:2')，预测的设备号为:tensor([ 9, 37, 37, 24], device='cuda:2')
# [87, 1000] acc: 0.7677500247955322
# [88, 1000] loss: 0.6513799166842946
# 设备号为: tensor([ 1,  2, 34, 52], device='cuda:2')，预测的设备号为:tensor([ 1,  2, 34, 52], device='cuda:2')
# [88, 1000] acc: 0.7595000267028809
# [89, 1000] loss: 0.6355772599746123
# 设备号为: tensor([42, 26, 37, 46], device='cuda:2')，预测的设备号为:tensor([42, 26, 37, 46], device='cuda:2')
# [89, 1000] acc: 0.7752500176429749
# [90, 1000] loss: 0.6536049961776007
# 设备号为: tensor([43, 35,  0, 21], device='cuda:2')，预测的设备号为:tensor([43, 35, 38, 21], device='cuda:2')
# [90, 1000] acc: 0.7577500343322754
# [91, 1000] loss: 0.6239797127023339
# 设备号为: tensor([28, 22, 36, 27], device='cuda:2')，预测的设备号为:tensor([28, 18, 36, 25], device='cuda:2')
# [91, 1000] acc: 0.768750011920929
# [92, 1000] loss: 0.6383764958026295
# 设备号为: tensor([ 1, 40, 16, 40], device='cuda:2')，预测的设备号为:tensor([ 1, 40, 19, 40], device='cuda:2')
# [92, 1000] acc: 0.7690000534057617
# [93, 1000] loss: 0.5986131525711389
# 设备号为: tensor([51, 34, 39,  4], device='cuda:2')，预测的设备号为:tensor([40, 34, 27,  4], device='cuda:2')
# [93, 1000] acc: 0.7887500524520874
# [94, 1000] loss: 0.578101236252347
# 设备号为: tensor([ 7, 42, 53, 38], device='cuda:2')，预测的设备号为:tensor([38, 42, 53, 38], device='cuda:2')
# [94, 1000] acc: 0.7935000658035278
# [95, 1000] loss: 0.5912441179719754
# 设备号为: tensor([ 8, 50,  2, 15], device='cuda:2')，预测的设备号为:tensor([ 8, 42,  2, 15], device='cuda:2')
# [95, 1000] acc: 0.7890000343322754
# [96, 1000] loss: 0.5748952142567141
# 设备号为: tensor([ 9, 52, 45, 47], device='cuda:2')，预测的设备号为:tensor([38, 52, 45, 47], device='cuda:2')
# [96, 1000] acc: 0.7895000576972961
# [97, 1000] loss: 0.5858394154644339
# 设备号为: tensor([26, 48,  3, 35], device='cuda:2')，预测的设备号为:tensor([26, 48,  3, 35], device='cuda:2')
# [97, 1000] acc: 0.7905000448226929
# [98, 1000] loss: 0.5662176403318299
# 设备号为: tensor([26,  9, 12,  4], device='cuda:2')，预测的设备号为:tensor([26,  9, 12, 27], device='cuda:2')
# [98, 1000] acc: 0.79625004529953
# [99, 1000] loss: 0.5552542814087356
# 设备号为: tensor([ 2, 51, 52, 39], device='cuda:2')，预测的设备号为:tensor([ 2, 21, 52, 39], device='cuda:2')
# [99, 1000] acc: 0.8015000224113464
# [100, 1000] loss: 0.5913487087833346
# 设备号为: tensor([19, 44, 33, 23], device='cuda:2')，预测的设备号为:tensor([13, 44,  7, 12], device='cuda:2')
# [100, 1000] acc: 0.7812500596046448
# [101, 1000] loss: 0.5470535728048999
# 设备号为: tensor([53, 44, 42,  3], device='cuda:2')，预测的设备号为:tensor([53, 44, 42,  7], device='cuda:2')
# [101, 1000] acc: 0.8010000586509705
# [102, 1000] loss: 0.5398496890730458
# 设备号为: tensor([27, 36, 19, 32], device='cuda:2')，预测的设备号为:tensor([27, 36, 19, 32], device='cuda:2')
# [102, 1000] acc: 0.800000011920929
# [103, 1000] loss: 0.5067264942589682
# 设备号为: tensor([ 7, 16, 12, 19], device='cuda:2')，预测的设备号为:tensor([ 7, 16, 12, 21], device='cuda:2')
# [103, 1000] acc: 0.8157500624656677
# [104, 1000] loss: 0.49040523218549786
# 设备号为: tensor([30, 47, 16, 48], device='cuda:2')，预测的设备号为:tensor([30, 47, 22, 48], device='cuda:2')
# [104, 1000] acc: 0.8285000324249268
# [105, 1000] loss: 0.5126687277945458
# 设备号为: tensor([17, 48, 31,  1], device='cuda:2')，预测的设备号为:tensor([17, 48, 31,  1], device='cuda:2')
# [105, 1000] acc: 0.8175000548362732
# [106, 1000] loss: 0.5060918627132923
# 设备号为: tensor([27, 25, 18,  2], device='cuda:2')，预测的设备号为:tensor([27, 25, 51,  2], device='cuda:2')
# [106, 1000] acc: 0.8130000233650208
# [107, 1000] loss: 0.5173155029586051
# 设备号为: tensor([42, 19,  9, 33], device='cuda:2')，预测的设备号为:tensor([42, 19,  1,  9], device='cuda:2')
# [107, 1000] acc: 0.8092500567436218
# [108, 1000] loss: 0.4952007161398651
# 设备号为: tensor([ 2,  5, 16, 23], device='cuda:2')，预测的设备号为:tensor([ 2,  5, 22, 12], device='cuda:2')
# [108, 1000] acc: 0.8267500400543213
# [109, 1000] loss: 0.5026437220250373
# 设备号为: tensor([ 3, 18, 34, 15], device='cuda:2')，预测的设备号为:tensor([ 3, 18, 34, 15], device='cuda:2')
# [109, 1000] acc: 0.8170000314712524
# [110, 1000] loss: 0.4652018261626945
# 设备号为: tensor([10, 40, 33, 13], device='cuda:2')，预测的设备号为:tensor([25, 40, 33, 13], device='cuda:2')
# [110, 1000] acc: 0.8350000381469727
# [111, 1000] loss: 0.4712981303433189
# 设备号为: tensor([38, 20, 43, 30], device='cuda:2')，预测的设备号为:tensor([38, 20, 43, 30], device='cuda:2')
# [111, 1000] acc: 0.831250011920929
# [112, 1000] loss: 0.47385627524407753
# 设备号为: tensor([ 5, 38, 48,  8], device='cuda:2')，预测的设备号为:tensor([ 0, 38, 48,  8], device='cuda:2')
# [112, 1000] acc: 0.8232500553131104
# [113, 1000] loss: 0.45271988753741604
# 设备号为: tensor([ 8, 41,  5, 15], device='cuda:2')，预测的设备号为:tensor([ 8, 42,  5, 15], device='cuda:2')
# [113, 1000] acc: 0.8397500514984131
# [114, 1000] loss: 0.45120121613571246
# 设备号为: tensor([53, 10, 45, 29], device='cuda:2')，预测的设备号为:tensor([52, 10, 45, 29], device='cuda:2')
# [114, 1000] acc: 0.8400000333786011
# [115, 1000] loss: 0.4348460625234293
# 设备号为: tensor([13,  4, 24, 37], device='cuda:2')，预测的设备号为:tensor([13,  4, 24, 37], device='cuda:2')
# [115, 1000] acc: 0.8482500314712524
# [116, 1000] loss: 0.44664902376893223
# 设备号为: tensor([52,  6, 52,  4], device='cuda:2')，预测的设备号为:tensor([52,  6, 45,  4], device='cuda:2')
# [116, 1000] acc: 0.8370000123977661
# [117, 1000] loss: 0.44771942243169177
# 设备号为: tensor([16, 27, 26,  4], device='cuda:2')，预测的设备号为:tensor([16, 27, 26,  2], device='cuda:2')
# [117, 1000] acc: 0.8407500386238098
# [118, 1000] loss: 0.4336380028075073
# 设备号为: tensor([27, 20, 44, 38], device='cuda:2')，预测的设备号为:tensor([27, 20, 44, 38], device='cuda:2')
# [118, 1000] acc: 0.843000054359436
# [119, 1000] loss: 0.4400817739325867
# 设备号为: tensor([51, 15,  6, 17], device='cuda:2')，预测的设备号为:tensor([51, 15,  6, 17], device='cuda:2')
# [119, 1000] acc: 0.8397500514984131
# [120, 1000] loss: 0.41216692291491924
# 设备号为: tensor([29, 53, 45, 36], device='cuda:2')，预测的设备号为:tensor([29, 53, 45, 36], device='cuda:2')
# [120, 1000] acc: 0.8545000553131104
# [121, 1000] loss: 0.4107911069558759
# 设备号为: tensor([29, 19, 18, 20], device='cuda:2')，预测的设备号为:tensor([29, 19, 20, 20], device='cuda:2')
# [121, 1000] acc: 0.8507500290870667
# [122, 1000] loss: 0.3907020512452873
# 设备号为: tensor([ 9, 23, 39, 16], device='cuda:2')，预测的设备号为:tensor([ 9, 23, 27, 20], device='cuda:2')
# [122, 1000] acc: 0.8560000658035278
# [123, 1000] loss: 0.37446959694286486
# 设备号为: tensor([ 9, 22, 52,  2], device='cuda:2')，预测的设备号为:tensor([ 9, 14, 52,  2], device='cuda:2')
# [123, 1000] acc: 0.8692500591278076
# [124, 1000] loss: 0.3761250427921477
# 设备号为: tensor([14, 20, 30,  8], device='cuda:2')，预测的设备号为:tensor([16, 20,  4,  8], device='cuda:2')
# [124, 1000] acc: 0.8667500615119934
# [125, 1000] loss: 0.3814343711254478
# 设备号为: tensor([46, 18,  0, 52], device='cuda:2')，预测的设备号为:tensor([46, 18,  0, 52], device='cuda:2')
# [125, 1000] acc: 0.8645000457763672
# [126, 1000] loss: 0.3632794304551244
# 设备号为: tensor([46,  1, 11,  7], device='cuda:2')，预测的设备号为:tensor([46,  1, 11,  7], device='cuda:2')
# [126, 1000] acc: 0.8757500648498535
# [127, 1000] loss: 0.37145320966865986
# 设备号为: tensor([28, 28, 19, 31], device='cuda:2')，预测的设备号为:tensor([28, 28, 19, 31], device='cuda:2')
# [127, 1000] acc: 0.8755000233650208
# [128, 1000] loss: 0.3628099502522018
# 设备号为: tensor([46, 23, 42, 15], device='cuda:2')，预测的设备号为:tensor([46, 23, 42, 15], device='cuda:2')
# [128, 1000] acc: 0.8760000467300415
# [129, 1000] loss: 0.359692282370117
# 设备号为: tensor([45,  7, 45, 15], device='cuda:2')，预测的设备号为:tensor([45,  7, 45, 15], device='cuda:2')
# [129, 1000] acc: 0.8737500309944153
# [130, 1000] loss: 0.3607014754737611
# 设备号为: tensor([30,  7, 33, 22], device='cuda:2')，预测的设备号为:tensor([30,  7, 33, 18], device='cuda:2')
# [130, 1000] acc: 0.8647500276565552
# [131, 1000] loss: 0.3505700643991804
# 设备号为: tensor([23, 14, 45, 41], device='cuda:2')，预测的设备号为:tensor([23, 14, 45, 41], device='cuda:2')
# [131, 1000] acc: 0.8740000128746033
# [132, 1000] loss: 0.3233848698354559
# 设备号为: tensor([ 4, 48, 28, 39], device='cuda:2')，预测的设备号为:tensor([ 4, 48, 28, 39], device='cuda:2')
# [132, 1000] acc: 0.8845000267028809
# [133, 1000] loss: 0.33551291371064146
# 设备号为: tensor([27,  2, 10, 53], device='cuda:2')，预测的设备号为:tensor([27,  2, 10, 53], device='cuda:2')
# [133, 1000] acc: 0.8800000548362732
# [134, 1000] loss: 0.31976970411499134
# 设备号为: tensor([40, 34, 32, 15], device='cuda:2')，预测的设备号为:tensor([40, 34, 32, 15], device='cuda:2')
# [134, 1000] acc: 0.8832500576972961
# [135, 1000] loss: 0.33782791213046587
# 设备号为: tensor([ 6, 20, 41, 32], device='cuda:2')，预测的设备号为:tensor([ 6, 16, 41, 32], device='cuda:2')
# [135, 1000] acc: 0.8790000677108765
# [136, 1000] loss: 0.3050015321112951
# 设备号为: tensor([ 6,  9, 27, 22], device='cuda:2')，预测的设备号为:tensor([ 6,  9, 27, 22], device='cuda:2')
# [136, 1000] acc: 0.8957500457763672
# [137, 1000] loss: 0.324434515481611
# 设备号为: tensor([39, 51, 26, 38], device='cuda:2')，预测的设备号为:tensor([39, 51, 26, 38], device='cuda:2')
# [137, 1000] acc: 0.8855000138282776
# [138, 1000] loss: 0.2872376451222517
# 设备号为: tensor([ 8, 36, 40, 28], device='cuda:2')，预测的设备号为:tensor([ 8, 36, 40, 28], device='cuda:2')
# [138, 1000] acc: 0.8960000276565552
# [139, 1000] loss: 0.30598613510027645
# 设备号为: tensor([13,  4, 30, 47], device='cuda:2')，预测的设备号为:tensor([13,  4, 30, 19], device='cuda:2')
# [139, 1000] acc: 0.8875000476837158
# [140, 1000] loss: 0.27449289172848784
# 设备号为: tensor([17, 46, 39, 17], device='cuda:2')，预测的设备号为:tensor([17, 46, 39, 17], device='cuda:2')
# [140, 1000] acc: 0.9077500700950623
# [141, 1000] loss: 0.2817340206095196
# 设备号为: tensor([ 1, 11, 23,  3], device='cuda:2')，预测的设备号为:tensor([ 1, 11, 23,  3], device='cuda:2')
# [141, 1000] acc: 0.9070000648498535
# [142, 1000] loss: 0.28313635962377887
# 设备号为: tensor([ 9, 17, 14, 24], device='cuda:2')，预测的设备号为:tensor([ 9, 17, 14, 24], device='cuda:2')
# [142, 1000] acc: 0.8997500538825989
# [143, 1000] loss: 0.2811080486232822
# 设备号为: tensor([27,  1, 40, 33], device='cuda:2')，预测的设备号为:tensor([ 7,  1, 40, 33], device='cuda:2')
# [143, 1000] acc: 0.8977500200271606
# [144, 1000] loss: 0.27172911064654726
# 设备号为: tensor([ 2, 20, 42, 20], device='cuda:2')，预测的设备号为:tensor([ 2, 20, 42, 20], device='cuda:2')
# [144, 1000] acc: 0.8997500538825989
# [145, 1000] loss: 0.27488378041744366
# 设备号为: tensor([38, 53, 47, 53], device='cuda:2')，预测的设备号为:tensor([ 8, 53, 47, 53], device='cuda:2')
# [145, 1000] acc: 0.9042500257492065
# [146, 1000] loss: 0.24971094486305445
# 设备号为: tensor([38, 14, 14,  6], device='cuda:2')，预测的设备号为:tensor([38, 14, 14,  6], device='cuda:2')
# [146, 1000] acc: 0.908750057220459
# [147, 1000] loss: 0.263340670484087
# 设备号为: tensor([24,  1,  5, 22], device='cuda:2')，预测的设备号为:tensor([24,  1,  5, 22], device='cuda:2')
# [147, 1000] acc: 0.905750036239624
# [148, 1000] loss: 0.25762118612371704
# 设备号为: tensor([39, 42, 21, 27], device='cuda:2')，预测的设备号为:tensor([39, 42, 21, 27], device='cuda:2')
# [148, 1000] acc: 0.909000039100647
# [149, 1000] loss: 0.2348425395716913
# 设备号为: tensor([43, 30, 28, 25], device='cuda:2')，预测的设备号为:tensor([21, 30, 28, 33], device='cuda:2')
# [149, 1000] acc: 0.9155000448226929
# [150, 1000] loss: 0.21913231141670986
# 设备号为: tensor([21, 29, 37, 27], device='cuda:2')，预测的设备号为:tensor([21, 29, 37, 27], device='cuda:2')
# [150, 1000] acc: 0.924250066280365
# [151, 1000] loss: 0.26019400009106175
# 设备号为: tensor([43, 43, 25, 19], device='cuda:2')，预测的设备号为:tensor([43, 43, 25, 19], device='cuda:2')
# [151, 1000] acc: 0.9072500467300415
# [152, 1000] loss: 0.2333194941701131
# 设备号为: tensor([17, 39, 21,  0], device='cuda:2')，预测的设备号为:tensor([17, 39, 21,  0], device='cuda:2')
# [152, 1000] acc: 0.9165000319480896
# [153, 1000] loss: 0.2268448857127937
# 设备号为: tensor([24,  5, 26,  7], device='cuda:2')，预测的设备号为:tensor([24,  5, 26,  7], device='cuda:2')
# [153, 1000] acc: 0.9207500219345093
# [154, 1000] loss: 0.23466891112429494
# 设备号为: tensor([48, 29, 45, 36], device='cuda:2')，预测的设备号为:tensor([48, 29, 45, 36], device='cuda:2')
# [154, 1000] acc: 0.9180000424385071
# [155, 1000] loss: 0.23584042909977143
# 设备号为: tensor([28,  9, 37, 13], device='cuda:2')，预测的设备号为:tensor([28,  9, 37, 13], device='cuda:2')
# [155, 1000] acc: 0.9165000319480896
# [156, 1000] loss: 0.22193351435834482
# 设备号为: tensor([18, 46, 47,  4], device='cuda:2')，预测的设备号为:tensor([18, 46, 16,  4], device='cuda:2')
# [156, 1000] acc: 0.9250000715255737
# [157, 1000] loss: 0.18935747307514156
# 设备号为: tensor([46, 46, 51,  7], device='cuda:2')，预测的设备号为:tensor([46, 46, 51,  7], device='cuda:2')
# [157, 1000] acc: 0.937000036239624
# [158, 1000] loss: 0.2234472256542697
# 设备号为: tensor([11,  2, 53,  8], device='cuda:2')，预测的设备号为:tensor([11,  2, 53,  8], device='cuda:2')
# [158, 1000] acc: 0.9162500500679016
# [159, 1000] loss: 0.18092692389290552
# 设备号为: tensor([26, 44,  4, 37], device='cuda:2')，预测的设备号为:tensor([26, 44,  4, 37], device='cuda:2')
# [159, 1000] acc: 0.9385000467300415
# [160, 1000] loss: 0.22228567900417692
# 设备号为: tensor([ 2, 12,  8, 28], device='cuda:2')，预测的设备号为:tensor([ 2, 12,  8, 28], device='cuda:2')
# [160, 1000] acc: 0.9255000352859497
# [161, 1000] loss: 0.20860827377983696
# 设备号为: tensor([47, 17, 33, 34], device='cuda:2')，预测的设备号为:tensor([47, 17,  3, 34], device='cuda:2')
# [161, 1000] acc: 0.9275000691413879
# [162, 1000] loss: 0.18110761962560515
# 设备号为: tensor([23, 25, 12, 25], device='cuda:2')，预测的设备号为:tensor([23, 25, 12, 25], device='cuda:2')
# [162, 1000] acc: 0.9375000596046448
# [163, 1000] loss: 0.16998707424930581
# 设备号为: tensor([45, 32, 32,  9], device='cuda:2')，预测的设备号为:tensor([45, 32, 32,  9], device='cuda:2')
# [163, 1000] acc: 0.940500020980835
# [164, 1000] loss: 0.1884011836670834
# 设备号为: tensor([ 6, 33, 33, 36], device='cuda:2')，预测的设备号为:tensor([ 6, 33, 33, 36], device='cuda:2')
# [164, 1000] acc: 0.9345000386238098
# [165, 1000] loss: 0.1881611947623569
# 设备号为: tensor([20, 24, 25, 44], device='cuda:2')，预测的设备号为:tensor([20, 24, 25, 44], device='cuda:2')
# [165, 1000] acc: 0.9380000233650208
# [166, 1000] loss: 0.1931544033568043
# 设备号为: tensor([32, 31, 36, 20], device='cuda:2')，预测的设备号为:tensor([32, 31, 36, 20], device='cuda:2')
# [166, 1000] acc: 0.9322500228881836
# [167, 1000] loss: 0.18456487256335002
# 设备号为: tensor([14, 40, 38,  0], device='cuda:2')，预测的设备号为:tensor([14, 40, 38,  0], device='cuda:2')
# [167, 1000] acc: 0.9320000410079956
# [168, 1000] loss: 0.16793730040599547
# 设备号为: tensor([45, 16, 28,  3], device='cuda:2')，预测的设备号为:tensor([45, 16, 28,  3], device='cuda:2')
# [168, 1000] acc: 0.9432500600814819
# [169, 1000] loss: 0.18063758049130343
# 设备号为: tensor([36, 11, 29, 15], device='cuda:2')，预测的设备号为:tensor([36, 11, 29, 15], device='cuda:2')
# [169, 1000] acc: 0.9335000514984131
# [170, 1000] loss: 0.17491942086883863
# 设备号为: tensor([ 0, 14, 20, 30], device='cuda:2')，预测的设备号为:tensor([ 0, 23, 20, 30], device='cuda:2')
# [170, 1000] acc: 0.9435000419616699
# [171, 1000] loss: 0.15855353815382842
# 设备号为: tensor([38, 29,  0, 11], device='cuda:2')，预测的设备号为:tensor([38, 29,  0, 11], device='cuda:2')
# [171, 1000] acc: 0.9497500658035278
# [172, 1000] loss: 0.16155255346610967
# 设备号为: tensor([ 9, 50, 29, 52], device='cuda:2')，预测的设备号为:tensor([ 9, 50, 29, 52], device='cuda:2')
# [172, 1000] acc: 0.9442500472068787
# [173, 1000] loss: 0.14532524321514392
# 设备号为: tensor([13,  5, 17, 33], device='cuda:2')，预测的设备号为:tensor([13,  5, 17, 33], device='cuda:2')
# [173, 1000] acc: 0.9515000581741333
# [174, 1000] loss: 0.15579226794287207
# 设备号为: tensor([ 0,  9, 52, 15], device='cuda:2')，预测的设备号为:tensor([ 0,  9, 52, 15], device='cuda:2')
# [174, 1000] acc: 0.9442500472068787
# [175, 1000] loss: 0.1579963990741892
# 设备号为: tensor([19, 18, 49, 30], device='cuda:2')，预测的设备号为:tensor([19, 18, 49, 30], device='cuda:2')
# [175, 1000] acc: 0.9462500214576721
# [176, 1000] loss: 0.15277282316907986
# 设备号为: tensor([20, 50, 46, 24], device='cuda:2')，预测的设备号为:tensor([20, 50, 46, 24], device='cuda:2')
# [176, 1000] acc: 0.9462500214576721
# [177, 1000] loss: 0.14239040039203213
# 设备号为: tensor([34, 49,  7, 50], device='cuda:2')，预测的设备号为:tensor([34, 49,  7, 50], device='cuda:2')
# [177, 1000] acc: 0.9532500505447388
# [178, 1000] loss: 0.13140523113304517
# 设备号为: tensor([13,  2,  2,  2], device='cuda:2')，预测的设备号为:tensor([13,  2,  2,  2], device='cuda:2')
# [178, 1000] acc: 0.9590000510215759
# [179, 1000] loss: 0.14913263589817508
# 设备号为: tensor([34, 52, 38, 39], device='cuda:2')，预测的设备号为:tensor([34, 52, 38, 39], device='cuda:2')
# [179, 1000] acc: 0.9495000243186951
# [180, 1000] loss: 0.15322567154000352
# 设备号为: tensor([34, 47, 12, 20], device='cuda:2')，预测的设备号为:tensor([34, 47, 12, 20], device='cuda:2')
# [180, 1000] acc: 0.9487500190734863
# [181, 1000] loss: 0.14142168708354075
# 设备号为: tensor([14,  9, 10, 21], device='cuda:2')，预测的设备号为:tensor([14,  9, 10, 21], device='cuda:2')
# [181, 1000] acc: 0.9515000581741333
# [182, 1000] loss: 0.11425785060682302
# 设备号为: tensor([28, 19, 44, 40], device='cuda:2')，预测的设备号为:tensor([31, 19, 44, 40], device='cuda:2')
# [182, 1000] acc: 0.9640000462532043
# [183, 1000] loss: 0.13197622297616168
# 设备号为: tensor([40,  6, 46, 11], device='cuda:2')，预测的设备号为:tensor([40,  6, 46, 11], device='cuda:2')
# [183, 1000] acc: 0.9575000405311584
# [184, 1000] loss: 0.1410571930791971
# 设备号为: tensor([51, 15, 19,  7], device='cuda:2')，预测的设备号为:tensor([51, 15, 19,  7], device='cuda:2')
# [184, 1000] acc: 0.9532500505447388
# [185, 1000] loss: 0.13192470869614134
# 设备号为: tensor([15,  9, 25, 27], device='cuda:2')，预测的设备号为:tensor([15,  1, 25, 27], device='cuda:2')
# [185, 1000] acc: 0.9535000324249268
# [186, 1000] loss: 0.1414582159946417
# 设备号为: tensor([21, 33, 27, 16], device='cuda:2')，预测的设备号为:tensor([21, 33, 27, 16], device='cuda:2')
# [186, 1000] acc: 0.9512500166893005
# [187, 1000] loss: 0.12606542475866125
# 设备号为: tensor([ 3, 39, 13, 47], device='cuda:2')，预测的设备号为:tensor([ 3, 39, 13, 47], device='cuda:2')
# [187, 1000] acc: 0.9572500586509705
# [188, 1000] loss: 0.12927869178655124
# 设备号为: tensor([ 5,  6, 21, 36], device='cuda:2')，预测的设备号为:tensor([ 5,  6, 21, 36], device='cuda:2')
# [188, 1000] acc: 0.9565000534057617
# [189, 1000] loss: 0.11715178747626123
# 设备号为: tensor([35, 23, 52, 45], device='cuda:2')，预测的设备号为:tensor([35, 23, 52, 45], device='cuda:2')
# [189, 1000] acc: 0.9635000228881836
# [190, 1000] loss: 0.10066100973371522
# 设备号为: tensor([ 4, 51, 52, 38], device='cuda:2')，预测的设备号为:tensor([ 4, 51, 52, 38], device='cuda:2')
# [190, 1000] acc: 0.9705000519752502
# [191, 1000] loss: 0.11629345056709371
# 设备号为: tensor([42,  4,  7,  8], device='cuda:2')，预测的设备号为:tensor([42,  4,  7,  8], device='cuda:2')
# [191, 1000] acc: 0.9600000381469727
# [192, 1000] loss: 0.10973233819940105
# 设备号为: tensor([21, 19,  3, 26], device='cuda:2')，预测的设备号为:tensor([21, 19,  3, 26], device='cuda:2')
# [192, 1000] acc: 0.9637500643730164
# [193, 1000] loss: 0.10037529068388722
# 设备号为: tensor([48,  4, 20, 19], device='cuda:2')，预测的设备号为:tensor([48,  4, 20, 19], device='cuda:2')
# [193, 1000] acc: 0.9655000567436218
# [194, 1000] loss: 0.09913418077404412
# 设备号为: tensor([ 7,  0, 47, 19], device='cuda:2')，预测的设备号为:tensor([ 7,  8, 47, 19], device='cuda:2')
# [194, 1000] acc: 0.9645000696182251
# [195, 1000] loss: 0.09484129659231405
# 设备号为: tensor([ 4, 22, 29, 18], device='cuda:2')，预测的设备号为:tensor([ 4, 22, 29, 18], device='cuda:2')
# [195, 1000] acc: 0.9675000309944153
# [196, 1000] loss: 0.10646756630793175
# 设备号为: tensor([ 3,  3, 34, 16], device='cuda:2')，预测的设备号为:tensor([ 3,  3, 34, 16], device='cuda:2')
# [196, 1000] acc: 0.9650000333786011
# [197, 1000] loss: 0.09378845829780903
# 设备号为: tensor([ 4, 27, 29, 27], device='cuda:2')，预测的设备号为:tensor([ 4, 27, 29, 27], device='cuda:2')
# [197, 1000] acc: 0.9725000262260437
# [198, 1000] loss: 0.1083490946401921
# 设备号为: tensor([24,  2, 37, 46], device='cuda:2')，预测的设备号为:tensor([24,  2, 37, 46], device='cuda:2')
# [198, 1000] acc: 0.9620000720024109
# [199, 1000] loss: 0.10790030524578265
# 设备号为: tensor([27, 45, 51, 47], device='cuda:2')，预测的设备号为:tensor([27, 45, 51, 47], device='cuda:2')
# [199, 1000] acc: 0.9660000205039978
# [200, 1000] loss: 0.10089086980861413
# 设备号为: tensor([28, 37, 25, 47], device='cuda:2')，预测的设备号为:tensor([28, 37, 25, 47], device='cuda:2')
# [200, 1000] acc: 0.9650000333786011
# [201, 1000] loss: 0.07560718928424216
# 设备号为: tensor([19, 36, 51, 36], device='cuda:2')，预测的设备号为:tensor([19, 36, 51, 36], device='cuda:2')
# [201, 1000] acc: 0.9732500314712524
# [202, 1000] loss: 0.10537087437469814
# 设备号为: tensor([13, 27, 47,  6], device='cuda:2')，预测的设备号为:tensor([13, 27, 47,  6], device='cuda:2')
# [202, 1000] acc: 0.9645000696182251
# [203, 1000] loss: 0.08075095590724374
# 设备号为: tensor([20, 27, 47, 32], device='cuda:2')，预测的设备号为:tensor([20, 27, 47, 32], device='cuda:2')
# [203, 1000] acc: 0.9750000238418579
# [204, 1000] loss: 0.09487658448066301
# 设备号为: tensor([53,  1, 19, 21], device='cuda:2')，预测的设备号为:tensor([53,  1, 19, 21], device='cuda:2')
# [204, 1000] acc: 0.968250036239624
# [205, 1000] loss: 0.10153670701433953
# 设备号为: tensor([ 2, 39, 20, 42], device='cuda:2')，预测的设备号为:tensor([ 2, 39, 20, 42], device='cuda:2')
# [205, 1000] acc: 0.9647500514984131
# [206, 1000] loss: 0.09867506157814865
# 设备号为: tensor([14,  2,  4,  6], device='cuda:2')，预测的设备号为:tensor([14,  2,  4,  6], device='cuda:2')
# [206, 1000] acc: 0.9697500467300415
# [207, 1000] loss: 0.09944488142363934
# 设备号为: tensor([11, 19, 29,  2], device='cuda:2')，预测的设备号为:tensor([11, 22, 29,  2], device='cuda:2')
# [207, 1000] acc: 0.9687500596046448
# [208, 1000] loss: 0.0870428788665572
# 设备号为: tensor([10, 39, 14, 13], device='cuda:2')，预测的设备号为:tensor([10, 39, 14, 13], device='cuda:2')
# [208, 1000] acc: 0.9692500233650208
# [209, 1000] loss: 0.09877978955559785
# 设备号为: tensor([21, 25, 45, 14], device='cuda:2')，预测的设备号为:tensor([21, 25, 45, 14], device='cuda:2')
# [209, 1000] acc: 0.9687500596046448
# [210, 1000] loss: 0.08649644723746315
# 设备号为: tensor([43, 14,  1, 45], device='cuda:2')，预测的设备号为:tensor([43, 14,  1, 45], device='cuda:2')
# [210, 1000] acc: 0.9725000262260437
# [211, 1000] loss: 0.07801539706033418
# 设备号为: tensor([38, 31, 37, 11], device='cuda:2')，预测的设备号为:tensor([38, 31, 37, 11], device='cuda:2')
# [211, 1000] acc: 0.9757500290870667
# [212, 1000] loss: 0.07462745105453626
# 设备号为: tensor([15, 34, 35,  8], device='cuda:2')，预测的设备号为:tensor([15, 34, 35,  8], device='cuda:2')
# [212, 1000] acc: 0.9767500758171082
# [213, 1000] loss: 0.06929079939432552
# 设备号为: tensor([45, 46, 35, 34], device='cuda:2')，预测的设备号为:tensor([45, 46, 35, 34], device='cuda:2')
# [213, 1000] acc: 0.9775000214576721
# [214, 1000] loss: 0.07938587221008749
# 设备号为: tensor([17, 35, 15, 44], device='cuda:2')，预测的设备号为:tensor([17, 35, 15, 44], device='cuda:2')
# [214, 1000] acc: 0.9755000472068787
# [215, 1000] loss: 0.08428167547807948
# 设备号为: tensor([22, 14, 39, 11], device='cuda:2')，预测的设备号为:tensor([22, 14, 39, 11], device='cuda:2')
# [215, 1000] acc: 0.9700000286102295
# [216, 1000] loss: 0.08593303829245497
# 设备号为: tensor([22, 13, 15, 37], device='cuda:2')，预测的设备号为:tensor([20, 13, 15, 37], device='cuda:2')
# [216, 1000] acc: 0.971000075340271
# [217, 1000] loss: 0.0831638980728261
# 设备号为: tensor([15, 32, 20,  1], device='cuda:2')，预测的设备号为:tensor([15, 32, 20,  1], device='cuda:2')
# [217, 1000] acc: 0.9727500677108765
# [218, 1000] loss: 0.06737787020915925
# 设备号为: tensor([26, 23, 52, 11], device='cuda:2')，预测的设备号为:tensor([26, 23, 52, 11], device='cuda:2')
# [218, 1000] acc: 0.9787500500679016
# [219, 1000] loss: 0.06183988028155193
# 设备号为: tensor([ 6,  5, 21,  6], device='cuda:2')，预测的设备号为:tensor([ 6,  5, 21,  6], device='cuda:2')
# [219, 1000] acc: 0.9815000295639038
# [220, 1000] loss: 0.05911005530748821
# 设备号为: tensor([43, 33, 29, 31], device='cuda:2')，预测的设备号为:tensor([43, 33, 29, 31], device='cuda:2')
# [220, 1000] acc: 0.9832500219345093
# [221, 1000] loss: 0.0690830143859157
# 设备号为: tensor([17,  1, 22, 41], device='cuda:2')，预测的设备号为:tensor([17,  1, 22, 41], device='cuda:2')
# [221, 1000] acc: 0.9782500267028809
# [222, 1000] loss: 0.07632562179654315
# 设备号为: tensor([42, 39, 17, 32], device='cuda:2')，预测的设备号为:tensor([42, 39, 17, 32], device='cuda:2')
# [222, 1000] acc: 0.9752500653266907
# [223, 1000] loss: 0.07342621494198534
# 设备号为: tensor([51, 26, 17, 24], device='cuda:2')，预测的设备号为:tensor([51, 26, 17, 24], device='cuda:2')
# [223, 1000] acc: 0.9752500653266907
# [224, 1000] loss: 0.053280019574634366
# 设备号为: tensor([18,  8, 23, 49], device='cuda:2')，预测的设备号为:tensor([18,  8, 23, 49], device='cuda:2')
# [224, 1000] acc: 0.984000027179718
# [225, 1000] loss: 0.07972517850766973
# 设备号为: tensor([27,  8, 53, 50], device='cuda:2')，预测的设备号为:tensor([27,  8, 53, 50], device='cuda:2')
# [225, 1000] acc: 0.9732500314712524
# [226, 1000] loss: 0.07583563376234474
# 设备号为: tensor([44, 35,  5, 40], device='cuda:2')，预测的设备号为:tensor([44, 35,  5, 40], device='cuda:2')
# [226, 1000] acc: 0.9762500524520874
# [227, 1000] loss: 0.06346875763034716
# 设备号为: tensor([ 4, 26, 46, 34], device='cuda:2')，预测的设备号为:tensor([ 4, 26, 46, 34], device='cuda:2')
# [227, 1000] acc: 0.9775000214576721
# [228, 1000] loss: 0.06627170465950133
# 设备号为: tensor([39, 30,  7,  0], device='cuda:2')，预测的设备号为:tensor([39, 30,  7,  0], device='cuda:2')
# [228, 1000] acc: 0.9790000319480896
# [229, 1000] loss: 0.07248027209603003
# 设备号为: tensor([40, 51,  8, 47], device='cuda:2')，预测的设备号为:tensor([40, 51,  8, 47], device='cuda:2')
# [229, 1000] acc: 0.9762500524520874
# [230, 1000] loss: 0.06336675426810802
# 设备号为: tensor([36, 14, 24, 21], device='cuda:2')，预测的设备号为:tensor([36, 14, 24, 21], device='cuda:2')
# [230, 1000] acc: 0.9805000424385071
# [231, 1000] loss: 0.06485195308579733
# 设备号为: tensor([40, 40, 24, 14], device='cuda:2')，预测的设备号为:tensor([40, 40, 24, 16], device='cuda:2')
# [231, 1000] acc: 0.9780000448226929
# [232, 1000] loss: 0.06992651836675086
# 设备号为: tensor([26,  9, 20,  7], device='cuda:2')，预测的设备号为:tensor([26,  9, 20,  7], device='cuda:2')
# [232, 1000] acc: 0.9785000681877136
# [233, 1000] loss: 0.0805359635407849
# 设备号为: tensor([10,  8, 30, 19], device='cuda:2')，预测的设备号为:tensor([10,  8, 30, 19], device='cuda:2')
# [233, 1000] acc: 0.9747500419616699
# [234, 1000] loss: 0.07623664170832353
# 设备号为: tensor([22,  7, 52, 30], device='cuda:2')，预测的设备号为:tensor([16,  7, 52, 30], device='cuda:2')
# [234, 1000] acc: 0.9752500653266907
# [235, 1000] loss: 0.05442877303299096
# 设备号为: tensor([48, 46, 25, 19], device='cuda:2')，预测的设备号为:tensor([48, 46, 25, 19], device='cuda:2')
# [235, 1000] acc: 0.9827500581741333
# [236, 1000] loss: 0.07752064416062678
# 设备号为: tensor([49, 42, 30,  5], device='cuda:2')，预测的设备号为:tensor([49, 42, 30,  5], device='cuda:2')
# [236, 1000] acc: 0.9762500524520874
# [237, 1000] loss: 0.06381260182708473
# 设备号为: tensor([34, 43, 15, 10], device='cuda:2')，预测的设备号为:tensor([34, 43, 15, 10], device='cuda:2')
# [237, 1000] acc: 0.9787500500679016
# [238, 1000] loss: 0.05115740074795733
# 设备号为: tensor([18, 26, 33, 39], device='cuda:2')，预测的设备号为:tensor([18, 26, 33, 39], device='cuda:2')
# [238, 1000] acc: 0.9855000376701355
# [239, 1000] loss: 0.056881282733489004
# 设备号为: tensor([50, 22,  4, 14], device='cuda:2')，预测的设备号为:tensor([50, 22,  4, 14], device='cuda:2')
# [239, 1000] acc: 0.984000027179718
# [240, 1000] loss: 0.04311467985437844
# 设备号为: tensor([45, 44, 19, 14], device='cuda:2')，预测的设备号为:tensor([45, 44, 19, 14], device='cuda:2')
# [240, 1000] acc: 0.9865000247955322
# [241, 1000] loss: 0.08314256935954939
# 设备号为: tensor([52, 34, 19, 25], device='cuda:2')，预测的设备号为:tensor([52, 34, 19, 25], device='cuda:2')
# [241, 1000] acc: 0.9692500233650208
# [242, 1000] loss: 0.0545553077742544
# 设备号为: tensor([ 1, 10,  3, 10], device='cuda:2')，预测的设备号为:tensor([ 1, 10,  3, 10], device='cuda:2')
# [242, 1000] acc: 0.9830000400543213
# [243, 1000] loss: 0.050835164904217266
# 设备号为: tensor([48,  4, 20, 35], device='cuda:2')，预测的设备号为:tensor([48,  4, 20, 35], device='cuda:2')
# [243, 1000] acc: 0.9847500324249268
# [244, 1000] loss: 0.0518713176052411
# 设备号为: tensor([40, 29, 42, 34], device='cuda:2')，预测的设备号为:tensor([40, 29, 42, 34], device='cuda:2')
# [244, 1000] acc: 0.9827500581741333
# [245, 1000] loss: 0.04333806875384562
# 设备号为: tensor([37, 14, 22, 44], device='cuda:2')，预测的设备号为:tensor([37, 14, 22, 44], device='cuda:2')
# [245, 1000] acc: 0.986750066280365
# [246, 1000] loss: 0.05434832978333446
# 设备号为: tensor([45, 36,  4, 39], device='cuda:2')，预测的设备号为:tensor([45, 36,  4, 39], device='cuda:2')
# [246, 1000] acc: 0.9820000529289246
# [247, 1000] loss: 0.06610452867048139
# 设备号为: tensor([34, 21, 18,  0], device='cuda:2')，预测的设备号为:tensor([34, 21, 18,  0], device='cuda:2')
# [247, 1000] acc: 0.9790000319480896
# [248, 1000] loss: 0.03861238042623404
# 设备号为: tensor([24, 16, 25, 15], device='cuda:2')，预测的设备号为:tensor([24, 16, 25, 15], device='cuda:2')
# [248, 1000] acc: 0.987250030040741
# [249, 1000] loss: 0.0483802614232394
# 设备号为: tensor([49, 47, 52, 37], device='cuda:2')，预测的设备号为:tensor([49, 47, 52, 37], device='cuda:2')
# [249, 1000] acc: 0.9842500686645508
# [250, 1000] loss: 0.053777280340836765
# 设备号为: tensor([25, 11,  0, 52], device='cuda:2')，预测的设备号为:tensor([25, 11,  0, 52], device='cuda:2')
# [250, 1000] acc: 0.9825000762939453
# [251, 1000] loss: 0.06209175288683178
# 设备号为: tensor([25, 32, 13, 45], device='cuda:2')，预测的设备号为:tensor([25, 32, 13, 45], device='cuda:2')
# [251, 1000] acc: 0.9800000190734863
# [252, 1000] loss: 0.05852791231418249
# 设备号为: tensor([20, 10, 29, 26], device='cuda:2')，预测的设备号为:tensor([20, 10, 29, 26], device='cuda:2')
# [252, 1000] acc: 0.9797500371932983
# [253, 1000] loss: 0.04116629024360269
# 设备号为: tensor([ 8,  2, 31,  6], device='cuda:2')，预测的设备号为:tensor([ 8,  2, 31,  6], device='cuda:2')
# [253, 1000] acc: 0.9877500534057617
# [254, 1000] loss: 0.05022255814020116
# 设备号为: tensor([44, 39,  0,  3], device='cuda:2')，预测的设备号为:tensor([44, 39,  0,  3], device='cuda:2')
# [254, 1000] acc: 0.9827500581741333
# [255, 1000] loss: 0.048713830527803106
# 设备号为: tensor([ 0, 51,  1,  8], device='cuda:2')，预测的设备号为:tensor([ 0, 51,  1,  8], device='cuda:2')
# [255, 1000] acc: 0.983500063419342
# [256, 1000] loss: 0.051434602724283
# 设备号为: tensor([13, 10, 51, 33], device='cuda:2')，预测的设备号为:tensor([13, 10, 51, 33], device='cuda:2')
# [256, 1000] acc: 0.9832500219345093
# [257, 1000] loss: 0.05380941494260804
# 设备号为: tensor([17, 13, 22, 23], device='cuda:2')，预测的设备号为:tensor([17, 13, 22, 23], device='cuda:2')
# [257, 1000] acc: 0.9817500710487366
# [258, 1000] loss: 0.040678892665772876
# 设备号为: tensor([ 4, 27, 38, 20], device='cuda:2')，预测的设备号为:tensor([ 4, 27, 38, 20], device='cuda:2')
# [258, 1000] acc: 0.9882500171661377
# [259, 1000] loss: 0.03575348760390346
# 设备号为: tensor([10, 48, 34,  3], device='cuda:2')，预测的设备号为:tensor([10, 48, 34,  3], device='cuda:2')
# [259, 1000] acc: 0.9890000224113464
# [260, 1000] loss: 0.05375571215592919
# 设备号为: tensor([31, 24, 51, 34], device='cuda:2')，预测的设备号为:tensor([31, 24, 51, 34], device='cuda:2')
# [260, 1000] acc: 0.9820000529289246
# [261, 1000] loss: 0.049307676214546146
# 设备号为: tensor([50, 19, 15, 35], device='cuda:2')，预测的设备号为:tensor([50, 19, 15, 35], device='cuda:2')
# [261, 1000] acc: 0.9850000739097595
# [262, 1000] loss: 0.037122884916797376
# 设备号为: tensor([45, 35, 11, 40], device='cuda:2')，预测的设备号为:tensor([45, 35, 11, 40], device='cuda:2')
# [262, 1000] acc: 0.9880000352859497
# [263, 1000] loss: 0.051477138856244435
# 设备号为: tensor([ 8, 16, 46, 22], device='cuda:2')，预测的设备号为:tensor([ 8, 16, 46, 22], device='cuda:2')
# [263, 1000] acc: 0.9830000400543213
# [264, 1000] loss: 0.05184171131029353
# 设备号为: tensor([39, 44, 50, 28], device='cuda:2')，预测的设备号为:tensor([39, 44, 50, 28], device='cuda:2')
# [264, 1000] acc: 0.9830000400543213
# [265, 1000] loss: 0.039976038002243655
# 设备号为: tensor([ 7, 49, 18, 17], device='cuda:2')，预测的设备号为:tensor([ 7, 49, 18, 17], device='cuda:2')
# [265, 1000] acc: 0.9877500534057617
# [266, 1000] loss: 0.045382330455093725
# 设备号为: tensor([33, 13, 52, 23], device='cuda:2')，预测的设备号为:tensor([33, 13, 52, 23], device='cuda:2')
# [266, 1000] acc: 0.9850000739097595
# [267, 1000] loss: 0.03883547635818121
# 设备号为: tensor([23,  4,  8, 29], device='cuda:2')，预测的设备号为:tensor([23,  4,  8, 29], device='cuda:2')
# [267, 1000] acc: 0.9882500171661377
# [268, 1000] loss: 0.06258173248030857
# 设备号为: tensor([14,  7, 25, 28], device='cuda:2')，预测的设备号为:tensor([14,  7, 25, 28], device='cuda:2')
# [268, 1000] acc: 0.9792500734329224
# [269, 1000] loss: 0.03442694076128666
# 设备号为: tensor([21, 36,  3, 35], device='cuda:2')，预测的设备号为:tensor([21, 36,  3, 35], device='cuda:2')
# [269, 1000] acc: 0.9880000352859497
# [270, 1000] loss: 0.045632896302171495
# 设备号为: tensor([ 8, 15, 19, 42], device='cuda:2')，预测的设备号为:tensor([ 8, 15, 19, 42], device='cuda:2')
# [270, 1000] acc: 0.9857500195503235
# [271, 1000] loss: 0.044177465704304586
# 设备号为: tensor([ 5, 36, 30, 25], device='cuda:2')，预测的设备号为:tensor([ 5, 36, 30, 25], device='cuda:2')
# [271, 1000] acc: 0.9880000352859497
# [272, 1000] loss: 0.04582829879789301
# 设备号为: tensor([34, 32, 50, 42], device='cuda:2')，预测的设备号为:tensor([34, 32, 50, 42], device='cuda:2')
# [272, 1000] acc: 0.9842500686645508
# [273, 1000] loss: 0.052964698656886584
# 设备号为: tensor([34, 22, 51, 18], device='cuda:2')，预测的设备号为:tensor([34, 22, 51, 18], device='cuda:2')
# [273, 1000] acc: 0.983500063419342
# [274, 1000] loss: 0.0466911455442377
# 设备号为: tensor([35, 15, 38, 19], device='cuda:2')，预测的设备号为:tensor([35, 15, 38, 19], device='cuda:2')
# [274, 1000] acc: 0.986750066280365
# [275, 1000] loss: 0.03382282332828672
# 设备号为: tensor([ 2,  9, 20, 50], device='cuda:2')，预测的设备号为:tensor([ 2,  9, 20, 50], device='cuda:2')
# [275, 1000] acc: 0.9895000457763672
# [276, 1000] loss: 0.053148781788067596
# 设备号为: tensor([22, 46, 24, 10], device='cuda:2')，预测的设备号为:tensor([22, 46, 24, 10], device='cuda:2')
# [276, 1000] acc: 0.9825000762939453
# [277, 1000] loss: 0.03889198957067707
# 设备号为: tensor([17,  6, 45,  6], device='cuda:2')，预测的设备号为:tensor([17,  6, 45,  6], device='cuda:2')
# [277, 1000] acc: 0.9857500195503235
# [278, 1000] loss: 0.02964504405497656
# 设备号为: tensor([25, 49,  0,  1], device='cuda:2')，预测的设备号为:tensor([25, 49,  0,  1], device='cuda:2')
# [278, 1000] acc: 0.9907500743865967
# [279, 1000] loss: 0.03658300797786927
# 设备号为: tensor([16, 18, 12, 49], device='cuda:2')，预测的设备号为:tensor([16, 18, 12, 49], device='cuda:2')
# [279, 1000] acc: 0.9892500638961792
# [280, 1000] loss: 0.032079456004588024
# ...
# 目前一共测试了1188组，预测成功的一共有790组
# 设备号为: tensor([48,  5, 37, 52], device='cuda:2')，模型训练后得到的设备号为:tensor([31,  5, 37, 52], device='cuda:2')
# 目前一共测试了1192组，预测成功的一共有793组
# 设备号为: tensor([ 8, 22,  0, 37], device='cuda:2')，模型训练后得到的设备号为:tensor([ 8, 16,  0, 37], device='cuda:2')
# 目前一共测试了1196组，预测成功的一共有796组
# 设备号为: tensor([39, 45, 34, 31], device='cuda:2')，模型训练后得到的设备号为:tensor([34, 45, 34, 31], device='cuda:2')
# 目前一共测试了1200组，预测成功的一共有799组
# 设备号为: tensor([29, 32, 31, 48], device='cuda:2')，模型训练后得到的设备号为:tensor([29, 32, 31, 48], device='cuda:2')
# 目前一共测试了1204组，预测成功的一共有803组
# 设备号为: tensor([23, 23,  9, 24], device='cuda:2')，模型训练后得到的设备号为:tensor([23, 12,  9, 24], device='cuda:2')
# 目前一共测试了1208组，预测成功的一共有806组
# 设备号为: tensor([36,  7, 31, 41], device='cuda:2')，模型训练后得到的设备号为:tensor([36, 28, 31, 42], device='cuda:2')
# 目前一共测试了1212组，预测成功的一共有808组
# 设备号为: tensor([52, 39,  7, 48], device='cuda:2')，模型训练后得到的设备号为:tensor([45, 39, 27, 48], device='cuda:2')
# 目前一共测试了1216组，预测成功的一共有810组
# 设备号为: tensor([41,  7, 19, 43], device='cuda:2')，模型训练后得到的设备号为:tensor([21,  7, 47, 21], device='cuda:2')
# 目前一共测试了1220组，预测成功的一共有811组
# 设备号为: tensor([10, 17, 21, 12], device='cuda:2')，模型训练后得到的设备号为:tensor([10, 17, 21, 24], device='cuda:2')
# 目前一共测试了1224组，预测成功的一共有814组
# 设备号为: tensor([ 9,  0, 50, 35], device='cuda:2')，模型训练后得到的设备号为:tensor([ 9,  0, 50, 35], device='cuda:2')
# 目前一共测试了1228组，预测成功的一共有818组
# 设备号为: tensor([50, 36, 20, 29], device='cuda:2')，模型训练后得到的设备号为:tensor([50, 36, 20, 29], device='cuda:2')
# 目前一共测试了1232组，预测成功的一共有822组
# 设备号为: tensor([27, 37,  6, 48], device='cuda:2')，模型训练后得到的设备号为:tensor([ 3, 37,  6, 48], device='cuda:2')
# 目前一共测试了1236组，预测成功的一共有825组
# 设备号为: tensor([51, 27, 28, 11], device='cuda:2')，模型训练后得到的设备号为:tensor([42, 33, 28, 11], device='cuda:2')
# 目前一共测试了1240组，预测成功的一共有827组
# 设备号为: tensor([10, 30, 28, 10], device='cuda:2')，模型训练后得到的设备号为:tensor([10, 30, 28, 10], device='cuda:2')
# 目前一共测试了1244组，预测成功的一共有831组
# 设备号为: tensor([19, 40, 12,  1], device='cuda:2')，模型训练后得到的设备号为:tensor([47, 40, 12,  1], device='cuda:2')
# 目前一共测试了1248组，预测成功的一共有834组
# 设备号为: tensor([ 6, 17, 43, 50], device='cuda:2')，模型训练后得到的设备号为:tensor([ 6, 17, 21, 50], device='cuda:2')
# 目前一共测试了1252组，预测成功的一共有837组
# 设备号为: tensor([22, 47, 18, 23], device='cuda:2')，模型训练后得到的设备号为:tensor([41, 47, 18, 23], device='cuda:2')
# 目前一共测试了1256组，预测成功的一共有840组
# 设备号为: tensor([51,  5,  6, 23], device='cuda:2')，模型训练后得到的设备号为:tensor([49,  5,  6, 23], device='cuda:2')
# 目前一共测试了1260组，预测成功的一共有843组
# 设备号为: tensor([14, 40,  1, 53], device='cuda:2')，模型训练后得到的设备号为:tensor([20, 18,  1, 53], device='cuda:2')
# 目前一共测试了1264组，预测成功的一共有845组
# 设备号为: tensor([ 0, 26, 34, 32], device='cuda:2')，模型训练后得到的设备号为:tensor([ 0, 26, 39, 32], device='cuda:2')
# 目前一共测试了1268组，预测成功的一共有848组
# 设备号为: tensor([18, 27, 47,  3], device='cuda:2')，模型训练后得到的设备号为:tensor([20, 25, 47,  3], device='cuda:2')
# 目前一共测试了1272组，预测成功的一共有850组
# 设备号为: tensor([33, 34,  9, 39], device='cuda:2')，模型训练后得到的设备号为:tensor([33, 34,  9, 34], device='cuda:2')
# 目前一共测试了1276组，预测成功的一共有853组
# 设备号为: tensor([27, 28, 31, 26], device='cuda:2')，模型训练后得到的设备号为:tensor([27, 28, 31, 26], device='cuda:2')
# 目前一共测试了1280组，预测成功的一共有857组
# 设备号为: tensor([52,  0, 22, 33], device='cuda:2')，模型训练后得到的设备号为:tensor([52,  0, 20, 11], device='cuda:2')
# 目前一共测试了1284组，预测成功的一共有859组
# 设备号为: tensor([45, 53,  4, 22], device='cuda:2')，模型训练后得到的设备号为:tensor([45, 46,  4, 20], device='cuda:2')
# 目前一共测试了1288组，预测成功的一共有861组
# 设备号为: tensor([20, 52, 17, 53], device='cuda:2')，模型训练后得到的设备号为:tensor([16, 52, 17, 15], device='cuda:2')
# 目前一共测试了1292组，预测成功的一共有863组
# 设备号为: tensor([21, 38, 22, 30], device='cuda:2')，模型训练后得到的设备号为:tensor([18, 38, 20, 30], device='cuda:2')
# 目前一共测试了1296组，预测成功的一共有865组
# 设备号为: tensor([ 4, 30, 19, 11], device='cuda:2')，模型训练后得到的设备号为:tensor([ 4, 30, 22, 11], device='cuda:2')
# 目前一共测试了1300组，预测成功的一共有868组
# 设备号为: tensor([40, 36, 22, 19], device='cuda:2')，模型训练后得到的设备号为:tensor([40, 36, 22, 19], device='cuda:2')
# 目前一共测试了1304组，预测成功的一共有872组
# 设备号为: tensor([29, 53, 29,  4], device='cuda:2')，模型训练后得到的设备号为:tensor([29, 53, 29,  4], device='cuda:2')
# 目前一共测试了1308组，预测成功的一共有876组
# 设备号为: tensor([16, 13, 43, 33], device='cuda:2')，模型训练后得到的设备号为:tensor([19, 13, 21, 33], device='cuda:2')
# 目前一共测试了1312组，预测成功的一共有878组
# 设备号为: tensor([11,  5, 19, 18], device='cuda:2')，模型训练后得到的设备号为:tensor([11,  5, 47, 18], device='cuda:2')
# 目前一共测试了1316组，预测成功的一共有881组
# 设备号为: tensor([29,  2, 20, 50], device='cuda:2')，模型训练后得到的设备号为:tensor([29, 13, 49, 50], device='cuda:2')
# 目前一共测试了1320组，预测成功的一共有883组
# 设备号为: tensor([31, 53, 18,  4], device='cuda:2')，模型训练后得到的设备号为:tensor([31, 53, 41,  4], device='cuda:2')
# 目前一共测试了1324组，预测成功的一共有886组
# 设备号为: tensor([33, 23, 25, 52], device='cuda:2')，模型训练后得到的设备号为:tensor([ 3, 23, 25, 45], device='cuda:2')
# 目前一共测试了1328组，预测成功的一共有888组
# 设备号为: tensor([42,  8, 49, 25], device='cuda:2')，模型训练后得到的设备号为:tensor([42,  8, 49, 25], device='cuda:2')
# 目前一共测试了1332组，预测成功的一共有892组
# 设备号为: tensor([30, 51, 11, 23], device='cuda:2')，模型训练后得到的设备号为:tensor([30, 40,  4, 23], device='cuda:2')
# 目前一共测试了1336组，预测成功的一共有894组
# 设备号为: tensor([ 3, 29, 30,  0], device='cuda:2')，模型训练后得到的设备号为:tensor([ 7, 29, 30,  0], device='cuda:2')
# 目前一共测试了1340组，预测成功的一共有897组
# 设备号为: tensor([30, 12, 53,  0], device='cuda:2')，模型训练后得到的设备号为:tensor([30, 12, 53,  0], device='cuda:2')
# 目前一共测试了1344组，预测成功的一共有901组
# 设备号为: tensor([50, 33,  1, 25], device='cuda:2')，模型训练后得到的设备号为:tensor([50, 33,  1, 31], device='cuda:2')
# 目前一共测试了1348组，预测成功的一共有904组
# 设备号为: tensor([48, 51, 11, 40], device='cuda:2')，模型训练后得到的设备号为:tensor([48, 51, 11, 21], device='cuda:2')
# 目前一共测试了1352组，预测成功的一共有907组
# 设备号为: tensor([25, 25, 10, 40], device='cuda:2')，模型训练后得到的设备号为:tensor([25, 31, 10, 42], device='cuda:2')
# 目前一共测试了1356组，预测成功的一共有909组
# 设备号为: tensor([27, 52, 38,  6], device='cuda:2')，模型训练后得到的设备号为:tensor([33, 52, 38,  6], device='cuda:2')
# 目前一共测试了1360组，预测成功的一共有912组
# 设备号为: tensor([ 3, 22, 51, 23], device='cuda:2')，模型训练后得到的设备号为:tensor([28, 19, 42, 23], device='cuda:2')
# 目前一共测试了1364组，预测成功的一共有913组
# 设备号为: tensor([35, 43, 12, 21], device='cuda:2')，模型训练后得到的设备号为:tensor([35, 41, 12, 41], device='cuda:2')
# 目前一共测试了1368组，预测成功的一共有915组
# 设备号为: tensor([ 5, 21, 26, 18], device='cuda:2')，模型训练后得到的设备号为:tensor([ 5, 41, 26, 40], device='cuda:2')
# 目前一共测试了1372组，预测成功的一共有917组
# 设备号为: tensor([36, 36,  3, 16], device='cuda:2')，模型训练后得到的设备号为:tensor([36, 36, 27, 21], device='cuda:2')
# 目前一共测试了1376组，预测成功的一共有919组
# 设备号为: tensor([ 4, 40,  0,  1], device='cuda:2')，模型训练后得到的设备号为:tensor([ 4, 40,  8,  1], device='cuda:2')
# 目前一共测试了1380组，预测成功的一共有922组
# 设备号为: tensor([41, 36, 25,  9], device='cuda:2')，模型训练后得到的设备号为:tensor([16, 36, 25,  9], device='cuda:2')
# 目前一共测试了1384组，预测成功的一共有925组
# 设备号为: tensor([30, 38, 47, 33], device='cuda:2')，模型训练后得到的设备号为:tensor([30, 38, 43,  7], device='cuda:2')
# 目前一共测试了1388组，预测成功的一共有927组
# 设备号为: tensor([53, 15, 33, 11], device='cuda:2')，模型训练后得到的设备号为:tensor([53, 44, 38, 11], device='cuda:2')
# 目前一共测试了1392组，预测成功的一共有929组
# 设备号为: tensor([ 3, 49, 46, 27], device='cuda:2')，模型训练后得到的设备号为:tensor([ 3, 50, 46, 33], device='cuda:2')
# 目前一共测试了1396组，预测成功的一共有931组
# 设备号为: tensor([49, 24, 19, 42], device='cuda:2')，模型训练后得到的设备号为:tensor([49, 24, 16, 42], device='cuda:2')
# 目前一共测试了1400组，预测成功的一共有934组
# 设备号为: tensor([30,  6,  7, 43], device='cuda:2')，模型训练后得到的设备号为:tensor([30,  6, 39, 43], device='cuda:2')
# 目前一共测试了1404组，预测成功的一共有937组
# 设备号为: tensor([46, 11, 52, 31], device='cuda:2')，模型训练后得到的设备号为:tensor([46, 11, 45, 31], device='cuda:2')
# 目前一共测试了1408组，预测成功的一共有940组
# 设备号为: tensor([29, 16, 18, 35], device='cuda:2')，模型训练后得到的设备号为:tensor([29, 22, 18, 35], device='cuda:2')
# 目前一共测试了1412组，预测成功的一共有943组
# 设备号为: tensor([43, 47, 46, 34], device='cuda:2')，模型训练后得到的设备号为:tensor([21, 19, 44, 34], device='cuda:2')
# 目前一共测试了1416组，预测成功的一共有944组
# 设备号为: tensor([43, 11, 44, 28], device='cuda:2')，模型训练后得到的设备号为:tensor([17, 39, 53, 28], device='cuda:2')
# 目前一共测试了1420组，预测成功的一共有945组
# 设备号为: tensor([46, 39, 34, 48], device='cuda:2')，模型训练后得到的设备号为:tensor([46, 11, 34, 48], device='cuda:2')
# 目前一共测试了1424组，预测成功的一共有948组
# 设备号为: tensor([47, 47, 19, 27], device='cuda:2')，模型训练后得到的设备号为:tensor([43, 16, 19, 27], device='cuda:2')
# 目前一共测试了1428组，预测成功的一共有950组
# 设备号为: tensor([52, 33, 30, 28], device='cuda:2')，模型训练后得到的设备号为:tensor([45, 33, 30, 10], device='cuda:2')
# 目前一共测试了1432组，预测成功的一共有952组
# 设备号为: tensor([28, 24, 29, 45], device='cuda:2')，模型训练后得到的设备号为:tensor([35, 24, 29, 45], device='cuda:2')
# 目前一共测试了1436组，预测成功的一共有955组
# 设备号为: tensor([24, 13, 45, 50], device='cuda:2')，模型训练后得到的设备号为:tensor([24, 13, 45, 50], device='cuda:2')
# 目前一共测试了1440组，预测成功的一共有959组
# 设备号为: tensor([ 7, 34, 20, 25], device='cuda:2')，模型训练后得到的设备号为:tensor([ 7, 34, 16, 25], device='cuda:2')
# 目前一共测试了1444组，预测成功的一共有962组
# 设备号为: tensor([52, 47, 49, 16], device='cuda:2')，模型训练后得到的设备号为:tensor([52, 40, 42, 51], device='cuda:2')
# 目前一共测试了1448组，预测成功的一共有963组
# 设备号为: tensor([18, 39,  4, 38], device='cuda:2')，模型训练后得到的设备号为:tensor([41, 39,  4,  1], device='cuda:2')
# 目前一共测试了1452组，预测成功的一共有965组
# 设备号为: tensor([35, 48, 45, 14], device='cuda:2')，模型训练后得到的设备号为:tensor([35, 48, 45, 49], device='cuda:2')
# 目前一共测试了1456组，预测成功的一共有968组
# 设备号为: tensor([16, 29, 39, 13], device='cuda:2')，模型训练后得到的设备号为:tensor([20, 29, 39, 13], device='cuda:2')
# 目前一共测试了1460组，预测成功的一共有971组
# 设备号为: tensor([ 2, 41, 16, 32], device='cuda:2')，模型训练后得到的设备号为:tensor([ 2, 42, 14, 32], device='cuda:2')
# 目前一共测试了1464组，预测成功的一共有973组
# 设备号为: tensor([13,  7, 19, 13], device='cuda:2')，模型训练后得到的设备号为:tensor([13, 28, 19, 13], device='cuda:2')
# 目前一共测试了1468组，预测成功的一共有976组
# 设备号为: tensor([49, 45, 40, 53], device='cuda:2')，模型训练后得到的设备号为:tensor([40, 45, 40, 53], device='cuda:2')
# 目前一共测试了1472组，预测成功的一共有979组
# 设备号为: tensor([39, 46, 38,  1], device='cuda:2')，模型训练后得到的设备号为:tensor([39, 46,  9,  1], device='cuda:2')
# 目前一共测试了1476组，预测成功的一共有982组
# 设备号为: tensor([13,  3, 35, 38], device='cuda:2')，模型训练后得到的设备号为:tensor([13, 28, 29, 10], device='cuda:2')
# 目前一共测试了1480组，预测成功的一共有983组
# 设备号为: tensor([24, 41, 32, 37], device='cuda:2')，模型训练后得到的设备号为:tensor([23, 43, 32, 37], device='cuda:2')
# 目前一共测试了1484组，预测成功的一共有985组
# 设备号为: tensor([ 2, 44,  3, 22], device='cuda:2')，模型训练后得到的设备号为:tensor([ 2, 46,  3, 51], device='cuda:2')
# 目前一共测试了1488组，预测成功的一共有987组
# 设备号为: tensor([47, 32,  2, 50], device='cuda:2')，模型训练后得到的设备号为:tensor([47, 32,  2, 50], device='cuda:2')
# 目前一共测试了1492组，预测成功的一共有991组
# 设备号为: tensor([ 2, 34, 17, 20], device='cuda:2')，模型训练后得到的设备号为:tensor([ 2, 34, 17, 22], device='cuda:2')
# 目前一共测试了1496组，预测成功的一共有994组
# 设备号为: tensor([39, 46,  7, 33], device='cuda:2')，模型训练后得到的设备号为:tensor([34, 46,  7, 38], device='cuda:2')
# 目前一共测试了1500组，预测成功的一共有996组
# 设备号为: tensor([ 2, 47,  2, 36], device='cuda:2')，模型训练后得到的设备号为:tensor([ 2, 22, 29, 36], device='cuda:2')
# 目前一共测试了1504组，预测成功的一共有998组
# 设备号为: tensor([23, 38, 33, 53], device='cuda:2')，模型训练后得到的设备号为:tensor([24, 38, 25, 53], device='cuda:2')
# 目前一共测试了1508组，预测成功的一共有1000组
# 设备号为: tensor([32, 16,  1,  5], device='cuda:2')，模型训练后得到的设备号为:tensor([32, 19,  1,  1], device='cuda:2')
# 目前一共测试了1512组，预测成功的一共有1002组
# 设备号为: tensor([42, 13, 50, 16], device='cuda:2')，模型训练后得到的设备号为:tensor([42, 13, 40, 19], device='cuda:2')
# 目前一共测试了1516组，预测成功的一共有1004组
# 设备号为: tensor([22, 27, 33, 49], device='cuda:2')，模型训练后得到的设备号为:tensor([14, 27,  3, 49], device='cuda:2')
# 目前一共测试了1520组，预测成功的一共有1006组
# 设备号为: tensor([27, 44, 11, 52], device='cuda:2')，模型训练后得到的设备号为:tensor([27, 44, 11, 52], device='cuda:2')
# 目前一共测试了1524组，预测成功的一共有1010组
# 设备号为: tensor([48, 49,  7, 45], device='cuda:2')，模型训练后得到的设备号为:tensor([48, 50,  7, 45], device='cuda:2')
# 目前一共测试了1528组，预测成功的一共有1013组
# 设备号为: tensor([17, 37, 25, 24], device='cuda:2')，模型训练后得到的设备号为:tensor([17, 37, 33, 24], device='cuda:2')
# 目前一共测试了1532组，预测成功的一共有1016组
# 设备号为: tensor([ 0, 15, 46, 43], device='cuda:2')，模型训练后得到的设备号为:tensor([ 8, 15, 46, 43], device='cuda:2')
# 目前一共测试了1536组，预测成功的一共有1019组
# 设备号为: tensor([40, 48, 36, 49], device='cuda:2')，模型训练后得到的设备号为:tensor([51, 48, 36, 40], device='cuda:2')
# 目前一共测试了1540组，预测成功的一共有1021组
# 设备号为: tensor([43, 38, 53, 48], device='cuda:2')，模型训练后得到的设备号为:tensor([43, 38, 53, 48], device='cuda:2')
# 目前一共测试了1544组，预测成功的一共有1025组
# 设备号为: tensor([31, 39,  6, 15], device='cuda:2')，模型训练后得到的设备号为:tensor([31, 34,  6, 14], device='cuda:2')
# 目前一共测试了1548组，预测成功的一共有1027组
# 设备号为: tensor([16, 40, 41, 19], device='cuda:2')，模型训练后得到的设备号为:tensor([20, 40, 16, 19], device='cuda:2')
# 目前一共测试了1552组，预测成功的一共有1029组
# 设备号为: tensor([52, 42,  2,  3], device='cuda:2')，模型训练后得到的设备号为:tensor([52, 42, 29,  3], device='cuda:2')
# 目前一共测试了1556组，预测成功的一共有1032组
# 设备号为: tensor([13, 51, 48,  6], device='cuda:2')，模型训练后得到的设备号为:tensor([13, 41, 48,  6], device='cuda:2')
# 目前一共测试了1560组，预测成功的一共有1035组
# 设备号为: tensor([15, 52, 27, 46], device='cuda:2')，模型训练后得到的设备号为:tensor([12, 52, 11, 44], device='cuda:2')
# 目前一共测试了1564组，预测成功的一共有1036组
# 设备号为: tensor([50,  2, 17, 36], device='cuda:2')，模型训练后得到的设备号为:tensor([50,  2, 17, 36], device='cuda:2')
# 目前一共测试了1568组，预测成功的一共有1040组
# 设备号为: tensor([18, 12, 29, 52], device='cuda:2')，模型训练后得到的设备号为:tensor([18, 12, 29, 52], device='cuda:2')
# 目前一共测试了1572组，预测成功的一共有1044组
# 设备号为: tensor([20, 53, 32, 25], device='cuda:2')，模型训练后得到的设备号为:tensor([20, 53, 32, 25], device='cuda:2')
# 目前一共测试了1576组，预测成功的一共有1048组
# 设备号为: tensor([32, 41, 33, 25], device='cuda:2')，模型训练后得到的设备号为:tensor([32, 20, 32, 33], device='cuda:2')
# 目前一共测试了1580组，预测成功的一共有1049组
# 设备号为: tensor([ 0,  0, 35, 41], device='cuda:2')，模型训练后得到的设备号为:tensor([ 5,  0, 35, 12], device='cuda:2')
# 目前一共测试了1584组，预测成功的一共有1051组
# 设备号为: tensor([ 2, 26, 47,  6], device='cuda:2')，模型训练后得到的设备号为:tensor([29, 31, 47,  6], device='cuda:2')
# 目前一共测试了1588组，预测成功的一共有1053组
# 设备号为: tensor([ 2,  3, 19, 33], device='cuda:2')，模型训练后得到的设备号为:tensor([ 2,  3, 13,  8], device='cuda:2')
# 目前一共测试了1592组，预测成功的一共有1055组
# 设备号为: tensor([38, 37, 25, 24], device='cuda:2')，模型训练后得到的设备号为:tensor([36, 37, 32, 24], device='cuda:2')
# 目前一共测试了1596组，预测成功的一共有1057组
# 设备号为: tensor([39,  2, 28, 50], device='cuda:2')，模型训练后得到的设备号为:tensor([33,  2, 28, 51], device='cuda:2')
# 目前一共测试了1600组，预测成功的一共有1059组
# 设备号为: tensor([47, 52, 52, 20], device='cuda:2')，模型训练后得到的设备号为:tensor([19, 52, 52, 20], device='cuda:2')
# 目前一共测试了1604组，预测成功的一共有1062组
# 设备号为: tensor([ 2, 36, 46, 43], device='cuda:2')，模型训练后得到的设备号为:tensor([ 2, 36, 46, 47], device='cuda:2')
# 目前一共测试了1608组，预测成功的一共有1065组
# 设备号为: tensor([ 4, 47, 13,  8], device='cuda:2')，模型训练后得到的设备号为:tensor([ 4, 47, 13,  5], device='cuda:2')
# 目前一共测试了1612组，预测成功的一共有1068组
# 设备号为: tensor([20, 39,  1,  0], device='cuda:2')，模型训练后得到的设备号为:tensor([14, 39,  1,  0], device='cuda:2')
# 目前一共测试了1616组，预测成功的一共有1071组
# 设备号为: tensor([ 2, 38, 44, 16], device='cuda:2')，模型训练后得到的设备号为:tensor([ 2,  9, 52, 14], device='cuda:2')
# 目前一共测试了1620组，预测成功的一共有1072组
# 设备号为: tensor([16, 45, 29,  6], device='cuda:2')，模型训练后得到的设备号为:tensor([16, 45, 29,  6], device='cuda:2')
# 目前一共测试了1624组，预测成功的一共有1076组
# 设备号为: tensor([25, 23, 14, 52], device='cuda:2')，模型训练后得到的设备号为:tensor([25, 23, 14, 52], device='cuda:2')
# 目前一共测试了1628组，预测成功的一共有1080组
# 设备号为: tensor([37,  6, 26, 28], device='cuda:2')，模型训练后得到的设备号为:tensor([37,  6, 26, 10], device='cuda:2')
# 目前一共测试了1632组，预测成功的一共有1083组
# 设备号为: tensor([23,  6, 37, 30], device='cuda:2')，模型训练后得到的设备号为:tensor([23,  6, 37, 30], device='cuda:2')
# 目前一共测试了1636组，预测成功的一共有1087组
# 设备号为: tensor([27,  6,  5,  3], device='cuda:2')，模型训练后得到的设备号为:tensor([27,  6,  5,  3], device='cuda:2')
# 目前一共测试了1640组，预测成功的一共有1091组
# 设备号为: tensor([37, 19, 23, 49], device='cuda:2')，模型训练后得到的设备号为:tensor([37, 12, 23, 42], device='cuda:2')
# 目前一共测试了1644组，预测成功的一共有1093组
# 设备号为: tensor([ 5, 12, 28, 52], device='cuda:2')，模型训练后得到的设备号为:tensor([ 0, 20, 28, 45], device='cuda:2')
# 目前一共测试了1648组，预测成功的一共有1094组
# 设备号为: tensor([ 9, 31, 20, 51], device='cuda:2')，模型训练后得到的设备号为:tensor([33, 31, 22, 16], device='cuda:2')
# 目前一共测试了1652组，预测成功的一共有1095组
# 设备号为: tensor([26, 41, 41, 16], device='cuda:2')，模型训练后得到的设备号为:tensor([26, 16, 41, 20], device='cuda:2')
# 目前一共测试了1656组，预测成功的一共有1097组
# 设备号为: tensor([14,  0, 45,  2], device='cuda:2')，模型训练后得到的设备号为:tensor([22,  8, 45,  2], device='cuda:2')
# 目前一共测试了1660组，预测成功的一共有1099组
# 设备号为: tensor([10, 24, 23,  4], device='cuda:2')，模型训练后得到的设备号为:tensor([10, 24, 23,  4], device='cuda:2')
# 目前一共测试了1664组，预测成功的一共有1103组
# 设备号为: tensor([48, 29, 12, 39], device='cuda:2')，模型训练后得到的设备号为:tensor([48, 29, 12, 39], device='cuda:2')
# 目前一共测试了1668组，预测成功的一共有1107组
# 设备号为: tensor([47, 14, 25, 50], device='cuda:2')，模型训练后得到的设备号为:tensor([47, 22, 25, 50], device='cuda:2')
# 目前一共测试了1672组，预测成功的一共有1110组
# 设备号为: tensor([23, 14], device='cuda:2')，模型训练后得到的设备号为:tensor([23, 23], device='cuda:2')
# 目前一共测试了1674组，预测成功的一共有1111组
# total的值为：{total}
# 1257张测试集中准确率为： 66.36798095703125%
# [[21  0  0 ...  0  0  0]
#  [ 0 25  0 ...  0  0  0]
#  [ 0  0 24 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  9  0  0]
#  [ 0  0  0 ...  0 20  0]
#  [ 0  0  0 ...  0  1 25]]

# %%
torch.cuda.current_device ()
# Out:
# 0

# %%
aa = iter(train_loader)
a, b = aa.next()
print(a[0].shape)
print(a)
# Out:
# torch.Size([1, 2, 1280])
# tensor([[[[ 0.0764,  0.5942,  0.7374,  ...,  0.1112, -0.4033, -0.4831],
#           [-1.1899, -1.3986, -0.8070,  ..., -1.2272, -1.1088, -1.0598]]],
#
#
#         [[[ 0.1487,  0.0312,  0.8155,  ...,  0.1659, -0.2684, -0.3538],
#           [-1.0150, -1.1150, -1.1933,  ..., -0.1415, -0.6916, -0.5935]]],
#
#
#         [[[ 0.4319,  0.8119,  1.2780,  ...,  0.4447,  0.3471, -0.2091],
#           [-1.2557, -1.2495, -1.2814,  ..., -0.8475, -0.8233, -0.7472]]],
#
#
#         [[[ 0.1980,  0.0663,  0.5115,  ...,  0.6133,  0.6756,  0.0450],
#           [-1.1964, -1.0797, -0.7153,  ..., -0.5603, -0.8270, -0.8443]]]],
#        dtype=torch.float64)

# %%
input = torch.randn(20, 16, 50, 100)
input.shape
# Out:
# torch.Size([20, 16, 50, 100])

# %%
m2=nn.Conv2d(16,33,(3,5),stride=(2,1),padding=(4,2))
inpu1=Variable(torch.randn(20,16,50,100))
print(inpu1.shape)
output=m2(inpu1)
print(output.shape)
# Out:
# torch.Size([20, 16, 50, 100])
# torch.Size([20, 33, 28, 100])

# %%
total
# Out:
# 2

# %%
torch.cuda.current_device ()
# Out:
# 0

# %%
x = range(0, len(average_loss_series))
plt.figure()
plt.plot(x, average_loss_series)
plt.savefig("Loss1.png", bbox_inches="tight")
plt.show()
