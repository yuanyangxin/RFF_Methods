# %%
import matplotlib.pyplot as plt
import torchvision as tv
from torchvision import transforms, utils


import torch.nn.functional as F
import torch 
import torch.nn as nn
from torch.autograd import Variable
import torchvision.models as models
# from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader
# from PIL import Image
# import numpy as np
import torch.optim as optim
# import os
import time

import loadData

# %%
device = torch.device("cuda:3")

# %%
# 日志记录模块2
import logging
logger = logging.getLogger(__name__)
logger.setLevel(level = logging.INFO)
handler = logging.FileHandler("./10dB-时域识别-1")
handler.setLevel(logging.INFO)
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

console = logging.StreamHandler()
console.setLevel(logging.INFO)

logger.addHandler(handler)
logger.addHandler(console)

# %%
startTime = time.time()

# %%
transforms = tv.transforms.Compose([
    transforms.ToTensor(),
])


numOfBatch = 9
pixel = 64
flag = 0
root = f'./{numOfBatch}/data'
batchSize = 4
train_data = loadData.MyDataset(txt=f'files_train10.txt', transform=None)
test_data = loadData.MyDataset(txt=f'files_test10.txt', transform=None)



train_loader = DataLoader(dataset=train_data, batch_size=batchSize, shuffle=True, num_workers=2)
test_loader = DataLoader(dataset=test_data, batch_size=batchSize, shuffle=True, num_workers=2)


print(train_loader)
print(test_loader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7f30cedb5f50>
# <torch.utils.data.dataloader.DataLoader object at 0x7f31b50b4b10>

# %%
print(len(train_data))
print(len(test_loader))
# Out:
# 43146
# 2714

# %%
# data = iter(train_loader)

# # print(type(data))
# # print(len(data))
# data_, label = data.next()
# print(train_loader.batch_size)
# print(data_.shape)
# # print(label)
# # print(data_, label)

# %%
x = torch.randn(4, 1, 1200, 2).float()
conv = nn.Conv2d(in_channels = 1, out_channels = 128, kernel_size = (10, 1))
x = conv(x)
x.shape
conv2 = nn.Conv2d(in_channels = 128, out_channels = 256, kernel_size = (3, 2))
x = conv2(x)
x.shape
# Out:
# torch.Size([4, 256, 1189, 1])

# %%
# 256*1189

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(in_channels = 1, out_channels = 8, kernel_size = (1, 10))
        self.conv2 = nn.Conv2d(in_channels = 8, out_channels = 16, kernel_size = (2, 3))
        
        self.dropout1 = nn.Dropout(0.5)
        self.dropout2 = nn.Dropout(0.5)
        
        self.fc1 = nn.Linear(2384, 1024)
        self.fc2 = nn.Linear(1024, 500)
        self.fc3 = nn.Linear(500, 54)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 1)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 1)
    
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.dropout1(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.dropout2(x)
        x = self.fc3(x)
        output = F.log_softmax(x, dim=1)
        return output

# %%
# TensorBoard
# from tensorboardX import SummaryWriter
# net = Net()
# # writer = SummaryWriter('writer928') #建立一个保存数据用的东西
# dummy_input = torch.rand(2,160,400)  # 假设输入20张1*28*28的图片
# with SummaryWriter(comment='Net1') as w:
#     w.add_graph(net, (dummy_input,))

# %%
net = Net()

net = net.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(params=net.parameters(), lr=0.0001, momentum=0.9)

epochs = 500
average_loss_series = []

# %%
for a, b in enumerate(train_loader):
    inputs, labels = b
    print(inputs.shape)
    break
# Out:
# torch.Size([4, 1, 2, 160])

# %%
# %matplotlib inline


if __name__ == '__main__':
    for epoch in range(epochs):
        running_loss = 0.0
        running_acc = 0.0

        for i, data in enumerate(train_loader):
#             print("i:", i )
#             print("data: ", data[0])
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()

#             inputs = inputs.permute(0, 2, 1)
            
            inputs = torch.tensor(inputs, dtype=torch.float32, device = device)

            outputs = net(inputs)
            _, predicted = torch.max(outputs.data, dim=1)
            total = labels.size(0)
#             print('原来的值:{0}, 预测的值:{1}'.format(labels, predicted))
            running_correct = (predicted == labels).sum()
            running_acc += running_correct
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            loss.backward()
            optimizer.step()

            # 每loopNum个batch打印一次训练状态
            loopNum = 200
            if i % loopNum == loopNum - 1:
                average_loss = running_loss / loopNum
                logger.info('[{0}, {1}] loss: {2}'.format(epoch + 1, i + 1, average_loss))
                logger.info('设备号为: {0}，预测的设备号为:{1}'.format(labels, predicted))
#                 logger.info(torch.cuda.current_device ())
                running_acc = running_acc.float()
                average_acc = running_acc / loopNum / total
                
                logger.info('[{0}, {1}] acc: {2}'.format(epoch + 1, i + 1, average_acc))
                average_loss_series.append(average_loss)
                running_loss = 0.0
                running_acc = 0.0
#         if epoch == 78:
#             torch.save(net, f'/workspace/DATASET/model_78.pkl')

    x = range(0, len(average_loss_series))
    plt.figure()
    plt.plot(x, average_loss_series)
#     plt.savefig("Loss.png")
    plt.savefig("Loss.png", bbox_inches="tight")
    plt.show()
    

    # %%
    # 在测试集上测试
    realLabel = []
    predictedLabel = []

    def correct_rate(net, testloader):
        correct = 0.0
        total = 0.0
        count = 0
        correctpredict = 0

        for data in testloader:
            images, labels = data
            images, labels = images.to(device),labels.to(device)
            realLabel.append([int(label) for label in labels])
    
            tests = torch.tensor(images, dtype=torch.float32,device=device)
            outputs = net(tests)

            _, predicted = torch.max(outputs.data, dim=1)
            logger.info('设备号为: {0}，模型训练后得到的设备号为:{1}'.format(labels, predicted))
#             deviceNumber = torch.cuda.current_device ()
#             logger.info(deviceNumber)
            
            labelsn = labels.cpu().numpy()
            pn = predicted.cpu().numpy()
            count += len(labelsn)
            
            for i in range(len(labelsn)):
                if labelsn[i] == pn[i]:
                    correctpredict += 1
                
            
            logger.info('目前一共测试了{0}组，预测成功的一共有{1}组'.format(count, correctpredict))
            predictedLabel.append([int(label) for label in predicted])
            
            total += labels.size(0)
            correct += (predicted == labels).sum()

            
        logger.info("total的值为：{total}")
#         return 100 * correct  # / total
        return 100 * correct/ total 


    correct = correct_rate(net, test_loader)
    logger.info(f'{len(test_loader) * 3}张测试集中准确率为： {correct}%')

    # %%
    import itertools
    from sklearn.metrics import confusion_matrix

    realLabel = list(itertools.chain.from_iterable(realLabel))
    predictedLabel = list(itertools.chain.from_iterable(predictedLabel))

    cm = confusion_matrix(realLabel, predictedLabel)
    logger.info(cm)

#     logger.info('the running time is:{1}'.format(time.time() - startTime))
    torch.save(net.state_dict(), f'./model_10dB_1.pkl')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# [1, 200] loss: 3.9918029832839967
# 设备号为: tensor([ 3, 48,  6, 41], device='cuda:0')，预测的设备号为:tensor([21, 14, 19, 24], device='cuda:0')
# [1, 200] acc: 0.023749999701976776
# [1, 400] loss: 3.990818433761597
# 设备号为: tensor([41, 50, 17, 24], device='cuda:0')，预测的设备号为:tensor([12, 16, 39, 24], device='cuda:0')
# [1, 400] acc: 0.013749999925494194
# [1, 600] loss: 3.9883856213092805
# 设备号为: tensor([ 4, 47, 29, 19], device='cuda:0')，预测的设备号为:tensor([40, 24, 24, 16], device='cuda:0')
# [1, 600] acc: 0.009999999776482582
# [1, 800] loss: 3.9906973993778228
# 设备号为: tensor([ 1, 34, 50, 41], device='cuda:0')，预测的设备号为:tensor([50, 47, 19, 20], device='cuda:0')
# [1, 800] acc: 0.017500000074505806
# [1, 1000] loss: 3.989941419363022
# 设备号为: tensor([32, 41,  6, 17], device='cuda:0')，预测的设备号为:tensor([11, 12, 43, 19], device='cuda:0')
# [1, 1000] acc: 0.021250000223517418
# [1, 1200] loss: 3.9894388937950134
# 设备号为: tensor([40, 24, 43, 23], device='cuda:0')，预测的设备号为:tensor([27, 11, 40, 32], device='cuda:0')
# [1, 1200] acc: 0.01874999888241291
# [1, 1400] loss: 3.987336292266846
# 设备号为: tensor([19, 19, 31, 42], device='cuda:0')，预测的设备号为:tensor([46, 19, 19,  6], device='cuda:0')
# [1, 1400] acc: 0.023749999701976776
# [1, 1600] loss: 3.9872942304611207
# 设备号为: tensor([ 3, 43, 42, 45], device='cuda:0')，预测的设备号为:tensor([17, 19, 21, 11], device='cuda:0')
# [1, 1600] acc: 0.016249999403953552
# [1, 1800] loss: 3.9903766286373137
# 设备号为: tensor([ 7, 46, 23, 17], device='cuda:0')，预测的设备号为:tensor([ 6, 19, 17, 46], device='cuda:0')
# [1, 1800] acc: 0.013749999925494194
# [1, 2000] loss: 3.988356909751892
# 设备号为: tensor([27,  5,  4, 21], device='cuda:0')，预测的设备号为:tensor([19, 12, 19, 15], device='cuda:0')
# [1, 2000] acc: 0.021250000223517418
# [1, 2200] loss: 3.9874668776988984
# 设备号为: tensor([38, 33,  4, 39], device='cuda:0')，预测的设备号为:tensor([40, 28, 19, 46], device='cuda:0')
# [1, 2200] acc: 0.016249999403953552
# [1, 2400] loss: 3.9872231781482697
# 设备号为: tensor([51, 46, 28, 14], device='cuda:0')，预测的设备号为:tensor([ 6,  6, 11, 16], device='cuda:0')
# [1, 2400] acc: 0.022499999031424522
# [1, 2600] loss: 3.9898281121253967
# 设备号为: tensor([22, 12, 20, 15], device='cuda:0')，预测的设备号为:tensor([20, 19, 20, 35], device='cuda:0')
# [1, 2600] acc: 0.023749999701976776
# [1, 2800] loss: 3.990079963207245
# 设备号为: tensor([18, 40, 29,  9], device='cuda:0')，预测的设备号为:tensor([32, 24, 24, 46], device='cuda:0')
# [1, 2800] acc: 0.017500000074505806
# [1, 3000] loss: 3.9866864037513734
# 设备号为: tensor([ 5, 40, 13, 34], device='cuda:0')，预测的设备号为:tensor([19, 35, 19, 19], device='cuda:0')
# [1, 3000] acc: 0.013749999925494194
# [1, 3200] loss: 3.9876295816898346
# 设备号为: tensor([43, 14, 18,  7], device='cuda:0')，预测的设备号为:tensor([24, 26, 12,  6], device='cuda:0')
# [1, 3200] acc: 0.014999999664723873
# [1, 3400] loss: 3.988328729867935
# 设备号为: tensor([ 3, 43,  6, 16], device='cuda:0')，预测的设备号为:tensor([40, 19, 16,  6], device='cuda:0')
# [1, 3400] acc: 0.019999999552965164
# [1, 3600] loss: 3.9883229875564576
# 设备号为: tensor([13, 31, 26, 19], device='cuda:0')，预测的设备号为:tensor([24, 33, 19,  1], device='cuda:0')
# [1, 3600] acc: 0.014999999664723873
# [1, 3800] loss: 3.985857321023941
# 设备号为: tensor([44, 41,  6, 40], device='cuda:0')，预测的设备号为:tensor([19, 32, 21, 17], device='cuda:0')
# [1, 3800] acc: 0.022499999031424522
# [1, 4000] loss: 3.986316279172897
# 设备号为: tensor([49, 13, 44, 24], device='cuda:0')，预测的设备号为:tensor([32, 46, 16, 19], device='cuda:0')
# [1, 4000] acc: 0.028749998658895493
# [1, 4200] loss: 3.9853245997428894
# 设备号为: tensor([53,  7,  3, 50], device='cuda:0')，预测的设备号为:tensor([14, 24, 46, 43], device='cuda:0')
# [1, 4200] acc: 0.02499999850988388
# [1, 4400] loss: 3.9857297384738923
# 设备号为: tensor([38, 46,  9,  4], device='cuda:0')，预测的设备号为:tensor([19, 19, 19, 17], device='cuda:0')
# [1, 4400] acc: 0.02499999850988388
# [1, 4600] loss: 3.9857588696479795
# 设备号为: tensor([15, 20, 41, 40], device='cuda:0')，预测的设备号为:tensor([12, 24, 24, 43], device='cuda:0')
# [1, 4600] acc: 0.017500000074505806
# [1, 4800] loss: 3.9839915978908538
# 设备号为: tensor([ 0, 25, 10, 35], device='cuda:0')，预测的设备号为:tensor([12, 17, 39, 19], device='cuda:0')
# [1, 4800] acc: 0.027499999850988388
# [1, 5000] loss: 3.9874245142936706
# 设备号为: tensor([49, 33, 27,  7], device='cuda:0')，预测的设备号为:tensor([19, 11, 14, 11], device='cuda:0')
# [1, 5000] acc: 0.017500000074505806
# [1, 5200] loss: 3.9846802937984465
# 设备号为: tensor([10, 13, 11, 40], device='cuda:0')，预测的设备号为:tensor([11, 19, 11, 19], device='cuda:0')
# [1, 5200] acc: 0.022499999031424522
# [1, 5400] loss: 3.9837882781028746
# 设备号为: tensor([23, 52, 32, 42], device='cuda:0')，预测的设备号为:tensor([11, 19, 19, 11], device='cuda:0')
# [1, 5400] acc: 0.02499999850988388
# [1, 5600] loss: 3.9847037291526792
# 设备号为: tensor([12, 45, 11, 44], device='cuda:0')，预测的设备号为:tensor([42, 46, 16, 11], device='cuda:0')
# [1, 5600] acc: 0.022499999031424522
# [1, 5800] loss: 3.9812495529651644
# 设备号为: tensor([19, 50, 43, 29], device='cuda:0')，预测的设备号为:tensor([17, 11, 40, 16], device='cuda:0')
# [1, 5800] acc: 0.021250000223517418
# [1, 6000] loss: 3.982837747335434
# 设备号为: tensor([53, 36, 21, 40], device='cuda:0')，预测的设备号为:tensor([49, 11, 19, 40], device='cuda:0')
# [1, 6000] acc: 0.01874999888241291
# [1, 6200] loss: 3.981250603199005
# 设备号为: tensor([37, 38,  5, 19], device='cuda:0')，预测的设备号为:tensor([16, 19, 27, 32], device='cuda:0')
# [1, 6200] acc: 0.027499999850988388
# [1, 6400] loss: 3.982885013818741
# 设备号为: tensor([ 5, 45,  3, 17], device='cuda:0')，预测的设备号为:tensor([19, 19, 16, 19], device='cuda:0')
# [1, 6400] acc: 0.02499999850988388
# [1, 6600] loss: 3.984094090461731
# 设备号为: tensor([38, 36, 22, 29], device='cuda:0')，预测的设备号为:tensor([17, 40, 46,  6], device='cuda:0')
# [1, 6600] acc: 0.027499999850988388
# [1, 6800] loss: 3.9807994782924654
# 设备号为: tensor([33, 28, 10, 34], device='cuda:0')，预测的设备号为:tensor([29, 16,  6, 15], device='cuda:0')
# [1, 6800] acc: 0.027499999850988388
# [1, 7000] loss: 3.980885976552963
# 设备号为: tensor([47, 21, 14,  4], device='cuda:0')，预测的设备号为:tensor([49, 24, 19, 12], device='cuda:0')
# [1, 7000] acc: 0.023749999701976776
# [1, 7200] loss: 3.981057575941086
# 设备号为: tensor([40, 13, 47, 30], device='cuda:0')，预测的设备号为:tensor([11, 19, 12, 44], device='cuda:0')
# [1, 7200] acc: 0.017500000074505806
# [1, 7400] loss: 3.982188763618469
# 设备号为: tensor([29, 31, 51, 38], device='cuda:0')，预测的设备号为:tensor([47, 43, 19, 33], device='cuda:0')
# [1, 7400] acc: 0.02499999850988388
# [1, 7600] loss: 3.980469698905945
# 设备号为: tensor([21, 53, 53, 14], device='cuda:0')，预测的设备号为:tensor([26, 32,  3, 17], device='cuda:0')
# [1, 7600] acc: 0.021250000223517418
# [1, 7800] loss: 3.9790432441234587
# 设备号为: tensor([52, 48, 46, 51], device='cuda:0')，预测的设备号为:tensor([24, 32, 17, 17], device='cuda:0')
# [1, 7800] acc: 0.02499999850988388
# [1, 8000] loss: 3.9774011790752413
# 设备号为: tensor([46,  3, 30, 41], device='cuda:0')，预测的设备号为:tensor([ 9, 32, 40, 12], device='cuda:0')
# [1, 8000] acc: 0.042500000447034836
# [1, 8200] loss: 3.9809673511981964
# 设备号为: tensor([47, 24, 51, 22], device='cuda:0')，预测的设备号为:tensor([32, 12, 17, 24], device='cuda:0')
# [1, 8200] acc: 0.01874999888241291
# [1, 8400] loss: 3.9775207304954527
# 设备号为: tensor([ 3, 17, 20, 18], device='cuda:0')，预测的设备号为:tensor([32, 32, 19, 28], device='cuda:0')
# [1, 8400] acc: 0.032499998807907104
# [1, 8600] loss: 3.979314157962799
# 设备号为: tensor([45, 21, 33,  6], device='cuda:0')，预测的设备号为:tensor([24, 26, 19, 24], device='cuda:0')
# [1, 8600] acc: 0.02499999850988388
# [1, 8800] loss: 3.9764533638954163
# 设备号为: tensor([18, 10, 48, 26], device='cuda:0')，预测的设备号为:tensor([ 3, 38, 17, 32], device='cuda:0')
# [1, 8800] acc: 0.038750000298023224
# [1, 9000] loss: 3.9771937775611876
# 设备号为: tensor([52, 19, 15,  5], device='cuda:0')，预测的设备号为:tensor([20, 19, 19, 26], device='cuda:0')
# [1, 9000] acc: 0.029999999329447746
# [1, 9200] loss: 3.973909811973572
# 设备号为: tensor([18,  4, 30, 10], device='cuda:0')，预测的设备号为:tensor([46, 26, 17, 32], device='cuda:0')
# [1, 9200] acc: 0.029999999329447746
# [1, 9400] loss: 3.9776900374889372
# 设备号为: tensor([53, 23, 22, 36], device='cuda:0')，预测的设备号为:tensor([43, 16, 15, 39], device='cuda:0')
# [1, 9400] acc: 0.021250000223517418
# [1, 9600] loss: 3.9726190066337583
# 设备号为: tensor([ 6,  5, 22, 41], device='cuda:0')，预测的设备号为:tensor([47, 11, 27, 32], device='cuda:0')
# [1, 9600] acc: 0.02499999850988388
# [1, 9800] loss: 3.974001070261002
# 设备号为: tensor([17, 38, 29,  8], device='cuda:0')，预测的设备号为:tensor([42,  3, 14,  6], device='cuda:0')
# [1, 9800] acc: 0.029999999329447746
# [1, 10000] loss: 3.9703264248371126
# 设备号为: tensor([38, 12,  3, 47], device='cuda:0')，预测的设备号为:tensor([27, 46, 17, 19], device='cuda:0')
# [1, 10000] acc: 0.028749998658895493
# [1, 10200] loss: 3.97053050160408
# 设备号为: tensor([20, 12, 32, 28], device='cuda:0')，预测的设备号为:tensor([15, 52, 17,  9], device='cuda:0')
# [1, 10200] acc: 0.032499998807907104
# [1, 10400] loss: 3.9696406495571135
# 设备号为: tensor([32, 33, 47,  9], device='cuda:0')，预测的设备号为:tensor([21, 17, 15, 26], device='cuda:0')
# [1, 10400] acc: 0.03125
# [1, 10600] loss: 3.9707721531391145
# 设备号为: tensor([ 7, 10, 34, 52], device='cuda:0')，预测的设备号为:tensor([31, 21, 42, 14], device='cuda:0')
# [1, 10600] acc: 0.036249998956918716
# [2, 200] loss: 3.9613913714885713
# 设备号为: tensor([29,  7, 34, 44], device='cuda:0')，预测的设备号为:tensor([15, 47, 42, 14], device='cuda:0')
# [2, 200] acc: 0.03500000014901161
# [2, 400] loss: 3.9661289942264557
# 设备号为: tensor([32, 29, 50, 38], device='cuda:0')，预测的设备号为:tensor([31, 34, 42, 31], device='cuda:0')
# [2, 400] acc: 0.03749999776482582
# [2, 600] loss: 3.961522396802902
# 设备号为: tensor([46,  4, 17, 27], device='cuda:0')，预测的设备号为:tensor([16, 47, 21, 47], device='cuda:0')
# [2, 600] acc: 0.03374999761581421
# [2, 800] loss: 3.9588566434383394
# 设备号为: tensor([15, 14,  4, 47], device='cuda:0')，预测的设备号为:tensor([16, 45, 21, 21], device='cuda:0')
# [2, 800] acc: 0.036249998956918716
# [2, 1000] loss: 3.9572856783866883
# 设备号为: tensor([24, 40, 21, 30], device='cuda:0')，预测的设备号为:tensor([12, 14, 47, 14], device='cuda:0')
# [2, 1000] acc: 0.03999999910593033
# [2, 1200] loss: 3.9568469536304476
# 设备号为: tensor([41,  5, 37, 10], device='cuda:0')，预测的设备号为:tensor([49, 10, 34, 14], device='cuda:0')
# [2, 1200] acc: 0.04374999925494194
# [2, 1400] loss: 3.952981902360916
# 设备号为: tensor([16, 22, 25, 39], device='cuda:0')，预测的设备号为:tensor([31, 42, 31, 26], device='cuda:0')
# [2, 1400] acc: 0.057499997317790985
# [2, 1600] loss: 3.9521328902244566
# 设备号为: tensor([42, 53, 48, 53], device='cuda:0')，预测的设备号为:tensor([31, 14, 52, 16], device='cuda:0')
# [2, 1600] acc: 0.04374999925494194
# [2, 1800] loss: 3.9506504106521607
# 设备号为: tensor([16, 33,  3,  2], device='cuda:0')，预测的设备号为:tensor([47,  3,  1, 31], device='cuda:0')
# [2, 1800] acc: 0.028749998658895493
# [2, 2000] loss: 3.9458024752140046
# 设备号为: tensor([23, 15, 48, 41], device='cuda:0')，预测的设备号为:tensor([14, 27, 10, 16], device='cuda:0')
# [2, 2000] acc: 0.05249999836087227
# [2, 2200] loss: 3.9446767473220827
# 设备号为: tensor([37, 16, 17, 30], device='cuda:0')，预测的设备号为:tensor([53, 45,  5,  1], device='cuda:0')
# [2, 2200] acc: 0.03999999910593033
# [2, 2400] loss: 3.9382173621654513
# 设备号为: tensor([27, 17, 47, 47], device='cuda:0')，预测的设备号为:tensor([43, 40, 16,  7], device='cuda:0')
# [2, 2400] acc: 0.054999999701976776
# [2, 2600] loss: 3.9308699667453766
# 设备号为: tensor([48, 18, 43, 23], device='cuda:0')，预测的设备号为:tensor([16, 14, 12, 44], device='cuda:0')
# [2, 2600] acc: 0.044999998062849045
# [2, 2800] loss: 3.933867129087448
# 设备号为: tensor([11, 13, 53, 53], device='cuda:0')，预测的设备号为:tensor([ 7, 15, 53, 18], device='cuda:0')
# [2, 2800] acc: 0.04999999701976776
# [2, 3000] loss: 3.9219214367866515
# 设备号为: tensor([13, 13, 13, 32], device='cuda:0')，预测的设备号为:tensor([ 4,  2, 46,  7], device='cuda:0')
# [2, 3000] acc: 0.04625000059604645
# [2, 3200] loss: 3.913892467021942
# 设备号为: tensor([45, 21, 43, 34], device='cuda:0')，预测的设备号为:tensor([52, 43, 24,  6], device='cuda:0')
# [2, 3200] acc: 0.051249999552965164
# [2, 3400] loss: 3.9101232182979584
# 设备号为: tensor([42,  7, 25,  3], device='cuda:0')，预测的设备号为:tensor([15,  5, 26, 39], device='cuda:0')
# [2, 3400] acc: 0.05249999836087227
# [2, 3600] loss: 3.895552693605423
# 设备号为: tensor([14, 17, 46, 33], device='cuda:0')，预测的设备号为:tensor([37, 37, 45, 26], device='cuda:0')
# [2, 3600] acc: 0.05874999985098839
# [2, 3800] loss: 3.877444967031479
# 设备号为: tensor([ 2, 32, 18, 13], device='cuda:0')，预测的设备号为:tensor([ 1,  5,  4, 53], device='cuda:0')
# [2, 3800] acc: 0.05374999716877937
# [2, 4000] loss: 3.8726409661769865
# 设备号为: tensor([39, 48,  9, 38], device='cuda:0')，预测的设备号为:tensor([26,  1, 10,  1], device='cuda:0')
# [2, 4000] acc: 0.057499997317790985
# [2, 4200] loss: 3.8527562379837037
# 设备号为: tensor([40, 49, 17,  5], device='cuda:0')，预测的设备号为:tensor([36,  4, 25, 26], device='cuda:0')
# [2, 4200] acc: 0.06875000149011612
# [2, 4400] loss: 3.844053260087967
# 设备号为: tensor([19, 37, 14, 44], device='cuda:0')，预测的设备号为:tensor([15, 44, 44, 52], device='cuda:0')
# [2, 4400] acc: 0.05249999836087227
# [2, 4600] loss: 3.801963975429535
# 设备号为: tensor([48, 49, 42, 17], device='cuda:0')，预测的设备号为:tensor([31, 44, 16, 42], device='cuda:0')
# [2, 4600] acc: 0.07374999672174454
# [2, 4800] loss: 3.794930648803711
# 设备号为: tensor([10, 14, 27, 33], device='cuda:0')，预测的设备号为:tensor([ 9, 16, 38, 42], device='cuda:0')
# [2, 4800] acc: 0.0625
# [2, 5000] loss: 3.7609669160842896
# 设备号为: tensor([27,  9, 43, 26], device='cuda:0')，预测的设备号为:tensor([ 1,  3, 37,  1], device='cuda:0')
# [2, 5000] acc: 0.054999999701976776
# [2, 5200] loss: 3.738245632648468
# 设备号为: tensor([24, 15, 10, 13], device='cuda:0')，预测的设备号为:tensor([52, 14,  6, 52], device='cuda:0')
# [2, 5200] acc: 0.05374999716877937
# [2, 5400] loss: 3.6932678055763244
# 设备号为: tensor([23, 20, 12, 10], device='cuda:0')，预测的设备号为:tensor([45, 44, 45,  2], device='cuda:0')
# [2, 5400] acc: 0.05999999865889549
# [2, 5600] loss: 3.670055376291275
# 设备号为: tensor([ 4, 31, 53, 13], device='cuda:0')，预测的设备号为:tensor([15, 48, 46, 42], device='cuda:0')
# [2, 5600] acc: 0.04625000059604645
# [2, 5800] loss: 3.619590827226639
# 设备号为: tensor([12, 15, 30, 37], device='cuda:0')，预测的设备号为:tensor([45, 44, 15, 44], device='cuda:0')
# [2, 5800] acc: 0.057499997317790985
# [2, 6000] loss: 3.566675490140915
# 设备号为: tensor([39,  3, 45, 33], device='cuda:0')，预测的设备号为:tensor([26, 21, 45, 10], device='cuda:0')
# [2, 6000] acc: 0.05999999865889549
# [2, 6200] loss: 3.54401181101799
# 设备号为: tensor([33, 27,  7,  5], device='cuda:0')，预测的设备号为:tensor([ 1, 38, 29,  1], device='cuda:0')
# [2, 6200] acc: 0.054999999701976776
# [2, 6400] loss: 3.496907048225403
# 设备号为: tensor([44, 29, 25, 21], device='cuda:0')，预测的设备号为:tensor([44,  6,  0, 16], device='cuda:0')
# [2, 6400] acc: 0.07750000059604645
# [2, 6600] loss: 3.4692165541648863
# 设备号为: tensor([38, 15,  3,  4], device='cuda:0')，预测的设备号为:tensor([ 6, 45,  0, 49], device='cuda:0')
# [2, 6600] acc: 0.05999999865889549
# [2, 6800] loss: 3.4502809655666353
# 设备号为: tensor([45, 24, 43, 52], device='cuda:0')，预测的设备号为:tensor([46, 44, 48, 45], device='cuda:0')
# [2, 6800] acc: 0.06499999761581421
# [2, 7000] loss: 3.4136876702308654
# 设备号为: tensor([18,  3, 17, 22], device='cuda:0')，预测的设备号为:tensor([40, 39, 43, 41], device='cuda:0')
# [2, 7000] acc: 0.06749999523162842
# [2, 7200] loss: 3.3987957561016082
# 设备号为: tensor([35, 36, 23, 20], device='cuda:0')，预测的设备号为:tensor([48,  6, 52, 24], device='cuda:0')
# [2, 7200] acc: 0.07374999672174454
# [2, 7400] loss: 3.3439001274108886
# 设备号为: tensor([40, 10, 11, 39], device='cuda:0')，预测的设备号为:tensor([30, 25, 25,  0], device='cuda:0')
# [2, 7400] acc: 0.07249999791383743
# [2, 7600] loss: 3.3548292553424837
# 设备号为: tensor([ 1,  3, 44,  1], device='cuda:0')，预测的设备号为:tensor([ 6, 26, 45, 33], device='cuda:0')
# [2, 7600] acc: 0.08124999701976776
# [2, 7800] loss: 3.353578027486801
# 设备号为: tensor([19, 22, 31, 26], device='cuda:0')，预测的设备号为:tensor([13, 13,  8,  9], device='cuda:0')
# [2, 7800] acc: 0.07499999552965164
# [2, 8000] loss: 3.277427589893341
# 设备号为: tensor([31, 18,  9,  6], device='cuda:0')，预测的设备号为:tensor([39, 18, 10,  6], device='cuda:0')
# [2, 8000] acc: 0.0912499949336052
# [2, 8200] loss: 3.2858281433582306
# 设备号为: tensor([ 1,  2, 17, 22], device='cuda:0')，预测的设备号为:tensor([38, 43,  2, 23], device='cuda:0')
# [2, 8200] acc: 0.08124999701976776
# [2, 8400] loss: 3.28424262046814
# 设备号为: tensor([29, 46, 15, 19], device='cuda:0')，预测的设备号为:tensor([29, 44, 44, 46], device='cuda:0')
# [2, 8400] acc: 0.08624999970197678
# [2, 8600] loss: 3.262501266002655
# 设备号为: tensor([36, 50, 15, 21], device='cuda:0')，预测的设备号为:tensor([26,  4, 15, 51], device='cuda:0')
# [2, 8600] acc: 0.08374999463558197
# [2, 8800] loss: 3.261929626464844
# 设备号为: tensor([48, 10, 30, 50], device='cuda:0')，预测的设备号为:tensor([27, 36, 13, 11], device='cuda:0')
# [2, 8800] acc: 0.07124999910593033
# [2, 9000] loss: 3.2424127471446993
# 设备号为: tensor([42, 52, 20, 37], device='cuda:0')，预测的设备号为:tensor([16, 45, 14, 45], device='cuda:0')
# [2, 9000] acc: 0.11499999463558197
# [2, 9200] loss: 3.1777489840984345
# 设备号为: tensor([11, 44, 46, 45], device='cuda:0')，预测的设备号为:tensor([36, 52, 24, 52], device='cuda:0')
# [2, 9200] acc: 0.09375
# [2, 9400] loss: 3.1929482448101045
# 设备号为: tensor([21, 46, 37, 25], device='cuda:0')，预测的设备号为:tensor([19, 46, 37, 34], device='cuda:0')
# [2, 9400] acc: 0.08124999701976776
# [2, 9600] loss: 3.1897676289081573
# 设备号为: tensor([48, 35, 20, 37], device='cuda:0')，预测的设备号为:tensor([26,  2, 42, 44], device='cuda:0')
# [2, 9600] acc: 0.07999999821186066
# [2, 9800] loss: 3.214369786977768
# 设备号为: tensor([25, 46,  5, 50], device='cuda:0')，预测的设备号为:tensor([ 5, 45,  8, 30], device='cuda:0')
# [2, 9800] acc: 0.07999999821186066
# [2, 10000] loss: 3.165433076620102
# 设备号为: tensor([51, 25, 29,  3], device='cuda:0')，预测的设备号为:tensor([12, 25, 31,  2], device='cuda:0')
# [2, 10000] acc: 0.0925000011920929

# %%
torch.cuda.current_device ()

# %%
aa = iter(train_loader)
a, b = aa.next()
print(a[0].shape)
print(a)

# %%
input = torch.randn(20, 16, 50, 100)
input.shape

# %%
m2=nn.Conv2d(16,33,(3,5),stride=(2,1),padding=(4,2))
inpu1=Variable(torch.randn(20,16,50,100))
print(inpu1.shape)
output=m2(inpu1)
print(output.shape)

# %%
total

# %%
torch.cuda.current_device ()

# %%
x = range(0, len(average_loss_series))
plt.figure()
plt.plot(x, average_loss_series)
plt.savefig("Loss15dB.png", bbox_inches="tight")
plt.show()
