# %% [markdown]
# step1: 对输入的I/O数据进行处理，I/O数据看作是nlp里面的文本数据

# %%
import os
import scipy.io as sio
import numpy as np
from shutil import copyfile

# %%
path = "/workspace/瑞利多径/一个0的情况/高延迟室外"

# %%
files = os.listdir(path)
data = []
labels = []

# %%
def del_file(filepath):
    """
    删除某一目录下的所有文件或文件夹
    :param filepath: 路径
    :return:
    """
    import shutil
    del_list = os.listdir(filepath)
    for f in del_list:
        file_path = os.path.join(filepath, f)
        if os.path.isfile(file_path):
            os.remove(file_path)
        elif os.path.isdir(file_path):
            shutil.rmtree(file_path)

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
saveFolder = "/workspace/瑞利多径/一个0的情况/高延迟室外-处理后的数据/"
del_file(saveFolder)
for file in files:
#     print(file)
    device = file.split('_')[2]
    y = int(device) - 1
    round = int(file.split('_')[3][0:-4])
    data = sio.loadmat(os.path.join(path, file))
    X = data["y"]
    a = X[0: len(X)]
    
    real = a.real 
    imag = a.imag
    
    real = real.transpose()
    imag = imag.transpose()
    real = real[0]
    imag = imag[0]
#     print(real)
#     print(len(real))
    
#     print(imag)
#     print(len(imag))

    result = real[0: len(X)]
    im = imag[0: len(X)]
    result = np.vstack((result, im))

    name = "30dBProcess_" + str("A_" + device) + "_" + str(round) + ".npy"
    path1 = saveFolder + name
    np.save(path1, result)

# %%
# %matplotlib inline

# import matplotlib.pyplot as plt

# for file in files:
# #     print(file)
#     device = file.split('_')[2]
#     y = int(device) - 1
#     round = int(file.split('_')[3][0:-4])
#     data = sio.loadmat(os.path.join(path, file))
#     X = data["Brush_Data_Temp"]
#     plt.figure()
#     plt.title(int(device))
#     for i in range(3, 7):
#         newX = X[160*i - 160 :160*i]   
#         x = [i for i in range(1, 161)]
#         plt.plot(x, newX)
#     plt.show()

# %%
import numpy as np
data = np.load("/workspace/瑞利多径/一个0的情况/高延迟室外-处理后的数据/30dBProcess_A_26_9.npy")
print(data.shape)
# Out:
# (2, 160)

# %%
# %matplotlib inline

# import matplotlib.pyplot as plt

# for file in files:
# #     print(file)
#     device = file.split('_')[2]
#     y = int(device) - 1
#     round = int(file.split('_')[3][0:-4])
#     data = sio.loadmat(os.path.join(path, file))
#     X = data["Brush_Data_Temp"][0:1281]
#     x = [i for i in range(0, 1281)]
#     plt.figure()
#     plt.plot(x, X)
#     plt.show()
#     break

# %%
print(data)
# Out:
# [[-1.18061984e+00 -9.92218453e-01 -5.44430481e-01 -1.49613390e-01
#    3.25105698e-01  7.72635849e-01  1.13762301e+00  1.32039449e+00
#    1.33883181e+00  1.22111032e+00  9.21818003e-01  5.74729955e-01
#    2.22950728e-01 -3.34651187e-02 -2.68115149e-01 -4.63353255e-01
#   -4.16479467e-01 -1.42070559e-01  1.44163674e-01  2.95701048e-01
#    3.81141813e-01  5.95561143e-01  6.55168293e-01  5.52084810e-01
#    2.41668389e-01  1.11650887e-02 -2.91733514e-01 -7.20386772e-01
#   -1.07341067e+00 -1.34656914e+00 -1.41879450e+00 -1.39185459e+00
