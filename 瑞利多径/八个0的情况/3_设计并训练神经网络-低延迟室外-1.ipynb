# %%
import matplotlib.pyplot as plt
import torchvision as tv
from torchvision import transforms, utils


import torch.nn.functional as F
import torch 
import torch.nn as nn
from torch.autograd import Variable
import torchvision.models as models
# from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader
# from PIL import Image
# import numpy as np
import torch.optim as optim
# import os
import time

import loadData

# %%
device = torch.device("cuda:1")

# %%
# 日志记录模块2
import logging
logger = logging.getLogger(__name__)
logger.setLevel(level = logging.INFO)
handler = logging.FileHandler("./低延迟室外-1500epoches-1")
handler.setLevel(logging.INFO)
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

console = logging.StreamHandler()
console.setLevel(logging.INFO)

logger.addHandler(handler)
logger.addHandler(console)

# %%
startTime = time.time()

# %%
transforms = tv.transforms.Compose([
    transforms.ToTensor(),
])


numOfBatch = 9
pixel = 64
flag = 0
root = f'./{numOfBatch}/data'
batchSize = 4
train_data = loadData.MyDataset(txt=f'files_train低延迟室外.txt', transform=None)
test_data = loadData.MyDataset(txt=f'files_test低延迟室外.txt', transform=None)



train_loader = DataLoader(dataset=train_data, batch_size=batchSize, shuffle=True, num_workers=2)
test_loader = DataLoader(dataset=test_data, batch_size=batchSize, shuffle=True, num_workers=2)


print(train_loader)
print(test_loader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7f9a7835a550>
# <torch.utils.data.dataloader.DataLoader object at 0x7f9993732f10>

# %%
print(len(train_data))
print(len(test_loader))
# Out:
# 6480
# 405

# %%
# data = iter(train_loader)

# # print(type(data))
# # print(len(data))
# data_, label = data.next()
# print(train_loader.batch_size)
# print(data_.shape)
# # print(label)
# # print(data_, label)

# %%
x = torch.randn(4, 1, 1200, 2).float()
conv = nn.Conv2d(in_channels = 1, out_channels = 128, kernel_size = (10, 1))
x = conv(x)
x.shape
conv2 = nn.Conv2d(in_channels = 128, out_channels = 256, kernel_size = (3, 2))
x = conv2(x)
x.shape
# Out:
# torch.Size([4, 256, 1189, 1])

# %%
# 256*1189

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(in_channels = 1, out_channels = 8, kernel_size = (1, 10))
        self.conv2 = nn.Conv2d(in_channels = 8, out_channels = 16, kernel_size = (2, 3))
        
        self.dropout1 = nn.Dropout(0.5)
        self.dropout2 = nn.Dropout(0.5)
        
        self.fc1 = nn.Linear(20304, 1024)
        self.fc2 = nn.Linear(1024, 500)
        self.fc3 = nn.Linear(500, 54)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 1)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 1)
    
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.dropout1(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.dropout2(x)
        x = self.fc3(x)
        output = F.log_softmax(x, dim=1)
        return output

# %%
# TensorBoard
# from tensorboardX import SummaryWriter
# net = Net()
# # writer = SummaryWriter('writer928') #建立一个保存数据用的东西
# dummy_input = torch.rand(2,160,400)  # 假设输入20张1*28*28的图片
# with SummaryWriter(comment='Net1') as w:
#     w.add_graph(net, (dummy_input,))

# %%
net = Net()

net = net.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(params=net.parameters(), lr=0.0001, momentum=0.9)

epochs = 1500
average_loss_series = []

# %%
for a, b in enumerate(train_loader):
    inputs, labels = b
    print(inputs.shape)
    break
# Out:
# torch.Size([4, 1, 2, 1280])

# %%
# %matplotlib inline


if __name__ == '__main__':
    for epoch in range(epochs):
        running_loss = 0.0
        running_acc = 0.0

        for i, data in enumerate(train_loader):
#             print("i:", i )
#             print("data: ", data[0])
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()

#             inputs = inputs.permute(0, 2, 1)
            
            inputs = torch.tensor(inputs, dtype=torch.float32, device = device)

            outputs = net(inputs)
            _, predicted = torch.max(outputs.data, dim=1)
            total = labels.size(0)
#             print('原来的值:{0}, 预测的值:{1}'.format(labels, predicted))
            running_correct = (predicted == labels).sum()
            running_acc += running_correct
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            loss.backward()
            optimizer.step()

            # 每loopNum个batch打印一次训练状态
            loopNum = 1000
            if i % loopNum == loopNum - 1:
                average_loss = running_loss / loopNum
                logger.info('[{0}, {1}] loss: {2}'.format(epoch + 1, i + 1, average_loss))
                logger.info('设备号为: {0}，预测的设备号为:{1}'.format(labels, predicted))
#                 logger.info(torch.cuda.current_device ())
                running_acc = running_acc.float()
                average_acc = running_acc / loopNum / total
                
                logger.info('[{0}, {1}] acc: {2}'.format(epoch + 1, i + 1, average_acc))
                average_loss_series.append(average_loss)
                running_loss = 0.0
                running_acc = 0.0

    x = range(0, len(average_loss_series))
    plt.figure()
    plt.plot(x, average_loss_series)
#     plt.savefig("Loss.png")
    plt.savefig("Loss.png", bbox_inches="tight")
    plt.show()
    

    # %%
    # 在测试集上测试
    realLabel = []
    predictedLabel = []

    def correct_rate(net, testloader):
        correct = 0.0
        total = 0.0
        count = 0
        correctpredict = 0

        for data in testloader:
            images, labels = data
            images, labels = images.to(device),labels.to(device)
            realLabel.append([int(label) for label in labels])
    
            tests = torch.tensor(images, dtype=torch.float32,device=device)
            outputs = net(tests)

            _, predicted = torch.max(outputs.data, dim=1)
            logger.info('设备号为: {0}，模型训练后得到的设备号为:{1}'.format(labels, predicted))
#             deviceNumber = torch.cuda.current_device ()
#             logger.info(deviceNumber)
            
            labelsn = labels.cpu().numpy()
            pn = predicted.cpu().numpy()
            count += len(labelsn)
            
            for i in range(len(labelsn)):
                if labelsn[i] == pn[i]:
                    correctpredict += 1
                
            
            logger.info('目前一共测试了{0}组，预测成功的一共有{1}组'.format(count, correctpredict))
            predictedLabel.append([int(label) for label in predicted])
            
            total += labels.size(0)
            correct += (predicted == labels).sum()

            
        logger.info("total的值为：{total}")
#         return 100 * correct  # / total
        return 100 * correct/ total 


    correct = correct_rate(net, test_loader)
    logger.info(f'{len(test_loader) * 3}张测试集中准确率为： {correct}%')

    # %%
    import itertools
    from sklearn.metrics import confusion_matrix

    realLabel = list(itertools.chain.from_iterable(realLabel))
    predictedLabel = list(itertools.chain.from_iterable(predictedLabel))

    cm = confusion_matrix(realLabel, predictedLabel)
    logger.info(cm)

#     logger.info('the running time is:{1}'.format(time.time() - startTime))
    torch.save(net.state_dict(), f'./model_低延迟室外_1.pkl')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# [1, 1000] loss: 3.989946627140045
# 设备号为: tensor([16, 12, 19, 29], device='cuda:3')，预测的设备号为:tensor([12, 37, 44, 18], device='cuda:3')
# [1, 1000] acc: 0.018250001594424248
# [2, 1000] loss: 3.985485981941223
# 设备号为: tensor([23, 14, 29, 17], device='cuda:3')，预测的设备号为:tensor([12, 18, 34, 12], device='cuda:3')
# [2, 1000] acc: 0.024250000715255737
# [3, 1000] loss: 3.9818149104118348
# 设备号为: tensor([30, 37, 22,  3], device='cuda:3')，预测的设备号为:tensor([12, 43, 18, 25], device='cuda:3')
# [3, 1000] acc: 0.02225000038743019
# [4, 1000] loss: 3.972633405685425
# 设备号为: tensor([47, 31, 52, 24], device='cuda:3')，预测的设备号为:tensor([18, 33, 52, 18], device='cuda:3')
# [4, 1000] acc: 0.03750000149011612
# [5, 1000] loss: 3.956678872346878
# 设备号为: tensor([21, 32, 14, 16], device='cuda:3')，预测的设备号为:tensor([53, 43, 44, 42], device='cuda:3')
# [5, 1000] acc: 0.04500000178813934
# [6, 1000] loss: 3.9070453867912294
# 设备号为: tensor([24, 18, 50, 28], device='cuda:3')，预测的设备号为:tensor([45, 52, 53, 51], device='cuda:3')
# [6, 1000] acc: 0.058250002562999725
# [7, 1000] loss: 3.68274827337265
# 设备号为: tensor([ 0, 43, 31,  4], device='cuda:3')，预测的设备号为:tensor([ 6, 15, 38, 13], device='cuda:3')
# [7, 1000] acc: 0.05900000408291817
# [8, 1000] loss: 3.3594678349494935
# 设备号为: tensor([48, 28, 39, 19], device='cuda:3')，预测的设备号为:tensor([38, 29, 31, 43], device='cuda:3')
# [8, 1000] acc: 0.07525000721216202
# [9, 1000] loss: 3.168295941352844
# 设备号为: tensor([18, 49, 35, 28], device='cuda:3')，预测的设备号为:tensor([37, 49, 17,  4], device='cuda:3')
# [9, 1000] acc: 0.10775000602006912
# [10, 1000] loss: 3.017519209265709
# 设备号为: tensor([21, 50, 26, 38], device='cuda:3')，预测的设备号为:tensor([41, 49, 32, 32], device='cuda:3')
# [10, 1000] acc: 0.12125000357627869
# [11, 1000] loss: 2.882489894747734
# 设备号为: tensor([22, 31, 10, 18], device='cuda:3')，预测的设备号为:tensor([14, 10, 10, 42], device='cuda:3')
# [11, 1000] acc: 0.1407500058412552
# [12, 1000] loss: 2.7904409614801406
# 设备号为: tensor([24, 17,  4,  6], device='cuda:3')，预测的设备号为:tensor([12, 31, 35,  8], device='cuda:3')
# [12, 1000] acc: 0.16225001215934753
# [13, 1000] loss: 2.6961379911899566
# 设备号为: tensor([34, 27, 47, 49], device='cuda:3')，预测的设备号为:tensor([31, 29, 43, 40], device='cuda:3')
# [13, 1000] acc: 0.17650000751018524
# [14, 1000] loss: 2.604895452260971
# 设备号为: tensor([10,  2, 27,  8], device='cuda:3')，预测的设备号为:tensor([7, 2, 3, 6], device='cuda:3')
# [14, 1000] acc: 0.18575000762939453
# [15, 1000] loss: 2.5112360662221906
# 设备号为: tensor([15, 44, 46,  4], device='cuda:3')，预测的设备号为:tensor([46, 46, 52,  4], device='cuda:3')
# [15, 1000] acc: 0.19975000619888306
# [16, 1000] loss: 2.37430318570137
# 设备号为: tensor([28, 19, 30, 11], device='cuda:3')，预测的设备号为:tensor([28, 50, 30, 38], device='cuda:3')
# [16, 1000] acc: 0.2317500114440918
# [17, 1000] loss: 2.231121875613928
# 设备号为: tensor([51, 26, 30, 44], device='cuda:3')，预测的设备号为:tensor([16,  1, 30, 52], device='cuda:3')
# [17, 1000] acc: 0.27775001525878906
# [18, 1000] loss: 2.0870670822262762
# 设备号为: tensor([19, 20, 39, 41], device='cuda:3')，预测的设备号为:tensor([21, 16, 11, 17], device='cuda:3')
# [18, 1000] acc: 0.3125
# [19, 1000] loss: 1.9875926516056062
# 设备号为: tensor([39, 12, 24, 17], device='cuda:3')，预测的设备号为:tensor([29, 23, 13, 17], device='cuda:3')
# [19, 1000] acc: 0.3297500014305115
# [20, 1000] loss: 1.8666575398445129
# 设备号为: tensor([31, 16, 27,  1], device='cuda:3')，预测的设备号为:tensor([48, 14, 39,  1], device='cuda:3')
# [20, 1000] acc: 0.36500000953674316
# [21, 1000] loss: 1.7547785832881928
# 设备号为: tensor([52,  3, 53, 44], device='cuda:3')，预测的设备号为:tensor([53, 33, 53, 46], device='cuda:3')
# [21, 1000] acc: 0.3942500054836273
# [22, 1000] loss: 1.630230320647359
# 设备号为: tensor([43, 28, 28,  4], device='cuda:3')，预测的设备号为:tensor([42,  7,  7,  4], device='cuda:3')
# [22, 1000] acc: 0.43425002694129944
# [23, 1000] loss: 1.531331789046526
# 设备号为: tensor([34,  4, 20, 23], device='cuda:3')，预测的设备号为:tensor([34,  4, 18, 12], device='cuda:3')
# [23, 1000] acc: 0.47450003027915955
# [24, 1000] loss: 1.4290442433655262
# 设备号为: tensor([40, 35, 11, 19], device='cuda:3')，预测的设备号为:tensor([21, 35, 34, 47], device='cuda:3')
# [24, 1000] acc: 0.5047500133514404
# [25, 1000] loss: 1.3584011443890631
# 设备号为: tensor([51,  7, 17, 48], device='cuda:3')，预测的设备号为:tensor([42,  7, 17, 17], device='cuda:3')
# [25, 1000] acc: 0.5240000486373901
# [26, 1000] loss: 1.279572674587369
# 设备号为: tensor([23, 52, 10, 49], device='cuda:3')，预测的设备号为:tensor([14, 53, 10, 50], device='cuda:3')
# [26, 1000] acc: 0.5412500500679016
# [27, 1000] loss: 1.2681520346477628
# 设备号为: tensor([45, 20, 48,  0], device='cuda:3')，预测的设备号为:tensor([45, 18, 48,  3], device='cuda:3')
# [27, 1000] acc: 0.5507500171661377
# [28, 1000] loss: 1.2037753541618585
# 设备号为: tensor([35, 42, 38, 34], device='cuda:3')，预测的设备号为:tensor([35, 43, 38, 11], device='cuda:3')
# [28, 1000] acc: 0.562000036239624
# [29, 1000] loss: 1.1759579638764261
# 设备号为: tensor([ 4, 29, 36, 43], device='cuda:3')，预测的设备号为:tensor([ 4, 29, 36, 42], device='cuda:3')
# [29, 1000] acc: 0.5782500505447388
# [30, 1000] loss: 1.0984366412730888
# 设备号为: tensor([17,  4, 32,  7], device='cuda:3')，预测的设备号为:tensor([17,  4, 26,  7], device='cuda:3')
# [30, 1000] acc: 0.6042500138282776
# [31, 1000] loss: 1.0707633158043026
# 设备号为: tensor([48, 22, 49, 37], device='cuda:3')，预测的设备号为:tensor([17, 16, 49, 37], device='cuda:3')
# [31, 1000] acc: 0.6167500019073486
# [32, 1000] loss: 1.01442662698403
# 设备号为: tensor([ 3, 43, 24, 22], device='cuda:3')，预测的设备号为:tensor([25, 43, 24, 14], device='cuda:3')
# [32, 1000] acc: 0.6362500190734863
# [33, 1000] loss: 1.0029413837864996
# 设备号为: tensor([19, 44,  4,  8], device='cuda:3')，预测的设备号为:tensor([47, 15,  4,  5], device='cuda:3')
# [33, 1000] acc: 0.6382500529289246
# [34, 1000] loss: 0.9822184793474152
# 设备号为: tensor([ 8, 52, 41, 30], device='cuda:3')，预测的设备号为:tensor([38, 52, 42, 30], device='cuda:3')
# [34, 1000] acc: 0.6420000195503235
# [35, 1000] loss: 0.904690602241084
# 设备号为: tensor([16, 45, 49, 51], device='cuda:3')，预测的设备号为:tensor([14, 45, 49, 42], device='cuda:3')
# [35, 1000] acc: 0.6727500557899475
# [36, 1000] loss: 0.8934556712824852
# 设备号为: tensor([31, 25, 16, 51], device='cuda:3')，预测的设备号为:tensor([48, 10, 20, 43], device='cuda:3')
# [36, 1000] acc: 0.6765000224113464
# [37, 1000] loss: 0.8454566590506584
# 设备号为: tensor([21, 32, 45, 49], device='cuda:3')，预测的设备号为:tensor([21, 32, 45, 50], device='cuda:3')
# [37, 1000] acc: 0.6907500624656677
# [38, 1000] loss: 0.8146959501313977
# 设备号为: tensor([16, 52,  3, 52], device='cuda:3')，预测的设备号为:tensor([14, 52,  7, 52], device='cuda:3')
# [38, 1000] acc: 0.7037500143051147
# [39, 1000] loss: 0.7824833539444953
# 设备号为: tensor([25,  3, 51, 21], device='cuda:3')，预测的设备号为:tensor([25,  3, 40, 21], device='cuda:3')
# [39, 1000] acc: 0.7160000205039978
# [40, 1000] loss: 0.7748440401032567
# 设备号为: tensor([45, 42, 19, 19], device='cuda:3')，预测的设备号为:tensor([45, 42, 22, 22], device='cuda:3')
# [40, 1000] acc: 0.7160000205039978
# [41, 1000] loss: 0.7496830383683555
# 设备号为: tensor([ 9,  0, 37, 29], device='cuda:3')，预测的设备号为:tensor([ 9,  0, 37, 29], device='cuda:3')
# [41, 1000] acc: 0.7275000214576721
# [42, 1000] loss: 0.7282884487360716
# 设备号为: tensor([ 1, 48, 10, 20], device='cuda:3')，预测的设备号为:tensor([ 9, 17, 10, 22], device='cuda:3')
# [42, 1000] acc: 0.73375004529953
# [43, 1000] loss: 0.6601333655165509
# 设备号为: tensor([21,  2, 45, 47], device='cuda:3')，预测的设备号为:tensor([21,  2, 45, 47], device='cuda:3')
# [43, 1000] acc: 0.7580000162124634
# [44, 1000] loss: 0.6544581702216529
# 设备号为: tensor([34, 15, 36, 36], device='cuda:3')，预测的设备号为:tensor([34, 15, 36, 36], device='cuda:3')
# [44, 1000] acc: 0.7620000243186951
# [45, 1000] loss: 0.617450643105898
# 设备号为: tensor([50, 51, 42, 48], device='cuda:3')，预测的设备号为:tensor([50, 40, 42, 48], device='cuda:3')
# [45, 1000] acc: 0.7812500596046448
# [46, 1000] loss: 0.623355631982442
# 设备号为: tensor([21, 16, 31, 42], device='cuda:3')，预测的设备号为:tensor([21, 16, 31, 42], device='cuda:3')
# [46, 1000] acc: 0.7667500376701355
# [47, 1000] loss: 0.6115006948700175
# 设备号为: tensor([15,  5,  8,  6], device='cuda:3')，预测的设备号为:tensor([15,  5,  8,  6], device='cuda:3')
# [47, 1000] acc: 0.7815000414848328
# [48, 1000] loss: 0.573681340701878
# 设备号为: tensor([45, 37, 35, 14], device='cuda:3')，预测的设备号为:tensor([45, 37, 35, 14], device='cuda:3')
# [48, 1000] acc: 0.7970000505447388
# [49, 1000] loss: 0.5527561299768277
# 设备号为: tensor([41, 31, 50, 47], device='cuda:3')，预测的设备号为:tensor([41, 31, 40, 47], device='cuda:3')
# [49, 1000] acc: 0.8067500591278076
# [50, 1000] loss: 0.5634424118050374
# 设备号为: tensor([14, 45, 14, 42], device='cuda:3')，预测的设备号为:tensor([14, 45, 14, 48], device='cuda:3')
# [50, 1000] acc: 0.7955000400543213
# [51, 1000] loss: 0.5235534462405486
# 设备号为: tensor([14, 11, 37, 20], device='cuda:3')，预测的设备号为:tensor([14, 11, 37, 20], device='cuda:3')
# [51, 1000] acc: 0.8140000104904175
# [52, 1000] loss: 0.5530008050097386
# 设备号为: tensor([28, 38, 52, 28], device='cuda:3')，预测的设备号为:tensor([ 7, 38, 52, 28], device='cuda:3')
# [52, 1000] acc: 0.7942500114440918
# [53, 1000] loss: 0.4980724116892088
# 设备号为: tensor([26, 53,  2,  0], device='cuda:3')，预测的设备号为:tensor([26, 53,  2,  6], device='cuda:3')
# [53, 1000] acc: 0.8197500109672546
# [54, 1000] loss: 0.4919223939618096
# 设备号为: tensor([48,  0, 11, 36], device='cuda:3')，预测的设备号为:tensor([48,  6, 11, 36], device='cuda:3')
# [54, 1000] acc: 0.8205000162124634
# [55, 1000] loss: 0.46302655794098974
# 设备号为: tensor([47, 33, 48, 23], device='cuda:3')，预测的设备号为:tensor([47, 33, 48, 23], device='cuda:3')
# [55, 1000] acc: 0.8297500610351562
# [56, 1000] loss: 0.45232502261374613
# 设备号为: tensor([39, 28, 29, 39], device='cuda:3')，预测的设备号为:tensor([39, 28, 29, 39], device='cuda:3')
# [56, 1000] acc: 0.8382500410079956
# [57, 1000] loss: 0.4165621959249256
# 设备号为: tensor([51, 16, 12, 51], device='cuda:3')，预测的设备号为:tensor([51, 14, 12, 51], device='cuda:3')
# [57, 1000] acc: 0.8470000624656677
# [58, 1000] loss: 0.45666899424488655
# 设备号为: tensor([45, 19, 50, 14], device='cuda:3')，预测的设备号为:tensor([45, 16, 50, 14], device='cuda:3')
# [58, 1000] acc: 0.8370000123977661
# [59, 1000] loss: 0.4272508858455694
# 设备号为: tensor([28,  3, 47, 24], device='cuda:3')，预测的设备号为:tensor([28,  3, 47, 24], device='cuda:3')
# [59, 1000] acc: 0.8497500419616699
# [60, 1000] loss: 0.40904437727457843
# 设备号为: tensor([43, 11,  1, 30], device='cuda:3')，预测的设备号为:tensor([43, 11,  1, 30], device='cuda:3')
# [60, 1000] acc: 0.8535000681877136
# [61, 1000] loss: 0.3957726129476214
# 设备号为: tensor([40, 27,  9, 38], device='cuda:3')，预测的设备号为:tensor([41, 27,  9,  8], device='cuda:3')
# [61, 1000] acc: 0.8565000295639038
# [62, 1000] loss: 0.3792562696574023
# 设备号为: tensor([29, 33,  9, 24], device='cuda:3')，预测的设备号为:tensor([29, 33,  9, 24], device='cuda:3')
# [62, 1000] acc: 0.8637500405311584
# [63, 1000] loss: 0.38571091296430676
# 设备号为: tensor([23, 34, 11, 13], device='cuda:3')，预测的设备号为:tensor([12, 34, 11, 13], device='cuda:3')
# [63, 1000] acc: 0.8602500557899475
# [64, 1000] loss: 0.3920188094678451
# 设备号为: tensor([18, 35, 13, 39], device='cuda:3')，预测的设备号为:tensor([18, 35, 13, 39], device='cuda:3')
# [64, 1000] acc: 0.85875004529953
# [65, 1000] loss: 0.34400509468640666
# 设备号为: tensor([45,  1, 31, 24], device='cuda:3')，预测的设备号为:tensor([45,  1, 25, 24], device='cuda:3')
# [65, 1000] acc: 0.8770000338554382
# [66, 1000] loss: 0.3450968737775111
# 设备号为: tensor([22,  0, 38, 30], device='cuda:3')，预测的设备号为:tensor([22,  0, 38, 30], device='cuda:3')
# [66, 1000] acc: 0.8797500133514404
# [67, 1000] loss: 0.37258165038668084
# 设备号为: tensor([33, 18, 13, 24], device='cuda:3')，预测的设备号为:tensor([33, 18, 13, 24], device='cuda:3')
# [67, 1000] acc: 0.8722500205039978
# [68, 1000] loss: 0.33440040402271554
# 设备号为: tensor([13, 44, 34, 14], device='cuda:3')，预测的设备号为:tensor([13, 44, 39, 23], device='cuda:3')
# [68, 1000] acc: 0.8805000185966492
# [69, 1000] loss: 0.3427228397204017
# 设备号为: tensor([50, 12, 10, 41], device='cuda:3')，预测的设备号为:tensor([50, 12,  9, 41], device='cuda:3')
# [69, 1000] acc: 0.8750000596046448
# [70, 1000] loss: 0.3071241342909052
# 设备号为: tensor([18, 51, 13, 16], device='cuda:3')，预测的设备号为:tensor([18, 51, 13, 16], device='cuda:3')
# [70, 1000] acc: 0.8895000219345093
# [71, 1000] loss: 0.30780352147834494
# 设备号为: tensor([ 8,  0, 32, 14], device='cuda:3')，预测的设备号为:tensor([ 8,  6, 32, 14], device='cuda:3')
# [71, 1000] acc: 0.8885000348091125
# [72, 1000] loss: 0.30653901759147995
# 设备号为: tensor([30, 19, 40, 38], device='cuda:3')，预测的设备号为:tensor([30, 19, 50, 38], device='cuda:3')
# [72, 1000] acc: 0.8905000686645508
# [73, 1000] loss: 0.2985347605270217
# 设备号为: tensor([41,  8, 35, 16], device='cuda:3')，预测的设备号为:tensor([41,  8, 35, 14], device='cuda:3')
# [73, 1000] acc: 0.8965000510215759
# [74, 1000] loss: 0.3000652161681055
# 设备号为: tensor([18, 27,  0, 25], device='cuda:3')，预测的设备号为:tensor([18, 27,  0, 25], device='cuda:3')
# [74, 1000] acc: 0.8860000371932983
# [75, 1000] loss: 0.2793795670916734
# 设备号为: tensor([48, 32, 53, 50], device='cuda:3')，预测的设备号为:tensor([48, 32, 53, 50], device='cuda:3')
# [75, 1000] acc: 0.8987500667572021
# [76, 1000] loss: 0.29913772038672504
# 设备号为: tensor([11, 40, 36, 18], device='cuda:3')，预测的设备号为:tensor([11, 40, 36, 18], device='cuda:3')
# [76, 1000] acc: 0.8895000219345093
# [77, 1000] loss: 0.2744459942085814
# 设备号为: tensor([ 3, 45, 45, 48], device='cuda:3')，预测的设备号为:tensor([ 3, 45, 45, 48], device='cuda:3')
# [77, 1000] acc: 0.8990000486373901
# [78, 1000] loss: 0.27600720686549174
# 设备号为: tensor([28, 35, 31, 34], device='cuda:3')，预测的设备号为:tensor([28, 35, 31, 34], device='cuda:3')
# [78, 1000] acc: 0.9035000205039978
# [79, 1000] loss: 0.26846653993549446
# 设备号为: tensor([17,  3, 52,  4], device='cuda:3')，预测的设备号为:tensor([17,  3, 52,  4], device='cuda:3')
# [79, 1000] acc: 0.8947500586509705
# [80, 1000] loss: 0.25343725611639095
# 设备号为: tensor([38, 33, 41, 18], device='cuda:3')，预测的设备号为:tensor([38, 33, 41, 18], device='cuda:3')
# [80, 1000] acc: 0.9105000495910645
# [81, 1000] loss: 0.2571225070467044
# 设备号为: tensor([42, 46, 36, 13], device='cuda:3')，预测的设备号为:tensor([42, 46, 36, 13], device='cuda:3')
# [81, 1000] acc: 0.9072500467300415
# [82, 1000] loss: 0.2304693981979108
# 设备号为: tensor([34, 44, 39,  9], device='cuda:3')，预测的设备号为:tensor([34, 15, 34,  9], device='cuda:3')
# [82, 1000] acc: 0.9220000505447388
# [83, 1000] loss: 0.26456603356043523
# 设备号为: tensor([21, 23,  1, 47], device='cuda:3')，预测的设备号为:tensor([21, 23,  1, 19], device='cuda:3')
# [83, 1000] acc: 0.9050000309944153
# [84, 1000] loss: 0.2559208579903643
# 设备号为: tensor([23, 17, 46, 31], device='cuda:3')，预测的设备号为:tensor([23, 17, 46, 31], device='cuda:3')
# [84, 1000] acc: 0.9037500619888306
# [85, 1000] loss: 0.228403536242884
# 设备号为: tensor([30,  5, 46, 16], device='cuda:3')，预测的设备号为:tensor([30,  5, 46, 18], device='cuda:3')
# [85, 1000] acc: 0.9207500219345093
# [86, 1000] loss: 0.23689023211489801
# 设备号为: tensor([ 4, 35,  6, 22], device='cuda:3')，预测的设备号为:tensor([ 4, 35,  6, 22], device='cuda:3')
# [86, 1000] acc: 0.9177500605583191
# [87, 1000] loss: 0.211237215843772
# 设备号为: tensor([52,  3, 18, 19], device='cuda:3')，预测的设备号为:tensor([45,  3, 18, 14], device='cuda:3')
# [87, 1000] acc: 0.92125004529953
# [88, 1000] loss: 0.20573785387161478
# 设备号为: tensor([21, 39, 51, 19], device='cuda:3')，预测的设备号为:tensor([21, 39, 51, 19], device='cuda:3')
# [88, 1000] acc: 0.924500048160553
# [89, 1000] loss: 0.21120445242546704
# 设备号为: tensor([ 1, 23,  8, 29], device='cuda:3')，预测的设备号为:tensor([ 1, 23,  8, 29], device='cuda:3')
# [89, 1000] acc: 0.9270000457763672
# [90, 1000] loss: 0.2053472525146717
# 设备号为: tensor([47, 26, 22, 29], device='cuda:3')，预测的设备号为:tensor([47, 26, 22, 29], device='cuda:3')
# [90, 1000] acc: 0.924250066280365
# [91, 1000] loss: 0.22165934170974289
# 设备号为: tensor([18, 40, 48, 12], device='cuda:3')，预测的设备号为:tensor([19, 40, 48, 23], device='cuda:3')
# [91, 1000] acc: 0.9177500605583191
# [92, 1000] loss: 0.21168088984650513
# 设备号为: tensor([51, 40,  1, 25], device='cuda:3')，预测的设备号为:tensor([51, 40,  1, 25], device='cuda:3')
# [92, 1000] acc: 0.9252500534057617
# [93, 1000] loss: 0.20574394105372584
# 设备号为: tensor([26, 20, 53, 28], device='cuda:3')，预测的设备号为:tensor([26, 20, 53, 28], device='cuda:3')
# [93, 1000] acc: 0.9292500615119934
# [94, 1000] loss: 0.19470313871956751
# 设备号为: tensor([ 3, 49,  9, 37], device='cuda:3')，预测的设备号为:tensor([ 3, 49,  9, 37], device='cuda:3')
# [94, 1000] acc: 0.9312500357627869
# [95, 1000] loss: 0.18140936916197825
# 设备号为: tensor([30, 33, 48, 16], device='cuda:3')，预测的设备号为:tensor([30, 33, 48, 16], device='cuda:3')
# [95, 1000] acc: 0.9325000643730164
# [96, 1000] loss: 0.18145119763192907
# 设备号为: tensor([49,  4, 30, 15], device='cuda:3')，预测的设备号为:tensor([49,  4, 30, 15], device='cuda:3')
# [96, 1000] acc: 0.9345000386238098
# [97, 1000] loss: 0.1921794094354209
# 设备号为: tensor([18, 45,  7, 50], device='cuda:3')，预测的设备号为:tensor([20, 45,  7, 50], device='cuda:3')
# [97, 1000] acc: 0.9295000433921814
# [98, 1000] loss: 0.20025002316391327
# 设备号为: tensor([13, 40, 50,  4], device='cuda:3')，预测的设备号为:tensor([13, 40, 50,  4], device='cuda:3')
# [98, 1000] acc: 0.9297500252723694
# [99, 1000] loss: 0.17450467142038542
# 设备号为: tensor([ 2, 16, 22, 44], device='cuda:3')，预测的设备号为:tensor([ 2, 16, 22, 44], device='cuda:3')
# [99, 1000] acc: 0.9362500309944153
# [100, 1000] loss: 0.18710400497219234
# 设备号为: tensor([43, 11, 26, 34], device='cuda:3')，预测的设备号为:tensor([43, 11, 31, 34], device='cuda:3')
# [100, 1000] acc: 0.9322500228881836
# [101, 1000] loss: 0.14879874035562535
# 设备号为: tensor([15, 29,  2, 37], device='cuda:3')，预测的设备号为:tensor([15, 29,  2, 37], device='cuda:3')
# [101, 1000] acc: 0.9457500576972961
# [102, 1000] loss: 0.16000293352238804
# 设备号为: tensor([25, 44, 44,  9], device='cuda:3')，预测的设备号为:tensor([25, 44, 44,  9], device='cuda:3')
# [102, 1000] acc: 0.9430000185966492
# [103, 1000] loss: 0.1762228288203005
# 设备号为: tensor([20, 47, 41, 21], device='cuda:3')，预测的设备号为:tensor([20, 47, 41, 21], device='cuda:3')
# [103, 1000] acc: 0.9355000257492065
# [104, 1000] loss: 0.16945707502229926
# 设备号为: tensor([29, 25, 40, 50], device='cuda:3')，预测的设备号为:tensor([29,  9, 40, 50], device='cuda:3')
# [104, 1000] acc: 0.9412500262260437
# [105, 1000] loss: 0.14827170787201613
# 设备号为: tensor([52,  2, 25, 36], device='cuda:3')，预测的设备号为:tensor([52,  2, 25, 36], device='cuda:3')
# [105, 1000] acc: 0.9485000371932983
# [106, 1000] loss: 0.15380400284652934
# 设备号为: tensor([32, 50, 35, 20], device='cuda:3')，预测的设备号为:tensor([32, 50, 35, 20], device='cuda:3')
# [106, 1000] acc: 0.9447500705718994
# [107, 1000] loss: 0.14445106971018687
# 设备号为: tensor([49, 48,  7, 12], device='cuda:3')，预测的设备号为:tensor([49, 48,  7, 12], device='cuda:3')
# [107, 1000] acc: 0.9470000267028809
# [108, 1000] loss: 0.1731387957824345
# 设备号为: tensor([50, 30,  6, 43], device='cuda:3')，预测的设备号为:tensor([50, 30,  6, 43], device='cuda:3')
# [108, 1000] acc: 0.937250018119812
# [109, 1000] loss: 0.1540606177341342
# 设备号为: tensor([46, 50, 43, 32], device='cuda:3')，预测的设备号为:tensor([46, 50, 43, 32], device='cuda:3')
# [109, 1000] acc: 0.9425000548362732
# [110, 1000] loss: 0.14065897159966517
# 设备号为: tensor([44, 36, 25, 18], device='cuda:3')，预测的设备号为:tensor([53, 36, 25, 18], device='cuda:3')
# [110, 1000] acc: 0.9482500553131104
# [111, 1000] loss: 0.11917910186939662
# 设备号为: tensor([24, 21, 27,  0], device='cuda:3')，预测的设备号为:tensor([24, 41, 27,  0], device='cuda:3')
# [111, 1000] acc: 0.9580000638961792
# [112, 1000] loss: 0.14432852534710036
# 设备号为: tensor([48, 16, 31, 34], device='cuda:3')，预测的设备号为:tensor([48, 16, 31, 34], device='cuda:3')
# [112, 1000] acc: 0.9470000267028809
# [113, 1000] loss: 0.141142217685132
# 设备号为: tensor([15,  3, 44, 38], device='cuda:3')，预测的设备号为:tensor([15,  3, 52, 38], device='cuda:3')
# [113, 1000] acc: 0.9507500529289246
# [114, 1000] loss: 0.14845504722621
# 设备号为: tensor([20, 33, 15,  2], device='cuda:3')，预测的设备号为:tensor([20, 33, 15,  2], device='cuda:3')
# [114, 1000] acc: 0.9487500190734863
# [115, 1000] loss: 0.1281948771668849
# 设备号为: tensor([41, 12, 11,  4], device='cuda:3')，预测的设备号为:tensor([51, 12, 11,  4], device='cuda:3')
# [115, 1000] acc: 0.9502500295639038
# [116, 1000] loss: 0.12714672785110726
# 设备号为: tensor([20,  4, 31, 32], device='cuda:3')，预测的设备号为:tensor([20,  4, 31, 32], device='cuda:3')
# [116, 1000] acc: 0.9547500610351562
# [117, 1000] loss: 0.14263745865661348
# 设备号为: tensor([32, 47, 33, 39], device='cuda:3')，预测的设备号为:tensor([32, 47, 33, 39], device='cuda:3')
# [117, 1000] acc: 0.9490000605583191
# [118, 1000] loss: 0.13449852898597078
# 设备号为: tensor([47, 33, 32, 10], device='cuda:3')，预测的设备号为:tensor([47, 33, 25, 10], device='cuda:3')
# [118, 1000] acc: 0.9497500658035278
# [119, 1000] loss: 0.1202705296676013
# 设备号为: tensor([50,  5, 25, 40], device='cuda:3')，预测的设备号为:tensor([50,  5, 25, 40], device='cuda:3')
# [119, 1000] acc: 0.9582500457763672
# [120, 1000] loss: 0.11592844203397544
# 设备号为: tensor([47, 24, 17, 20], device='cuda:3')，预测的设备号为:tensor([47, 24, 17, 21], device='cuda:3')
# [120, 1000] acc: 0.9577500224113464
# [121, 1000] loss: 0.12672699713144903
# 设备号为: tensor([11, 50, 13, 17], device='cuda:3')，预测的设备号为:tensor([11, 50, 13, 17], device='cuda:3')
# [121, 1000] acc: 0.955500066280365
# [122, 1000] loss: 0.13990353662448707
# 设备号为: tensor([15, 12,  0, 11], device='cuda:3')，预测的设备号为:tensor([15, 12,  0, 11], device='cuda:3')
# [122, 1000] acc: 0.9462500214576721
# [123, 1000] loss: 0.12275241811652177
# 设备号为: tensor([36, 17, 25, 30], device='cuda:3')，预测的设备号为:tensor([36, 17, 25, 30], device='cuda:3')
# [123, 1000] acc: 0.9572500586509705
# [124, 1000] loss: 0.14463358559093104
# 设备号为: tensor([20,  8,  2, 12], device='cuda:3')，预测的设备号为:tensor([20,  8,  2, 12], device='cuda:3')
# [124, 1000] acc: 0.9467500448226929
# [125, 1000] loss: 0.12901097094121952
# 设备号为: tensor([46, 45, 29, 26], device='cuda:3')，预测的设备号为:tensor([46, 45, 29, 26], device='cuda:3')
# [125, 1000] acc: 0.9567500352859497
# [126, 1000] loss: 0.10998474490028662
# 设备号为: tensor([14, 36, 22, 24], device='cuda:3')，预测的设备号为:tensor([14, 36, 22, 24], device='cuda:3')
# [126, 1000] acc: 0.9577500224113464
# [127, 1000] loss: 0.10942222695370174
# 设备号为: tensor([34, 23, 49, 43], device='cuda:3')，预测的设备号为:tensor([34, 23, 49, 43], device='cuda:3')
# [127, 1000] acc: 0.9632500410079956
# [128, 1000] loss: 0.09918934974759032
# 设备号为: tensor([31, 48, 31, 31], device='cuda:3')，预测的设备号为:tensor([31, 48, 31, 31], device='cuda:3')
# [128, 1000] acc: 0.967750072479248
# [129, 1000] loss: 0.11833113659855167
# 设备号为: tensor([29, 17, 53, 22], device='cuda:3')，预测的设备号为:tensor([29, 17, 53, 22], device='cuda:3')
# [129, 1000] acc: 0.9595000743865967
# [130, 1000] loss: 0.10048990532958714
# 设备号为: tensor([49, 11, 34, 48], device='cuda:3')，预测的设备号为:tensor([49, 11, 34, 48], device='cuda:3')
# [130, 1000] acc: 0.9635000228881836

# %%
torch.cuda.current_device ()

# %%
aa = iter(train_loader)
a, b = aa.next()
print(a[0].shape)
print(a)

# %%
input = torch.randn(20, 16, 50, 100)
input.shape

# %%
m2=nn.Conv2d(16,33,(3,5),stride=(2,1),padding=(4,2))
inpu1=Variable(torch.randn(20,16,50,100))
print(inpu1.shape)
output=m2(inpu1)
print(output.shape)

# %%
total

# %%
torch.cuda.current_device ()

# %%
x = range(0, len(average_loss_series))
plt.figure()
plt.plot(x, average_loss_series)
plt.savefig("Loss30.png", bbox_inches="tight")
plt.show()
